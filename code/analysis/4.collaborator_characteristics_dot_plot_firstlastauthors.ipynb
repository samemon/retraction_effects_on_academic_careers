# %% [markdown]
# # Plotting Collaborator Characteristics by Seniority

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.patches import Rectangle
    
from config_reader import read_config

# %%
INDIR = "/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/plot_data/"

# Reading paths
paths = read_config()
# Path to where we will save our processed files
OUTDIR = paths['PLOTS_FOLDER_LOCAL']

# %%
data = {
    'Junior': {'retracted': [20, 30, 40], 'non-retracted': [30, 40, 50]},
    'Senior': {'retracted': [20, 30, 40], 'non-retracted': [30, 40, 50]}
}

df = pd.DataFrame(data)
df
# Out:
#                      Junior        Senior
# retracted      [20, 30, 40]  [20, 30, 40]
# non-retracted  [30, 40, 50]  [30, 40, 50]

# %%
def create_collaborator_char_plot(categories, retracted_data, non_retracted_data, p_data, color_dict, marker_dict, 
                                  xticks, foutname, create_legend=False, 
                                 letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']):
    # Generate some random data for demonstration

    #retracted_data = np.random.rand(3,3)  # Three categories with three pairs of data points each
    #non_retracted_data = np.random.rand(3, 3)

    # Set the significance threshold for connecting lines
    significance_threshold = 0.05

    # Create the figure with subplots
    fig, axs = plt.subplots(3, 3, figsize=(8, 5.5), sharey='row')
    fig.subplots_adjust(hspace=0.5)

    counter = 0
    
    colors = [color_dict.get(categories[0]),
             color_dict.get(categories[1]),
             color_dict.get(categories[2]),]
    
    # Iterate over each subplot
    for i, ax in enumerate(axs.flat):
        category_index = i % 3  # Determine the category (0, 1, or 2)
        retracted_values = retracted_data[counter]
        non_retracted_values = non_retracted_data[counter]
        pval_values = p_data[counter]
    
        # Connect the dots with solid or dotted lines based on significance
        for j in range(len(retracted_values)):
            line_style = '-' if pval_values[j] < significance_threshold else ':'
            ax.plot([retracted_values[j], non_retracted_values[j]], [j + 1, j + 1], 'k', linestyle=line_style)
            
        # This is the code to go with.
        for x, y, color in zip(retracted_values, [1,2,3], colors):
            ax.plot(x, y, color=color, label='Retracted', marker='o')

        for x, y, color in zip(non_retracted_values, [1,2,3], colors):
            ax.plot(x, y, color=color, label='Non-retracted', marker='s')


        
        ax.set_xticks(xticks[counter])
        ax.set_xticklabels(xticks[counter])
        
        ax.set_yticks([1, 2, 3])
        ax.set_yticklabels(categories)
        ax.set_ylim(-0.5, 4)
        ax.spines[['right', 'top']].set_visible(False)
        
        ax.invert_yaxis()
        
        ax.annotate(letters[i], xy=(0.05, 0.9), xycoords='axes fraction', fontsize=14, fontweight='bold')
        
        counter += 1
        
        # Labeling the x and y axis
        if(counter == 1):
            ax.set_ylabel('Collaborators\nRetained', labelpad=25, fontsize=12)
            ax.set_xlabel("Academic Age", labelpad=25, fontsize=12)
            ax.xaxis.set_label_position("top")
        
        elif(counter == 2):
            ax.set_xlabel("Number of Papers", labelpad=25, fontsize=12)
            ax.xaxis.set_label_position("top")
            
        elif(counter == 3):
            ax.set_xlabel("Number of Citations", labelpad=25, fontsize=12)
            ax.xaxis.set_label_position("top")
        
        elif(counter == 4):
            ax.set_ylabel('Collaborators\nGained', labelpad=25, fontsize=12)
            
        elif(counter == 7):
            ax.set_ylabel('Difference-in-\nDifference', labelpad=25, fontsize=12)

    #     ax.legend(False)

    # Set the overall title for the figure
    #fig.suptitle('Comparison of Retracted and Non-retracted Scientists', fontsize=16)
    
    if(create_legend):
        # Create a custom legend
        # Let us add items to the legend 
        legend_elements = []
        for key in color_dict.keys():
            colori = color_dict.get(key)
            markeri = marker_dict.get(key)

#             elementi = plt.Line2D([0], [0], marker=markeri, color='w', markerfacecolor=colori, 
#                                   markersize=8, label=key)
    
            elementi = None
        
            if key == "Retracted":
            # Create an empty circle as a marker
                elementi = plt.Line2D([0], [0], marker='o', color=colori, markerfacecolor='none', 
                                      markersize=8, label=key, linestyle='', fillstyle='none')
            elif key == "Non-retracted":
            # Create an empty square as a marker
                elementi = plt.Line2D([0], [0], marker='s', color=colori, markerfacecolor='none', 
                                  markersize=8, label=key, linestyle='', fillstyle='none')
            else:
                elementi = plt.Line2D([0], [0], color=colori, linewidth=5, label=key)

            legend_elements.append(elementi)

        #fig.legend(handles=legend_elements, loc='lower right')
        legend = fig.legend(handles=legend_elements, loc='upper center', ncol=len(legend_elements), prop={'size': 11},
                  frameon=False)
        legend.set_bbox_to_anchor((0.5, 0.98))
    
    rect = Rectangle((0, 0), 1, 0.90, transform=fig.transFigure, fill=False, edgecolor='black')

    fig.patches.append(rect)

    # Adjust the layout to accommodate the legend
    plt.tight_layout(rect=[0, 0, 1, 0.90])
    #plt.tight_layout()
    
    plt.savefig(foutname, format='pdf')
    # Show the plot
    plt.show()

# %% [markdown]
# # Plotting Collaborator Characteristics by Reason

# %%
def read_dict(fname):
    import pickle
    
    with open(fname, 'rb') as f:
        loaded_dict = pickle.load(f)
        return loaded_dict

    
dict_forAge = read_dict(INDIR+"/collaborator_chars_byAge_firstlastauthors.pkl")
dict_forReason = read_dict(INDIR+"/collaborator_chars_byReason_firstlastauthors.pkl")

# Let us now create retracted means, and retracted pvals, and non-retracted means, and non-retracted pvals
# We will do so for both stratified by age, and stratified by reason


def create_lists_for_plots(dicto, categories=['Junior','Mid','Senior'], 
                                    scientistType='retracted',
                                    statistic="mean"):
    expFields = ['Academic Age', 'Number of Papers', 'Number of Citations']
    expFields2 = ['AcademicAge', 'MAGCumPapers', 'MAGCumCitations']
    outcomeTypes = ['Retention', 'Gain', 'DiD']
    lstOflst = []
    
    for outcomeType in outcomeTypes:
        for i in range(len(expFields)):
            field1 = expFields[i]
            field2 = expFields2[i]
            lst_i = []
            # going through senior junior and mid-career
            for category in categories:
                statistic_key = ''
                if outcomeType in ['Retention', 'Gain']:
                    statistic_key = 'Collab' + field2 + "AtCollaboration_" + scientistType + "_" + statistic

                elif outcomeType in ['DiD']:
                    statistic_key = 'Diff' + field2 + "AtRetraction_" + scientistType + "_" + statistic

                val = dicto.get(outcomeType).get(field1).get(category).get(statistic_key)
                
                print(field1, field2, outcomeType, scientistType, category, val)
                
                lst_i.append(val)
            lstOflst.append(lst_i)

    return lstOflst

# %%
def create_pval_lists_for_plots(dicto, categories=['Junior','Mid','Senior'], 
                                    statistic="pval_welch"):
    
    expFields = ['Academic Age', 'Number of Papers', 'Number of Citations']
    expFields2 = ['AcademicAge', 'MAGCumPapers', 'MAGCumCitations']
    outcomeTypes = ['Retention', 'Gain', 'DiD']
    lstOflst = []
    
    for outcomeType in outcomeTypes:
        for i in range(len(expFields)):
            field1 = expFields[i]
            field2 = expFields2[i]
            lst_i = []
            # going through senior junior and mid-career
            for category in categories:
                statistic_key = ''
                if outcomeType in ['Retention', 'Gain']:
                    statistic_key = 'Collab' + field2 + "AtCollaboration_"  + statistic

                elif outcomeType in ['DiD']:
                    statistic_key = 'Diff' + field2 + "AtRetraction_" + statistic

                val = dicto.get(outcomeType).get(field1).get(category).get(statistic_key)
                
                print(field1, field2, outcomeType, category, val)
                
                lst_i.append(val)
            lstOflst.append(lst_i)

    return lstOflst

# %%
retracted_means_age = create_lists_for_plots(dict_forAge, categories=['Junior','Mid','Senior'], 
                                    scientistType='retracted',
                                    statistic="mean")

nonretracted_means_age = create_lists_for_plots(dict_forAge, categories=['Junior','Mid','Senior'], 
                                    scientistType='nonretracted',
                                    statistic="mean")
# Out:
# Academic Age AcademicAge Retention retracted Junior 12.61
# Academic Age AcademicAge Retention retracted Mid 14.63
# Academic Age AcademicAge Retention retracted Senior 14.7
# Number of Papers MAGCumPapers Retention retracted Junior 68.22
# Number of Papers MAGCumPapers Retention retracted Mid 76.44
# Number of Papers MAGCumPapers Retention retracted Senior 61.64
# Number of Citations MAGCumCitations Retention retracted Junior 1375.15
# Number of Citations MAGCumCitations Retention retracted Mid 1451.05
# Number of Citations MAGCumCitations Retention retracted Senior 1600.02
# Academic Age AcademicAge Gain retracted Junior 7.07
# Academic Age AcademicAge Gain retracted Mid 8.15
# Academic Age AcademicAge Gain retracted Senior 8.26
# Number of Papers MAGCumPapers Gain retracted Junior 34.08
# Number of Papers MAGCumPapers Gain retracted Mid 40.45
# Number of Papers MAGCumPapers Gain retracted Senior 35.27
# Number of Citations MAGCumCitations Gain retracted Junior 826.74
# Number of Citations MAGCumCitations Gain retracted Mid 779.37
# Number of Citations MAGCumCitations Gain retracted Senior 759.34
# Academic Age AcademicAge DiD retracted Junior 3.05
# Academic Age AcademicAge DiD retracted Mid 3.19
# Academic Age AcademicAge DiD retracted Senior -0.73
# Number of Papers MAGCumPapers DiD retracted Junior 26.23
# Number of Papers MAGCumPapers DiD retracted Mid 22.86
# Number of Papers MAGCumPapers DiD retracted Senior 13.25
# Number of Citations MAGCumCitations DiD retracted Junior 439.08
# Number of Citations MAGCumCitations DiD retracted Mid 33.32
# Number of Citations MAGCumCitations DiD retracted Senior 238.65
# Academic Age AcademicAge Retention nonretracted Junior 14.48
# Academic Age AcademicAge Retention nonretracted Mid 15.86
# Academic Age AcademicAge Retention nonretracted Senior 16.44
# Number of Papers MAGCumPapers Retention nonretracted Junior 80.12
# Number of Papers MAGCumPapers Retention nonretracted Mid 78.95
# Number of Papers MAGCumPapers Retention nonretracted Senior 65.82
# Number of Citations MAGCumCitations Retention nonretracted Junior 1356.35
# Number of Citations MAGCumCitations Retention nonretracted Mid 1530.51
# Number of Citations MAGCumCitations Retention nonretracted Senior 1242.4
# Academic Age AcademicAge Gain nonretracted Junior 7.73
# Academic Age AcademicAge Gain nonretracted Mid 7.81
# Academic Age AcademicAge Gain nonretracted Senior 8.47
# Number of Papers MAGCumPapers Gain nonretracted Junior 36.42
# Number of Papers MAGCumPapers Gain nonretracted Mid 32.42
# Number of Papers MAGCumPapers Gain nonretracted Senior 34.86
# Number of Citations MAGCumCitations Gain nonretracted Junior 855.75
# Number of Citations MAGCumCitations Gain nonretracted Mid 585.2
# Number of Citations MAGCumCitations Gain nonretracted Senior 712.43
# Academic Age AcademicAge DiD nonretracted Junior 3.89
# Academic Age AcademicAge DiD nonretracted Mid 4.08
# Academic Age AcademicAge DiD nonretracted Senior 0.54
# Number of Papers MAGCumPapers DiD nonretracted Junior 28.85
# Number of Papers MAGCumPapers DiD nonretracted Mid 29.0
# Number of Papers MAGCumPapers DiD nonretracted Senior 19.17
# Number of Citations MAGCumCitations DiD nonretracted Junior 332.56
# Number of Citations MAGCumCitations DiD nonretracted Mid 423.13
# Number of Citations MAGCumCitations DiD nonretracted Senior 247.34

# %%
retracted_pvals_age = create_pval_lists_for_plots(dict_forAge, categories=['Junior','Mid','Senior'],
                                    statistic="pval_welch")
# Out:
# Academic Age AcademicAge Retention Junior 0.026
# Academic Age AcademicAge Retention Mid 0.232
# Academic Age AcademicAge Retention Senior 0.038
# Number of Papers MAGCumPapers Retention Junior 0.298
# Number of Papers MAGCumPapers Retention Mid 0.819
# Number of Papers MAGCumPapers Retention Senior 0.582
# Number of Citations MAGCumCitations Retention Junior 0.943
# Number of Citations MAGCumCitations Retention Mid 0.822
# Number of Citations MAGCumCitations Retention Senior 0.517
# Academic Age AcademicAge Gain Junior 0.355
# Academic Age AcademicAge Gain Mid 0.63
# Academic Age AcademicAge Gain Senior 0.712
# Number of Papers MAGCumPapers Gain Junior 0.583
# Number of Papers MAGCumPapers Gain Mid 0.066
# Number of Papers MAGCumPapers Gain Senior 0.902
# Number of Citations MAGCumCitations Gain Junior 0.878
# Number of Citations MAGCumCitations Gain Mid 0.123
# Number of Citations MAGCumCitations Gain Senior 0.72
# Academic Age AcademicAge DiD Junior 0.397
# Academic Age AcademicAge DiD Mid 0.362
# Academic Age AcademicAge DiD Senior 0.087
# Number of Papers MAGCumPapers DiD Junior 0.798
# Number of Papers MAGCumPapers DiD Mid 0.491
# Number of Papers MAGCumPapers DiD Senior 0.305
# Number of Citations MAGCumCitations DiD Junior 0.612
# Number of Citations MAGCumCitations DiD Mid 0.122
# Number of Citations MAGCumCitations DiD Senior 0.977

# %%
expFields = ['Academic Age', 'Number of Papers', 'Number of Citations']
outcomeTypes = ['Retention', 'Gain', 'DiD']
categories = ['Early-Career', 'Mid-Career', 'Senior']


combos = []

for e in expFields:
    for o in outcomeTypes:
        for c in categories:
            combos.append(e+","+o+","+c)


counter = 0
            
for i in range(len(retracted_pvals_age)):
    for j in range(len(retracted_pvals_age[i])):
        
        combo_i = combos[counter]
        counter += 1
        
        retracted_mean = retracted_means_age[i][j]
        nonretracted_mean = nonretracted_means_age[i][j]
        
        retracted_pval = retracted_pvals_age[i][j]
        
        printString = ""
        
        if(retracted_pval < 0.05):
            if(retracted_mean < nonretracted_mean):
                printString = combo_i + "," + str(retracted_mean) + "," + str(nonretracted_mean) + "***," + str(retracted_pval)
            else:
                printString = combo_i + "," + str(retracted_mean) + "***," + str(nonretracted_mean) + "," + str(retracted_pval)
            
        else:
            printString = combo_i + "," + str(retracted_mean) + "," + str(nonretracted_mean) + "," + str(retracted_pval)
        
        print(printString)
# Out:
# Academic Age,Retention,Early-Career,12.61,14.48***,0.026
# Academic Age,Retention,Mid-Career,14.63,15.86,0.232
# Academic Age,Retention,Senior,14.7,16.44***,0.038
# Academic Age,Gain,Early-Career,68.22,80.12,0.298
# Academic Age,Gain,Mid-Career,76.44,78.95,0.819
# Academic Age,Gain,Senior,61.64,65.82,0.582
# Academic Age,DiD,Early-Career,1375.15,1356.35,0.943
# Academic Age,DiD,Mid-Career,1451.05,1530.51,0.822
# Academic Age,DiD,Senior,1600.02,1242.4,0.517
# Number of Papers,Retention,Early-Career,7.07,7.73,0.355
# Number of Papers,Retention,Mid-Career,8.15,7.81,0.63
# Number of Papers,Retention,Senior,8.26,8.47,0.712
# Number of Papers,Gain,Early-Career,34.08,36.42,0.583
# Number of Papers,Gain,Mid-Career,40.45,32.42,0.066
# Number of Papers,Gain,Senior,35.27,34.86,0.902
# Number of Papers,DiD,Early-Career,826.74,855.75,0.878
# Number of Papers,DiD,Mid-Career,779.37,585.2,0.123
# Number of Papers,DiD,Senior,759.34,712.43,0.72
# Number of Citations,Retention,Early-Career,3.05,3.89,0.397
# Number of Citations,Retention,Mid-Career,3.19,4.08,0.362
# Number of Citations,Retention,Senior,-0.73,0.54,0.087
# Number of Citations,Gain,Early-Career,26.23,28.85,0.798
# Number of Citations,Gain,Mid-Career,22.86,29.0,0.491
# Number of Citations,Gain,Senior,13.25,19.17,0.305
# Number of Citations,DiD,Early-Career,439.08,332.56,0.612
# Number of Citations,DiD,Mid-Career,33.32,423.13,0.122
# Number of Citations,DiD,Senior,238.65,247.34,0.977

# %%
categories = ['Early-Career', 'Mid-career', 'Senior']

color_dict = {'Early-Career':'#AFD8F2',
             'Mid-career':'#5289B5',
             'Senior': '#1F3541',
             'Retracted': 'black',
             'Non-retracted':'black'}

marker_dict = {'Retracted':'o',
             'Non-retracted':'s',
             'Early-Career': 'o',
             'Senior': 'o',
              'Mid-career':'o'}

xticks = [[11,13,15,17,19],
         [60,70,80,90],
         [1200,1600,2000,2400],
         [6,7,8,9,10],
         [30,35,40,45,50],
         [600,800,1000,1200,1400],
         [-1.5,0,1.5,3.0,4.5],
         [12,18,24,30,36],
         [0,150,300,450,600]]

create_collaborator_char_plot(categories, retracted_means_age, 
                              nonretracted_means_age, retracted_pvals_age, 
                              color_dict, marker_dict, xticks, 
                              foutname = OUTDIR+"/collaborator_quality_bySeniority_firstlastauthors_new.pdf",
                              create_legend=True)

# %%
retracted_means_age
# Out:
# [[12.61, 14.63, 14.7],
#  [68.22, 76.44, 61.64],
#  [1375.15, 1451.05, 1600.02],
#  [7.07, 8.15, 8.26],
#  [34.08, 40.45, 35.27],
#  [826.74, 779.37, 759.34],
#  [3.05, 3.19, -0.73],
#  [26.23, 22.86, 13.25],
#  [439.08, 33.32, 238.65]]

# %%
retracted_means_reason = create_lists_for_plots(dict_forReason, categories=['Misconduct','Plagiarism','Mistake'], 
                                    scientistType='retracted',
                                    statistic="mean")

nonretracted_means_reason = create_lists_for_plots(dict_forReason, categories=['Misconduct','Plagiarism','Mistake'], 
                                    scientistType='nonretracted',
                                    statistic="mean")

retracted_pvals_reason = create_pval_lists_for_plots(dict_forReason, categories=['Misconduct','Plagiarism','Mistake'],
                                    statistic="pval_welch")
# Out:
# Academic Age AcademicAge Retention retracted Misconduct 12.92
# Academic Age AcademicAge Retention retracted Plagiarism 12.61
# Academic Age AcademicAge Retention retracted Mistake 15.11
# Number of Papers MAGCumPapers Retention retracted Misconduct 69.8
# Number of Papers MAGCumPapers Retention retracted Plagiarism 63.89
# Number of Papers MAGCumPapers Retention retracted Mistake 69.93
# Number of Citations MAGCumCitations Retention retracted Misconduct 1498.48
# Number of Citations MAGCumCitations Retention retracted Plagiarism 1158.96
# Number of Citations MAGCumCitations Retention retracted Mistake 1487.99
# Academic Age AcademicAge Gain retracted Misconduct 7.22
# Academic Age AcademicAge Gain retracted Plagiarism 6.49
# Academic Age AcademicAge Gain retracted Mistake 8.89
# Number of Papers MAGCumPapers Gain retracted Misconduct 40.07
# Number of Papers MAGCumPapers Gain retracted Plagiarism 29.84
# Number of Papers MAGCumPapers Gain retracted Mistake 43.2
# Number of Citations MAGCumCitations Gain retracted Misconduct 1076.05
# Number of Citations MAGCumCitations Gain retracted Plagiarism 493.04
# Number of Citations MAGCumCitations Gain retracted Mistake 1044.05
# Academic Age AcademicAge DiD retracted Misconduct 0.85
# Academic Age AcademicAge DiD retracted Plagiarism 1.59
# Academic Age AcademicAge DiD retracted Mistake 2.59
# Number of Papers MAGCumPapers DiD retracted Misconduct 18.57
# Number of Papers MAGCumPapers DiD retracted Plagiarism 21.28
# Number of Papers MAGCumPapers DiD retracted Mistake 19.98
# Number of Citations MAGCumCitations DiD retracted Misconduct 267.93
# Number of Citations MAGCumCitations DiD retracted Plagiarism 264.13
# Number of Citations MAGCumCitations DiD retracted Mistake 81.25
# Academic Age AcademicAge Retention nonretracted Misconduct 14.68
# Academic Age AcademicAge Retention nonretracted Plagiarism 15.41
# Academic Age AcademicAge Retention nonretracted Mistake 15.88
# Number of Papers MAGCumPapers Retention nonretracted Misconduct 93.75
# Number of Papers MAGCumPapers Retention nonretracted Plagiarism 66.41
# Number of Papers MAGCumPapers Retention nonretracted Mistake 74.76
# Number of Citations MAGCumCitations Retention nonretracted Misconduct 1683.14
# Number of Citations MAGCumCitations Retention nonretracted Plagiarism 1009.08
# Number of Citations MAGCumCitations Retention nonretracted Mistake 1568.09
# Academic Age AcademicAge Gain nonretracted Misconduct 7.54
# Academic Age AcademicAge Gain nonretracted Plagiarism 7.73
# Academic Age AcademicAge Gain nonretracted Mistake 7.95
# Number of Papers MAGCumPapers Gain nonretracted Misconduct 35.18
# Number of Papers MAGCumPapers Gain nonretracted Plagiarism 31.83
# Number of Papers MAGCumPapers Gain nonretracted Mistake 37.48
# Number of Citations MAGCumCitations Gain nonretracted Misconduct 701.72
# Number of Citations MAGCumCitations Gain nonretracted Plagiarism 569.0
# Number of Citations MAGCumCitations Gain nonretracted Mistake 918.02
# Academic Age AcademicAge DiD nonretracted Misconduct 1.89
# Academic Age AcademicAge DiD nonretracted Plagiarism 3.07
# Academic Age AcademicAge DiD nonretracted Mistake 2.52
# Number of Papers MAGCumPapers DiD nonretracted Misconduct 37.57
# Number of Papers MAGCumPapers DiD nonretracted Plagiarism 23.67
# Number of Papers MAGCumPapers DiD nonretracted Mistake 23.29
# Number of Citations MAGCumCitations DiD nonretracted Misconduct 481.13
# Number of Citations MAGCumCitations DiD nonretracted Plagiarism 217.33
# Number of Citations MAGCumCitations DiD nonretracted Mistake 344.66
# Academic Age AcademicAge Retention Misconduct 0.154
# Academic Age AcademicAge Retention Plagiarism 0.003
# Academic Age AcademicAge Retention Mistake 0.401
# Number of Papers MAGCumPapers Retention Misconduct 0.343
# Number of Papers MAGCumPapers Retention Plagiarism 0.759
# Number of Papers MAGCumPapers Retention Mistake 0.572
# Number of Citations MAGCumCitations Retention Misconduct 0.689
# Number of Citations MAGCumCitations Retention Plagiarism 0.603
# Number of Citations MAGCumCitations Retention Mistake 0.773
# Academic Age AcademicAge Gain Misconduct 0.722
# Academic Age AcademicAge Gain Plagiarism 0.052
# Academic Age AcademicAge Gain Mistake 0.107
# Number of Papers MAGCumPapers Gain Misconduct 0.392
# Number of Papers MAGCumPapers Gain Plagiarism 0.587
# Number of Papers MAGCumPapers Gain Mistake 0.195
# Number of Citations MAGCumCitations Gain Misconduct 0.222
# Number of Citations MAGCumCitations Gain Plagiarism 0.439
# Number of Citations MAGCumCitations Gain Mistake 0.501
# Academic Age AcademicAge DiD Misconduct 0.398
# Academic Age AcademicAge DiD Plagiarism 0.11
# Academic Age AcademicAge DiD Mistake 0.938
# Number of Papers MAGCumPapers DiD Misconduct 0.349
# Number of Papers MAGCumPapers DiD Plagiarism 0.744
# Number of Papers MAGCumPapers DiD Mistake 0.656
# Number of Citations MAGCumCitations DiD Misconduct 0.498
# Number of Citations MAGCumCitations DiD Plagiarism 0.789
# Number of Citations MAGCumCitations DiD Mistake 0.215

# %%
expFields = ['Academic Age', 'Number of Papers', 'Number of Citations']
outcomeTypes = ['Retention', 'Gain', 'DiD']
categories = ['Misconduct','Plagiarism','Mistake']


combos = []

for e in expFields:
    for o in outcomeTypes:
        for c in categories:
            combos.append(e+","+o+","+c)


counter = 0
            
for i in range(len(retracted_pvals_reason)):
    for j in range(len(retracted_pvals_reason[i])):
        
        combo_i = combos[counter]
        counter += 1
        
        retracted_mean = retracted_means_reason[i][j]
        nonretracted_mean = nonretracted_means_reason[i][j]
        
        retracted_pval = retracted_pvals_reason[i][j]
        
        printString = ""
        
        if(retracted_pval < 0.05):
            if(retracted_mean < nonretracted_mean):
                printString = combo_i + "," + str(retracted_mean) + "," + str(nonretracted_mean) + "***," + str(retracted_pval)
            else:
                printString = combo_i + "," + str(retracted_mean) + "***," + str(nonretracted_mean) + "," + str(retracted_pval)
            
        else:
            printString = combo_i + "," + str(retracted_mean) + "," + str(nonretracted_mean) + "," + str(retracted_pval)
        
        print(printString)
# Out:
# Academic Age,Retention,Misconduct,12.92,14.68,0.154
# Academic Age,Retention,Plagiarism,12.61,15.41***,0.003
# Academic Age,Retention,Mistake,15.11,15.88,0.401
# Academic Age,Gain,Misconduct,69.8,93.75,0.343
# Academic Age,Gain,Plagiarism,63.89,66.41,0.759
# Academic Age,Gain,Mistake,69.93,74.76,0.572
# Academic Age,DiD,Misconduct,1498.48,1683.14,0.689
# Academic Age,DiD,Plagiarism,1158.96,1009.08,0.603
# Academic Age,DiD,Mistake,1487.99,1568.09,0.773
# Number of Papers,Retention,Misconduct,7.22,7.54,0.722
# Number of Papers,Retention,Plagiarism,6.49,7.73,0.052
# Number of Papers,Retention,Mistake,8.89,7.95,0.107
# Number of Papers,Gain,Misconduct,40.07,35.18,0.392
# Number of Papers,Gain,Plagiarism,29.84,31.83,0.587
# Number of Papers,Gain,Mistake,43.2,37.48,0.195
# Number of Papers,DiD,Misconduct,1076.05,701.72,0.222
# Number of Papers,DiD,Plagiarism,493.04,569.0,0.439
# Number of Papers,DiD,Mistake,1044.05,918.02,0.501
# Number of Citations,Retention,Misconduct,0.85,1.89,0.398
# Number of Citations,Retention,Plagiarism,1.59,3.07,0.11
# Number of Citations,Retention,Mistake,2.59,2.52,0.938
# Number of Citations,Gain,Misconduct,18.57,37.57,0.349
# Number of Citations,Gain,Plagiarism,21.28,23.67,0.744
# Number of Citations,Gain,Mistake,19.98,23.29,0.656
# Number of Citations,DiD,Misconduct,267.93,481.13,0.498
# Number of Citations,DiD,Plagiarism,264.13,217.33,0.789
# Number of Citations,DiD,Mistake,81.25,344.66,0.215

# %%
categories = ['Misconduct', 'Plagiarism', 'Mistake']

color_dict = {'Misconduct':'#7B2869',
             'Plagiarism':'#C85C8E',
             'Mistake': '#FFBABA',
             'Retracted': 'black',
             'Non-retracted':'black'}

color_dict = {'Misconduct':'#FF5C4D',
             'Plagiarism':'#FF9636',
             'Mistake': '#FFCD58',
             'Retracted': 'black',
             'Non-retracted':'black'}

marker_dict = {'Retracted':'o',
             'Non-retracted':'s',
             'Misconduct': 'o',
             'Plagiarism': 'o',
              'Mistake':'o'}

xticks = [[12,13,14,15,16],
         [60,70,80,90,100],
         [800,1200,1600,2000],
         [6,7,8,9,10],
         [30,35,40,45,50],
         [400,600,800,1000,1200],
         [0,1.5,3,5.0],
         [15,25,35,45],
         [50,200,350,500]]

create_collaborator_char_plot(categories, retracted_means_reason, 
                              nonretracted_means_reason, retracted_pvals_reason, 
                              color_dict, marker_dict, xticks, 
                              foutname = OUTDIR+"/collaborator_quality_byReason_firstlastauthors_new.pdf",
                              create_legend=True,
                             letters = ['j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r'])
