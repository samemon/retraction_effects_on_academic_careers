# %% [markdown]
# # Characterizing Collaborators
#
# In this notebook, we shall characterize collaborators. We shall do that in the following way:
#
# There are three academic age groups: junior (0-3), mid (4-9), and senior (10-).
#
# For each academic age group within retracted and matched scientists **at the time of retraction**, we shall conduct three analysis and create three tables:
#
# #### Retained for retracted vs. matched
# 1. Table 1 comparing the **retained** collaborators of retracted and matched scientists in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of collaboration**. The table will also contain median, standard deviation, and p-value for t-test.
#
# #### Gained for retracted vs. matched
# 2. Table 2 comparing the **gained/new** collaborators of retracted and matched scientists in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of collaboration**. The table will also contain median, standard deviation, and p-value for t-test.
#
# #### Retained vs. lost for retracted vs. matched
# 3. Table 3 comparing the **retained** collaborators of retracted and matched scientists to those **lost** in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of retraction**. The table will be produced by difference in differences approach where we shall first compute the averages for each field (papers, citations, etc.) for retained and lost for retracted and matched. Then we shall compute the difference between retained for retracted and matched, and between lost for retracted and matched. Finally we shall take the difference in difference (DiD) i.e. **RETAINED-LOST**. The table will also contain median, standard deviation, and p-value for t-test.

# %%
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
INDIR = "/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/"
INDIR_MATCHING = INDIR+"/author_matching/"
INDIR_COLLAB = INDIR+"/collaborator_quality_analysis/"

df = pd.read_csv(INDIR_COLLAB+"/1Dcollaborators_for_matched_sample_30.csv")

print(df.shape)

df.head()
# Out:
# (773033, 20)
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2004120834          1994.0                1983.0
# 1  2.105038e+09    2124401064          1994.0                1983.0
# 2  2.105038e+09    2486043001          1994.0                1983.0
# 3  2.105038e+09    2124401064          1994.0                1992.0
# 4  2.105038e+09    2276877851          1994.0                1992.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.74
# 2     retracted                  male                       0.60
# 3     retracted                  male                       0.74
# 4     retracted                female                       0.98
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1967.0                              1994.0
# 1                 1964.0                              1994.0
# 2                 1971.0                              1983.0
# 3                 1964.0                              1994.0
# 4                 1984.0                              1993.0
#
#    CollabMAGCumPapersAtRetraction  CollabMAGCumCitationsYearAtRetraction  \
# 0                           104.0                                 1994.0
# 1                            78.0                                 1994.0
# 2                            10.0                                 1994.0
# 3                            78.0                                 1994.0
# 4                            16.0                                 1994.0
#
#    CollabMAGCumCitationsAtRetraction  \
# 0                             3683.0
# 1                             2668.0
# 2                              532.0
# 3                             2668.0
# 4                              136.0
#
#    CollabMAGCumCollaboratorsYearAtRetraction  \
# 0                                     1994.0
# 1                                     1994.0
# 2                                     1983.0
# 3                                     1994.0
# 4                                     1993.0
#
#    CollabMAGCumCollaboratorsAtRetraction  \
# 0                                   83.0
# 1                                   81.0
# 2                                   18.0
# 3                                   81.0
# 4                                   31.0
#
#    CollabMAGCumPapersYearAtCollaboration  CollabMAGCumPapersAtCollaboration  \
# 0                                 1983.0                               47.0
# 1                                 1983.0                               47.0
# 2                                 1983.0                               10.0
# 3                                 1992.0                               74.0
# 4                                 1992.0                               14.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1983.0
# 1                                    1983.0
# 2                                    1983.0
# 3                                    1992.0
# 4                                    1992.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                1076.0
# 1                                1305.0
# 2                                 199.0
# 3                                2449.0
# 4                                  90.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1983.0
# 1                                        1983.0
# 2                                        1983.0
# 3                                        1992.0
# 4                                        1992.0
#
#    CollabMAGCumCollaboratorsAtCollaboration
# 0                                        46
# 1                                        37
# 2                                        18
# 3                                        71
# 4                                        27

# %%
print(df.shape)
# Out:
# (773033, 20)

# %%
df.MAGCollabAID.nunique()
# Out:
# 411911

# %%
df_treatment = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_treatment_augmented_rematching_30perc.csv")
df_treatment['MAGAIDFirstORLastAuthorFlag']
# Out:
# 0            MAGMiddleAuthor
# 1            MAGMiddleAuthor
# 2            MAGMiddleAuthor
# 3            MAGMiddleAuthor
# 4            MAGMiddleAuthor
#                 ...
# 2803    MAGFirstOrLastAuthor
# 2804         MAGMiddleAuthor
# 2805         MAGMiddleAuthor
# 2806    MAGFirstOrLastAuthor
# 2807    MAGFirstOrLastAuthor
# Name: MAGAIDFirstORLastAuthorFlag, Length: 2808, dtype: object

# %% [markdown]
# ### Preprocessing

# %%
# Let us first augment the academic age of MAGAIDs. We will also add other columns to be used later

# Reading files used for matching

df_treatment = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_treatment_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5','AcademicAgeBeforeRetraction',
                            'MAGAIDFirstORLastAuthorFlag'])\
                    .drop_duplicates()\
                    .rename(columns={'AcademicAgeBeforeRetraction': 'AcademicAgeAtRetraction'})

df_control = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MatchMAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5','AcademicAgeBeforeRetraction',
                            'MAGAIDFirstORLastAuthorFlag'])\
                    .drop_duplicates()\
                    .rename(columns={'MatchMAGAID':'MAGAID',
                                    'AcademicAgeBeforeRetraction': 'AcademicAgeAtRetraction'})

# Filtering process for choosing only first and last authors

df_treatment = df_treatment[df_treatment['MAGAIDFirstORLastAuthorFlag']=='MAGFirstOrLastAuthor']

df_control = df_control[df_control['MAGAIDFirstORLastAuthorFlag']=='MAGFirstOrLastAuthor']


df_treatment_control = pd.concat([df_treatment,df_control])

# Filtering process
df = df[df['MAGAID'].isin(df_treatment_control['MAGAID'])]

# Now let us categorize age into 3 bins we discussed: 0-3, 4-9, and >10

def categorize_age(age):
    if age <= 3:
        return 'early-career author'
    elif (age > 3) and (age < 10):
        return 'mid-career author'
    elif age >= 10:
        return 'senior author'

df_treatment_control['AuthorSeniorityAtRetraction'] = df_treatment_control['AcademicAgeAtRetraction'].\
                                                        apply(lambda age: categorize_age(age))

df_treatment_control
# Out:
#             MAGAID  RetractionYear MAGAIDFirstORLastAuthorFlag  \
# 20    1.839367e+08          2007.0        MAGFirstOrLastAuthor
# 22    2.004364e+08          2012.0        MAGFirstOrLastAuthor
# 23    2.066031e+08          2012.0        MAGFirstOrLastAuthor
# 25    2.072804e+08          2012.0        MAGFirstOrLastAuthor
# 26    2.074934e+08          2008.0        MAGFirstOrLastAuthor
# ...            ...             ...                         ...
# 5411  2.127710e+09          2015.0        MAGFirstOrLastAuthor
# 5412  1.974243e+09          2013.0        MAGFirstOrLastAuthor
# 5413  2.100696e+09          2014.0        MAGFirstOrLastAuthor
# 5416  2.077873e+09          2008.0        MAGFirstOrLastAuthor
# 5417  3.019838e+08          2014.0        MAGFirstOrLastAuthor
#
#       AcademicAgeAtRetraction  NumRetentionW5  NumNewCollaboratorsW5  \
# 20                        2.0               8                     79
# 22                        6.0              13                     18
# 23                        1.0              12                     28
# 25                       23.0              20                     88
# 26                       22.0              13                     55
# ...                       ...             ...                    ...
# 5411                      9.0               3                     25
# 5412                      6.0               3                      2
# 5413                     37.0              15                     89
# 5416                      3.0               2                      3
# 5417                     21.0              41                    141
#
#      AuthorSeniorityAtRetraction
# 20           early-career author
# 22             mid-career author
# 23           early-career author
# 25                 senior author
# 26                 senior author
# ...                          ...
# 5411           mid-career author
# 5412           mid-career author
# 5413               senior author
# 5416         early-career author
# 5417               senior author
#
# [2249 rows x 7 columns]

# %%
# Merging that with df

df2 = df.merge(df_treatment_control.drop(columns=['NumRetentionW5','NumNewCollaboratorsW5']), 
                                         on=['MAGAID','RetractionYear'])
df2
# Out:
#               MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0       2.033335e+09    1917877966          1995.0                1999.0
# 1       2.033335e+09    2169118091          1995.0                1999.0
# 2       2.033335e+09     275085591          1995.0                1997.0
# 3       2.033335e+09    2111014462          1995.0                1997.0
# 4       2.033335e+09    2622920657          1995.0                1997.0
# ...              ...           ...             ...                   ...
# 249984  2.147516e+09    2144146330          2009.0                2016.0
# 249985  2.147516e+09    3146371485          2009.0                2015.0
# 249986  2.147516e+09    3149630639          2009.0                2014.0
# 249987  2.147516e+09    3165764306          2009.0                2014.0
# 249988  2.147516e+09    3142706001          2009.0                2019.0
#
#        ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0          retracted                  male                       0.99
# 1          retracted                  male                       1.00
# 2          retracted                  male                       0.99
# 3          retracted                female                       0.98
# 4          retracted                  male                       0.99
# ...              ...                   ...                        ...
# 249984       matched                  male                       0.81
# 249985       matched                  male                       0.60
# 249986       matched                  male                       0.97
# 249987       matched                  male                       0.81
# 249988       matched                female                       0.78
#
#         CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                      1994.0                              1994.0
# 1                      1995.0                              1995.0
# 2                      1994.0                              1995.0
# 3                      1988.0                              1995.0
# 4                      1991.0                              1995.0
# ...                       ...                                 ...
# 249984                 1982.0                              2009.0
# 249985                 2015.0                                 NaN
# 249986                 2014.0                                 NaN
# 249987                 2014.0                                 NaN
# 249988                 2019.0                                 NaN
#
#         CollabMAGCumPapersAtRetraction  ...  \
# 0                                  1.0  ...
# 1                                  1.0  ...
# 2                                  5.0  ...
# 3                                 17.0  ...
# 4                                 17.0  ...
# ...                                ...  ...
# 249984                           284.0  ...
# 249985                             0.0  ...
# 249986                             0.0  ...
# 249987                             0.0  ...
# 249988                             0.0  ...
#
#         CollabMAGCumCollaboratorsAtRetraction  \
# 0                                         2.0
# 1                                         3.0
# 2                                        11.0
# 3                                        30.0
# 4                                        33.0
# ...                                       ...
# 249984                                  464.0
# 249985                                    0.0
# 249986                                    0.0
# 249987                                    0.0
# 249988                                    0.0
#
#         CollabMAGCumPapersYearAtCollaboration  \
# 0                                      1999.0
# 1                                      1999.0
# 2                                      1997.0
# 3                                      1997.0
# 4                                      1997.0
# ...                                       ...
# 249984                                 2016.0
# 249985                                 2015.0
# 249986                                 2014.0
# 249987                                 2014.0
# 249988                                 2019.0
#
#         CollabMAGCumPapersAtCollaboration  \
# 0                                    14.0
# 1                                     9.0
# 2                                    12.0
# 3                                    22.0
# 4                                    26.0
# ...                                   ...
# 249984                              563.0
# 249985                                1.0
# 249986                                1.0
# 249987                                1.0
# 249988                                1.0
#
#         CollabMAGCumCitationsYearAtCollaboration  \
# 0                                         1999.0
# 1                                         1999.0
# 2                                         1997.0
# 3                                         1997.0
# 4                                         1997.0
# ...                                          ...
# 249984                                    2016.0
# 249985                                    2015.0
# 249986                                       NaN
# 249987                                       NaN
# 249988                                       NaN
#
#         CollabMAGCumCitationsAtCollaboration  \
# 0                                       99.0
# 1                                        8.0
# 2                                       53.0
# 3                                      921.0
# 4                                      306.0
# ...                                      ...
# 249984                               16846.0
# 249985                                   1.0
# 249986                                   0.0
# 249987                                   0.0
# 249988                                   0.0
#
#         CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                             1999.0
# 1                                             1999.0
# 2                                             1997.0
# 3                                             1997.0
# 4                                             1997.0
# ...                                              ...
# 249984                                        2016.0
# 249985                                        2015.0
# 249986                                        2014.0
# 249987                                        2014.0
# 249988                                        2019.0
#
#         CollabMAGCumCollaboratorsAtCollaboration  MAGAIDFirstORLastAuthorFlag  \
# 0                                             31         MAGFirstOrLastAuthor
# 1                                             23         MAGFirstOrLastAuthor
# 2                                             22         MAGFirstOrLastAuthor
# 3                                             42         MAGFirstOrLastAuthor
# 4                                             44         MAGFirstOrLastAuthor
# ...                                          ...                          ...
# 249984                                      3686         MAGFirstOrLastAuthor
# 249985                                         4         MAGFirstOrLastAuthor
# 249986                                         4         MAGFirstOrLastAuthor
# 249987                                         4         MAGFirstOrLastAuthor
# 249988                                         5         MAGFirstOrLastAuthor
#
#         AcademicAgeAtRetraction  AuthorSeniorityAtRetraction
# 0                          28.0                senior author
# 1                          28.0                senior author
# 2                          28.0                senior author
# 3                          28.0                senior author
# 4                          28.0                senior author
# ...                         ...                          ...
# 249984                      4.0            mid-career author
# 249985                      4.0            mid-career author
# 249986                      4.0            mid-career author
# 249987                      4.0            mid-career author
# 249988                      4.0            mid-career author
#
# [249989 rows x 23 columns]

# %%
# Let us first compute academic age at retraction and at collaboration for collaborators
df2['CollabAcademicAgeAtRetraction'] = df2['RetractionYear']-df2['CollabMAGFirstPubYear']

df2['CollabAcademicAgeAtCollaboration'] = df2['MAGCollaborationYear']-df2['CollabMAGFirstPubYear']

# So negatives are possible in academic age at retraction but not collaboration
df2.CollabAcademicAgeAtRetraction.describe()
# Out:
# count    249989.000000
# mean          9.189364
# std          13.634279
# min         -30.000000
# 25%           0.000000
# 50%           7.000000
# 75%          17.000000
# max         215.000000
# Name: CollabAcademicAgeAtRetraction, dtype: float64

# %%
df2.CollabAcademicAgeAtCollaboration.describe()
# Out:
# count    249989.000000
# mean         10.315014
# std          12.304358
# min           0.000000
# 25%           1.000000
# 50%           6.000000
# 75%          16.000000
# max         220.000000
# Name: CollabAcademicAgeAtCollaboration, dtype: float64

# %%
# Let us first identify if the collaboration was pre- or post-retraction

def get_prepost_flag(row):
    if(row['MAGCollaborationYear'] <= row['RetractionYear']):
        return 'pre'
    else:
        if((row['MAGCollaborationYear']-row['RetractionYear'])<=5):
            return 'post5'
        else:
            return 'post'

df2['PrePostFlag5'] = df2.apply(lambda row: get_prepost_flag(row), axis=1)

# %%
# Let us remove the collaborators that are "post"

df3 = df2[~df2.PrePostFlag5.eq('post')]

# %%
df3.head()
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.033335e+09    1917877966          1995.0                1999.0
# 1  2.033335e+09    2169118091          1995.0                1999.0
# 2  2.033335e+09     275085591          1995.0                1997.0
# 3  2.033335e+09    2111014462          1995.0                1997.0
# 4  2.033335e+09    2622920657          1995.0                1997.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       1.00
# 2     retracted                  male                       0.99
# 3     retracted                female                       0.98
# 4     retracted                  male                       0.99
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1994.0                              1994.0
# 1                 1995.0                              1995.0
# 2                 1994.0                              1995.0
# 3                 1988.0                              1995.0
# 4                 1991.0                              1995.0
#
#    CollabMAGCumPapersAtRetraction  ...  \
# 0                             1.0  ...
# 1                             1.0  ...
# 2                             5.0  ...
# 3                            17.0  ...
# 4                            17.0  ...
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1999.0
# 1                                    1999.0
# 2                                    1997.0
# 3                                    1997.0
# 4                                    1997.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                  99.0
# 1                                   8.0
# 2                                  53.0
# 3                                 921.0
# 4                                 306.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1999.0
# 1                                        1999.0
# 2                                        1997.0
# 3                                        1997.0
# 4                                        1997.0
#
#    CollabMAGCumCollaboratorsAtCollaboration  MAGAIDFirstORLastAuthorFlag  \
# 0                                        31         MAGFirstOrLastAuthor
# 1                                        23         MAGFirstOrLastAuthor
# 2                                        22         MAGFirstOrLastAuthor
# 3                                        42         MAGFirstOrLastAuthor
# 4                                        44         MAGFirstOrLastAuthor
#
#    AcademicAgeAtRetraction  AuthorSeniorityAtRetraction  \
# 0                     28.0                senior author
# 1                     28.0                senior author
# 2                     28.0                senior author
# 3                     28.0                senior author
# 4                     28.0                senior author
#
#    CollabAcademicAgeAtRetraction  CollabAcademicAgeAtCollaboration  \
# 0                            1.0                               5.0
# 1                            0.0                               4.0
# 2                            1.0                               3.0
# 3                            7.0                               9.0
# 4                            4.0                               6.0
#
#    PrePostFlag5
# 0         post5
# 1         post5
# 2         post5
# 3         post5
# 4         post5
#
# [5 rows x 26 columns]

# %%
df3.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'MAGAIDFirstORLastAuthorFlag', 'AcademicAgeAtRetraction',
#        'AuthorSeniorityAtRetraction', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5'],
#       dtype='object')

# %%
# For each MAGAID, let us create a set of collaborators pre- and post- retraction

df4 = df3.groupby(['MAGAID','RetractionYear','PrePostFlag5'])\
                        ['MAGCollabAID'].apply(set).unstack().reset_index()


# Converting pre- and post5 columns to set so we can do set operations
df4['pre'] = df4['pre'].apply(lambda d: d if isinstance(d, set) else set())
df4['post5'] = df4['post5'].apply(lambda d: d if isinstance(d, set) else set())


# COLLABORATOR RETENTION

# Computing number of collaborators retained
df4['NumRetentionW5'] = df4.apply(lambda row: len(row.post5.intersection(row.pre)), 
                            axis=1)

# Creating the list of collaborators retained
df4['CollabAIDRetainedW5'] = df4.apply(lambda row: row.post5.intersection(row.pre), 
                                                    axis=1)


# Creating list of collaborators lost
df4['CollabAIDLostW5'] = df4.apply(lambda row: row['pre'] - row['CollabAIDRetainedW5'], 
                                                    axis=1)


# COLLABORATOR GAIN

# Computing number of collabortors gained
df4['NumNewCollaboratorsW5'] = df4.apply(lambda row: len(row['post5']-row['pre']), 
                                                    axis=1)

# Creating set of collaborators gained
df4['CollabAIDGainedW5'] = df4.apply(lambda row: row['post5']-row['pre'], 
                                                    axis=1)


df4.head()
# Out:
# PrePostFlag5      MAGAID  RetractionYear  \
# 0             19100288.0          2002.0
# 1             21686935.0          2008.0
# 2             29680017.0          1997.0
# 3             33433812.0          2009.0
# 4             41957466.0          2015.0
#
# PrePostFlag5                                              post5  \
# 0             {18011520, 2181345027, 2608247304, 2043645593,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2             {2309217606, 2070053831, 1588714087, 252097620...
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2034626565, 1848517639, 2597654027, 203201076...
#
# PrePostFlag5                                                pre  \
# 0             {2437904394, 2171993227, 2043645593, 220887567...
# 1             {2170694433, 2064283617, 2327654243, 247583094...
# 2             {287126053, 1971237384, 2023717609, 2273398858...
# 3             {2653850944, 2127386819, 2572203943, 212894289...
# 4             {2152585733, 2142553607, 2110808072, 294896999...
#
# PrePostFlag5  NumRetentionW5  \
# 0                          5
# 1                          0
# 2                          1
# 3                          4
# 4                         32
#
# PrePostFlag5                                CollabAIDRetainedW5  \
# 0             {2128982626, 1863203661, 2043645593, 410625722...
# 1                                                            {}
# 2                                                  {2920459384}
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2047324288, 2133711754, 1719173006, 219254094...
#
# PrePostFlag5                                    CollabAIDLostW5  \
# 0             {2059887737, 2186312265, 2437904394, 217199322...
# 1             {2330648593, 2965357269, 3081263517, 250572015...
# 2             {1971237384, 2273398858, 1998215821, 230597927...
# 3                          {2137538457, 2149027090, 2572203943}
# 4             {2152585733, 2142553607, 2110808072, 294896999...
#
# PrePostFlag5  NumNewCollaboratorsW5  \
# 0                                23
# 1                                12
# 2                                 4
# 3                                 0
# 4                                83
#
# PrePostFlag5                                  CollabAIDGainedW5
# 0             {18011520, 2181345027, 2608247304, 2111905563,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2              {2520976201, 1588714087, 2309217606, 2070053831}
# 3                                                            {}
# 4             {2034626565, 1848517639, 2597654027, 203201076...

# %% [markdown]
# ### Validation of the number of collaborators retained and gained
#
# We shall validate if the numbers we calculated now match the ones on which matching was done.

# %%
# Merging
dfvalidation = df4[['MAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5']].drop_duplicates().\
                    merge(df_treatment_control, on=['MAGAID','RetractionYear'])

dfvalidation
# Out:
#             MAGAID  RetractionYear  NumRetentionW5_x  NumNewCollaboratorsW5_x  \
# 0     1.910029e+07          2002.0                 5                       23
# 1     2.168694e+07          2008.0                 0                       12
# 2     2.968002e+07          1997.0                 1                        4
# 3     3.343381e+07          2009.0                 4                        0
# 4     4.195747e+07          2015.0                32                       83
# ...            ...             ...               ...                      ...
# 1757  3.173544e+09          2011.0                 0                        2
# 1758  3.174124e+09          2004.0                 1                        6
# 1759  3.174448e+09          2008.0                 1                        0
# 1760  3.175436e+09          2015.0                 1                       14
# 1761  3.176346e+09          2011.0                 1                        8
#
#      MAGAIDFirstORLastAuthorFlag  AcademicAgeAtRetraction  NumRetentionW5_y  \
# 0           MAGFirstOrLastAuthor                      9.0                 5
# 1           MAGFirstOrLastAuthor                      3.0                 0
# 2           MAGFirstOrLastAuthor                      5.0                 1
# 3           MAGFirstOrLastAuthor                      2.0                 4
# 4           MAGFirstOrLastAuthor                     22.0                32
# ...                          ...                      ...               ...
# 1757        MAGFirstOrLastAuthor                      6.0                 0
# 1758        MAGFirstOrLastAuthor                      1.0                 1
# 1759        MAGFirstOrLastAuthor                      2.0                 1
# 1760        MAGFirstOrLastAuthor                      6.0                 1
# 1761        MAGFirstOrLastAuthor                      1.0                 1
#
#       NumNewCollaboratorsW5_y AuthorSeniorityAtRetraction
# 0                          23           mid-career author
# 1                          12         early-career author
# 2                           4           mid-career author
# 3                           0         early-career author
# 4                          83               senior author
# ...                       ...                         ...
# 1757                        2           mid-career author
# 1758                        6         early-career author
# 1759                        0         early-career author
# 1760                       14           mid-career author
# 1761                        8         early-career author
#
# [1762 rows x 9 columns]

# %%
# Finally validating

dfvalidation[(dfvalidation.NumRetentionW5_x == dfvalidation.NumRetentionW5_y) & 
            (dfvalidation.NumNewCollaboratorsW5_x == dfvalidation.NumNewCollaboratorsW5_y)]
# Out:
#             MAGAID  RetractionYear  NumRetentionW5_x  NumNewCollaboratorsW5_x  \
# 0     1.910029e+07          2002.0                 5                       23
# 1     2.168694e+07          2008.0                 0                       12
# 2     2.968002e+07          1997.0                 1                        4
# 3     3.343381e+07          2009.0                 4                        0
# 4     4.195747e+07          2015.0                32                       83
# ...            ...             ...               ...                      ...
# 1757  3.173544e+09          2011.0                 0                        2
# 1758  3.174124e+09          2004.0                 1                        6
# 1759  3.174448e+09          2008.0                 1                        0
# 1760  3.175436e+09          2015.0                 1                       14
# 1761  3.176346e+09          2011.0                 1                        8
#
#      MAGAIDFirstORLastAuthorFlag  AcademicAgeAtRetraction  NumRetentionW5_y  \
# 0           MAGFirstOrLastAuthor                      9.0                 5
# 1           MAGFirstOrLastAuthor                      3.0                 0
# 2           MAGFirstOrLastAuthor                      5.0                 1
# 3           MAGFirstOrLastAuthor                      2.0                 4
# 4           MAGFirstOrLastAuthor                     22.0                32
# ...                          ...                      ...               ...
# 1757        MAGFirstOrLastAuthor                      6.0                 0
# 1758        MAGFirstOrLastAuthor                      1.0                 1
# 1759        MAGFirstOrLastAuthor                      2.0                 1
# 1760        MAGFirstOrLastAuthor                      6.0                 1
# 1761        MAGFirstOrLastAuthor                      1.0                 1
#
#       NumNewCollaboratorsW5_y AuthorSeniorityAtRetraction
# 0                          23           mid-career author
# 1                          12         early-career author
# 2                           4           mid-career author
# 3                           0         early-career author
# 4                          83               senior author
# ...                       ...                         ...
# 1757                        2           mid-career author
# 1758                        6         early-career author
# 1759                        0         early-career author
# 1760                       14           mid-career author
# 1761                        8         early-career author
#
# [1762 rows x 9 columns]

# %% [markdown]
# **Hence all of them are validated.**

# %% [markdown]
# ## Analysis

# %%
# Our main dataframes are df3 and df4
# Let us look at them first
print(df3.shape)
df3.head()
# Out:
# (184830, 26)
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.033335e+09    1917877966          1995.0                1999.0
# 1  2.033335e+09    2169118091          1995.0                1999.0
# 2  2.033335e+09     275085591          1995.0                1997.0
# 3  2.033335e+09    2111014462          1995.0                1997.0
# 4  2.033335e+09    2622920657          1995.0                1997.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       1.00
# 2     retracted                  male                       0.99
# 3     retracted                female                       0.98
# 4     retracted                  male                       0.99
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1994.0                              1994.0
# 1                 1995.0                              1995.0
# 2                 1994.0                              1995.0
# 3                 1988.0                              1995.0
# 4                 1991.0                              1995.0
#
#    CollabMAGCumPapersAtRetraction  ...  \
# 0                             1.0  ...
# 1                             1.0  ...
# 2                             5.0  ...
# 3                            17.0  ...
# 4                            17.0  ...
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1999.0
# 1                                    1999.0
# 2                                    1997.0
# 3                                    1997.0
# 4                                    1997.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                  99.0
# 1                                   8.0
# 2                                  53.0
# 3                                 921.0
# 4                                 306.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1999.0
# 1                                        1999.0
# 2                                        1997.0
# 3                                        1997.0
# 4                                        1997.0
#
#    CollabMAGCumCollaboratorsAtCollaboration  MAGAIDFirstORLastAuthorFlag  \
# 0                                        31         MAGFirstOrLastAuthor
# 1                                        23         MAGFirstOrLastAuthor
# 2                                        22         MAGFirstOrLastAuthor
# 3                                        42         MAGFirstOrLastAuthor
# 4                                        44         MAGFirstOrLastAuthor
#
#    AcademicAgeAtRetraction  AuthorSeniorityAtRetraction  \
# 0                     28.0                senior author
# 1                     28.0                senior author
# 2                     28.0                senior author
# 3                     28.0                senior author
# 4                     28.0                senior author
#
#    CollabAcademicAgeAtRetraction  CollabAcademicAgeAtCollaboration  \
# 0                            1.0                               5.0
# 1                            0.0                               4.0
# 2                            1.0                               3.0
# 3                            7.0                               9.0
# 4                            4.0                               6.0
#
#    PrePostFlag5
# 0         post5
# 1         post5
# 2         post5
# 3         post5
# 4         post5
#
# [5 rows x 26 columns]

# %%
df4
# Out:
# PrePostFlag5        MAGAID  RetractionYear  \
# 0             1.910029e+07          2002.0
# 1             2.168694e+07          2008.0
# 2             2.968002e+07          1997.0
# 3             3.343381e+07          2009.0
# 4             4.195747e+07          2015.0
# ...                    ...             ...
# 1757          3.173544e+09          2011.0
# 1758          3.174124e+09          2004.0
# 1759          3.174448e+09          2008.0
# 1760          3.175436e+09          2015.0
# 1761          3.176346e+09          2011.0
#
# PrePostFlag5                                              post5  \
# 0             {18011520, 2181345027, 2608247304, 2043645593,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2             {2309217606, 2070053831, 1588714087, 252097620...
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2034626565, 1848517639, 2597654027, 203201076...
# ...                                                         ...
# 1757                                   {3120802076, 2236143686}
# 1758          {2706053123, 2250669861, 2568589385, 222924385...
# 1759                                               {2561941943}
# 1760          {1805786912, 2999619457, 2658197410, 257933920...
# 1761          {2078002947, 2029403719, 2137379546, 199009346...
#
# PrePostFlag5                                                pre  \
# 0             {2437904394, 2171993227, 2043645593, 220887567...
# 1             {2170694433, 2064283617, 2327654243, 247583094...
# 2             {287126053, 1971237384, 2023717609, 2273398858...
# 3             {2653850944, 2127386819, 2572203943, 212894289...
# 4             {2152585733, 2142553607, 2110808072, 294896999...
# ...                                                         ...
# 1757          {2096029443, 2160112133, 2158121610, 230907623...
# 1758           {2939265617, 2687883010, 2424699715, 2100866894}
# 1759          {2413204075, 2100828844, 3175667245, 299211752...
# 1760          {2130470407, 2395301650, 1455333013, 231293572...
# 1761          {677348324, 2657776906, 3170697964, 1758167412...
#
# PrePostFlag5  NumRetentionW5  \
# 0                          5
# 1                          0
# 2                          1
# 3                          4
# 4                         32
# ...                      ...
# 1757                       0
# 1758                       1
# 1759                       1
# 1760                       1
# 1761                       1
#
# PrePostFlag5                                CollabAIDRetainedW5  \
# 0             {2128982626, 1863203661, 2043645593, 410625722...
# 1                                                            {}
# 2                                                  {2920459384}
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2047324288, 2133711754, 1719173006, 219254094...
# ...                                                         ...
# 1757                                                         {}
# 1758                                               {2100866894}
# 1759                                               {2561941943}
# 1760                                               {2121913688}
# 1761                                               {1990093460}
#
# PrePostFlag5                                    CollabAIDLostW5  \
# 0             {2059887737, 2186312265, 2437904394, 217199322...
# 1             {2330648593, 2965357269, 3081263517, 250572015...
# 2             {1971237384, 2273398858, 1998215821, 230597927...
# 3                          {2137538457, 2149027090, 2572203943}
# 4             {2152585733, 2142553607, 2110808072, 294896999...
# ...                                                         ...
# 1757          {2096029443, 2160112133, 2158121610, 230907623...
# 1758                       {2939265617, 2687883010, 2424699715}
# 1759          {2413204075, 2100828844, 3175667245, 299211752...
# 1760          {2240552385, 2130470407, 2333910471, 252033530...
# 1761          {677348324, 2657776906, 3170697964, 1758167412...
#
# PrePostFlag5  NumNewCollaboratorsW5  \
# 0                                23
# 1                                12
# 2                                 4
# 3                                 0
# 4                                83
# ...                             ...
# 1757                              2
# 1758                              6
# 1759                              0
# 1760                             14
# 1761                              8
#
# PrePostFlag5                                  CollabAIDGainedW5
# 0             {18011520, 2181345027, 2608247304, 2111905563,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2              {2520976201, 1588714087, 2309217606, 2070053831}
# 3                                                            {}
# 4             {2034626565, 1848517639, 2597654027, 203201076...
# ...                                                         ...
# 1757                                   {3120802076, 2236143686}
# 1758          {2706053123, 2250669861, 2568589385, 222924385...
# 1759                                                         {}
# 1760          {1805786912, 2999619457, 2658197410, 196858720...
# 1761          {2078002947, 2029403719, 2051974682, 188354341...
#
# [1762 rows x 9 columns]

# %%
# Let us first merge df3 and df4

df_A = df3.merge(df4, on=['MAGAID','RetractionYear'])

# Let us also create three flags checking whether current collaborator is retained, gained, or lost

df_A['CollabAIDinRetained'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDRetainedW5'], 
                                          axis=1)

df_A['CollabAIDinGained'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDGainedW5'], 
                                          axis=1)

df_A['CollabAIDinLost'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDLostW5'], 
                                          axis=1)

df_A.head(3)
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.033335e+09    1917877966          1995.0                1999.0
# 1  2.033335e+09    2169118091          1995.0                1999.0
# 2  2.033335e+09     275085591          1995.0                1997.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       1.00
# 2     retracted                  male                       0.99
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1994.0                              1994.0
# 1                 1995.0                              1995.0
# 2                 1994.0                              1995.0
#
#    CollabMAGCumPapersAtRetraction  ...  \
# 0                             1.0  ...
# 1                             1.0  ...
# 2                             5.0  ...
#
#                                                post5  \
# 0  {1973921793, 2041262087, 2570043915, 213721346...
# 1  {1973921793, 2041262087, 2570043915, 213721346...
# 2  {1973921793, 2041262087, 2570043915, 213721346...
#
#                                                  pre  NumRetentionW5  \
# 0  {2041262087, 2590561305, 1940968476, 211428099...              23
# 1  {2041262087, 2590561305, 1940968476, 211428099...              23
# 2  {2041262087, 2590561305, 1940968476, 211428099...              23
#
#                                  CollabAIDRetainedW5  \
# 0  {2690057605, 2041262087, 2466141063, 230478619...
# 1  {2690057605, 2041262087, 2466141063, 230478619...
# 2  {2690057605, 2041262087, 2466141063, 230478619...
#
#                                      CollabAIDLostW5  NumNewCollaboratorsW5  \
# 0  {2590561305, 1940968476, 2657016352, 265692164...                     60
# 1  {2590561305, 1940968476, 2657016352, 265692164...                     60
# 2  {2590561305, 1940968476, 2657016352, 265692164...                     60
#
#                                    CollabAIDGainedW5  CollabAIDinRetained  \
# 0  {1973921793, 2308182914, 1147890307, 265602649...                False
# 1  {1973921793, 2308182914, 1147890307, 265602649...                False
# 2  {1973921793, 2308182914, 1147890307, 265602649...                 True
#
#    CollabAIDinGained  CollabAIDinLost
# 0               True            False
# 1               True            False
# 2              False            False
#
# [3 rows x 36 columns]

# %%
# Sensibility checks

df_A[['CollabAIDinRetained','CollabAIDinGained','CollabAIDinLost']].value_counts()
# Out:
# CollabAIDinRetained  CollabAIDinGained  CollabAIDinLost
# False                False              True               74864
#                      True               False              62430
# True                 False              False              47536
# Name: count, dtype: int64

# %%
df_A.columns, df_A.shape
# Out:
# (Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#         'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#         'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#         'CollabMAGCumPapersAtRetraction',
#         'CollabMAGCumCitationsYearAtRetraction',
#         'CollabMAGCumCitationsAtRetraction',
#         'CollabMAGCumCollaboratorsYearAtRetraction',
#         'CollabMAGCumCollaboratorsAtRetraction',
#         'CollabMAGCumPapersYearAtCollaboration',
#         'CollabMAGCumPapersAtCollaboration',
#         'CollabMAGCumCitationsYearAtCollaboration',
#         'CollabMAGCumCitationsAtCollaboration',
#         'CollabMAGCumCollaboratorsYearAtCollaboration',
#         'CollabMAGCumCollaboratorsAtCollaboration',
#         'MAGAIDFirstORLastAuthorFlag', 'AcademicAgeAtRetraction',
#         'AuthorSeniorityAtRetraction', 'CollabAcademicAgeAtRetraction',
#         'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#         'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#         'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#         'CollabAIDinGained', 'CollabAIDinLost'],
#        dtype='object'),
#  (184830, 36))

# %% [markdown]
# ## DANGER ZONE!
#
# This code removes collaborators that have academic age > 70 at the time of collaboration.

# %%
#df_A[df_A.CollabAcademicAgeAtCollaboration.gt(70) & df_A.ScientistType.eq('retracted')].MAGAID.nunique()

# %%
#df_A = df_A[df_A.CollabAcademicAgeAtCollaboration.le(70)]

# %% [markdown]
# ### A1: Collaborators retained: retracted vs. matched

# %%
#Let us now modify df_A1 such that we remove all rows with collaborations pre-retraction

df_A1_post = df_A[df_A['PrePostFlag5']=='post5']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A1_firstcollabs = df_A1_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A1_w_firstcollabs = df_A1_post.merge(df_A1_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A1_w_firstcollabs.shape
# Out:
# (83316, 37)

# %%
# Sensibility checks

df_A1_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#           MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 3472  19100288.0      18011520                2004.0
# 3479  19100288.0     121410733                2004.0
# 3460  19100288.0     410625722                2005.0
# 3473  19100288.0    1235268530                2004.0
# 3482  19100288.0    1340583028                2006.0
# 3454  19100288.0    1793107545                2003.0
# 3455  19100288.0    1793107545                2004.0
# 3474  19100288.0    1859744180                2004.0
# 3456  19100288.0    1863203661                2003.0
# 3457  19100288.0    1863203661                2004.0
# 3459  19100288.0    1863203661                2006.0
# 3458  19100288.0    1863203661                2007.0
# 3451  19100288.0    1986621809                2006.0
# 3450  19100288.0    1986621809                2007.0
# 3475  19100288.0    2004612287                2004.0
# 3466  19100288.0    2043645593                2004.0
# 3467  19100288.0    2043645593                2007.0
# 3480  19100288.0    2051205987                2004.0
# 3485  19100288.0    2078618456                2003.0
# 3486  19100288.0    2111905563                2003.0
# 3471  19100288.0    2115457216                2003.0
# 3468  19100288.0    2115457216                2004.0
# 3470  19100288.0    2115457216                2006.0
# 3469  19100288.0    2115457216                2007.0
# 3462  19100288.0    2128982626                2004.0
# 3461  19100288.0    2128982626                2005.0
# 3463  19100288.0    2128982626                2007.0
# 3476  19100288.0    2134604144                2004.0
# 3481  19100288.0    2149884334                2004.0
# 3464  19100288.0    2151293749                2005.0
#
#       FirstPostRetractionMAGCollaborationYear
# 3472                                   2004.0
# 3479                                   2004.0
# 3460                                   2005.0
# 3473                                   2004.0
# 3482                                   2006.0
# 3454                                   2003.0
# 3455                                   2003.0
# 3474                                   2004.0
# 3456                                   2003.0
# 3457                                   2003.0
# 3459                                   2003.0
# 3458                                   2003.0
# 3451                                   2006.0
# 3450                                   2006.0
# 3475                                   2004.0
# 3466                                   2004.0
# 3467                                   2004.0
# 3480                                   2004.0
# 3485                                   2003.0
# 3486                                   2003.0
# 3471                                   2003.0
# 3468                                   2003.0
# 3470                                   2003.0
# 3469                                   2003.0
# 3462                                   2004.0
# 3461                                   2004.0
# 3463                                   2004.0
# 3476                                   2004.0
# 3481                                   2004.0
# 3464                                   2005.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A1_w_firstcollabs_only = df_A1_w_firstcollabs[df_A1_w_firstcollabs.MAGCollaborationYear == \
                                                df_A1_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A1_w_firstcollabs_only.shape
# Out:
# (63167, 37)

# %%
df_A1_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'MAGAIDFirstORLastAuthorFlag', 'AcademicAgeAtRetraction',
#        'AuthorSeniorityAtRetraction', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#        'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#        'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#        'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
def create_stratified_dfs_retention(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
               'CollabMAGCumPapersAtCollaboration', 'CollabMAGCumCitationsAtCollaboration',
               'CollabMAGCumCollaboratorsAtCollaboration', 'AuthorSeniorityAtRetraction',
               'CollabAcademicAgeAtCollaboration', 'CollabAIDinRetained', 'NumRetentionW5']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi = dfi[dfi['CollabAIDinRetained']]
    
    # Dividing into retracted and matched
    df_retracted = dfi[dfi.ScientistType == 'retracted']
    df_nonretracted = dfi[dfi.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the retracted scientists have matches with non zero collaborators
    df_retracted = df_retracted[df_retracted.MAGAID.isin(df_nonretracted.MAGAID.unique())]
    
    # We need to make sure that the matches of those who retained 0 collaborators are removed
    df_nonretracted = df_nonretracted[df_nonretracted.MAGAID.isin(df_retracted.MAGAID.unique())]
    
    # Dividing into seniority for retracted
    df_retracted_junior = df_retracted[df_retracted.AuthorSeniorityAtRetraction=='early-career author']
    df_retracted_midcareer = df_retracted[df_retracted.AuthorSeniorityAtRetraction=='mid-career author']
    df_retracted_senior = df_retracted[df_retracted.AuthorSeniorityAtRetraction=='senior author']
    # and matched
    df_nonretracted_junior = df_nonretracted[df_nonretracted.AuthorSeniorityAtRetraction=='early-career author']
    df_nonretracted_midcareer = df_nonretracted[df_nonretracted.AuthorSeniorityAtRetraction=='mid-career author']
    df_nonretracted_senior = df_nonretracted[df_nonretracted.AuthorSeniorityAtRetraction=='senior author']
    
    return df_retracted_junior, df_retracted_midcareer, df_retracted_senior, df_nonretracted_junior, df_nonretracted_midcareer, df_nonretracted_senior

# %%
df_rj, df_rm, df_rs, df_nrj, df_nrm, df_nrs = create_stratified_dfs_retention(df_A1_w_firstcollabs_only)

# %%
df_rj.MAGAID.nunique(), df_rm.MAGAID.nunique(), df_rs.MAGAID.nunique(), df_nrj.MAGAID.nunique(), df_nrm.MAGAID.nunique(), df_nrs.MAGAID.nunique()
# Out:
# (162, 86, 152, 162, 86, 152)

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_retention(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtCollaboration':'MatchCollabMAGCumPapersAtCollaboration',
                                    'CollabAcademicAgeAtCollaboration':'MatchCollabAcademicAgeAtCollaboration',
                                    'CollabMAGCumCitationsAtCollaboration': 'MatchCollabMAGCumCitationsAtCollaboration',
                                    'CollabMAGCumCollaboratorsAtCollaboration': 'MatchCollabMAGCumCollaboratorsAtCollaboration'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj, mean_dfnrj = get_mean_df_retention(df_rj, df_nrj)
mean_dfrm, mean_dfnrm = get_mean_df_retention(df_rm, df_nrm)
mean_dfrs, mean_dfnrs = get_mean_df_retention(df_rs, df_nrs)

mean_dfnrj
# Out:
#             MatchCollabAcademicAgeAtCollaboration  \
# MAGAID
# 33433812                                15.333333
# 94287040                                 7.600000
# 183936737                               10.666667
# 206603143                               13.270833
# 298061212                               17.200000
# ...                                           ...
# 2987934803                              16.722222
# 2996120756                              11.962500
# 3049602676                              21.000000
# 3052744139                               8.812500
# 3174447547                              21.000000
#
#             MatchCollabMAGCumPapersAtCollaboration  \
# MAGAID
# 33433812                                 91.000000
# 94287040                                120.400000
# 183936737                                25.333333
# 206603143                               104.308333
# 298061212                               154.400000
# ...                                            ...
# 2987934803                               73.972222
# 2996120756                               60.300000
# 3049602676                               87.000000
# 3052744139                              110.187500
# 3174447547                               78.000000
#
#             MatchCollabMAGCumCitationsAtCollaboration  \
# MAGAID
# 33433812                                   924.000000
# 94287040                                  1556.800000
# 183936737                                 1090.000000
# 206603143                                 1874.112500
# 298061212                                 1413.000000
# ...                                               ...
# 2987934803                                 497.777778
# 2996120756                                1022.666667
# 3049602676                                 285.000000
# 3052744139                                 898.125000
# 3174447547                                 423.000000
#
#             MatchCollabMAGCumCollaboratorsAtCollaboration
# MAGAID
# 33433812                                        76.333333
# 94287040                                       142.200000
# 183936737                                       75.333333
# 206603143                                      347.070833
# 298061212                                      755.800000
# ...                                                   ...
# 2987934803                                     158.555556
# 2996120756                                     147.112500
# 3049602676                                      24.000000
# 3052744139                                     123.250000
# 3174447547                                      81.000000
#
# [162 rows x 4 columns]

# %%
exp_fields = ['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_retention = []

for exp_field in exp_fields:
    dicts_retention = {}
    
    dict_stats_j = get_stats(mean_dfrj, mean_dfnrj, exp_field)
    dict_stats_m = get_stats(mean_dfrm, mean_dfnrm, exp_field)
    dict_stats_s = get_stats(mean_dfrs, mean_dfnrs, exp_field)
    
    dicts_retention['Junior'] = dict_stats_j
    dicts_retention['Mid'] = dict_stats_m
    dicts_retention['Senior'] = dict_stats_s
    
    lst_dicts_retention.append(dicts_retention)

# %%
pd.DataFrame(lst_dicts_retention[0])
# Out:
#                                                     Junior     Mid  Senior
# CollabAcademicAgeAtCollaboration_retracted_mean     12.610  14.630  14.700
# CollabAcademicAgeAtCollaboration_retracted_median   12.000  14.660  15.270
# CollabAcademicAgeAtCollaboration_retracted_std       8.060   6.310   6.690
# CollabAcademicAgeAtCollaboration_nonretracted_mean  14.480  15.860  16.440
# CollabAcademicAgeAtCollaboration_nonretracted_m...  13.170  14.670  14.770
# CollabAcademicAgeAtCollaboration_nonretracted_std    7.030   7.140   7.780
# CollabAcademicAgeAtCollaboration_delta_mean         -1.870  -1.230  -1.740
# CollabAcademicAgeAtCollaboration_pval_welch          0.026   0.232   0.038
# CollabAcademicAgeAtCollaboration_CI_95lower         -3.350  -2.850  -3.250
# CollabAcademicAgeAtCollaboration_CI_95upper         -0.400   0.390  -0.230

# %%
pd.DataFrame(lst_dicts_retention[1])
# Out:
#                                                      Junior     Mid  Senior
# CollabMAGCumPapersAtCollaboration_retracted_mean     68.220  76.440  61.640
# CollabMAGCumPapersAtCollaboration_retracted_median   44.920  63.350  46.170
# CollabMAGCumPapersAtCollaboration_retracted_std      81.330  81.400  71.740
# CollabMAGCumPapersAtCollaboration_nonretracted_...   80.120  78.950  65.820
# CollabMAGCumPapersAtCollaboration_nonretracted_...   61.610  67.750  54.280
# CollabMAGCumPapersAtCollaboration_nonretracted_std  120.230  60.060  60.070
# CollabMAGCumPapersAtCollaboration_delta_mean        -11.900  -2.500  -4.190
# CollabMAGCumPapersAtCollaboration_pval_welch          0.298   0.819   0.582
# CollabMAGCumPapersAtCollaboration_CI_95lower        -34.430 -23.910 -19.380
# CollabMAGCumPapersAtCollaboration_CI_95upper         10.620  18.910  11.010

# %%
pd.DataFrame(lst_dicts_retention[2])
# Out:
#                                                       Junior       Mid  \
# CollabMAGCumCitationsAtCollaboration_retracted_...  1375.150  1451.050
# CollabMAGCumCitationsAtCollaboration_retracted_...   405.500   650.210
# CollabMAGCumCitationsAtCollaboration_retracted_std  2403.440  2106.280
# CollabMAGCumCitationsAtCollaboration_nonretract...  1356.350  1530.510
# CollabMAGCumCitationsAtCollaboration_nonretract...   690.480   846.900
# CollabMAGCumCitationsAtCollaboration_nonretract...  2306.960  2496.010
# CollabMAGCumCitationsAtCollaboration_delta_mean       18.800   -79.460
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.943     0.822
# CollabMAGCumCitationsAtCollaboration_CI_95lower     -467.110  -763.370
# CollabMAGCumCitationsAtCollaboration_CI_95upper      504.710   604.450
#
#                                                       Senior
# CollabMAGCumCitationsAtCollaboration_retracted_...  1600.020
# CollabMAGCumCitationsAtCollaboration_retracted_...   551.750
# CollabMAGCumCitationsAtCollaboration_retracted_std  6538.350
# CollabMAGCumCitationsAtCollaboration_nonretract...  1242.400
# CollabMAGCumCitationsAtCollaboration_nonretract...   496.910
# CollabMAGCumCitationsAtCollaboration_nonretract...  1802.620
# CollabMAGCumCitationsAtCollaboration_delta_mean      357.620
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.517
# CollabMAGCumCitationsAtCollaboration_CI_95lower     -712.490
# CollabMAGCumCitationsAtCollaboration_CI_95upper     1427.720

# %%
pd.DataFrame(lst_dicts_retention[3])
# Out:
#                                                      Junior      Mid   Senior
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  145.930  179.870  167.200
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   77.500  119.620   83.560
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  234.200  176.470  220.150
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  203.740  179.740  143.860
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  100.200  121.230  104.250
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  486.630  181.800  144.350
# CollabMAGCumCollaboratorsAtCollaboration_delta_...  -57.810    0.120   23.340
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...    0.174    0.996    0.275
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l... -143.700  -50.630  -16.770
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...   28.080   50.880   63.450

# %% [markdown]
# ### A2: Collaborators gained: retracted vs. matched

# %%
#Let us now modify df_A1 such that we remove all rows with collaborations pre-retraction

df_A2_post = df_A[df_A['PrePostFlag5']=='post5']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A2_firstcollabs = df_A2_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A2_w_firstcollabs = df_A2_post.merge(df_A2_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A2_w_firstcollabs.shape
# Out:
# (83316, 37)

# %%
# Sensibility checks

df_A2_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#           MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 3472  19100288.0      18011520                2004.0
# 3479  19100288.0     121410733                2004.0
# 3460  19100288.0     410625722                2005.0
# 3473  19100288.0    1235268530                2004.0
# 3482  19100288.0    1340583028                2006.0
# 3454  19100288.0    1793107545                2003.0
# 3455  19100288.0    1793107545                2004.0
# 3474  19100288.0    1859744180                2004.0
# 3456  19100288.0    1863203661                2003.0
# 3457  19100288.0    1863203661                2004.0
# 3459  19100288.0    1863203661                2006.0
# 3458  19100288.0    1863203661                2007.0
# 3451  19100288.0    1986621809                2006.0
# 3450  19100288.0    1986621809                2007.0
# 3475  19100288.0    2004612287                2004.0
# 3466  19100288.0    2043645593                2004.0
# 3467  19100288.0    2043645593                2007.0
# 3480  19100288.0    2051205987                2004.0
# 3485  19100288.0    2078618456                2003.0
# 3486  19100288.0    2111905563                2003.0
# 3471  19100288.0    2115457216                2003.0
# 3468  19100288.0    2115457216                2004.0
# 3470  19100288.0    2115457216                2006.0
# 3469  19100288.0    2115457216                2007.0
# 3462  19100288.0    2128982626                2004.0
# 3461  19100288.0    2128982626                2005.0
# 3463  19100288.0    2128982626                2007.0
# 3476  19100288.0    2134604144                2004.0
# 3481  19100288.0    2149884334                2004.0
# 3464  19100288.0    2151293749                2005.0
#
#       FirstPostRetractionMAGCollaborationYear
# 3472                                   2004.0
# 3479                                   2004.0
# 3460                                   2005.0
# 3473                                   2004.0
# 3482                                   2006.0
# 3454                                   2003.0
# 3455                                   2003.0
# 3474                                   2004.0
# 3456                                   2003.0
# 3457                                   2003.0
# 3459                                   2003.0
# 3458                                   2003.0
# 3451                                   2006.0
# 3450                                   2006.0
# 3475                                   2004.0
# 3466                                   2004.0
# 3467                                   2004.0
# 3480                                   2004.0
# 3485                                   2003.0
# 3486                                   2003.0
# 3471                                   2003.0
# 3468                                   2003.0
# 3470                                   2003.0
# 3469                                   2003.0
# 3462                                   2004.0
# 3461                                   2004.0
# 3463                                   2004.0
# 3476                                   2004.0
# 3481                                   2004.0
# 3464                                   2005.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A2_w_firstcollabs_only = df_A2_w_firstcollabs[df_A2_w_firstcollabs.MAGCollaborationYear == \
                                                df_A2_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A2_w_firstcollabs_only.shape
# Out:
# (63167, 37)

# %%
df_A2_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'MAGAIDFirstORLastAuthorFlag', 'AcademicAgeAtRetraction',
#        'AuthorSeniorityAtRetraction', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#        'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#        'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#        'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
def create_stratified_dfs_gain(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
               'CollabMAGCumPapersAtCollaboration', 'CollabMAGCumCitationsAtCollaboration',
               'CollabMAGCumCollaboratorsAtCollaboration', 'AuthorSeniorityAtRetraction',
               'CollabAcademicAgeAtCollaboration', 'CollabAIDinGained', 'NumNewCollaboratorsW5']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi = dfi[dfi['CollabAIDinGained']]
    
    # Dividing into retracted and matched
    df_retracted = dfi[dfi.ScientistType == 'retracted']
    df_nonretracted = dfi[dfi.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the retracted scientists have matches with non zero collaborators
    df_retracted = df_retracted[df_retracted.MAGAID.isin(df_nonretracted.MAGAID.unique())]
    
    # We need to make sure that the matches of those who retained 0 collaborators are removed
    df_nonretracted = df_nonretracted[df_nonretracted.MAGAID.isin(df_retracted.MAGAID.unique())]
    
    # Dividing into seniority for retracted
    df_retracted_junior = df_retracted[df_retracted.AuthorSeniorityAtRetraction=='early-career author']
    df_retracted_midcareer = df_retracted[df_retracted.AuthorSeniorityAtRetraction=='mid-career author']
    df_retracted_senior = df_retracted[df_retracted.AuthorSeniorityAtRetraction=='senior author']
    # and matched
    df_nonretracted_junior = df_nonretracted[df_nonretracted.AuthorSeniorityAtRetraction=='early-career author']
    df_nonretracted_midcareer = df_nonretracted[df_nonretracted.AuthorSeniorityAtRetraction=='mid-career author']
    df_nonretracted_senior = df_nonretracted[df_nonretracted.AuthorSeniorityAtRetraction=='senior author']
    
    return df_retracted_junior, df_retracted_midcareer, df_retracted_senior,df_nonretracted_junior, df_nonretracted_midcareer, df_nonretracted_senior

# %%
df_rj, df_rm, df_rs, df_nrj, df_nrm, df_nrs = create_stratified_dfs_gain(df_A2_w_firstcollabs_only)

# %%
df_rj.MAGAID.nunique(), df_rm.MAGAID.nunique(), df_rs.MAGAID.nunique(), df_nrj.MAGAID.nunique(), df_nrm.MAGAID.nunique(), df_nrs.MAGAID.nunique()
# Out:
# (169, 97, 145, 169, 97, 145)

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_gain(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtCollaboration':'MatchCollabMAGCumPapersAtCollaboration',
                                    'CollabAcademicAgeAtCollaboration':'MatchCollabAcademicAgeAtCollaboration',
                                    'CollabMAGCumCitationsAtCollaboration': 'MatchCollabMAGCumCitationsAtCollaboration',
                                    'CollabMAGCumCollaboratorsAtCollaboration': 'MatchCollabMAGCumCollaboratorsAtCollaboration'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj, mean_dfnrj = get_mean_df_gain(df_rj, df_nrj)
mean_dfrm, mean_dfnrm = get_mean_df_gain(df_rm, df_nrm)
mean_dfrs, mean_dfnrs = get_mean_df_gain(df_rs, df_nrs)

mean_dfnrj
# Out:
#             MatchCollabAcademicAgeAtCollaboration  \
# MAGAID
# 21686935                                43.000000
# 94287040                                 6.814815
# 183936737                                6.500000
# 206603143                               10.027729
# 291910480                                1.000000
# ...                                           ...
# 2987934803                               7.289866
# 2996120756                               3.067666
# 3037812393                              11.000000
# 3049602676                               0.000000
# 3052744139                               6.987405
#
#             MatchCollabMAGCumPapersAtCollaboration  \
# MAGAID
# 21686935                                 97.000000
# 94287040                                 52.925926
# 183936737                                23.681818
# 206603143                                74.910030
# 291910480                                 2.250000
# ...                                            ...
# 2987934803                               23.298474
# 2996120756                               12.751142
# 3037812393                              136.000000
# 3049602676                                1.000000
# 3052744139                               53.289624
#
#             MatchCollabMAGCumCitationsAtCollaboration  \
# MAGAID
# 21686935                                  1729.000000
# 94287040                                   732.629630
# 183936737                                 1075.681818
# 206603143                                 1431.565466
# 291910480                                    3.000000
# ...                                               ...
# 2987934803                                 223.897741
# 2996120756                                 517.052081
# 3037812393                               12688.000000
# 3049602676                                   0.000000
# 3052744139                                1168.337350
#
#             MatchCollabMAGCumCollaboratorsAtCollaboration
# MAGAID
# 21686935                                       223.000000
# 94287040                                        54.555556
# 183936737                                       99.727273
# 206603143                                      259.011772
# 291910480                                        4.500000
# ...                                                   ...
# 2987934803                                      79.404396
# 2996120756                                      36.953806
# 3037812393                                     481.000000
# 3049602676                                       3.000000
# 3052744139                                     245.023625
#
# [169 rows x 4 columns]

# %%
exp_fields = ['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_gain = []

for exp_field in exp_fields:
    dicts_gain = {}
    
    dict_stats_j = get_stats(mean_dfrj, mean_dfnrj, exp_field)
    dict_stats_m = get_stats(mean_dfrm, mean_dfnrm, exp_field)
    dict_stats_s = get_stats(mean_dfrs, mean_dfnrs, exp_field)
    
    dicts_gain['Junior'] = dict_stats_j
    dicts_gain['Mid'] = dict_stats_m
    dicts_gain['Senior'] = dict_stats_s
    
    lst_dicts_gain.append(dicts_gain)

# %%
pd.DataFrame(lst_dicts_gain[0])
# Out:
#                                                     Junior   Mid  Senior
# CollabAcademicAgeAtCollaboration_retracted_mean      7.070  8.15   8.260
# CollabAcademicAgeAtCollaboration_retracted_median    5.140  8.00   7.860
# CollabAcademicAgeAtCollaboration_retracted_std       7.560  5.08   4.730
# CollabAcademicAgeAtCollaboration_nonretracted_mean   7.730  7.81   8.470
# CollabAcademicAgeAtCollaboration_nonretracted_m...   7.500  7.32   7.740
# CollabAcademicAgeAtCollaboration_nonretracted_std    5.340  4.73   4.730
# CollabAcademicAgeAtCollaboration_delta_mean         -0.660  0.34  -0.210
# CollabAcademicAgeAtCollaboration_pval_welch          0.355  0.63   0.712
# CollabAcademicAgeAtCollaboration_CI_95lower         -1.840 -0.96  -1.230
# CollabAcademicAgeAtCollaboration_CI_95upper          0.520  1.65   0.820

# %%
pd.DataFrame(lst_dicts_gain[1])
# Out:
#                                                     Junior     Mid  Senior
# CollabMAGCumPapersAtCollaboration_retracted_mean    34.080  40.450  35.270
# CollabMAGCumPapersAtCollaboration_retracted_median  17.750  30.530  29.430
# CollabMAGCumPapersAtCollaboration_retracted_std     45.040  33.890  27.020
# CollabMAGCumPapersAtCollaboration_nonretracted_...  36.420  32.420  34.860
# CollabMAGCumPapersAtCollaboration_nonretracted_...  29.400  28.150  29.840
# CollabMAGCumPapersAtCollaboration_nonretracted_std  32.080  25.920  28.910
# CollabMAGCumPapersAtCollaboration_delta_mean        -2.340   8.020   0.400
# CollabMAGCumPapersAtCollaboration_pval_welch         0.583   0.066   0.902
# CollabMAGCumPapersAtCollaboration_CI_95lower       -10.200  -0.160  -5.800
# CollabMAGCumPapersAtCollaboration_CI_95upper         5.530  16.200   6.610

# %%
pd.DataFrame(lst_dicts_gain[2])
# Out:
#                                                       Junior      Mid   Senior
# CollabMAGCumCitationsAtCollaboration_retracted_...   826.740  779.370   759.34
# CollabMAGCumCitationsAtCollaboration_retracted_...   147.570  408.000   493.76
# CollabMAGCumCitationsAtCollaboration_retracted_std  1988.280  942.500   869.04
# CollabMAGCumCitationsAtCollaboration_nonretract...   855.750  585.200   712.43
# CollabMAGCumCitationsAtCollaboration_nonretract...   386.710  303.380   361.32
# CollabMAGCumCitationsAtCollaboration_nonretract...  1426.110  798.070  1313.15
# CollabMAGCumCitationsAtCollaboration_delta_mean      -29.010  194.170    46.91
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.878    0.123     0.72
# CollabMAGCumCitationsAtCollaboration_CI_95lower     -387.280  -42.570  -199.63
# CollabMAGCumCitationsAtCollaboration_CI_95upper      329.270  430.920   293.46

# %%
pd.DataFrame(lst_dicts_gain[3])
# Out:
#                                                      Junior      Mid   Senior
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   95.850  133.360  157.230
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   38.080   74.810   72.320
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  155.450  180.110  295.060
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  110.230   92.450  109.440
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   63.970   57.600   72.500
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  144.510  154.970  139.220
# CollabMAGCumCollaboratorsAtCollaboration_delta_...  -14.380   40.910   47.790
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...    0.379    0.092    0.079
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...  -45.050   -2.980   -3.550
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...   16.300   84.800   99.120

# %%
def create_latex_for_filling(dicto, col):
    
    def create_string(metric):
        string = ""
        if metric == 'pval_welch':
            string = "& " + \
                str(dicto.get('Junior').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Junior').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mid').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mid').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Senior').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Senior').get(col+"_"+metric)) + \
                "\\\ \n"
        else:
            string = "& " + \
                    str(dicto.get('Junior').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Junior').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mid').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mid').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Senior').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Senior').get(col+"_nonretracted_"+metric)) + \
                    "\\\ \n"
        
        
        
        return string
    
    print(create_string("mean"))
    print(create_string("median"))
    print(create_string("std"))
    print(create_string("pval_welch"))
    
# pd.DataFrame(lst_dicts_retention[0])

# %%
for i in range(len(lst_dicts_retention)):
    dicto_retention = lst_dicts_retention[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto_retention, col)
# Out:
# CollabAcademicAgeAtCollaboration
# & 12.61 & 14.48 & 14.63 & 15.86 & 14.7 & 16.44\\
#
# & 12.0 & 13.17 & 14.66 & 14.67 & 15.27 & 14.77\\
#
# & 8.06 & 7.03 & 6.31 & 7.14 & 6.69 & 7.78\\
#
# & 0.026 & 0.026 & 0.232 & 0.232 & 0.038 & 0.038\\
#
# CollabMAGCumPapersAtCollaboration
# & 68.22 & 80.12 & 76.44 & 78.95 & 61.64 & 65.82\\
#
# & 44.92 & 61.61 & 63.35 & 67.75 & 46.17 & 54.28\\
#
# & 81.33 & 120.23 & 81.4 & 60.06 & 71.74 & 60.07\\
#
# & 0.298 & 0.298 & 0.819 & 0.819 & 0.582 & 0.582\\
#
# CollabMAGCumCitationsAtCollaboration
# & 1375.15 & 1356.35 & 1451.05 & 1530.51 & 1600.02 & 1242.4\\
#
# & 405.5 & 690.48 & 650.21 & 846.9 & 551.75 & 496.91\\
#
# & 2403.44 & 2306.96 & 2106.28 & 2496.01 & 6538.35 & 1802.62\\
#
# & 0.943 & 0.943 & 0.822 & 0.822 & 0.517 & 0.517\\
#
# CollabMAGCumCollaboratorsAtCollaboration
# & 145.93 & 203.74 & 179.87 & 179.74 & 167.2 & 143.86\\
#
# & 77.5 & 100.2 & 119.62 & 121.23 & 83.56 & 104.25\\
#
# & 234.2 & 486.63 & 176.47 & 181.8 & 220.15 & 144.35\\
#
# & 0.174 & 0.174 & 0.996 & 0.996 & 0.275 & 0.275\\

# %%
for i in range(len(lst_dicts_gain)):
    dicto_gain = lst_dicts_gain[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto_gain, col)
# Out:
# CollabAcademicAgeAtCollaboration
# & 7.07 & 7.73 & 8.15 & 7.81 & 8.26 & 8.47\\
#
# & 5.14 & 7.5 & 8.0 & 7.32 & 7.86 & 7.74\\
#
# & 7.56 & 5.34 & 5.08 & 4.73 & 4.73 & 4.73\\
#
# & 0.355 & 0.355 & 0.63 & 0.63 & 0.712 & 0.712\\
#
# CollabMAGCumPapersAtCollaboration
# & 34.08 & 36.42 & 40.45 & 32.42 & 35.27 & 34.86\\
#
# & 17.75 & 29.4 & 30.53 & 28.15 & 29.43 & 29.84\\
#
# & 45.04 & 32.08 & 33.89 & 25.92 & 27.02 & 28.91\\
#
# & 0.583 & 0.583 & 0.066 & 0.066 & 0.902 & 0.902\\
#
# CollabMAGCumCitationsAtCollaboration
# & 826.74 & 855.75 & 779.37 & 585.2 & 759.34 & 712.43\\
#
# & 147.57 & 386.71 & 408.0 & 303.38 & 493.76 & 361.32\\
#
# & 1988.28 & 1426.11 & 942.5 & 798.07 & 869.04 & 1313.15\\
#
# & 0.878 & 0.878 & 0.123 & 0.123 & 0.72 & 0.72\\
#
# CollabMAGCumCollaboratorsAtCollaboration
# & 95.85 & 110.23 & 133.36 & 92.45 & 157.23 & 109.44\\
#
# & 38.08 & 63.97 & 74.81 & 57.6 & 72.32 & 72.5\\
#
# & 155.45 & 144.51 & 180.11 & 154.97 & 295.06 & 139.22\\
#
# & 0.379 & 0.379 & 0.092 & 0.092 & 0.079 & 0.079\\

# %%
dicto_retention
# Out:
# {'Junior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 145.93,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 77.5,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 234.2,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 203.74,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 100.2,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 486.63,
#   'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -57.81,
#   'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.174,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -143.7,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 28.08},
#  'Mid': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 179.87,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 119.62,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 176.47,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 179.74,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 121.23,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 181.8,
#   'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 0.12,
#   'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.996,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -50.63,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 50.88},
#  'Senior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 167.2,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 83.56,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 220.15,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 143.86,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 104.25,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 144.35,
#   'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 23.34,
#   'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.275,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -16.77,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 63.45}}

# %%
dicto_gain
# Out:
# {'Junior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 95.85,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 38.08,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 155.45,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 110.23,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 63.97,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 144.51,
#   'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -14.38,
#   'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.379,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -45.05,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 16.3},
#  'Mid': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 133.36,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.81,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 180.11,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 92.45,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 57.6,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 154.97,
#   'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 40.91,
#   'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.092,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -2.98,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 84.8},
#  'Senior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 157.23,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 72.32,
#   'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 295.06,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 109.44,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 72.5,
#   'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 139.22,
#   'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 47.79,
#   'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.079,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -3.55,
#   'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 99.12}}

# %% [markdown]
# ### A3: Collaborators retained vs lost: retracted vs. matched

# %%
#Let us now modify df_A3 such that we remove all rows with collaborations pre-retraction

df_A3_post = df_A[df_A['PrePostFlag5']=='post5']
df_A3_pre = df_A[df_A['PrePostFlag5']=='pre']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A3_firstcollabs = df_A3_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A3_w_firstcollabs = df_A3_post.merge(df_A1_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A3_w_firstcollabs.shape
# Out:
# (83316, 37)

# %%
# Sensibility checks

df_A3_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#           MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 3472  19100288.0      18011520                2004.0
# 3479  19100288.0     121410733                2004.0
# 3460  19100288.0     410625722                2005.0
# 3473  19100288.0    1235268530                2004.0
# 3482  19100288.0    1340583028                2006.0
# 3454  19100288.0    1793107545                2003.0
# 3455  19100288.0    1793107545                2004.0
# 3474  19100288.0    1859744180                2004.0
# 3456  19100288.0    1863203661                2003.0
# 3457  19100288.0    1863203661                2004.0
# 3459  19100288.0    1863203661                2006.0
# 3458  19100288.0    1863203661                2007.0
# 3451  19100288.0    1986621809                2006.0
# 3450  19100288.0    1986621809                2007.0
# 3475  19100288.0    2004612287                2004.0
# 3466  19100288.0    2043645593                2004.0
# 3467  19100288.0    2043645593                2007.0
# 3480  19100288.0    2051205987                2004.0
# 3485  19100288.0    2078618456                2003.0
# 3486  19100288.0    2111905563                2003.0
# 3471  19100288.0    2115457216                2003.0
# 3468  19100288.0    2115457216                2004.0
# 3470  19100288.0    2115457216                2006.0
# 3469  19100288.0    2115457216                2007.0
# 3462  19100288.0    2128982626                2004.0
# 3461  19100288.0    2128982626                2005.0
# 3463  19100288.0    2128982626                2007.0
# 3476  19100288.0    2134604144                2004.0
# 3481  19100288.0    2149884334                2004.0
# 3464  19100288.0    2151293749                2005.0
#
#       FirstPostRetractionMAGCollaborationYear
# 3472                                   2004.0
# 3479                                   2004.0
# 3460                                   2005.0
# 3473                                   2004.0
# 3482                                   2006.0
# 3454                                   2003.0
# 3455                                   2003.0
# 3474                                   2004.0
# 3456                                   2003.0
# 3457                                   2003.0
# 3459                                   2003.0
# 3458                                   2003.0
# 3451                                   2006.0
# 3450                                   2006.0
# 3475                                   2004.0
# 3466                                   2004.0
# 3467                                   2004.0
# 3480                                   2004.0
# 3485                                   2003.0
# 3486                                   2003.0
# 3471                                   2003.0
# 3468                                   2003.0
# 3470                                   2003.0
# 3469                                   2003.0
# 3462                                   2004.0
# 3461                                   2004.0
# 3463                                   2004.0
# 3476                                   2004.0
# 3481                                   2004.0
# 3464                                   2005.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A3_w_firstcollabs_only = df_A3_w_firstcollabs[df_A3_w_firstcollabs.MAGCollaborationYear == \
                                                df_A3_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A3_w_firstcollabs_only.shape
# Out:
# (63167, 37)

# %%
df_A3_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'MAGAIDFirstORLastAuthorFlag', 'AcademicAgeAtRetraction',
#        'AuthorSeniorityAtRetraction', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#        'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#        'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#        'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
# Finally let us merge post and pre

df_A3_post_pre = pd.concat([df_A3_w_firstcollabs_only,df_A3_pre])

df_A3_post_pre.head()
# Out:
#           MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 2   2.033335e+09    1917877966          1995.0                1998.0
# 4   2.033335e+09    2169118091          1995.0                1998.0
# 7   2.033335e+09     275085591          1995.0                1996.0
# 9   2.033335e+09    2111014462          1995.0                1996.0
# 12  2.033335e+09    2622920657          1995.0                1996.0
#
#    ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 2      retracted                  male                       0.99
# 4      retracted                  male                       1.00
# 7      retracted                  male                       0.99
# 9      retracted                female                       0.98
# 12     retracted                  male                       0.99
#
#     CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 2                  1994.0                              1994.0
# 4                  1995.0                              1995.0
# 7                  1994.0                              1995.0
# 9                  1988.0                              1995.0
# 12                 1991.0                              1995.0
#
#     CollabMAGCumPapersAtRetraction  ...  \
# 2                              1.0  ...
# 4                              1.0  ...
# 7                              5.0  ...
# 9                             17.0  ...
# 12                            17.0  ...
#
#                                                   pre  NumRetentionW5  \
# 2   {2041262087, 2590561305, 1940968476, 211428099...              23
# 4   {2041262087, 2590561305, 1940968476, 211428099...              23
# 7   {2041262087, 2590561305, 1940968476, 211428099...              23
# 9   {2041262087, 2590561305, 1940968476, 211428099...              23
# 12  {2041262087, 2590561305, 1940968476, 211428099...              23
#
#                                   CollabAIDRetainedW5  \
# 2   {2690057605, 2041262087, 2466141063, 230478619...
# 4   {2690057605, 2041262087, 2466141063, 230478619...
# 7   {2690057605, 2041262087, 2466141063, 230478619...
# 9   {2690057605, 2041262087, 2466141063, 230478619...
# 12  {2690057605, 2041262087, 2466141063, 230478619...
#
#                                       CollabAIDLostW5  NumNewCollaboratorsW5  \
# 2   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 4   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 7   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 9   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 12  {2590561305, 1940968476, 2657016352, 265692164...                     60
#
#                                     CollabAIDGainedW5  CollabAIDinRetained  \
# 2   {1973921793, 2308182914, 1147890307, 265602649...                False
# 4   {1973921793, 2308182914, 1147890307, 265602649...                False
# 7   {1973921793, 2308182914, 1147890307, 265602649...                 True
# 9   {1973921793, 2308182914, 1147890307, 265602649...                 True
# 12  {1973921793, 2308182914, 1147890307, 265602649...                 True
#
#     CollabAIDinGained  CollabAIDinLost  \
# 2                True            False
# 4                True            False
# 7               False            False
# 9               False            False
# 12              False            False
#
#     FirstPostRetractionMAGCollaborationYear
# 2                                    1998.0
# 4                                    1998.0
# 7                                    1996.0
# 9                                    1996.0
# 12                                   1996.0
#
# [5 rows x 37 columns]

# %%
def create_stratified_dfs_a3(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear',
               'CollabMAGCumPapersAtRetraction', 'CollabMAGCumCitationsAtRetraction',
               'CollabMAGCumCollaboratorsAtRetraction', 'AuthorSeniorityAtRetraction',
               'CollabAcademicAgeAtRetraction', 'CollabAIDinRetained', 'CollabAIDinLost']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi_retained = dfi[dfi['CollabAIDinRetained']]
    dfi_lost = dfi[dfi['CollabAIDinLost']]
    
    # Dividing into retracted and matched
    df_retracted_retained = dfi_retained[dfi_retained.ScientistType == 'retracted']
    df_retracted_lost = dfi_lost[dfi_lost.ScientistType == 'retracted']
    
    df_nonretracted_retained = dfi_retained[dfi_retained.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    df_nonretracted_lost = dfi_lost[dfi_lost.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the four groups retracted,non-retracted,retained,lost have same ids
    
    set1 = set(df_retracted_retained['MAGAID'].unique())
    set2 = set(df_retracted_lost['MAGAID'].unique())
    set3 = set(df_nonretracted_retained['MAGAID'].unique())
    set4 = set(df_nonretracted_lost['MAGAID'].unique())
    
    magaids_intersection = set1.intersection(set2, set3, set4)
    
    df_retracted_retained = df_retracted_retained[df_retracted_retained.MAGAID.isin(magaids_intersection)]
    df_retracted_lost = df_retracted_lost[df_retracted_lost.MAGAID.isin(magaids_intersection)]
    df_nonretracted_retained = df_nonretracted_retained[df_nonretracted_retained.MAGAID.isin(magaids_intersection)]
    df_nonretracted_lost = df_nonretracted_lost[df_nonretracted_lost.MAGAID.isin(magaids_intersection)]

    
    # Dividing into seniority for retracted retained
    
    dfrj_r = df_retracted_retained[df_retracted_retained.AuthorSeniorityAtRetraction=='early-career author']
    dfrm_r = df_retracted_retained[df_retracted_retained.AuthorSeniorityAtRetraction=='mid-career author']
    dfrs_r = df_retracted_retained[df_retracted_retained.AuthorSeniorityAtRetraction=='senior author']
    
    dfrj_l = df_retracted_lost[df_retracted_lost.AuthorSeniorityAtRetraction=='early-career author']
    dfrm_l = df_retracted_lost[df_retracted_lost.AuthorSeniorityAtRetraction=='mid-career author']
    dfrs_l = df_retracted_lost[df_retracted_lost.AuthorSeniorityAtRetraction=='senior author']
    
    # and matched
    dfnrj_r = df_nonretracted_retained[df_nonretracted_retained.AuthorSeniorityAtRetraction=='early-career author']
    dfnrm_r = df_nonretracted_retained[df_nonretracted_retained.AuthorSeniorityAtRetraction=='mid-career author']
    dfnrs_r = df_nonretracted_retained[df_nonretracted_retained.AuthorSeniorityAtRetraction=='senior author']
    
    dfnrj_l = df_nonretracted_lost[df_nonretracted_lost.AuthorSeniorityAtRetraction=='early-career author']
    dfnrm_l = df_nonretracted_lost[df_nonretracted_lost.AuthorSeniorityAtRetraction=='mid-career author']
    dfnrs_l = df_nonretracted_lost[df_nonretracted_lost.AuthorSeniorityAtRetraction=='senior author']
    
    return [dfrj_r,dfrm_r,dfrs_r,dfrj_l,dfrm_l,dfrs_l,dfnrj_r,dfnrm_r,dfnrs_r,dfnrj_l,dfnrm_l,dfnrs_l]

# %%
lst_stratified_dfs = create_stratified_dfs_a3(df_A3_post_pre)

for dfj in lst_stratified_dfs:
    print(dfj.MAGAID.nunique())
    
dfrj_r,dfrm_r,dfrs_r,dfrj_l,dfrm_l,dfrs_l,dfnrj_r,dfnrm_r,dfnrs_r,dfnrj_l,dfnrm_l,dfnrs_l = lst_stratified_dfs
# Out:
# 146
# 85
# 152
# 146
# 85
# 152
# 146
# 85
# 152
# 146
# 85
# 152

# %%
dfrj_r
# Out:
#              MAGAID ScientistType  MAGCollabAID  RetractionYear  \
# 5012   2.703327e+09     retracted    1974151439          1999.0
# 5016   2.703327e+09     retracted    2307543124          1999.0
# 6698   2.098044e+09     retracted    2104946485          2007.0
# 6699   2.098044e+09     retracted    2131257641          2007.0
# 6700   2.098044e+09     retracted    2145415599          2007.0
# ...             ...           ...           ...             ...
# 52252  2.114194e+09     retracted    2612188761          2015.0
# 52257  2.114194e+09     retracted    2693916240          2015.0
# 52420  2.569982e+09     retracted    2113686342          2007.0
# 52424  2.569982e+09     retracted    2566957369          2007.0
# 52437  2.569982e+09     retracted     707565557          2007.0
#
#        CollabMAGCumPapersAtRetraction  CollabMAGCumCitationsAtRetraction  \
# 5012                            110.0                             4437.0
# 5016                              1.0                                5.0
# 6698                              4.0                               29.0
# 6699                            152.0                             1344.0
# 6700                             51.0                              723.0
# ...                               ...                                ...
# 52252                             4.0                                9.0
# 52257                             2.0                                3.0
# 52420                            38.0                             4192.0
# 52424                           106.0                            14090.0
# 52437                            86.0                             1353.0
#
#        CollabMAGCumCollaboratorsAtRetraction AuthorSeniorityAtRetraction  \
# 5012                                   170.0         early-career author
# 5016                                     3.0         early-career author
# 6698                                     8.0         early-career author
# 6699                                   180.0         early-career author
# 6700                                    61.0         early-career author
# ...                                      ...                         ...
# 52252                                   17.0         early-career author
# 52257                                   13.0         early-career author
# 52420                                  109.0         early-career author
# 52424                                  250.0         early-career author
# 52437                                  392.0         early-career author
#
#        CollabAcademicAgeAtRetraction  CollabAIDinRetained  CollabAIDinLost
# 5012                            26.0                 True            False
# 5016                             2.0                 True            False
# 6698                             5.0                 True            False
# 6699                            29.0                 True            False
# 6700                            33.0                 True            False
# ...                              ...                  ...              ...
# 52252                            1.0                 True            False
# 52257                            1.0                 True            False
# 52420                           36.0                 True            False
# 52424                           33.0                 True            False
# 52437                           14.0                 True            False
#
# [645 rows x 11 columns]

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_a3(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtRetraction',
                      'CollabMAGCumPapersAtRetraction',
                      'CollabMAGCumCitationsAtRetraction',
                      'CollabMAGCumCollaboratorsAtRetraction']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtRetraction',
                      'CollabMAGCumPapersAtRetraction',
                      'CollabMAGCumCitationsAtRetraction',
                      'CollabMAGCumCollaboratorsAtRetraction']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtRetraction':'MatchCollabMAGCumPapersAtRetraction',
                                    'CollabAcademicAgeAtRetraction':'MatchCollabAcademicAgeAtRetraction',
                                    'CollabMAGCumCitationsAtRetraction': 'MatchCollabMAGCumCitationsAtRetraction',
                                    'CollabMAGCumCollaboratorsAtRetraction': 'MatchCollabMAGCumCollaboratorsAtRetraction'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

# for junior
mean_dfrj_r, mean_dfnrj_r = get_mean_df_a3(dfrj_r, dfnrj_r) # for retained
mean_dfrj_l, mean_dfnrj_l = get_mean_df_a3(dfrj_l, dfnrj_l) # for lost

# for mid-rank
mean_dfrm_r, mean_dfnrm_r = get_mean_df_a3(dfrm_r, dfnrm_r) 
mean_dfrm_l, mean_dfnrm_l = get_mean_df_a3(dfrm_l, dfnrm_l)

# for senior
mean_dfrs_r, mean_dfnrs_r = get_mean_df_a3(dfrs_r, dfnrs_r)
mean_dfrs_l, mean_dfnrs_l = get_mean_df_a3(dfrs_l, dfnrs_l)


# Now let us compute differences

def compute_diff_df(df_ri, df_li, scientistType='retracted'):
    
    dfrli = df_ri.merge(df_li, right_index=True, left_index=True)
    
    if scientistType == 'matched':
        
        dfrli['MatchDiffAcademicAgeAtRetraction'] = dfrli['MatchCollabAcademicAgeAtRetraction_x'] - \
                                                dfrli['MatchCollabAcademicAgeAtRetraction_y']
        
        dfrli['MatchDiffMAGCumPapersAtRetraction'] = dfrli['MatchCollabMAGCumPapersAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumPapersAtRetraction_y']
        
        dfrli['MatchDiffMAGCumCitationsAtRetraction'] = dfrli['MatchCollabMAGCumCitationsAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumCitationsAtRetraction_y']
        
        dfrli['MatchDiffMAGCumCollaboratorsAtRetraction'] = dfrli['MatchCollabMAGCumCollaboratorsAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumCollaboratorsAtRetraction_y']
        
        return dfrli
    
        
    dfrli['DiffAcademicAgeAtRetraction'] = dfrli['CollabAcademicAgeAtRetraction_x'] - \
                                            dfrli['CollabAcademicAgeAtRetraction_y']

    dfrli['DiffMAGCumPapersAtRetraction'] = dfrli['CollabMAGCumPapersAtRetraction_x'] - \
                                            dfrli['CollabMAGCumPapersAtRetraction_y']

    dfrli['DiffMAGCumCitationsAtRetraction'] = dfrli['CollabMAGCumCitationsAtRetraction_x'] - \
                                            dfrli['CollabMAGCumCitationsAtRetraction_y']

    dfrli['DiffMAGCumCollaboratorsAtRetraction'] = dfrli['CollabMAGCumCollaboratorsAtRetraction_x'] - \
                                            dfrli['CollabMAGCumCollaboratorsAtRetraction_y']

    return dfrli

# %%
dfrj_rMinusl = compute_diff_df(mean_dfrj_r, mean_dfrj_l)
dfnrj_rMinusl = compute_diff_df(mean_dfnrj_r, mean_dfnrj_l, scientistType='matched')


dfrm_rMinusl = compute_diff_df(mean_dfrm_r, mean_dfrm_l)
dfnrm_rMinusl = compute_diff_df(mean_dfnrm_r, mean_dfnrm_l, scientistType='matched')

dfrs_rMinusl = compute_diff_df(mean_dfrs_r, mean_dfrs_l)
dfnrs_rMinusl = compute_diff_df(mean_dfnrs_r, mean_dfnrs_l, scientistType='matched')

# %%
dfrj_rMinusl
# Out:
#               CollabAcademicAgeAtRetraction_x  \
# MAGAID
# 3.343381e+07                        12.500000
# 9.428704e+07                        13.000000
# 1.839367e+08                        17.375000
# 2.066031e+08                         6.666667
# 3.474066e+08                        13.000000
# ...                                       ...
# 2.955031e+09                        13.560000
# 2.987935e+09                         1.666667
# 2.996121e+09                        11.800000
# 3.052744e+09                         3.200000
# 3.174448e+09                        20.000000
#
#               CollabMAGCumPapersAtRetraction_x  \
# MAGAID
# 3.343381e+07                         39.250000
# 9.428704e+07                         16.500000
# 1.839367e+08                         33.500000
# 2.066031e+08                         37.416667
# 3.474066e+08                         40.000000
# ...                                        ...
# 2.955031e+09                         74.680000
# 2.987935e+09                          2.000000
# 2.996121e+09                         30.600000
# 3.052744e+09                          4.800000
# 3.174448e+09                        174.000000
#
#               CollabMAGCumCitationsAtRetraction_x  \
# MAGAID
# 3.343381e+07                           242.250000
# 9.428704e+07                           161.500000
# 1.839367e+08                           882.375000
# 2.066031e+08                           245.250000
# 3.474066e+08                           738.000000
# ...                                           ...
# 2.955031e+09                          1704.280000
# 2.987935e+09                             3.666667
# 2.996121e+09                            63.600000
# 3.052744e+09                             5.800000
# 3.174448e+09                           544.000000
#
#               CollabMAGCumCollaboratorsAtRetraction_x  \
# MAGAID
# 3.343381e+07                                23.000000
# 9.428704e+07                                15.500000
# 1.839367e+08                                67.500000
# 2.066031e+08                               252.000000
# 3.474066e+08                                40.000000
# ...                                               ...
# 2.955031e+09                               314.520000
# 2.987935e+09                                 8.333333
# 2.996121e+09                                82.800000
# 3.052744e+09                                 8.800000
# 3.174448e+09                               249.000000
#
#               CollabAcademicAgeAtRetraction_y  \
# MAGAID
# 3.343381e+07                         4.333333
# 9.428704e+07                         3.300000
# 1.839367e+08                        16.000000
# 2.066031e+08                         4.200000
# 3.474066e+08                        19.750000
# ...                                       ...
# 2.955031e+09                        12.538462
# 2.987935e+09                         0.666667
# 2.996121e+09                         3.300000
# 3.052744e+09                        18.000000
# 3.174448e+09                        27.200000
#
#               CollabMAGCumPapersAtRetraction_y  \
# MAGAID
# 3.343381e+07                          9.333333
# 9.428704e+07                          5.200000
# 1.839367e+08                         24.625000
# 2.066031e+08                         29.000000
# 3.474066e+08                         57.000000
# ...                                        ...
# 2.955031e+09                         43.769231
# 2.987935e+09                          2.000000
# 2.996121e+09                         56.600000
# 3.052744e+09                        113.000000
# 3.174448e+09                         99.200000
#
#               CollabMAGCumCitationsAtRetraction_y  \
# MAGAID
# 3.343381e+07                            32.666667
# 9.428704e+07                            14.200000
# 1.839367e+08                           247.250000
# 2.066031e+08                           121.600000
# 3.474066e+08                           971.250000
# ...                                           ...
# 2.955031e+09                           743.384615
# 2.987935e+09                             0.666667
# 2.996121e+09                           617.300000
# 3.052744e+09                           537.500000
# 3.174448e+09                           686.000000
#
#               CollabMAGCumCollaboratorsAtRetraction_y  \
# MAGAID
# 3.343381e+07                                14.000000
# 9.428704e+07                                 9.800000
# 1.839367e+08                               105.375000
# 2.066031e+08                               312.200000
# 3.474066e+08                                49.750000
# ...                                               ...
# 2.955031e+09                               218.000000
# 2.987935e+09                                 5.333333
# 2.996121e+09                               126.100000
# 3.052744e+09                                48.000000
# 3.174448e+09                               238.400000
#
#               DiffAcademicAgeAtRetraction  DiffMAGCumPapersAtRetraction  \
# MAGAID
# 3.343381e+07                     8.166667                     29.916667
# 9.428704e+07                     9.700000                     11.300000
# 1.839367e+08                     1.375000                      8.875000
# 2.066031e+08                     2.466667                      8.416667
# 3.474066e+08                    -6.750000                    -17.000000
# ...                                   ...                           ...
# 2.955031e+09                     1.021538                     30.910769
# 2.987935e+09                     1.000000                      0.000000
# 2.996121e+09                     8.500000                    -26.000000
# 3.052744e+09                   -14.800000                   -108.200000
# 3.174448e+09                    -7.200000                     74.800000
#
#               DiffMAGCumCitationsAtRetraction  \
# MAGAID
# 3.343381e+07                       209.583333
# 9.428704e+07                       147.300000
# 1.839367e+08                       635.125000
# 2.066031e+08                       123.650000
# 3.474066e+08                      -233.250000
# ...                                       ...
# 2.955031e+09                       960.895385
# 2.987935e+09                         3.000000
# 2.996121e+09                      -553.700000
# 3.052744e+09                      -531.700000
# 3.174448e+09                      -142.000000
#
#               DiffMAGCumCollaboratorsAtRetraction
# MAGAID
# 3.343381e+07                                9.000
# 9.428704e+07                                5.700
# 1.839367e+08                              -37.875
# 2.066031e+08                              -60.200
# 3.474066e+08                               -9.750
# ...                                           ...
# 2.955031e+09                               96.520
# 2.987935e+09                                3.000
# 2.996121e+09                              -43.300
# 3.052744e+09                              -39.200
# 3.174448e+09                               10.600
#
# [146 rows x 12 columns]

# %%
exp_fields = ['DiffAcademicAgeAtRetraction',
              'DiffMAGCumPapersAtRetraction',
              'DiffMAGCumCitationsAtRetraction',
              'DiffMAGCumCollaboratorsAtRetraction']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_a3 = []

# For age, papers, cites, collabs
for exp_field in exp_fields:
    dicts_a3 = {}
    # we compute the stats for junior, mid, and senior
    dict_stats_j = get_stats(dfrj_rMinusl, dfnrj_rMinusl, exp_field)
    dict_stats_m = get_stats(dfrm_rMinusl, dfnrm_rMinusl, exp_field)
    dict_stats_s = get_stats(dfrs_rMinusl, dfnrs_rMinusl, exp_field)
    
    dicts_a3['Junior'] = dict_stats_j
    dicts_a3['Mid'] = dict_stats_m
    dicts_a3['Senior'] = dict_stats_s
    
    lst_dicts_a3.append(dicts_a3)

# %%
pd.DataFrame(lst_dicts_a3[0])
# Out:
#                                                  Junior    Mid  Senior
# DiffAcademicAgeAtRetraction_retracted_mean        3.050  3.190  -0.730
# DiffAcademicAgeAtRetraction_retracted_median      2.470  2.730  -0.010
# DiffAcademicAgeAtRetraction_retracted_std         9.780  6.030   5.810
# DiffAcademicAgeAtRetraction_nonretracted_mean     3.890  4.080   0.540
# DiffAcademicAgeAtRetraction_nonretracted_median   3.180  3.540   0.060
# DiffAcademicAgeAtRetraction_nonretracted_std      6.830  6.590   7.080
# DiffAcademicAgeAtRetraction_delta_mean           -0.840 -0.890  -1.280
# DiffAcademicAgeAtRetraction_pval_welch            0.397  0.362   0.087
# DiffAcademicAgeAtRetraction_CI_95lower           -2.680 -2.390  -2.780
# DiffAcademicAgeAtRetraction_CI_95upper            1.000  0.620   0.220

# %%
pd.DataFrame(lst_dicts_a3[1])
# Out:
#                                                    Junior     Mid  Senior
# DiffMAGCumPapersAtRetraction_retracted_mean        26.230  22.860  13.250
# DiffMAGCumPapersAtRetraction_retracted_median       9.390   9.190   6.020
# DiffMAGCumPapersAtRetraction_retracted_std         71.830  68.390  47.800
# DiffMAGCumPapersAtRetraction_nonretracted_mean     28.850  29.000  19.170
# DiffMAGCumPapersAtRetraction_nonretracted_median   16.530  21.500   9.640
# DiffMAGCumPapersAtRetraction_nonretracted_std     100.540  45.090  52.600
# DiffMAGCumPapersAtRetraction_delta_mean            -2.620  -6.140  -5.920
# DiffMAGCumPapersAtRetraction_pval_welch             0.798   0.491   0.305
# DiffMAGCumPapersAtRetraction_CI_95lower           -23.020 -24.290 -18.000
# DiffMAGCumPapersAtRetraction_CI_95upper            17.780  12.010   6.160

# %%
pd.DataFrame(lst_dicts_a3[2])
# Out:
#                                                       Junior       Mid  \
# DiffMAGCumCitationsAtRetraction_retracted_mean       439.080    33.320
# DiffMAGCumCitationsAtRetraction_retracted_median      60.420    -4.980
# DiffMAGCumCitationsAtRetraction_retracted_std       1988.350  1621.720
# DiffMAGCumCitationsAtRetraction_nonretracted_mean    332.560   423.130
# DiffMAGCumCitationsAtRetraction_nonretracted_me...   115.260   118.410
# DiffMAGCumCitationsAtRetraction_nonretracted_std    1576.830  1646.590
# DiffMAGCumCitationsAtRetraction_delta_mean           106.530  -389.810
# DiffMAGCumCitationsAtRetraction_pval_welch             0.612     0.122
# DiffMAGCumCitationsAtRetraction_CI_95lower          -299.500  -948.010
# DiffMAGCumCitationsAtRetraction_CI_95upper           512.560   168.400
#
#                                                       Senior
# DiffMAGCumCitationsAtRetraction_retracted_mean       238.650
# DiffMAGCumCitationsAtRetraction_retracted_median      -0.760
# DiffMAGCumCitationsAtRetraction_retracted_std       3374.010
# DiffMAGCumCitationsAtRetraction_nonretracted_mean    247.340
# DiffMAGCumCitationsAtRetraction_nonretracted_me...   -20.150
# DiffMAGCumCitationsAtRetraction_nonretracted_std    1370.700
# DiffMAGCumCitationsAtRetraction_delta_mean            -8.690
# DiffMAGCumCitationsAtRetraction_pval_welch             0.977
# DiffMAGCumCitationsAtRetraction_CI_95lower          -603.620
# DiffMAGCumCitationsAtRetraction_CI_95upper           586.240

# %%
pd.DataFrame(lst_dicts_a3[3])
# Out:
#                                                      Junior      Mid   Senior
# DiffMAGCumCollaboratorsAtRetraction_retracted_mean   35.470   11.100   20.300
# DiffMAGCumCollaboratorsAtRetraction_retracted_m...   13.650   15.000    3.730
# DiffMAGCumCollaboratorsAtRetraction_retracted_std   227.240  136.110  147.360
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...   59.860   58.240   25.480
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...   21.390   24.250   13.400
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...  341.140  136.260  124.140
# DiffMAGCumCollaboratorsAtRetraction_delta_mean      -24.400  -47.140   -5.180
# DiffMAGCumCollaboratorsAtRetraction_pval_welch        0.473    0.025    0.741
# DiffMAGCumCollaboratorsAtRetraction_CI_95lower      -94.690  -90.160  -37.520
# DiffMAGCumCollaboratorsAtRetraction_CI_95upper       45.900   -4.120   27.160

# %%
def create_latex_for_filling(dicto, col):
    
    def create_string(metric):
        string = ""
        if metric == 'pval_welch':
            string = "& " + \
                str(dicto.get('Junior').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Junior').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mid').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mid').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Senior').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Senior').get(col+"_"+metric)) + \
                "\\\ \n"
        else:
            string = "& " + \
                    str(dicto.get('Junior').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Junior').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mid').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mid').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Senior').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Senior').get(col+"_nonretracted_"+metric)) + \
                    "\\\ \n"
        
        
        
        return string
    
    print(create_string("mean"))
    print(create_string("median"))
    print(create_string("std"))
    print(create_string("pval_welch"))



for i in range(len(lst_dicts_a3)):
    dicto_did = lst_dicts_a3[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto_did, col)
# Out:
# DiffAcademicAgeAtRetraction
# & 3.05 & 3.89 & 3.19 & 4.08 & -0.73 & 0.54\\
#
# & 2.47 & 3.18 & 2.73 & 3.54 & -0.01 & 0.06\\
#
# & 9.78 & 6.83 & 6.03 & 6.59 & 5.81 & 7.08\\
#
# & 0.397 & 0.397 & 0.362 & 0.362 & 0.087 & 0.087\\
#
# DiffMAGCumPapersAtRetraction
# & 26.23 & 28.85 & 22.86 & 29.0 & 13.25 & 19.17\\
#
# & 9.39 & 16.53 & 9.19 & 21.5 & 6.02 & 9.64\\
#
# & 71.83 & 100.54 & 68.39 & 45.09 & 47.8 & 52.6\\
#
# & 0.798 & 0.798 & 0.491 & 0.491 & 0.305 & 0.305\\
#
# DiffMAGCumCitationsAtRetraction
# & 439.08 & 332.56 & 33.32 & 423.13 & 238.65 & 247.34\\
#
# & 60.42 & 115.26 & -4.98 & 118.41 & -0.76 & -20.15\\
#
# & 1988.35 & 1576.83 & 1621.72 & 1646.59 & 3374.01 & 1370.7\\
#
# & 0.612 & 0.612 & 0.122 & 0.122 & 0.977 & 0.977\\
#
# DiffMAGCumCollaboratorsAtRetraction
# & 35.47 & 59.86 & 11.1 & 58.24 & 20.3 & 25.48\\
#
# & 13.65 & 21.39 & 15.0 & 24.25 & 3.73 & 13.4\\
#
# & 227.24 & 341.14 & 136.11 & 136.26 & 147.36 & 124.14\\
#
# & 0.473 & 0.473 & 0.025 & 0.025 & 0.741 & 0.741\\

# %%
dicto_did
# Out:
# {'Junior': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 35.47,
#   'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 13.65,
#   'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 227.24,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 59.86,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 21.39,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 341.14,
#   'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -24.4,
#   'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.473,
#   'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -94.69,
#   'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 45.9},
#  'Mid': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 11.1,
#   'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 15.0,
#   'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 136.11,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 58.24,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 24.25,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 136.26,
#   'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -47.14,
#   'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.025,
#   'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -90.16,
#   'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': -4.12},
#  'Senior': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 20.3,
#   'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 3.73,
#   'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 147.36,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 25.48,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 13.4,
#   'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 124.14,
#   'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -5.18,
#   'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.741,
#   'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -37.52,
#   'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 27.16}}

# %% [markdown]
# # Preprocessing dictionaries for plots

# %%
expfield_categories = ['Academic Age','Number of Papers',
                       'Number of Citations', 'Number of Collaborators']

master_dict = {}

master_dict['Retention'] = {}

for i in range(len(expfield_categories)):
    master_dict['Retention'][expfield_categories[i]] = lst_dicts_retention[i]

master_dict['Gain'] = {}

for i in range(len(expfield_categories)):
    master_dict['Gain'][expfield_categories[i]] = lst_dicts_gain[i]
    
master_dict['DiD'] = {}

for i in range(len(expfield_categories)):
    master_dict['DiD'][expfield_categories[i]] = lst_dicts_a3[i]

# %%
master_dict.keys()
# Out:
# dict_keys(['Retention', 'Gain', 'DiD'])

# %%
master_dict
# Out:
# {'Retention': {'Academic Age': {'Junior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.61,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 12.0,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 8.06,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 14.48,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 13.17,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.03,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.87,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.026,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.35,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.4},
#    'Mid': {'CollabAcademicAgeAtCollaboration_retracted_mean': 14.63,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 14.66,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.31,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.86,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.67,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.14,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.23,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.232,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.85,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.39},
#    'Senior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 14.7,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 15.27,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.69,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 16.44,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.77,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.78,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.74,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.038,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.25,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.23}},
#   'Number of Papers': {'Junior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 68.22,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 44.92,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 81.33,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 80.12,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 61.61,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 120.23,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -11.9,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.298,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -34.43,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 10.62},
#    'Mid': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 76.44,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 63.35,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 81.4,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 78.95,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 67.75,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 60.06,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -2.5,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.819,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -23.91,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 18.91},
#    'Senior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 61.64,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 46.17,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 71.74,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 65.82,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 54.28,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 60.07,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -4.19,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.582,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -19.38,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 11.01}},
#   'Number of Citations': {'Junior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1375.15,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 405.5,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2403.44,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1356.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 690.48,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2306.96,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 18.8,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.943,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -467.11,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 504.71},
#    'Mid': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1451.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 650.21,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2106.28,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1530.51,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 846.9,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2496.01,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -79.46,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.822,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -763.37,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 604.45},
#    'Senior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1600.02,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 551.75,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 6538.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1242.4,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 496.91,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1802.62,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 357.62,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.517,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -712.49,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 1427.72}},
#   'Number of Collaborators': {'Junior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 145.93,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 77.5,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 234.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 203.74,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 100.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 486.63,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -57.81,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.174,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -143.7,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 28.08},
#    'Mid': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 179.87,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 119.62,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 176.47,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 179.74,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 121.23,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 181.8,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 0.12,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.996,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -50.63,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 50.88},
#    'Senior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 167.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 83.56,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 220.15,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 143.86,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 104.25,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 144.35,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 23.34,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.275,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -16.77,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 63.45}}},
#  'Gain': {'Academic Age': {'Junior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 7.07,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 5.14,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.56,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.5,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 5.34,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.66,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.355,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.84,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.52},
#    'Mid': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.15,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 8.0,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 5.08,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.81,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.32,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.73,
#     'CollabAcademicAgeAtCollaboration_delta_mean': 0.34,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.63,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -0.96,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.65},
#    'Senior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.26,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 7.86,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 8.47,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.74,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.73,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.21,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.712,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.23,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.82}},
#   'Number of Papers': {'Junior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 34.08,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 17.75,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 45.04,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 36.42,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 29.4,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 32.08,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -2.34,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.583,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -10.2,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 5.53},
#    'Mid': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 40.45,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 30.53,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 33.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 32.42,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 28.15,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 25.92,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 8.02,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.066,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -0.16,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 16.2},
#    'Senior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 35.27,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 29.43,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 27.02,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 34.86,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 29.84,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 28.91,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 0.4,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.902,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -5.8,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 6.61}},
#   'Number of Citations': {'Junior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 826.74,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 147.57,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1988.28,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 855.75,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 386.71,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1426.11,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -29.01,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.878,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -387.28,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 329.27},
#    'Mid': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 779.37,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 408.0,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 942.5,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 585.2,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 303.38,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 798.07,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 194.17,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.123,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -42.57,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 430.92},
#    'Senior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 759.34,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 493.76,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 869.04,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 712.43,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 361.32,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1313.15,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 46.91,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.72,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -199.63,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 293.46}},
#   'Number of Collaborators': {'Junior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 95.85,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 38.08,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 155.45,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 110.23,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 63.97,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 144.51,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -14.38,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.379,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -45.05,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 16.3},
#    'Mid': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 133.36,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.81,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 180.11,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 92.45,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 57.6,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 154.97,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 40.91,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.092,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -2.98,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 84.8},
#    'Senior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 157.23,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 72.32,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 295.06,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 109.44,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 72.5,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 139.22,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 47.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.079,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -3.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 99.12}}},
#  'DiD': {'Academic Age': {'Junior': {'DiffAcademicAgeAtRetraction_retracted_mean': 3.05,
#     'DiffAcademicAgeAtRetraction_retracted_median': 2.47,
#     'DiffAcademicAgeAtRetraction_retracted_std': 9.78,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 3.89,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 3.18,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.83,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.84,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.397,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -2.68,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 1.0},
#    'Mid': {'DiffAcademicAgeAtRetraction_retracted_mean': 3.19,
#     'DiffAcademicAgeAtRetraction_retracted_median': 2.73,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.03,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 4.08,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 3.54,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.59,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.89,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.362,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -2.39,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.62},
#    'Senior': {'DiffAcademicAgeAtRetraction_retracted_mean': -0.73,
#     'DiffAcademicAgeAtRetraction_retracted_median': -0.01,
#     'DiffAcademicAgeAtRetraction_retracted_std': 5.81,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 0.54,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 0.06,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 7.08,
#     'DiffAcademicAgeAtRetraction_delta_mean': -1.28,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.087,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -2.78,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.22}},
#   'Number of Papers': {'Junior': {'DiffMAGCumPapersAtRetraction_retracted_mean': 26.23,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.39,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 71.83,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 28.85,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 16.53,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 100.54,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -2.62,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.798,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -23.02,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 17.78},
#    'Mid': {'DiffMAGCumPapersAtRetraction_retracted_mean': 22.86,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.19,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 68.39,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 29.0,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 21.5,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 45.09,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -6.14,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.491,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -24.29,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.01},
#    'Senior': {'DiffMAGCumPapersAtRetraction_retracted_mean': 13.25,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 6.02,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 47.8,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 19.17,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 9.64,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 52.6,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -5.92,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.305,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -18.0,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 6.16}},
#   'Number of Citations': {'Junior': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 439.08,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 60.42,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1988.35,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 332.56,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 115.26,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1576.83,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': 106.53,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.612,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -299.5,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 512.56},
#    'Mid': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 33.32,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': -4.98,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1621.72,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 423.13,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 118.41,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1646.59,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -389.81,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.122,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -948.01,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 168.4},
#    'Senior': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 238.65,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': -0.76,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 3374.01,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 247.34,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': -20.15,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1370.7,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -8.69,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.977,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -603.62,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 586.24}},
#   'Number of Collaborators': {'Junior': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 35.47,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 13.65,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 227.24,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 59.86,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 21.39,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 341.14,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -24.4,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.473,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -94.69,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 45.9},
#    'Mid': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 11.1,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 15.0,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 136.11,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 58.24,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 24.25,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 136.26,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -47.14,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.025,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -90.16,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': -4.12},
#    'Senior': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 20.3,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 3.73,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 147.36,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 25.48,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 13.4,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 124.14,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -5.18,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.741,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -37.52,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 27.16}}}}

# %%
pd.DataFrame.from_dict(master_dict)
# Out:
#                                                                  Retention  \
# Academic Age             {'Junior': {'CollabAcademicAgeAtCollaboration_...
# Number of Papers         {'Junior': {'CollabMAGCumPapersAtCollaboration...
# Number of Citations      {'Junior': {'CollabMAGCumCitationsAtCollaborat...
# Number of Collaborators  {'Junior': {'CollabMAGCumCollaboratorsAtCollab...
#
#                                                                       Gain  \
# Academic Age             {'Junior': {'CollabAcademicAgeAtCollaboration_...
# Number of Papers         {'Junior': {'CollabMAGCumPapersAtCollaboration...
# Number of Citations      {'Junior': {'CollabMAGCumCitationsAtCollaborat...
# Number of Collaborators  {'Junior': {'CollabMAGCumCollaboratorsAtCollab...
#
#                                                                        DiD
# Academic Age             {'Junior': {'DiffAcademicAgeAtRetraction_retra...
# Number of Papers         {'Junior': {'DiffMAGCumPapersAtRetraction_retr...
# Number of Citations      {'Junior': {'DiffMAGCumCitationsAtRetraction_r...
# Number of Collaborators  {'Junior': {'DiffMAGCumCollaboratorsAtRetracti...

# %%
def save_dict(dicto, fname):
    import pickle 

    with open(fname, 'wb') as f:
        pickle.dump(dicto, f)
        
def read_dict(fname):
    import pickle
    
    with open(fname, 'rb') as f:
        loaded_dict = pickle.load(f)
        return loaded_dict

# %%
OUTDIR = "/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/plot_data/"

save_dict(master_dict, OUTDIR+"/collaborator_chars_byAge_firstlastauthors.pkl")

# %%
dict_temp = read_dict(OUTDIR+"/collaborator_chars_byAge_firstlastauthors.pkl")
dict_temp
# Out:
# {'Retention': {'Academic Age': {'Junior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.61,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 12.0,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 8.06,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 14.48,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 13.17,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.03,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.87,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.026,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.35,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.4},
#    'Mid': {'CollabAcademicAgeAtCollaboration_retracted_mean': 14.63,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 14.66,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.31,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.86,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.67,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.14,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.23,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.232,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.85,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.39},
#    'Senior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 14.7,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 15.27,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.69,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 16.44,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.77,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.78,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.74,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.038,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.25,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.23}},
#   'Number of Papers': {'Junior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 68.22,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 44.92,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 81.33,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 80.12,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 61.61,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 120.23,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -11.9,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.298,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -34.43,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 10.62},
#    'Mid': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 76.44,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 63.35,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 81.4,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 78.95,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 67.75,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 60.06,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -2.5,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.819,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -23.91,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 18.91},
#    'Senior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 61.64,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 46.17,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 71.74,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 65.82,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 54.28,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 60.07,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -4.19,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.582,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -19.38,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 11.01}},
#   'Number of Citations': {'Junior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1375.15,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 405.5,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2403.44,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1356.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 690.48,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2306.96,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 18.8,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.943,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -467.11,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 504.71},
#    'Mid': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1451.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 650.21,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2106.28,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1530.51,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 846.9,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2496.01,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -79.46,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.822,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -763.37,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 604.45},
#    'Senior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1600.02,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 551.75,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 6538.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1242.4,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 496.91,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1802.62,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 357.62,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.517,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -712.49,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 1427.72}},
#   'Number of Collaborators': {'Junior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 145.93,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 77.5,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 234.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 203.74,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 100.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 486.63,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -57.81,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.174,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -143.7,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 28.08},
#    'Mid': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 179.87,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 119.62,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 176.47,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 179.74,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 121.23,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 181.8,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 0.12,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.996,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -50.63,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 50.88},
#    'Senior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 167.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 83.56,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 220.15,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 143.86,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 104.25,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 144.35,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 23.34,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.275,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -16.77,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 63.45}}},
#  'Gain': {'Academic Age': {'Junior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 7.07,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 5.14,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.56,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.5,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 5.34,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.66,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.355,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.84,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.52},
#    'Mid': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.15,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 8.0,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 5.08,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.81,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.32,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.73,
#     'CollabAcademicAgeAtCollaboration_delta_mean': 0.34,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.63,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -0.96,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.65},
#    'Senior': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.26,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 7.86,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 8.47,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.74,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.73,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.21,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.712,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.23,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.82}},
#   'Number of Papers': {'Junior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 34.08,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 17.75,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 45.04,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 36.42,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 29.4,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 32.08,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -2.34,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.583,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -10.2,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 5.53},
#    'Mid': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 40.45,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 30.53,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 33.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 32.42,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 28.15,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 25.92,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 8.02,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.066,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -0.16,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 16.2},
#    'Senior': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 35.27,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 29.43,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 27.02,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 34.86,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 29.84,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 28.91,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 0.4,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.902,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -5.8,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 6.61}},
#   'Number of Citations': {'Junior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 826.74,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 147.57,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1988.28,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 855.75,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 386.71,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1426.11,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -29.01,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.878,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -387.28,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 329.27},
#    'Mid': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 779.37,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 408.0,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 942.5,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 585.2,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 303.38,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 798.07,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 194.17,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.123,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -42.57,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 430.92},
#    'Senior': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 759.34,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 493.76,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 869.04,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 712.43,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 361.32,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1313.15,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 46.91,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.72,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -199.63,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 293.46}},
#   'Number of Collaborators': {'Junior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 95.85,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 38.08,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 155.45,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 110.23,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 63.97,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 144.51,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -14.38,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.379,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -45.05,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 16.3},
#    'Mid': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 133.36,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.81,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 180.11,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 92.45,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 57.6,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 154.97,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 40.91,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.092,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -2.98,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 84.8},
#    'Senior': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 157.23,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 72.32,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 295.06,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 109.44,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 72.5,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 139.22,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 47.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.079,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -3.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 99.12}}},
#  'DiD': {'Academic Age': {'Junior': {'DiffAcademicAgeAtRetraction_retracted_mean': 3.05,
#     'DiffAcademicAgeAtRetraction_retracted_median': 2.47,
#     'DiffAcademicAgeAtRetraction_retracted_std': 9.78,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 3.89,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 3.18,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.83,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.84,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.397,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -2.68,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 1.0},
#    'Mid': {'DiffAcademicAgeAtRetraction_retracted_mean': 3.19,
#     'DiffAcademicAgeAtRetraction_retracted_median': 2.73,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.03,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 4.08,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 3.54,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.59,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.89,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.362,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -2.39,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.62},
#    'Senior': {'DiffAcademicAgeAtRetraction_retracted_mean': -0.73,
#     'DiffAcademicAgeAtRetraction_retracted_median': -0.01,
#     'DiffAcademicAgeAtRetraction_retracted_std': 5.81,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 0.54,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 0.06,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 7.08,
#     'DiffAcademicAgeAtRetraction_delta_mean': -1.28,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.087,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -2.78,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.22}},
#   'Number of Papers': {'Junior': {'DiffMAGCumPapersAtRetraction_retracted_mean': 26.23,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.39,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 71.83,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 28.85,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 16.53,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 100.54,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -2.62,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.798,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -23.02,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 17.78},
#    'Mid': {'DiffMAGCumPapersAtRetraction_retracted_mean': 22.86,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.19,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 68.39,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 29.0,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 21.5,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 45.09,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -6.14,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.491,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -24.29,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.01},
#    'Senior': {'DiffMAGCumPapersAtRetraction_retracted_mean': 13.25,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 6.02,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 47.8,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 19.17,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 9.64,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 52.6,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -5.92,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.305,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -18.0,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 6.16}},
#   'Number of Citations': {'Junior': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 439.08,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 60.42,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1988.35,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 332.56,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 115.26,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1576.83,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': 106.53,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.612,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -299.5,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 512.56},
#    'Mid': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 33.32,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': -4.98,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1621.72,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 423.13,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 118.41,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1646.59,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -389.81,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.122,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -948.01,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 168.4},
#    'Senior': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 238.65,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': -0.76,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 3374.01,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 247.34,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': -20.15,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1370.7,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -8.69,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.977,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -603.62,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 586.24}},
#   'Number of Collaborators': {'Junior': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 35.47,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 13.65,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 227.24,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 59.86,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 21.39,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 341.14,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -24.4,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.473,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -94.69,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 45.9},
#    'Mid': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 11.1,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 15.0,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 136.11,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 58.24,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 24.25,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 136.26,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -47.14,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.025,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -90.16,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': -4.12},
#    'Senior': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 20.3,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 3.73,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 147.36,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 25.48,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 13.4,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 124.14,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -5.18,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.741,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -37.52,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 27.16}}}}
