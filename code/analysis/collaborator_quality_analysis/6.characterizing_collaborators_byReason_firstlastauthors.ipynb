# %% [markdown]
# # Characterizing Collaborators
#
# In this notebook, we shall characterize collaborators. We shall do that in the following way:
#
# There are three reasons: misconduct, plagiarism, and mistake.
#
# For each academic age group within retracted and matched scientists **at the time of retraction**, we shall conduct three analysis and create three tables:
#
# #### Retained for retracted vs. matched
# 1. Table 1 comparing the **retained** collaborators of retracted and matched scientists in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of collaboration**. The table will also contain median, standard deviation, and p-value for t-test.
#
# #### Gained for retracted vs. matched
# 2. Table 2 comparing the **gained/new** collaborators of retracted and matched scientists in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of collaboration**. The table will also contain median, standard deviation, and p-value for t-test.
#
# #### Retained vs. lost for retracted vs. matched
# 3. Table 3 comparing the **retained** collaborators of retracted and matched scientists to those **lost** in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of retraction**. The table will be produced by difference in differences approach where we shall first compute the averages for each field (papers, citations, etc.) for retained and lost for retracted and matched. Then we shall compute the difference between retained for retracted and matched, and between lost for retracted and matched. Finally we shall take the difference in difference (DiD) i.e. **RETAINED-LOST**. The table will also contain median, standard deviation, and p-value for t-test.

# %%
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
INDIR = "/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/"
INDIR_MATCHING = INDIR+"/author_matching/"
INDIR_COLLAB = INDIR+"/collaborator_quality_analysis/"

df = pd.read_csv(INDIR_COLLAB+"/1Dcollaborators_for_matched_sample_30.csv")

print(df.shape)

df.head()
# Out:
# (773033, 20)
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2004120834          1994.0                1983.0
# 1  2.105038e+09    2124401064          1994.0                1983.0
# 2  2.105038e+09    2486043001          1994.0                1983.0
# 3  2.105038e+09    2124401064          1994.0                1992.0
# 4  2.105038e+09    2276877851          1994.0                1992.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.74
# 2     retracted                  male                       0.60
# 3     retracted                  male                       0.74
# 4     retracted                female                       0.98
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1967.0                              1994.0
# 1                 1964.0                              1994.0
# 2                 1971.0                              1983.0
# 3                 1964.0                              1994.0
# 4                 1984.0                              1993.0
#
#    CollabMAGCumPapersAtRetraction  CollabMAGCumCitationsYearAtRetraction  \
# 0                           104.0                                 1994.0
# 1                            78.0                                 1994.0
# 2                            10.0                                 1994.0
# 3                            78.0                                 1994.0
# 4                            16.0                                 1994.0
#
#    CollabMAGCumCitationsAtRetraction  \
# 0                             3683.0
# 1                             2668.0
# 2                              532.0
# 3                             2668.0
# 4                              136.0
#
#    CollabMAGCumCollaboratorsYearAtRetraction  \
# 0                                     1994.0
# 1                                     1994.0
# 2                                     1983.0
# 3                                     1994.0
# 4                                     1993.0
#
#    CollabMAGCumCollaboratorsAtRetraction  \
# 0                                   83.0
# 1                                   81.0
# 2                                   18.0
# 3                                   81.0
# 4                                   31.0
#
#    CollabMAGCumPapersYearAtCollaboration  CollabMAGCumPapersAtCollaboration  \
# 0                                 1983.0                               47.0
# 1                                 1983.0                               47.0
# 2                                 1983.0                               10.0
# 3                                 1992.0                               74.0
# 4                                 1992.0                               14.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1983.0
# 1                                    1983.0
# 2                                    1983.0
# 3                                    1992.0
# 4                                    1992.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                1076.0
# 1                                1305.0
# 2                                 199.0
# 3                                2449.0
# 4                                  90.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1983.0
# 1                                        1983.0
# 2                                        1983.0
# 3                                        1992.0
# 4                                        1992.0
#
#    CollabMAGCumCollaboratorsAtCollaboration
# 0                                        46
# 1                                        37
# 2                                        18
# 3                                        71
# 4                                        27

# %%
print(df.shape)
# Out:
# (773033, 20)

# %%
df.MAGCollabAID.nunique()
# Out:
# 411911

# %% [markdown]
# ### Preprocessing

# %%
# Let us first augment the academic age of MAGAIDs. We will also add other columns to be used later

# Reading files used for matching

df_treatment = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_treatment_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5','ReasonPropagatedMajorityOfMajority',
                            'MAGAIDFirstORLastAuthorFlag'])\
                    .drop_duplicates()\
                    .rename(columns={
                                    'AcademicAgeBeforeRetraction': 'AcademicAgeAtRetraction'})

df_control = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MatchMAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5','ReasonPropagatedMajorityOfMajority',
                            'MAGAIDFirstORLastAuthorFlag'])\
                    .drop_duplicates()\
                    .rename(columns={'MatchMAGAID':'MAGAID'})

# Filtering process for choosing only first and last authors

df_treatment = df_treatment[df_treatment['MAGAIDFirstORLastAuthorFlag']=='MAGFirstOrLastAuthor']

df_control = df_control[df_control['MAGAIDFirstORLastAuthorFlag']=='MAGFirstOrLastAuthor']


df_treatment_control = pd.concat([df_treatment,df_control])

# Filtering process
df = df[df['MAGAID'].isin(df_treatment_control['MAGAID'])]

# Removing reasons that are not misconduct, plagiarism, mistake

df_treatment_control = df_treatment_control[df_treatment_control.\
                                        ReasonPropagatedMajorityOfMajority.isin(['misconduct',
                                                                                'plagiarism',
                                                                                'mistake'])]

df_treatment_control
# Out:
#             MAGAID  RetractionYear ReasonPropagatedMajorityOfMajority  \
# 20    1.839367e+08          2007.0                            mistake
# 22    2.004364e+08          2012.0                         misconduct
# 23    2.066031e+08          2012.0                            mistake
# 25    2.072804e+08          2012.0                         misconduct
# 26    2.074934e+08          2008.0                            mistake
# ...            ...             ...                                ...
# 5409  2.135624e+09          2014.0                         plagiarism
# 5411  2.127710e+09          2015.0                         plagiarism
# 5412  1.974243e+09          2013.0                            mistake
# 5416  2.077873e+09          2008.0                         misconduct
# 5417  3.019838e+08          2014.0                         misconduct
#
#      MAGAIDFirstORLastAuthorFlag  NumRetentionW5  NumNewCollaboratorsW5
# 20          MAGFirstOrLastAuthor               8                     79
# 22          MAGFirstOrLastAuthor              13                     18
# 23          MAGFirstOrLastAuthor              12                     28
# 25          MAGFirstOrLastAuthor              20                     88
# 26          MAGFirstOrLastAuthor              13                     55
# ...                          ...             ...                    ...
# 5409        MAGFirstOrLastAuthor               1                      2
# 5411        MAGFirstOrLastAuthor               3                     25
# 5412        MAGFirstOrLastAuthor               3                      2
# 5416        MAGFirstOrLastAuthor               2                      3
# 5417        MAGFirstOrLastAuthor              41                    141
#
# [1807 rows x 6 columns]

# %%
# Merging that with df

df2 = df.merge(df_treatment_control.drop(columns=['NumRetentionW5','NumNewCollaboratorsW5']), 
                                         on=['MAGAID','RetractionYear'])
df2
# Out:
#               MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0       2.033335e+09    1917877966          1995.0                1999.0
# 1       2.033335e+09    2169118091          1995.0                1999.0
# 2       2.033335e+09     275085591          1995.0                1997.0
# 3       2.033335e+09    2111014462          1995.0                1997.0
# 4       2.033335e+09    2622920657          1995.0                1997.0
# ...              ...           ...             ...                   ...
# 195007  2.147516e+09    2144146330          2009.0                2016.0
# 195008  2.147516e+09    3146371485          2009.0                2015.0
# 195009  2.147516e+09    3149630639          2009.0                2014.0
# 195010  2.147516e+09    3165764306          2009.0                2014.0
# 195011  2.147516e+09    3142706001          2009.0                2019.0
#
#        ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0          retracted                  male                       0.99
# 1          retracted                  male                       1.00
# 2          retracted                  male                       0.99
# 3          retracted                female                       0.98
# 4          retracted                  male                       0.99
# ...              ...                   ...                        ...
# 195007       matched                  male                       0.81
# 195008       matched                  male                       0.60
# 195009       matched                  male                       0.97
# 195010       matched                  male                       0.81
# 195011       matched                female                       0.78
#
#         CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                      1994.0                              1994.0
# 1                      1995.0                              1995.0
# 2                      1994.0                              1995.0
# 3                      1988.0                              1995.0
# 4                      1991.0                              1995.0
# ...                       ...                                 ...
# 195007                 1982.0                              2009.0
# 195008                 2015.0                                 NaN
# 195009                 2014.0                                 NaN
# 195010                 2014.0                                 NaN
# 195011                 2019.0                                 NaN
#
#         CollabMAGCumPapersAtRetraction  ...  \
# 0                                  1.0  ...
# 1                                  1.0  ...
# 2                                  5.0  ...
# 3                                 17.0  ...
# 4                                 17.0  ...
# ...                                ...  ...
# 195007                           284.0  ...
# 195008                             0.0  ...
# 195009                             0.0  ...
# 195010                             0.0  ...
# 195011                             0.0  ...
#
#         CollabMAGCumCollaboratorsYearAtRetraction  \
# 0                                          1994.0
# 1                                          1995.0
# 2                                          1995.0
# 3                                          1995.0
# 4                                          1995.0
# ...                                           ...
# 195007                                     2009.0
# 195008                                        NaN
# 195009                                        NaN
# 195010                                        NaN
# 195011                                        NaN
#
#         CollabMAGCumCollaboratorsAtRetraction  \
# 0                                         2.0
# 1                                         3.0
# 2                                        11.0
# 3                                        30.0
# 4                                        33.0
# ...                                       ...
# 195007                                  464.0
# 195008                                    0.0
# 195009                                    0.0
# 195010                                    0.0
# 195011                                    0.0
#
#         CollabMAGCumPapersYearAtCollaboration  \
# 0                                      1999.0
# 1                                      1999.0
# 2                                      1997.0
# 3                                      1997.0
# 4                                      1997.0
# ...                                       ...
# 195007                                 2016.0
# 195008                                 2015.0
# 195009                                 2014.0
# 195010                                 2014.0
# 195011                                 2019.0
#
#         CollabMAGCumPapersAtCollaboration  \
# 0                                    14.0
# 1                                     9.0
# 2                                    12.0
# 3                                    22.0
# 4                                    26.0
# ...                                   ...
# 195007                              563.0
# 195008                                1.0
# 195009                                1.0
# 195010                                1.0
# 195011                                1.0
#
#         CollabMAGCumCitationsYearAtCollaboration  \
# 0                                         1999.0
# 1                                         1999.0
# 2                                         1997.0
# 3                                         1997.0
# 4                                         1997.0
# ...                                          ...
# 195007                                    2016.0
# 195008                                    2015.0
# 195009                                       NaN
# 195010                                       NaN
# 195011                                       NaN
#
#         CollabMAGCumCitationsAtCollaboration  \
# 0                                       99.0
# 1                                        8.0
# 2                                       53.0
# 3                                      921.0
# 4                                      306.0
# ...                                      ...
# 195007                               16846.0
# 195008                                   1.0
# 195009                                   0.0
# 195010                                   0.0
# 195011                                   0.0
#
#         CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                             1999.0
# 1                                             1999.0
# 2                                             1997.0
# 3                                             1997.0
# 4                                             1997.0
# ...                                              ...
# 195007                                        2016.0
# 195008                                        2015.0
# 195009                                        2014.0
# 195010                                        2014.0
# 195011                                        2019.0
#
#         CollabMAGCumCollaboratorsAtCollaboration  \
# 0                                             31
# 1                                             23
# 2                                             22
# 3                                             42
# 4                                             44
# ...                                          ...
# 195007                                      3686
# 195008                                         4
# 195009                                         4
# 195010                                         4
# 195011                                         5
#
#         ReasonPropagatedMajorityOfMajority  MAGAIDFirstORLastAuthorFlag
# 0                                  mistake         MAGFirstOrLastAuthor
# 1                                  mistake         MAGFirstOrLastAuthor
# 2                                  mistake         MAGFirstOrLastAuthor
# 3                                  mistake         MAGFirstOrLastAuthor
# 4                                  mistake         MAGFirstOrLastAuthor
# ...                                    ...                          ...
# 195007                             mistake         MAGFirstOrLastAuthor
# 195008                             mistake         MAGFirstOrLastAuthor
# 195009                             mistake         MAGFirstOrLastAuthor
# 195010                             mistake         MAGFirstOrLastAuthor
# 195011                             mistake         MAGFirstOrLastAuthor
#
# [195012 rows x 22 columns]

# %%
# Let us first compute academic age at retraction and at collaboration for collaborators
df2['CollabAcademicAgeAtRetraction'] = df2['RetractionYear']-df2['CollabMAGFirstPubYear']

df2['CollabAcademicAgeAtCollaboration'] = df2['MAGCollaborationYear']-df2['CollabMAGFirstPubYear']

# So negatives are possible in academic age at retraction but not collaboration
df2.CollabAcademicAgeAtRetraction.describe()
# Out:
# count    195012.000000
# mean          9.226478
# std          13.767529
# min         -30.000000
# 25%           0.000000
# 50%           7.000000
# 75%          17.000000
# max         215.000000
# Name: CollabAcademicAgeAtRetraction, dtype: float64

# %%
# Let us first identify if the collaboration was pre- or post-retraction

def get_prepost_flag(row):
    if(row['MAGCollaborationYear'] <= row['RetractionYear']):
        return 'pre'
    else:
        if((row['MAGCollaborationYear']-row['RetractionYear'])<=5):
            return 'post5'
        else:
            return 'post'

df2['PrePostFlag5'] = df2.apply(lambda row: get_prepost_flag(row), axis=1)

# %%
# Let us remove the collaborators that are "post"

df3 = df2[~df2.PrePostFlag5.eq('post')]

# %%
df3.head()
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.033335e+09    1917877966          1995.0                1999.0
# 1  2.033335e+09    2169118091          1995.0                1999.0
# 2  2.033335e+09     275085591          1995.0                1997.0
# 3  2.033335e+09    2111014462          1995.0                1997.0
# 4  2.033335e+09    2622920657          1995.0                1997.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       1.00
# 2     retracted                  male                       0.99
# 3     retracted                female                       0.98
# 4     retracted                  male                       0.99
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1994.0                              1994.0
# 1                 1995.0                              1995.0
# 2                 1994.0                              1995.0
# 3                 1988.0                              1995.0
# 4                 1991.0                              1995.0
#
#    CollabMAGCumPapersAtRetraction  ...  CollabMAGCumPapersAtCollaboration  \
# 0                             1.0  ...                               14.0
# 1                             1.0  ...                                9.0
# 2                             5.0  ...                               12.0
# 3                            17.0  ...                               22.0
# 4                            17.0  ...                               26.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1999.0
# 1                                    1999.0
# 2                                    1997.0
# 3                                    1997.0
# 4                                    1997.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                  99.0
# 1                                   8.0
# 2                                  53.0
# 3                                 921.0
# 4                                 306.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1999.0
# 1                                        1999.0
# 2                                        1997.0
# 3                                        1997.0
# 4                                        1997.0
#
#    CollabMAGCumCollaboratorsAtCollaboration  \
# 0                                        31
# 1                                        23
# 2                                        22
# 3                                        42
# 4                                        44
#
#    ReasonPropagatedMajorityOfMajority  MAGAIDFirstORLastAuthorFlag  \
# 0                             mistake         MAGFirstOrLastAuthor
# 1                             mistake         MAGFirstOrLastAuthor
# 2                             mistake         MAGFirstOrLastAuthor
# 3                             mistake         MAGFirstOrLastAuthor
# 4                             mistake         MAGFirstOrLastAuthor
#
#    CollabAcademicAgeAtRetraction  CollabAcademicAgeAtCollaboration  \
# 0                            1.0                               5.0
# 1                            0.0                               4.0
# 2                            1.0                               3.0
# 3                            7.0                               9.0
# 4                            4.0                               6.0
#
#    PrePostFlag5
# 0         post5
# 1         post5
# 2         post5
# 3         post5
# 4         post5
#
# [5 rows x 25 columns]

# %%
df3.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'MAGAIDFirstORLastAuthorFlag',
#        'CollabAcademicAgeAtRetraction', 'CollabAcademicAgeAtCollaboration',
#        'PrePostFlag5'],
#       dtype='object')

# %%
# For each MAGAID, let us create a set of collaborators pre- and post- retraction

df4 = df3.groupby(['MAGAID','RetractionYear','PrePostFlag5'])\
                        ['MAGCollabAID'].apply(set).unstack().reset_index()


# Converting pre- and post5 columns to set so we can do set operations
df4['pre'] = df4['pre'].apply(lambda d: d if isinstance(d, set) else set())
df4['post5'] = df4['post5'].apply(lambda d: d if isinstance(d, set) else set())


# COLLABORATOR RETENTION

# Computing number of collaborators retained
df4['NumRetentionW5'] = df4.apply(lambda row: len(row.post5.intersection(row.pre)), 
                            axis=1)

# Creating the list of collaborators retained
df4['CollabAIDRetainedW5'] = df4.apply(lambda row: row.post5.intersection(row.pre), 
                                                    axis=1)


# Creating list of collaborators lost
df4['CollabAIDLostW5'] = df4.apply(lambda row: row['pre'] - row['CollabAIDRetainedW5'], 
                                                    axis=1)


# COLLABORATOR GAIN

# Computing number of collabortors gained
df4['NumNewCollaboratorsW5'] = df4.apply(lambda row: len(row['post5']-row['pre']), 
                                                    axis=1)

# Creating set of collaborators gained
df4['CollabAIDGainedW5'] = df4.apply(lambda row: row['post5']-row['pre'], 
                                                    axis=1)


df4.head()
# Out:
# PrePostFlag5      MAGAID  RetractionYear  \
# 0             19100288.0          2002.0
# 1             21686935.0          2008.0
# 2             29680017.0          1997.0
# 3             33433812.0          2009.0
# 4             41957466.0          2015.0
#
# PrePostFlag5                                              post5  \
# 0             {18011520, 2181345027, 2608247304, 2043645593,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2             {2309217606, 2070053831, 1588714087, 252097620...
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2034626565, 1848517639, 2597654027, 203201076...
#
# PrePostFlag5                                                pre  \
# 0             {2437904394, 2171993227, 2043645593, 220887567...
# 1             {2170694433, 2064283617, 2327654243, 247583094...
# 2             {287126053, 1971237384, 2023717609, 2273398858...
# 3             {2653850944, 2127386819, 2572203943, 212894289...
# 4             {2152585733, 2142553607, 2110808072, 294896999...
#
# PrePostFlag5  NumRetentionW5  \
# 0                          5
# 1                          0
# 2                          1
# 3                          4
# 4                         32
#
# PrePostFlag5                                CollabAIDRetainedW5  \
# 0             {2128982626, 1863203661, 2043645593, 410625722...
# 1                                                            {}
# 2                                                  {2920459384}
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2047324288, 2133711754, 1719173006, 219254094...
#
# PrePostFlag5                                    CollabAIDLostW5  \
# 0             {2059887737, 2186312265, 2437904394, 217199322...
# 1             {2330648593, 2965357269, 3081263517, 250572015...
# 2             {1971237384, 2273398858, 1998215821, 230597927...
# 3                          {2137538457, 2149027090, 2572203943}
# 4             {2152585733, 2142553607, 2110808072, 294896999...
#
# PrePostFlag5  NumNewCollaboratorsW5  \
# 0                                23
# 1                                12
# 2                                 4
# 3                                 0
# 4                                83
#
# PrePostFlag5                                  CollabAIDGainedW5
# 0             {18011520, 2181345027, 2608247304, 2111905563,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2              {2520976201, 1588714087, 2309217606, 2070053831}
# 3                                                            {}
# 4             {2034626565, 1848517639, 2597654027, 203201076...

# %% [markdown]
# ### Validation of the number of collaborators retained and gained
#
# We shall validate if the numbers we calculated now match the ones on which matching was done.

# %%
# Merging
dfvalidation = df4[['MAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5']].drop_duplicates().\
                    merge(df_treatment_control, on=['MAGAID','RetractionYear'])

dfvalidation
# Out:
#             MAGAID  RetractionYear  NumRetentionW5_x  NumNewCollaboratorsW5_x  \
# 0     1.910029e+07          2002.0                 5                       23
# 1     2.168694e+07          2008.0                 0                       12
# 2     2.968002e+07          1997.0                 1                        4
# 3     3.343381e+07          2009.0                 4                        0
# 4     4.195747e+07          2015.0                32                       83
# ...            ...             ...               ...                      ...
# 1414  3.170688e+09          2012.0                 1                        4
# 1415  3.173544e+09          2011.0                 0                        2
# 1416  3.174124e+09          2004.0                 1                        6
# 1417  3.175436e+09          2015.0                 1                       14
# 1418  3.176346e+09          2011.0                 1                        8
#
#      ReasonPropagatedMajorityOfMajority MAGAIDFirstORLastAuthorFlag  \
# 0                               mistake        MAGFirstOrLastAuthor
# 1                            plagiarism        MAGFirstOrLastAuthor
# 2                               mistake        MAGFirstOrLastAuthor
# 3                               mistake        MAGFirstOrLastAuthor
# 4                               mistake        MAGFirstOrLastAuthor
# ...                                 ...                         ...
# 1414                         plagiarism        MAGFirstOrLastAuthor
# 1415                         misconduct        MAGFirstOrLastAuthor
# 1416                            mistake        MAGFirstOrLastAuthor
# 1417                         plagiarism        MAGFirstOrLastAuthor
# 1418                         misconduct        MAGFirstOrLastAuthor
#
#       NumRetentionW5_y  NumNewCollaboratorsW5_y
# 0                    5                       23
# 1                    0                       12
# 2                    1                        4
# 3                    4                        0
# 4                   32                       83
# ...                ...                      ...
# 1414                 1                        4
# 1415                 0                        2
# 1416                 1                        6
# 1417                 1                       14
# 1418                 1                        8
#
# [1419 rows x 8 columns]

# %%
# Finally validating

dfvalidation[(dfvalidation.NumRetentionW5_x == dfvalidation.NumRetentionW5_y) & 
            (dfvalidation.NumNewCollaboratorsW5_x == dfvalidation.NumNewCollaboratorsW5_y)]
# Out:
#             MAGAID  RetractionYear  NumRetentionW5_x  NumNewCollaboratorsW5_x  \
# 0     1.910029e+07          2002.0                 5                       23
# 1     2.168694e+07          2008.0                 0                       12
# 2     2.968002e+07          1997.0                 1                        4
# 3     3.343381e+07          2009.0                 4                        0
# 4     4.195747e+07          2015.0                32                       83
# ...            ...             ...               ...                      ...
# 1414  3.170688e+09          2012.0                 1                        4
# 1415  3.173544e+09          2011.0                 0                        2
# 1416  3.174124e+09          2004.0                 1                        6
# 1417  3.175436e+09          2015.0                 1                       14
# 1418  3.176346e+09          2011.0                 1                        8
#
#      ReasonPropagatedMajorityOfMajority MAGAIDFirstORLastAuthorFlag  \
# 0                               mistake        MAGFirstOrLastAuthor
# 1                            plagiarism        MAGFirstOrLastAuthor
# 2                               mistake        MAGFirstOrLastAuthor
# 3                               mistake        MAGFirstOrLastAuthor
# 4                               mistake        MAGFirstOrLastAuthor
# ...                                 ...                         ...
# 1414                         plagiarism        MAGFirstOrLastAuthor
# 1415                         misconduct        MAGFirstOrLastAuthor
# 1416                            mistake        MAGFirstOrLastAuthor
# 1417                         plagiarism        MAGFirstOrLastAuthor
# 1418                         misconduct        MAGFirstOrLastAuthor
#
#       NumRetentionW5_y  NumNewCollaboratorsW5_y
# 0                    5                       23
# 1                    0                       12
# 2                    1                        4
# 3                    4                        0
# 4                   32                       83
# ...                ...                      ...
# 1414                 1                        4
# 1415                 0                        2
# 1416                 1                        6
# 1417                 1                       14
# 1418                 1                        8
#
# [1419 rows x 8 columns]

# %% [markdown]
# **Hence all of them are validated.**

# %% [markdown]
# ## Analysis

# %%
# Our main dataframes are df3 and df4
# Let us look at them first
print(df3.shape)
df3.head()
# Out:
# (143648, 25)
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.033335e+09    1917877966          1995.0                1999.0
# 1  2.033335e+09    2169118091          1995.0                1999.0
# 2  2.033335e+09     275085591          1995.0                1997.0
# 3  2.033335e+09    2111014462          1995.0                1997.0
# 4  2.033335e+09    2622920657          1995.0                1997.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       1.00
# 2     retracted                  male                       0.99
# 3     retracted                female                       0.98
# 4     retracted                  male                       0.99
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1994.0                              1994.0
# 1                 1995.0                              1995.0
# 2                 1994.0                              1995.0
# 3                 1988.0                              1995.0
# 4                 1991.0                              1995.0
#
#    CollabMAGCumPapersAtRetraction  ...  CollabMAGCumPapersAtCollaboration  \
# 0                             1.0  ...                               14.0
# 1                             1.0  ...                                9.0
# 2                             5.0  ...                               12.0
# 3                            17.0  ...                               22.0
# 4                            17.0  ...                               26.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1999.0
# 1                                    1999.0
# 2                                    1997.0
# 3                                    1997.0
# 4                                    1997.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                  99.0
# 1                                   8.0
# 2                                  53.0
# 3                                 921.0
# 4                                 306.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1999.0
# 1                                        1999.0
# 2                                        1997.0
# 3                                        1997.0
# 4                                        1997.0
#
#    CollabMAGCumCollaboratorsAtCollaboration  \
# 0                                        31
# 1                                        23
# 2                                        22
# 3                                        42
# 4                                        44
#
#    ReasonPropagatedMajorityOfMajority  MAGAIDFirstORLastAuthorFlag  \
# 0                             mistake         MAGFirstOrLastAuthor
# 1                             mistake         MAGFirstOrLastAuthor
# 2                             mistake         MAGFirstOrLastAuthor
# 3                             mistake         MAGFirstOrLastAuthor
# 4                             mistake         MAGFirstOrLastAuthor
#
#    CollabAcademicAgeAtRetraction  CollabAcademicAgeAtCollaboration  \
# 0                            1.0                               5.0
# 1                            0.0                               4.0
# 2                            1.0                               3.0
# 3                            7.0                               9.0
# 4                            4.0                               6.0
#
#    PrePostFlag5
# 0         post5
# 1         post5
# 2         post5
# 3         post5
# 4         post5
#
# [5 rows x 25 columns]

# %%
df4
# Out:
# PrePostFlag5        MAGAID  RetractionYear  \
# 0             1.910029e+07          2002.0
# 1             2.168694e+07          2008.0
# 2             2.968002e+07          1997.0
# 3             3.343381e+07          2009.0
# 4             4.195747e+07          2015.0
# ...                    ...             ...
# 1414          3.170688e+09          2012.0
# 1415          3.173544e+09          2011.0
# 1416          3.174124e+09          2004.0
# 1417          3.175436e+09          2015.0
# 1418          3.176346e+09          2011.0
#
# PrePostFlag5                                              post5  \
# 0             {18011520, 2181345027, 2608247304, 2043645593,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2             {2309217606, 2070053831, 1588714087, 252097620...
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2034626565, 1848517639, 2597654027, 203201076...
# ...                                                         ...
# 1414          {2152436290, 2122621478, 2798995243, 216039336...
# 1415                                   {3120802076, 2236143686}
# 1416          {2706053123, 2250669861, 2568589385, 222924385...
# 1417          {1805786912, 2999619457, 2658197410, 257933920...
# 1418          {2078002947, 2029403719, 2137379546, 199009346...
#
# PrePostFlag5                                                pre  \
# 0             {2437904394, 2171993227, 2043645593, 220887567...
# 1             {2170694433, 2064283617, 2327654243, 247583094...
# 2             {287126053, 1971237384, 2023717609, 2273398858...
# 3             {2653850944, 2127386819, 2572203943, 212894289...
# 4             {2152585733, 2142553607, 2110808072, 294896999...
# ...                                                         ...
# 1414                       {2798928472, 2531157211, 2901115159}
# 1415          {2096029443, 2160112133, 2158121610, 230907623...
# 1416           {2939265617, 2687883010, 2424699715, 2100866894}
# 1417          {2130470407, 2395301650, 1455333013, 231293572...
# 1418          {677348324, 2657776906, 3170697964, 1758167412...
#
# PrePostFlag5  NumRetentionW5  \
# 0                          5
# 1                          0
# 2                          1
# 3                          4
# 4                         32
# ...                      ...
# 1414                       1
# 1415                       0
# 1416                       1
# 1417                       1
# 1418                       1
#
# PrePostFlag5                                CollabAIDRetainedW5  \
# 0             {2128982626, 1863203661, 2043645593, 410625722...
# 1                                                            {}
# 2                                                  {2920459384}
# 3              {2653850944, 2127386819, 2128942892, 2113925965}
# 4             {2047324288, 2133711754, 1719173006, 219254094...
# ...                                                         ...
# 1414                                               {2531157211}
# 1415                                                         {}
# 1416                                               {2100866894}
# 1417                                               {2121913688}
# 1418                                               {1990093460}
#
# PrePostFlag5                                    CollabAIDLostW5  \
# 0             {2059887737, 2186312265, 2437904394, 217199322...
# 1             {2330648593, 2965357269, 3081263517, 250572015...
# 2             {1971237384, 2273398858, 1998215821, 230597927...
# 3                          {2137538457, 2149027090, 2572203943}
# 4             {2152585733, 2142553607, 2110808072, 294896999...
# ...                                                         ...
# 1414                                   {2798928472, 2901115159}
# 1415          {2096029443, 2160112133, 2158121610, 230907623...
# 1416                       {2939265617, 2687883010, 2424699715}
# 1417          {2240552385, 2130470407, 2333910471, 252033530...
# 1418          {677348324, 2657776906, 3170697964, 1758167412...
#
# PrePostFlag5  NumNewCollaboratorsW5  \
# 0                                23
# 1                                12
# 2                                 4
# 3                                 0
# 4                                83
# ...                             ...
# 1414                              4
# 1415                              2
# 1416                              6
# 1417                             14
# 1418                              8
#
# PrePostFlag5                                  CollabAIDGainedW5
# 0             {18011520, 2181345027, 2608247304, 2111905563,...
# 1             {2646743714, 2800470565, 2117660071, 269971592...
# 2              {2520976201, 1588714087, 2309217606, 2070053831}
# 3                                                            {}
# 4             {2034626565, 1848517639, 2597654027, 203201076...
# ...                                                         ...
# 1414           {2152436290, 2798995243, 2122621478, 2160393366}
# 1415                                   {3120802076, 2236143686}
# 1416          {2706053123, 2250669861, 2568589385, 222924385...
# 1417          {1805786912, 2999619457, 2658197410, 196858720...
# 1418          {2078002947, 2029403719, 2051974682, 188354341...
#
# [1419 rows x 9 columns]

# %%
# Let us first merge df3 and df4

df_A = df3.merge(df4, on=['MAGAID','RetractionYear'])

# Let us also create three flags checking whether current collaborator is retained, gained, or lost

df_A['CollabAIDinRetained'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDRetainedW5'], 
                                          axis=1)

df_A['CollabAIDinGained'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDGainedW5'], 
                                          axis=1)

df_A['CollabAIDinLost'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDLostW5'], 
                                          axis=1)

df_A.head(3)
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.033335e+09    1917877966          1995.0                1999.0
# 1  2.033335e+09    2169118091          1995.0                1999.0
# 2  2.033335e+09     275085591          1995.0                1997.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       1.00
# 2     retracted                  male                       0.99
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1994.0                              1994.0
# 1                 1995.0                              1995.0
# 2                 1994.0                              1995.0
#
#    CollabMAGCumPapersAtRetraction  ...  \
# 0                             1.0  ...
# 1                             1.0  ...
# 2                             5.0  ...
#
#                                                post5  \
# 0  {1973921793, 2041262087, 2570043915, 213721346...
# 1  {1973921793, 2041262087, 2570043915, 213721346...
# 2  {1973921793, 2041262087, 2570043915, 213721346...
#
#                                                  pre  NumRetentionW5  \
# 0  {2041262087, 2590561305, 1940968476, 211428099...              23
# 1  {2041262087, 2590561305, 1940968476, 211428099...              23
# 2  {2041262087, 2590561305, 1940968476, 211428099...              23
#
#                                  CollabAIDRetainedW5  \
# 0  {2690057605, 2041262087, 2466141063, 230478619...
# 1  {2690057605, 2041262087, 2466141063, 230478619...
# 2  {2690057605, 2041262087, 2466141063, 230478619...
#
#                                      CollabAIDLostW5  NumNewCollaboratorsW5  \
# 0  {2590561305, 1940968476, 2657016352, 265692164...                     60
# 1  {2590561305, 1940968476, 2657016352, 265692164...                     60
# 2  {2590561305, 1940968476, 2657016352, 265692164...                     60
#
#                                    CollabAIDGainedW5  CollabAIDinRetained  \
# 0  {1973921793, 2308182914, 1147890307, 265602649...                False
# 1  {1973921793, 2308182914, 1147890307, 265602649...                False
# 2  {1973921793, 2308182914, 1147890307, 265602649...                 True
#
#    CollabAIDinGained  CollabAIDinLost
# 0               True            False
# 1               True            False
# 2              False            False
#
# [3 rows x 35 columns]

# %%
# Sensibility checks

df_A[['CollabAIDinRetained','CollabAIDinGained','CollabAIDinLost']].value_counts()
# Out:
# CollabAIDinRetained  CollabAIDinGained  CollabAIDinLost
# False                False              True               57073
#                      True               False              50210
# True                 False              False              36365
# Name: count, dtype: int64

# %%
df_A.columns, df_A.shape
# Out:
# (Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#         'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#         'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#         'CollabMAGCumPapersAtRetraction',
#         'CollabMAGCumCitationsYearAtRetraction',
#         'CollabMAGCumCitationsAtRetraction',
#         'CollabMAGCumCollaboratorsYearAtRetraction',
#         'CollabMAGCumCollaboratorsAtRetraction',
#         'CollabMAGCumPapersYearAtCollaboration',
#         'CollabMAGCumPapersAtCollaboration',
#         'CollabMAGCumCitationsYearAtCollaboration',
#         'CollabMAGCumCitationsAtCollaboration',
#         'CollabMAGCumCollaboratorsYearAtCollaboration',
#         'CollabMAGCumCollaboratorsAtCollaboration',
#         'ReasonPropagatedMajorityOfMajority', 'MAGAIDFirstORLastAuthorFlag',
#         'CollabAcademicAgeAtRetraction', 'CollabAcademicAgeAtCollaboration',
#         'PrePostFlag5', 'post5', 'pre', 'NumRetentionW5', 'CollabAIDRetainedW5',
#         'CollabAIDLostW5', 'NumNewCollaboratorsW5', 'CollabAIDGainedW5',
#         'CollabAIDinRetained', 'CollabAIDinGained', 'CollabAIDinLost'],
#        dtype='object'),
#  (143648, 35))

# %% [markdown]
# ## DANGER ZONE!
#
# This code removes collaborators that have academic age > 70 at the time of collaboration.

# %%
df_A[df_A.CollabAcademicAgeAtCollaboration.gt(70) & df_A.ScientistType.eq('retracted')].MAGAID.nunique()
# Out:
# 81

# %%
df_A = df_A[df_A.CollabAcademicAgeAtCollaboration.le(70)]

# %% [markdown]
# ### A1: Collaborators retained: retracted vs. matched

# %%
#Let us now modify df_A1 such that we remove all rows with collaborations pre-retraction

df_A1_post = df_A[df_A['PrePostFlag5']=='post5']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A1_firstcollabs = df_A1_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A1_w_firstcollabs = df_A1_post.merge(df_A1_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A1_w_firstcollabs.shape
# Out:
# (66141, 36)

# %%
# Sensibility checks

df_A1_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#           MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 2121  19100288.0      18011520                2004.0
# 2128  19100288.0     121410733                2004.0
# 2109  19100288.0     410625722                2005.0
# 2122  19100288.0    1235268530                2004.0
# 2131  19100288.0    1340583028                2006.0
# 2103  19100288.0    1793107545                2003.0
# 2104  19100288.0    1793107545                2004.0
# 2123  19100288.0    1859744180                2004.0
# 2105  19100288.0    1863203661                2003.0
# 2106  19100288.0    1863203661                2004.0
# 2108  19100288.0    1863203661                2006.0
# 2107  19100288.0    1863203661                2007.0
# 2100  19100288.0    1986621809                2006.0
# 2099  19100288.0    1986621809                2007.0
# 2124  19100288.0    2004612287                2004.0
# 2115  19100288.0    2043645593                2004.0
# 2116  19100288.0    2043645593                2007.0
# 2129  19100288.0    2051205987                2004.0
# 2134  19100288.0    2078618456                2003.0
# 2135  19100288.0    2111905563                2003.0
# 2120  19100288.0    2115457216                2003.0
# 2117  19100288.0    2115457216                2004.0
# 2119  19100288.0    2115457216                2006.0
# 2118  19100288.0    2115457216                2007.0
# 2111  19100288.0    2128982626                2004.0
# 2110  19100288.0    2128982626                2005.0
# 2112  19100288.0    2128982626                2007.0
# 2125  19100288.0    2134604144                2004.0
# 2130  19100288.0    2149884334                2004.0
# 2113  19100288.0    2151293749                2005.0
#
#       FirstPostRetractionMAGCollaborationYear
# 2121                                   2004.0
# 2128                                   2004.0
# 2109                                   2005.0
# 2122                                   2004.0
# 2131                                   2006.0
# 2103                                   2003.0
# 2104                                   2003.0
# 2123                                   2004.0
# 2105                                   2003.0
# 2106                                   2003.0
# 2108                                   2003.0
# 2107                                   2003.0
# 2100                                   2006.0
# 2099                                   2006.0
# 2124                                   2004.0
# 2115                                   2004.0
# 2116                                   2004.0
# 2129                                   2004.0
# 2134                                   2003.0
# 2135                                   2003.0
# 2120                                   2003.0
# 2117                                   2003.0
# 2119                                   2003.0
# 2118                                   2003.0
# 2111                                   2004.0
# 2110                                   2004.0
# 2112                                   2004.0
# 2125                                   2004.0
# 2130                                   2004.0
# 2113                                   2005.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A1_w_firstcollabs_only = df_A1_w_firstcollabs[df_A1_w_firstcollabs.MAGCollaborationYear == \
                                                df_A1_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A1_w_firstcollabs_only.shape
# Out:
# (50527, 36)

# %%
df_A1_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'MAGAIDFirstORLastAuthorFlag',
#        'CollabAcademicAgeAtRetraction', 'CollabAcademicAgeAtCollaboration',
#        'PrePostFlag5', 'post5', 'pre', 'NumRetentionW5', 'CollabAIDRetainedW5',
#        'CollabAIDLostW5', 'NumNewCollaboratorsW5', 'CollabAIDGainedW5',
#        'CollabAIDinRetained', 'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
def create_stratified_dfs_retention(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
               'CollabMAGCumPapersAtCollaboration', 'CollabMAGCumCitationsAtCollaboration',
               'CollabMAGCumCollaboratorsAtCollaboration', 'ReasonPropagatedMajorityOfMajority',
               'CollabAcademicAgeAtCollaboration', 'CollabAIDinRetained', 'NumRetentionW5']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi = dfi[dfi['CollabAIDinRetained']]
    
    # Dividing into retracted and matched
    df_retracted = dfi[dfi.ScientistType == 'retracted']
    df_nonretracted = dfi[dfi.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the retracted scientists have matches with non zero collaborators
    df_retracted = df_retracted[df_retracted.MAGAID.isin(df_nonretracted.MAGAID.unique())]
    
    # We need to make sure that the matches of those who retained 0 collaborators are removed
    df_nonretracted = df_nonretracted[df_nonretracted.MAGAID.isin(df_retracted.MAGAID.unique())]
    
    # Dividing into seniority for retracted
    df_retracted_junior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_retracted_midcareer = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_retracted_senior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='mistake']
    # and matched
    df_nonretracted_junior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_nonretracted_midcareer = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_nonretracted_senior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='mistake']
    
    return df_retracted_junior, df_retracted_midcareer, df_retracted_senior,df_nonretracted_junior, df_nonretracted_midcareer, df_nonretracted_senior

# %%
df_rj, df_rm, df_rs, df_nrj, df_nrm, df_nrs = create_stratified_dfs_retention(df_A1_w_firstcollabs_only)

# %%
df_rj.MAGAID.nunique(), df_rm.MAGAID.nunique(), df_rs.MAGAID.nunique(), df_nrj.MAGAID.nunique(), df_nrm.MAGAID.nunique(), df_nrs.MAGAID.nunique()
# Out:
# (64, 123, 115, 64, 123, 115)

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_retention(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtCollaboration':'MatchCollabMAGCumPapersAtCollaboration',
                                    'CollabAcademicAgeAtCollaboration':'MatchCollabAcademicAgeAtCollaboration',
                                    'CollabMAGCumCitationsAtCollaboration': 'MatchCollabMAGCumCitationsAtCollaboration',
                                    'CollabMAGCumCollaboratorsAtCollaboration': 'MatchCollabMAGCumCollaboratorsAtCollaboration'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj, mean_dfnrj = get_mean_df_retention(df_rj, df_nrj)
mean_dfrm, mean_dfnrm = get_mean_df_retention(df_rm, df_nrm)
mean_dfrs, mean_dfnrs = get_mean_df_retention(df_rs, df_nrs)

mean_dfnrj
# Out:
#             MatchCollabAcademicAgeAtCollaboration  \
# MAGAID
# 48740240                                11.142857
# 115663519                                7.904762
# 207280435                               13.857143
# 409654858                               16.454545
# 1646188048                              18.000000
# ...                                           ...
# 2890048425                              16.714286
# 2935411574                              12.500000
# 2935995536                               2.666667
# 2947073985                              13.121951
# 3052744139                               8.812500
#
#             MatchCollabMAGCumPapersAtCollaboration  \
# MAGAID
# 48740240                                 40.142857
# 115663519                                18.238095
# 207280435                                28.500000
# 409654858                                58.272727
# 1646188048                               62.666667
# ...                                            ...
# 2890048425                              197.428571
# 2935411574                               99.500000
# 2935995536                                2.666667
# 2947073985                               51.000000
# 3052744139                              110.187500
#
#             MatchCollabMAGCumCitationsAtCollaboration  \
# MAGAID
# 48740240                                   443.714286
# 115663519                                  268.428571
# 207280435                                  439.642857
# 409654858                                 2185.818182
# 1646188048                                 403.777778
# ...                                               ...
# 2890048425                                7190.857143
# 2935411574                                1502.000000
# 2935995536                                   4.333333
# 2947073985                                 391.829268
# 3052744139                                 898.125000
#
#             MatchCollabMAGCumCollaboratorsAtCollaboration
# MAGAID
# 48740240                                       126.000000
# 115663519                                       56.428571
# 207280435                                       61.642857
# 409654858                                      219.545455
# 1646188048                                      74.333333
# ...                                                   ...
# 2890048425                                     513.857143
# 2935411574                                     158.500000
# 2935995536                                       5.666667
# 2947073985                                      78.926829
# 3052744139                                     123.250000
#
# [64 rows x 4 columns]

# %%
exp_fields = ['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_retention = []

for exp_field in exp_fields:
    dicts_retention = {}
    
    dict_stats_j = get_stats(mean_dfrj, mean_dfnrj, exp_field)
    dict_stats_m = get_stats(mean_dfrm, mean_dfnrm, exp_field)
    dict_stats_s = get_stats(mean_dfrs, mean_dfnrs, exp_field)
    
    dicts_retention['Misconduct'] = dict_stats_j
    dicts_retention['Plagiarism'] = dict_stats_m
    dicts_retention['Mistake'] = dict_stats_s
    
    lst_dicts_retention.append(dicts_retention)

# %%
pd.DataFrame(lst_dicts_retention[0])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabAcademicAgeAtCollaboration_retracted_mean         12.920      12.610
# CollabAcademicAgeAtCollaboration_retracted_median       13.860      12.500
# CollabAcademicAgeAtCollaboration_retracted_std           7.120       6.970
# CollabAcademicAgeAtCollaboration_nonretracted_mean      14.680      15.410
# CollabAcademicAgeAtCollaboration_nonretracted_m...      13.360      13.730
# CollabAcademicAgeAtCollaboration_nonretracted_std        6.800       7.870
# CollabAcademicAgeAtCollaboration_delta_mean             -1.770      -2.800
# CollabAcademicAgeAtCollaboration_pval_welch              0.154       0.003
# CollabAcademicAgeAtCollaboration_CI_95lower             -3.970      -4.530
# CollabAcademicAgeAtCollaboration_CI_95upper              0.440      -1.070
#
#                                                     Mistake
# CollabAcademicAgeAtCollaboration_retracted_mean      15.110
# CollabAcademicAgeAtCollaboration_retracted_median    15.460
# CollabAcademicAgeAtCollaboration_retracted_std        6.750
# CollabAcademicAgeAtCollaboration_nonretracted_mean   15.880
# CollabAcademicAgeAtCollaboration_nonretracted_m...   14.640
# CollabAcademicAgeAtCollaboration_nonretracted_std     7.140
# CollabAcademicAgeAtCollaboration_delta_mean          -0.770
# CollabAcademicAgeAtCollaboration_pval_welch           0.401
# CollabAcademicAgeAtCollaboration_CI_95lower          -2.290
# CollabAcademicAgeAtCollaboration_CI_95upper           0.740

# %%
pd.DataFrame(lst_dicts_retention[1])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumPapersAtCollaboration_retracted_mean        69.800      63.890
# CollabMAGCumPapersAtCollaboration_retracted_median      46.510      44.000
# CollabMAGCumPapersAtCollaboration_retracted_std         96.540      68.830
# CollabMAGCumPapersAtCollaboration_nonretracted_...      93.750      66.410
# CollabMAGCumPapersAtCollaboration_nonretracted_...      63.280      57.000
# CollabMAGCumPapersAtCollaboration_nonretracted_std     176.220      59.840
# CollabMAGCumPapersAtCollaboration_delta_mean           -23.940      -2.520
# CollabMAGCumPapersAtCollaboration_pval_welch             0.343       0.759
# CollabMAGCumPapersAtCollaboration_CI_95lower           -75.210     -18.700
# CollabMAGCumPapersAtCollaboration_CI_95upper            27.320      13.660
#
#                                                     Mistake
# CollabMAGCumPapersAtCollaboration_retracted_mean     69.930
# CollabMAGCumPapersAtCollaboration_retracted_median   53.000
# CollabMAGCumPapersAtCollaboration_retracted_std      72.680
# CollabMAGCumPapersAtCollaboration_nonretracted_...   74.760
# CollabMAGCumPapersAtCollaboration_nonretracted_...   61.670
# CollabMAGCumPapersAtCollaboration_nonretracted_std   55.390
# CollabMAGCumPapersAtCollaboration_delta_mean         -4.820
# CollabMAGCumPapersAtCollaboration_pval_welch          0.572
# CollabMAGCumPapersAtCollaboration_CI_95lower        -21.620
# CollabMAGCumPapersAtCollaboration_CI_95upper         11.980

# %%
pd.DataFrame(lst_dicts_retention[2])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCitationsAtCollaboration_retracted_...    1498.480    1158.960
# CollabMAGCumCitationsAtCollaboration_retracted_...     532.420     410.500
# CollabMAGCumCitationsAtCollaboration_retracted_std    2443.600    2846.240
# CollabMAGCumCitationsAtCollaboration_nonretract...    1683.140    1009.080
# CollabMAGCumCitationsAtCollaboration_nonretract...    1037.170     497.780
# CollabMAGCumCitationsAtCollaboration_nonretract...    2759.870    1440.510
# CollabMAGCumCitationsAtCollaboration_delta_mean       -184.670     149.880
# CollabMAGCumCitationsAtCollaboration_pval_welch          0.689       0.603
# CollabMAGCumCitationsAtCollaboration_CI_95lower      -1116.730    -390.570
# CollabMAGCumCitationsAtCollaboration_CI_95upper        747.400     690.330
#
#                                                      Mistake
# CollabMAGCumCitationsAtCollaboration_retracted_...  1487.990
# CollabMAGCumCitationsAtCollaboration_retracted_...   862.220
# CollabMAGCumCitationsAtCollaboration_retracted_std  1947.440
# CollabMAGCumCitationsAtCollaboration_nonretract...  1568.090
# CollabMAGCumCitationsAtCollaboration_nonretract...   924.000
# CollabMAGCumCitationsAtCollaboration_nonretract...  2243.950
# CollabMAGCumCitationsAtCollaboration_delta_mean      -80.110
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.773
# CollabMAGCumCitationsAtCollaboration_CI_95lower     -609.850
# CollabMAGCumCitationsAtCollaboration_CI_95upper      449.640

# %%
pd.DataFrame(lst_dicts_retention[3])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     194.340     140.040
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     102.000      70.860
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     326.470     175.550
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     272.990     140.570
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     142.930      95.250
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     712.280     170.370
# CollabMAGCumCollaboratorsAtCollaboration_delta_...     -78.650      -0.530
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...       0.424       0.981
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...    -281.120     -43.020
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...     123.820      41.950
#
#                                                     Mistake
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   175.55
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   101.00
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   203.20
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   162.51
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   120.29
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   149.90
# CollabMAGCumCollaboratorsAtCollaboration_delta_...    13.05
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...     0.58
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...   -31.83
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...    57.92

# %% [markdown]
# ### A2: Collaborators gained: retracted vs. matched

# %%
#Let us now modify df_A1 such that we remove all rows with collaborations pre-retraction

df_A2_post = df_A[df_A['PrePostFlag5']=='post5']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A2_firstcollabs = df_A2_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A2_w_firstcollabs = df_A2_post.merge(df_A2_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A2_w_firstcollabs.shape
# Out:
# (66141, 36)

# %%
# Sensibility checks

df_A2_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#           MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 2121  19100288.0      18011520                2004.0
# 2128  19100288.0     121410733                2004.0
# 2109  19100288.0     410625722                2005.0
# 2122  19100288.0    1235268530                2004.0
# 2131  19100288.0    1340583028                2006.0
# 2103  19100288.0    1793107545                2003.0
# 2104  19100288.0    1793107545                2004.0
# 2123  19100288.0    1859744180                2004.0
# 2105  19100288.0    1863203661                2003.0
# 2106  19100288.0    1863203661                2004.0
# 2108  19100288.0    1863203661                2006.0
# 2107  19100288.0    1863203661                2007.0
# 2100  19100288.0    1986621809                2006.0
# 2099  19100288.0    1986621809                2007.0
# 2124  19100288.0    2004612287                2004.0
# 2115  19100288.0    2043645593                2004.0
# 2116  19100288.0    2043645593                2007.0
# 2129  19100288.0    2051205987                2004.0
# 2134  19100288.0    2078618456                2003.0
# 2135  19100288.0    2111905563                2003.0
# 2120  19100288.0    2115457216                2003.0
# 2117  19100288.0    2115457216                2004.0
# 2119  19100288.0    2115457216                2006.0
# 2118  19100288.0    2115457216                2007.0
# 2111  19100288.0    2128982626                2004.0
# 2110  19100288.0    2128982626                2005.0
# 2112  19100288.0    2128982626                2007.0
# 2125  19100288.0    2134604144                2004.0
# 2130  19100288.0    2149884334                2004.0
# 2113  19100288.0    2151293749                2005.0
#
#       FirstPostRetractionMAGCollaborationYear
# 2121                                   2004.0
# 2128                                   2004.0
# 2109                                   2005.0
# 2122                                   2004.0
# 2131                                   2006.0
# 2103                                   2003.0
# 2104                                   2003.0
# 2123                                   2004.0
# 2105                                   2003.0
# 2106                                   2003.0
# 2108                                   2003.0
# 2107                                   2003.0
# 2100                                   2006.0
# 2099                                   2006.0
# 2124                                   2004.0
# 2115                                   2004.0
# 2116                                   2004.0
# 2129                                   2004.0
# 2134                                   2003.0
# 2135                                   2003.0
# 2120                                   2003.0
# 2117                                   2003.0
# 2119                                   2003.0
# 2118                                   2003.0
# 2111                                   2004.0
# 2110                                   2004.0
# 2112                                   2004.0
# 2125                                   2004.0
# 2130                                   2004.0
# 2113                                   2005.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A2_w_firstcollabs_only = df_A2_w_firstcollabs[df_A2_w_firstcollabs.MAGCollaborationYear == \
                                                df_A2_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A2_w_firstcollabs_only.shape
# Out:
# (50527, 36)

# %%
df_A2_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'MAGAIDFirstORLastAuthorFlag',
#        'CollabAcademicAgeAtRetraction', 'CollabAcademicAgeAtCollaboration',
#        'PrePostFlag5', 'post5', 'pre', 'NumRetentionW5', 'CollabAIDRetainedW5',
#        'CollabAIDLostW5', 'NumNewCollaboratorsW5', 'CollabAIDGainedW5',
#        'CollabAIDinRetained', 'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
def create_stratified_dfs_gain(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
               'CollabMAGCumPapersAtCollaboration', 'CollabMAGCumCitationsAtCollaboration',
               'CollabMAGCumCollaboratorsAtCollaboration', 'ReasonPropagatedMajorityOfMajority',
               'CollabAcademicAgeAtCollaboration', 'CollabAIDinGained', 'NumNewCollaboratorsW5']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi = dfi[dfi['CollabAIDinGained']]
    
    # Dividing into retracted and matched
    df_retracted = dfi[dfi.ScientistType == 'retracted']
    df_nonretracted = dfi[dfi.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the retracted scientists have matches with non zero collaborators
    df_retracted = df_retracted[df_retracted.MAGAID.isin(df_nonretracted.MAGAID.unique())]
    
    # We need to make sure that the matches of those who retained 0 collaborators are removed
    df_nonretracted = df_nonretracted[df_nonretracted.MAGAID.isin(df_retracted.MAGAID.unique())]
    
    # Dividing into seniority for retracted
    df_retracted_junior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_retracted_midcareer = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_retracted_senior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='mistake']
    # and matched
    df_nonretracted_junior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_nonretracted_midcareer = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_nonretracted_senior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='mistake']
    
    return df_retracted_junior, df_retracted_midcareer, df_retracted_senior,df_nonretracted_junior, df_nonretracted_midcareer, df_nonretracted_senior

# %%
df_rj, df_rm, df_rs, df_nrj, df_nrm, df_nrs = create_stratified_dfs_gain(df_A2_w_firstcollabs_only)

# %%
df_rj.MAGAID.nunique(), df_rm.MAGAID.nunique(), df_rs.MAGAID.nunique(), df_nrj.MAGAID.nunique(), df_nrm.MAGAID.nunique(), df_nrs.MAGAID.nunique()
# Out:
# (69, 125, 120, 69, 125, 120)

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_gain(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtCollaboration':'MatchCollabMAGCumPapersAtCollaboration',
                                    'CollabAcademicAgeAtCollaboration':'MatchCollabAcademicAgeAtCollaboration',
                                    'CollabMAGCumCitationsAtCollaboration': 'MatchCollabMAGCumCitationsAtCollaboration',
                                    'CollabMAGCumCollaboratorsAtCollaboration': 'MatchCollabMAGCumCollaboratorsAtCollaboration'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj, mean_dfnrj = get_mean_df_gain(df_rj, df_nrj)
mean_dfrm, mean_dfnrm = get_mean_df_gain(df_rm, df_nrm)
mean_dfrs, mean_dfnrs = get_mean_df_gain(df_rs, df_nrs)

mean_dfnrj
# Out:
#             MatchCollabAcademicAgeAtCollaboration  \
# MAGAID
# 48740240                                 9.166667
# 115663519                                3.840000
# 207280435                               12.034483
# 409654858                               11.400000
# 1126006285                              13.444444
# ...                                           ...
# 2889150962                               7.543082
# 2890048425                               5.318182
# 2935995536                               0.321429
# 2947073985                              10.531915
# 3052744139                               6.987405
#
#             MatchCollabMAGCumPapersAtCollaboration  \
# MAGAID
# 48740240                                 34.000000
# 115663519                                13.906667
# 207280435                                37.310345
# 409654858                                40.246154
# 1126006285                               28.666667
# ...                                            ...
# 2889150962                               22.223316
# 2890048425                               45.909091
# 2935995536                                1.964286
# 2947073985                               43.297872
# 3052744139                               53.289624
#
#             MatchCollabMAGCumCitationsAtCollaboration  \
# MAGAID
# 48740240                                   624.500000
# 115663519                                  183.520000
# 207280435                                  563.172414
# 409654858                                 1196.446154
# 1126006285                                 481.666667
# ...                                               ...
# 2889150962                                 528.895626
# 2890048425                                 921.818182
# 2935995536                                   0.892857
# 2947073985                                 651.078014
# 3052744139                                1168.337350
#
#             MatchCollabMAGCumCollaboratorsAtCollaboration
# MAGAID
# 48740240                                        71.333333
# 115663519                                       52.933333
# 207280435                                       90.241379
# 409654858                                      115.800000
# 1126006285                                      57.333333
# ...                                                   ...
# 2889150962                                      57.686717
# 2890048425                                     122.590909
# 2935995536                                       4.892857
# 2947073985                                      96.872340
# 3052744139                                     245.023625
#
# [69 rows x 4 columns]

# %%
exp_fields = ['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_gain = []

for exp_field in exp_fields:
    dicts_gain = {}
    
    dict_stats_j = get_stats(mean_dfrj, mean_dfnrj, exp_field)
    dict_stats_m = get_stats(mean_dfrm, mean_dfnrm, exp_field)
    dict_stats_s = get_stats(mean_dfrs, mean_dfnrs, exp_field)
    
    dicts_gain['Misconduct'] = dict_stats_j
    dicts_gain['Plagiarism'] = dict_stats_m
    dicts_gain['Mistake'] = dict_stats_s
    
    lst_dicts_gain.append(dicts_gain)

# %%
pd.DataFrame(lst_dicts_gain[0])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabAcademicAgeAtCollaboration_retracted_mean          7.220       6.490
# CollabAcademicAgeAtCollaboration_retracted_median        6.500       6.100
# CollabAcademicAgeAtCollaboration_retracted_std           6.340       4.830
# CollabAcademicAgeAtCollaboration_nonretracted_mean       7.540       7.730
# CollabAcademicAgeAtCollaboration_nonretracted_m...       7.400       7.330
# CollabAcademicAgeAtCollaboration_nonretracted_std        3.970       5.210
# CollabAcademicAgeAtCollaboration_delta_mean             -0.320      -1.240
# CollabAcademicAgeAtCollaboration_pval_welch              0.722       0.052
# CollabAcademicAgeAtCollaboration_CI_95lower             -1.810      -2.410
# CollabAcademicAgeAtCollaboration_CI_95upper              1.170      -0.070
#
#                                                     Mistake
# CollabAcademicAgeAtCollaboration_retracted_mean       8.890
# CollabAcademicAgeAtCollaboration_retracted_median     8.670
# CollabAcademicAgeAtCollaboration_retracted_std        4.970
# CollabAcademicAgeAtCollaboration_nonretracted_mean    7.950
# CollabAcademicAgeAtCollaboration_nonretracted_m...    7.820
# CollabAcademicAgeAtCollaboration_nonretracted_std     3.950
# CollabAcademicAgeAtCollaboration_delta_mean           0.940
# CollabAcademicAgeAtCollaboration_pval_welch           0.107
# CollabAcademicAgeAtCollaboration_CI_95lower          -0.110
# CollabAcademicAgeAtCollaboration_CI_95upper           1.980

# %%
pd.DataFrame(lst_dicts_gain[1])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumPapersAtCollaboration_retracted_mean        40.070      29.840
# CollabMAGCumPapersAtCollaboration_retracted_median      28.000      20.920
# CollabMAGCumPapersAtCollaboration_retracted_std         42.090      32.650
# CollabMAGCumPapersAtCollaboration_nonretracted_...      35.180      31.830
# CollabMAGCumPapersAtCollaboration_nonretracted_...      32.470      27.890
# CollabMAGCumPapersAtCollaboration_nonretracted_std      21.420      24.460
# CollabMAGCumPapersAtCollaboration_delta_mean             4.880      -1.990
# CollabMAGCumPapersAtCollaboration_pval_welch             0.392       0.587
# CollabMAGCumPapersAtCollaboration_CI_95lower            -5.800      -8.830
# CollabMAGCumPapersAtCollaboration_CI_95upper            15.560       4.850
#
#                                                     Mistake
# CollabMAGCumPapersAtCollaboration_retracted_mean     43.200
# CollabMAGCumPapersAtCollaboration_retracted_median   35.890
# CollabMAGCumPapersAtCollaboration_retracted_std      35.950
# CollabMAGCumPapersAtCollaboration_nonretracted_...   37.480
# CollabMAGCumPapersAtCollaboration_nonretracted_...   29.130
# CollabMAGCumPapersAtCollaboration_nonretracted_std   32.200
# CollabMAGCumPapersAtCollaboration_delta_mean          5.720
# CollabMAGCumPapersAtCollaboration_pval_welch          0.195
# CollabMAGCumPapersAtCollaboration_CI_95lower         -2.420
# CollabMAGCumPapersAtCollaboration_CI_95upper         13.870

# %%
pd.DataFrame(lst_dicts_gain[2])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCitationsAtCollaboration_retracted_...    1076.050     493.040
# CollabMAGCumCitationsAtCollaboration_retracted_...     377.000     208.300
# CollabMAGCumCitationsAtCollaboration_retracted_std    2407.450     807.300
# CollabMAGCumCitationsAtCollaboration_nonretract...     701.720     569.000
# CollabMAGCumCitationsAtCollaboration_nonretract...     455.600     299.030
# CollabMAGCumCitationsAtCollaboration_nonretract...     775.030     740.290
# CollabMAGCumCitationsAtCollaboration_delta_mean        374.320     -75.960
# CollabMAGCumCitationsAtCollaboration_pval_welch          0.222       0.439
# CollabMAGCumCitationsAtCollaboration_CI_95lower       -219.000    -249.690
# CollabMAGCumCitationsAtCollaboration_CI_95upper        967.650      97.770
#
#                                                      Mistake
# CollabMAGCumCitationsAtCollaboration_retracted_...  1044.050
# CollabMAGCumCitationsAtCollaboration_retracted_...   626.400
# CollabMAGCumCitationsAtCollaboration_retracted_std  1289.480
# CollabMAGCumCitationsAtCollaboration_nonretract...   918.020
# CollabMAGCumCitationsAtCollaboration_nonretract...   398.870
# CollabMAGCumCitationsAtCollaboration_nonretract...  1590.280
# CollabMAGCumCitationsAtCollaboration_delta_mean      126.040
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.501
# CollabMAGCumCitationsAtCollaboration_CI_95lower     -239.470
# CollabMAGCumCitationsAtCollaboration_CI_95upper      491.540

# %%
pd.DataFrame(lst_dicts_gain[3])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     121.880      98.820
# CollabMAGCumCollaboratorsAtCollaboration_retrac...      74.430      39.760
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     157.370     179.720
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     115.580      85.220
# CollabMAGCumCollaboratorsAtCollaboration_nonret...      75.520      55.550
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     155.200      89.080
# CollabMAGCumCollaboratorsAtCollaboration_delta_...       6.310      13.600
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...       0.813       0.449
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...     -48.730     -18.110
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...      61.340      45.310
#
#                                                     Mistake
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  181.710
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   74.440
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  317.590
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  108.250
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   71.710
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  117.650
# CollabMAGCumCollaboratorsAtCollaboration_delta_...   73.460
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...    0.019
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...   14.620
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...  132.300

# %%
def create_latex_for_filling(dicto, col):
    
    def create_string(metric):
        string = ""
        if metric == 'pval_welch':
            string = "& " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                "\\\ \n"
        else:
            string = "& " + \
                    str(dicto.get('Misconduct').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Misconduct').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_nonretracted_"+metric)) + \
                    "\\\ \n"
        
        
        
        return string
    
    print(create_string("mean"))
    print(create_string("median"))
    print(create_string("std"))
    print(create_string("pval_welch"))
    

for i in range(len(lst_dicts_retention)):
    dicto = lst_dicts_retention[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto, col)
    
    
# pd.DataFrame(lst_dicts_retention[0])
# Out:
# CollabAcademicAgeAtCollaboration
# & 12.92 & 14.68 & 12.61 & 15.41 & 15.11 & 15.88\\
#
# & 13.86 & 13.36 & 12.5 & 13.73 & 15.46 & 14.64\\
#
# & 7.12 & 6.8 & 6.97 & 7.87 & 6.75 & 7.14\\
#
# & 0.154 & 0.154 & 0.003 & 0.003 & 0.401 & 0.401\\
#
# CollabMAGCumPapersAtCollaboration
# & 69.8 & 93.75 & 63.89 & 66.41 & 69.93 & 74.76\\
#
# & 46.51 & 63.28 & 44.0 & 57.0 & 53.0 & 61.67\\
#
# & 96.54 & 176.22 & 68.83 & 59.84 & 72.68 & 55.39\\
#
# & 0.343 & 0.343 & 0.759 & 0.759 & 0.572 & 0.572\\
#
# CollabMAGCumCitationsAtCollaboration
# & 1498.48 & 1683.14 & 1158.96 & 1009.08 & 1487.99 & 1568.09\\
#
# & 532.42 & 1037.17 & 410.5 & 497.78 & 862.22 & 924.0\\
#
# & 2443.6 & 2759.87 & 2846.24 & 1440.51 & 1947.44 & 2243.95\\
#
# & 0.689 & 0.689 & 0.603 & 0.603 & 0.773 & 0.773\\
#
# CollabMAGCumCollaboratorsAtCollaboration
# & 194.34 & 272.99 & 140.04 & 140.57 & 175.55 & 162.51\\
#
# & 102.0 & 142.93 & 70.86 & 95.25 & 101.0 & 120.29\\
#
# & 326.47 & 712.28 & 175.55 & 170.37 & 203.2 & 149.9\\
#
# & 0.424 & 0.424 & 0.981 & 0.981 & 0.58 & 0.58\\

# %%
for i in range(len(lst_dicts_gain)):
    dicto = lst_dicts_gain[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto, col)
# Out:
# CollabAcademicAgeAtCollaboration
# & 7.22 & 7.54 & 6.49 & 7.73 & 8.89 & 7.95\\
#
# & 6.5 & 7.4 & 6.1 & 7.33 & 8.67 & 7.82\\
#
# & 6.34 & 3.97 & 4.83 & 5.21 & 4.97 & 3.95\\
#
# & 0.722 & 0.722 & 0.052 & 0.052 & 0.107 & 0.107\\
#
# CollabMAGCumPapersAtCollaboration
# & 40.07 & 35.18 & 29.84 & 31.83 & 43.2 & 37.48\\
#
# & 28.0 & 32.47 & 20.92 & 27.89 & 35.89 & 29.13\\
#
# & 42.09 & 21.42 & 32.65 & 24.46 & 35.95 & 32.2\\
#
# & 0.392 & 0.392 & 0.587 & 0.587 & 0.195 & 0.195\\
#
# CollabMAGCumCitationsAtCollaboration
# & 1076.05 & 701.72 & 493.04 & 569.0 & 1044.05 & 918.02\\
#
# & 377.0 & 455.6 & 208.3 & 299.03 & 626.4 & 398.87\\
#
# & 2407.45 & 775.03 & 807.3 & 740.29 & 1289.48 & 1590.28\\
#
# & 0.222 & 0.222 & 0.439 & 0.439 & 0.501 & 0.501\\
#
# CollabMAGCumCollaboratorsAtCollaboration
# & 121.88 & 115.58 & 98.82 & 85.22 & 181.71 & 108.25\\
#
# & 74.43 & 75.52 & 39.76 & 55.55 & 74.44 & 71.71\\
#
# & 157.37 & 155.2 & 179.72 & 89.08 & 317.59 & 117.65\\
#
# & 0.813 & 0.813 & 0.449 & 0.449 & 0.019 & 0.019\\

# %% [markdown]
# ### A3: Collaborators retained vs lost: retracted vs. matched

# %%
#Let us now modify df_A3 such that we remove all rows with collaborations pre-retraction

df_A3_post = df_A[df_A['PrePostFlag5']=='post5']
df_A3_pre = df_A[df_A['PrePostFlag5']=='pre']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A3_firstcollabs = df_A3_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A3_w_firstcollabs = df_A3_post.merge(df_A1_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A3_w_firstcollabs.shape
# Out:
# (66141, 36)

# %%
# Sensibility checks

df_A3_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#           MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 2121  19100288.0      18011520                2004.0
# 2128  19100288.0     121410733                2004.0
# 2109  19100288.0     410625722                2005.0
# 2122  19100288.0    1235268530                2004.0
# 2131  19100288.0    1340583028                2006.0
# 2103  19100288.0    1793107545                2003.0
# 2104  19100288.0    1793107545                2004.0
# 2123  19100288.0    1859744180                2004.0
# 2105  19100288.0    1863203661                2003.0
# 2106  19100288.0    1863203661                2004.0
# 2108  19100288.0    1863203661                2006.0
# 2107  19100288.0    1863203661                2007.0
# 2100  19100288.0    1986621809                2006.0
# 2099  19100288.0    1986621809                2007.0
# 2124  19100288.0    2004612287                2004.0
# 2115  19100288.0    2043645593                2004.0
# 2116  19100288.0    2043645593                2007.0
# 2129  19100288.0    2051205987                2004.0
# 2134  19100288.0    2078618456                2003.0
# 2135  19100288.0    2111905563                2003.0
# 2120  19100288.0    2115457216                2003.0
# 2117  19100288.0    2115457216                2004.0
# 2119  19100288.0    2115457216                2006.0
# 2118  19100288.0    2115457216                2007.0
# 2111  19100288.0    2128982626                2004.0
# 2110  19100288.0    2128982626                2005.0
# 2112  19100288.0    2128982626                2007.0
# 2125  19100288.0    2134604144                2004.0
# 2130  19100288.0    2149884334                2004.0
# 2113  19100288.0    2151293749                2005.0
#
#       FirstPostRetractionMAGCollaborationYear
# 2121                                   2004.0
# 2128                                   2004.0
# 2109                                   2005.0
# 2122                                   2004.0
# 2131                                   2006.0
# 2103                                   2003.0
# 2104                                   2003.0
# 2123                                   2004.0
# 2105                                   2003.0
# 2106                                   2003.0
# 2108                                   2003.0
# 2107                                   2003.0
# 2100                                   2006.0
# 2099                                   2006.0
# 2124                                   2004.0
# 2115                                   2004.0
# 2116                                   2004.0
# 2129                                   2004.0
# 2134                                   2003.0
# 2135                                   2003.0
# 2120                                   2003.0
# 2117                                   2003.0
# 2119                                   2003.0
# 2118                                   2003.0
# 2111                                   2004.0
# 2110                                   2004.0
# 2112                                   2004.0
# 2125                                   2004.0
# 2130                                   2004.0
# 2113                                   2005.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A3_w_firstcollabs_only = df_A3_w_firstcollabs[df_A3_w_firstcollabs.MAGCollaborationYear == \
                                                df_A3_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A3_w_firstcollabs_only.shape
# Out:
# (50527, 36)

# %%
df_A3_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'MAGAIDFirstORLastAuthorFlag',
#        'CollabAcademicAgeAtRetraction', 'CollabAcademicAgeAtCollaboration',
#        'PrePostFlag5', 'post5', 'pre', 'NumRetentionW5', 'CollabAIDRetainedW5',
#        'CollabAIDLostW5', 'NumNewCollaboratorsW5', 'CollabAIDGainedW5',
#        'CollabAIDinRetained', 'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
# Finally let us merge post and pre

df_A3_post_pre = pd.concat([df_A3_w_firstcollabs_only,df_A3_pre])

df_A3_post_pre.head()
# Out:
#           MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 2   2.033335e+09    1917877966          1995.0                1998.0
# 4   2.033335e+09    2169118091          1995.0                1998.0
# 7   2.033335e+09     275085591          1995.0                1996.0
# 9   2.033335e+09    2111014462          1995.0                1996.0
# 12  2.033335e+09    2622920657          1995.0                1996.0
#
#    ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 2      retracted                  male                       0.99
# 4      retracted                  male                       1.00
# 7      retracted                  male                       0.99
# 9      retracted                female                       0.98
# 12     retracted                  male                       0.99
#
#     CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 2                  1994.0                              1994.0
# 4                  1995.0                              1995.0
# 7                  1994.0                              1995.0
# 9                  1988.0                              1995.0
# 12                 1991.0                              1995.0
#
#     CollabMAGCumPapersAtRetraction  ...  \
# 2                              1.0  ...
# 4                              1.0  ...
# 7                              5.0  ...
# 9                             17.0  ...
# 12                            17.0  ...
#
#                                                   pre  NumRetentionW5  \
# 2   {2041262087, 2590561305, 1940968476, 211428099...              23
# 4   {2041262087, 2590561305, 1940968476, 211428099...              23
# 7   {2041262087, 2590561305, 1940968476, 211428099...              23
# 9   {2041262087, 2590561305, 1940968476, 211428099...              23
# 12  {2041262087, 2590561305, 1940968476, 211428099...              23
#
#                                   CollabAIDRetainedW5  \
# 2   {2690057605, 2041262087, 2466141063, 230478619...
# 4   {2690057605, 2041262087, 2466141063, 230478619...
# 7   {2690057605, 2041262087, 2466141063, 230478619...
# 9   {2690057605, 2041262087, 2466141063, 230478619...
# 12  {2690057605, 2041262087, 2466141063, 230478619...
#
#                                       CollabAIDLostW5  NumNewCollaboratorsW5  \
# 2   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 4   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 7   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 9   {2590561305, 1940968476, 2657016352, 265692164...                     60
# 12  {2590561305, 1940968476, 2657016352, 265692164...                     60
#
#                                     CollabAIDGainedW5  CollabAIDinRetained  \
# 2   {1973921793, 2308182914, 1147890307, 265602649...                False
# 4   {1973921793, 2308182914, 1147890307, 265602649...                False
# 7   {1973921793, 2308182914, 1147890307, 265602649...                 True
# 9   {1973921793, 2308182914, 1147890307, 265602649...                 True
# 12  {1973921793, 2308182914, 1147890307, 265602649...                 True
#
#     CollabAIDinGained  CollabAIDinLost  \
# 2                True            False
# 4                True            False
# 7               False            False
# 9               False            False
# 12              False            False
#
#     FirstPostRetractionMAGCollaborationYear
# 2                                    1998.0
# 4                                    1998.0
# 7                                    1996.0
# 9                                    1996.0
# 12                                   1996.0
#
# [5 rows x 36 columns]

# %%
def create_stratified_dfs_a3(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear',
               'CollabMAGCumPapersAtRetraction', 'CollabMAGCumCitationsAtRetraction',
               'CollabMAGCumCollaboratorsAtRetraction', 'ReasonPropagatedMajorityOfMajority',
               'CollabAcademicAgeAtRetraction', 'CollabAIDinRetained', 'CollabAIDinLost']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi_retained = dfi[dfi['CollabAIDinRetained']]
    dfi_lost = dfi[dfi['CollabAIDinLost']]
    
    # Dividing into retracted and matched
    df_retracted_retained = dfi_retained[dfi_retained.ScientistType == 'retracted']
    df_retracted_lost = dfi_lost[dfi_lost.ScientistType == 'retracted']
    
    df_nonretracted_retained = dfi_retained[dfi_retained.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    df_nonretracted_lost = dfi_lost[dfi_lost.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the four groups retracted,non-retracted,retained,lost have same ids
    
    set1 = set(df_retracted_retained['MAGAID'].unique())
    set2 = set(df_retracted_lost['MAGAID'].unique())
    set3 = set(df_nonretracted_retained['MAGAID'].unique())
    set4 = set(df_nonretracted_lost['MAGAID'].unique())
    
    magaids_intersection = set1.intersection(set2, set3, set4)
    
    df_retracted_retained = df_retracted_retained[df_retracted_retained.MAGAID.isin(magaids_intersection)]
    df_retracted_lost = df_retracted_lost[df_retracted_lost.MAGAID.isin(magaids_intersection)]
    df_nonretracted_retained = df_nonretracted_retained[df_nonretracted_retained.MAGAID.isin(magaids_intersection)]
    df_nonretracted_lost = df_nonretracted_lost[df_nonretracted_lost.MAGAID.isin(magaids_intersection)]

    
    # Dividing into seniority for retracted retained
    
    dfrj_r = df_retracted_retained[df_retracted_retained.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfrm_r = df_retracted_retained[df_retracted_retained.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfrs_r = df_retracted_retained[df_retracted_retained.ReasonPropagatedMajorityOfMajority=='mistake']
    
    dfrj_l = df_retracted_lost[df_retracted_lost.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfrm_l = df_retracted_lost[df_retracted_lost.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfrs_l = df_retracted_lost[df_retracted_lost.ReasonPropagatedMajorityOfMajority=='mistake']
    
    # and matched
    dfnrj_r = df_nonretracted_retained[df_nonretracted_retained.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfnrm_r = df_nonretracted_retained[df_nonretracted_retained.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfnrs_r = df_nonretracted_retained[df_nonretracted_retained.ReasonPropagatedMajorityOfMajority=='mistake']
    
    dfnrj_l = df_nonretracted_lost[df_nonretracted_lost.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfnrm_l = df_nonretracted_lost[df_nonretracted_lost.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfnrs_l = df_nonretracted_lost[df_nonretracted_lost.ReasonPropagatedMajorityOfMajority=='mistake']
    
    return [dfrj_r,dfrm_r,dfrs_r,dfrj_l,dfrm_l,dfrs_l,dfnrj_r,dfnrm_r,dfnrs_r,dfnrj_l,dfnrm_l,dfnrs_l]

# %%
lst_stratified_dfs = create_stratified_dfs_a3(df_A3_post_pre)

for dfj in lst_stratified_dfs:
    print(dfj.MAGAID.nunique())
    
dfrj_r,dfrm_r,dfrs_r,dfrj_l,dfrm_l,dfrs_l,dfnrj_r,dfnrm_r,dfnrs_r,dfnrj_l,dfnrm_l,dfnrs_l = lst_stratified_dfs
# Out:
# 62
# 115
# 111
# 62
# 115
# 111
# 62
# 115
# 111
# 62
# 115
# 111

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_a3(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtRetraction',
                      'CollabMAGCumPapersAtRetraction',
                      'CollabMAGCumCitationsAtRetraction',
                      'CollabMAGCumCollaboratorsAtRetraction']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtRetraction',
                      'CollabMAGCumPapersAtRetraction',
                      'CollabMAGCumCitationsAtRetraction',
                      'CollabMAGCumCollaboratorsAtRetraction']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtRetraction':'MatchCollabMAGCumPapersAtRetraction',
                                    'CollabAcademicAgeAtRetraction':'MatchCollabAcademicAgeAtRetraction',
                                    'CollabMAGCumCitationsAtRetraction': 'MatchCollabMAGCumCitationsAtRetraction',
                                    'CollabMAGCumCollaboratorsAtRetraction': 'MatchCollabMAGCumCollaboratorsAtRetraction'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj_r, mean_dfnrj_r = get_mean_df_a3(dfrj_r, dfnrj_r)
mean_dfrj_l, mean_dfnrj_l = get_mean_df_a3(dfrj_l, dfnrj_l)

mean_dfrm_r, mean_dfnrm_r = get_mean_df_a3(dfrm_r, dfnrm_r)
mean_dfrm_l, mean_dfnrm_l = get_mean_df_a3(dfrm_l, dfnrm_l)

mean_dfrs_r, mean_dfnrs_r = get_mean_df_a3(dfrs_r, dfnrs_r)
mean_dfrs_l, mean_dfnrs_l = get_mean_df_a3(dfrs_l, dfnrs_l)


# Now let us compute differences

def compute_diff_df(df_ri, df_li, scientistType='retracted'):
    
    dfrli = df_ri.merge(df_li, right_index=True, left_index=True)
    
    if scientistType == 'matched':
        
        dfrli['MatchDiffAcademicAgeAtRetraction'] = dfrli['MatchCollabAcademicAgeAtRetraction_x'] - \
                                                dfrli['MatchCollabAcademicAgeAtRetraction_y']
        
        dfrli['MatchDiffMAGCumPapersAtRetraction'] = dfrli['MatchCollabMAGCumPapersAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumPapersAtRetraction_y']
        
        dfrli['MatchDiffMAGCumCitationsAtRetraction'] = dfrli['MatchCollabMAGCumCitationsAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumCitationsAtRetraction_y']
        
        dfrli['MatchDiffMAGCumCollaboratorsAtRetraction'] = dfrli['MatchCollabMAGCumCollaboratorsAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumCollaboratorsAtRetraction_y']
        
        return dfrli
    
        
    dfrli['DiffAcademicAgeAtRetraction'] = dfrli['CollabAcademicAgeAtRetraction_x'] - \
                                            dfrli['CollabAcademicAgeAtRetraction_y']

    dfrli['DiffMAGCumPapersAtRetraction'] = dfrli['CollabMAGCumPapersAtRetraction_x'] - \
                                            dfrli['CollabMAGCumPapersAtRetraction_y']

    dfrli['DiffMAGCumCitationsAtRetraction'] = dfrli['CollabMAGCumCitationsAtRetraction_x'] - \
                                            dfrli['CollabMAGCumCitationsAtRetraction_y']

    dfrli['DiffMAGCumCollaboratorsAtRetraction'] = dfrli['CollabMAGCumCollaboratorsAtRetraction_x'] - \
                                            dfrli['CollabMAGCumCollaboratorsAtRetraction_y']

    return dfrli

# %%
dfrj_rMinusl = compute_diff_df(mean_dfrj_r, mean_dfrj_l)
dfnrj_rMinusl = compute_diff_df(mean_dfnrj_r, mean_dfnrj_l, scientistType='matched')


dfrm_rMinusl = compute_diff_df(mean_dfrm_r, mean_dfrm_l)
dfnrm_rMinusl = compute_diff_df(mean_dfnrm_r, mean_dfnrm_l, scientistType='matched')

dfrs_rMinusl = compute_diff_df(mean_dfrs_r, mean_dfrs_l)
dfnrs_rMinusl = compute_diff_df(mean_dfnrs_r, mean_dfnrs_l, scientistType='matched')

# %%
exp_fields = ['DiffAcademicAgeAtRetraction',
              'DiffMAGCumPapersAtRetraction',
              'DiffMAGCumCitationsAtRetraction',
              'DiffMAGCumCollaboratorsAtRetraction']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_a3 = []

for exp_field in exp_fields:
    dicts_a3 = {}
    
    dict_stats_j = get_stats(dfrj_rMinusl, dfnrj_rMinusl, exp_field)
    dict_stats_m = get_stats(dfrm_rMinusl, dfnrm_rMinusl, exp_field)
    dict_stats_s = get_stats(dfrs_rMinusl, dfnrs_rMinusl, exp_field)
    
    dicts_a3['Misconduct'] = dict_stats_j
    dicts_a3['Plagiarism'] = dict_stats_m
    dicts_a3['Mistake'] = dict_stats_s
    
    lst_dicts_a3.append(dicts_a3)

# %%
pd.DataFrame(lst_dicts_a3[0])
# Out:
#                                                  Misconduct  Plagiarism  \
# DiffAcademicAgeAtRetraction_retracted_mean            0.850        1.59
# DiffAcademicAgeAtRetraction_retracted_median          0.150        1.00
# DiffAcademicAgeAtRetraction_retracted_std             6.640        6.08
# DiffAcademicAgeAtRetraction_nonretracted_mean         1.890        3.07
# DiffAcademicAgeAtRetraction_nonretracted_median       1.010        1.62
# DiffAcademicAgeAtRetraction_nonretracted_std          6.900        7.79
# DiffAcademicAgeAtRetraction_delta_mean               -1.030       -1.48
# DiffAcademicAgeAtRetraction_pval_welch                0.398        0.11
# DiffAcademicAgeAtRetraction_CI_95lower               -3.180       -3.09
# DiffAcademicAgeAtRetraction_CI_95upper                1.120        0.13
#
#                                                  Mistake
# DiffAcademicAgeAtRetraction_retracted_mean         2.590
# DiffAcademicAgeAtRetraction_retracted_median       2.260
# DiffAcademicAgeAtRetraction_retracted_std          6.300
# DiffAcademicAgeAtRetraction_nonretracted_mean      2.520
# DiffAcademicAgeAtRetraction_nonretracted_median    1.740
# DiffAcademicAgeAtRetraction_nonretracted_std       6.470
# DiffAcademicAgeAtRetraction_delta_mean             0.070
# DiffAcademicAgeAtRetraction_pval_welch             0.938
# DiffAcademicAgeAtRetraction_CI_95lower            -1.460
# DiffAcademicAgeAtRetraction_CI_95upper             1.590

# %%
pd.DataFrame(lst_dicts_a3[1])
# Out:
#                                                   Misconduct  Plagiarism  \
# DiffMAGCumPapersAtRetraction_retracted_mean           18.570      21.280
# DiffMAGCumPapersAtRetraction_retracted_median          5.290      10.760
# DiffMAGCumPapersAtRetraction_retracted_std            81.920      53.050
# DiffMAGCumPapersAtRetraction_nonretracted_mean        37.570      23.670
# DiffMAGCumPapersAtRetraction_nonretracted_median      13.990      13.080
# DiffMAGCumPapersAtRetraction_nonretracted_std        136.100      57.890
# DiffMAGCumPapersAtRetraction_delta_mean              -19.000      -2.400
# DiffMAGCumPapersAtRetraction_pval_welch                0.349       0.744
# DiffMAGCumPapersAtRetraction_CI_95lower              -59.840     -17.220
# DiffMAGCumPapersAtRetraction_CI_95upper               21.840      12.430
#
#                                                   Mistake
# DiffMAGCumPapersAtRetraction_retracted_mean        19.980
# DiffMAGCumPapersAtRetraction_retracted_median      11.360
# DiffMAGCumPapersAtRetraction_retracted_std         60.350
# DiffMAGCumPapersAtRetraction_nonretracted_mean     23.290
# DiffMAGCumPapersAtRetraction_nonretracted_median   11.890
# DiffMAGCumPapersAtRetraction_nonretracted_std      49.720
# DiffMAGCumPapersAtRetraction_delta_mean            -3.310
# DiffMAGCumPapersAtRetraction_pval_welch             0.656
# DiffMAGCumPapersAtRetraction_CI_95lower           -18.700
# DiffMAGCumPapersAtRetraction_CI_95upper            12.090

# %%
pd.DataFrame(lst_dicts_a3[2])
# Out:
#                                                     Misconduct  Plagiarism  \
# DiffMAGCumCitationsAtRetraction_retracted_mean         267.930     264.130
# DiffMAGCumCitationsAtRetraction_retracted_median         3.820      -0.100
# DiffMAGCumCitationsAtRetraction_retracted_std         1695.690    1459.280
# DiffMAGCumCitationsAtRetraction_nonretracted_mean      481.130     217.330
# DiffMAGCumCitationsAtRetraction_nonretracted_me...      94.670      24.000
# DiffMAGCumCitationsAtRetraction_nonretracted_std      1794.340    1175.920
# DiffMAGCumCitationsAtRetraction_delta_mean            -213.200      46.800
# DiffMAGCumCitationsAtRetraction_pval_welch               0.498       0.789
# DiffMAGCumCitationsAtRetraction_CI_95lower            -854.340    -296.920
# DiffMAGCumCitationsAtRetraction_CI_95upper             427.950     390.520
#
#                                                      Mistake
# DiffMAGCumCitationsAtRetraction_retracted_mean        81.250
# DiffMAGCumCitationsAtRetraction_retracted_median      59.010
# DiffMAGCumCitationsAtRetraction_retracted_std       1554.050
# DiffMAGCumCitationsAtRetraction_nonretracted_mean    344.660
# DiffMAGCumCitationsAtRetraction_nonretracted_me...   111.300
# DiffMAGCumCitationsAtRetraction_nonretracted_std    1603.380
# DiffMAGCumCitationsAtRetraction_delta_mean          -263.410
# DiffMAGCumCitationsAtRetraction_pval_welch             0.215
# DiffMAGCumCitationsAtRetraction_CI_95lower          -711.180
# DiffMAGCumCitationsAtRetraction_CI_95upper           184.360

# %%
pd.DataFrame(lst_dicts_a3[3])
# Out:
#                                                     Misconduct  Plagiarism  \
# DiffMAGCumCollaboratorsAtRetraction_retracted_mean       4.480      21.290
# DiffMAGCumCollaboratorsAtRetraction_retracted_m...       1.880       8.200
# DiffMAGCumCollaboratorsAtRetraction_retracted_std      329.310     142.850
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...      73.670      34.670
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...      31.940      19.140
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...     460.630     136.040
# DiffMAGCumCollaboratorsAtRetraction_delta_mean         -69.200     -13.380
# DiffMAGCumCollaboratorsAtRetraction_pval_welch           0.338       0.468
# DiffMAGCumCollaboratorsAtRetraction_CI_95lower        -218.610     -50.950
# DiffMAGCumCollaboratorsAtRetraction_CI_95upper          80.210      24.190
#
#                                                     Mistake
# DiffMAGCumCollaboratorsAtRetraction_retracted_mean   32.730
# DiffMAGCumCollaboratorsAtRetraction_retracted_m...   12.500
# DiffMAGCumCollaboratorsAtRetraction_retracted_std   120.910
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...   31.860
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...   15.800
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...  125.690
# DiffMAGCumCollaboratorsAtRetraction_delta_mean        0.870
# DiffMAGCumCollaboratorsAtRetraction_pval_welch        0.958
# DiffMAGCumCollaboratorsAtRetraction_CI_95lower      -32.490
# DiffMAGCumCollaboratorsAtRetraction_CI_95upper       34.220

# %%
def create_latex_for_filling(dicto, col):
    
    def create_string(metric):
        string = ""
        if metric == 'pval_welch':
            string = "& " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                "\\\ \n"
        else:
            string = "& " + \
                    str(dicto.get('Misconduct').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Misconduct').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_nonretracted_"+metric)) + \
                    "\\\ \n"
        
        
        
        return string
    
    print(create_string("mean"))
    print(create_string("median"))
    print(create_string("std"))
    print(create_string("pval_welch"))
    

for i in range(len(lst_dicts_a3)):
    dicto = lst_dicts_a3[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto, col)
# Out:
# DiffAcademicAgeAtRetraction
# & 0.85 & 1.89 & 1.59 & 3.07 & 2.59 & 2.52\\
#
# & 0.15 & 1.01 & 1.0 & 1.62 & 2.26 & 1.74\\
#
# & 6.64 & 6.9 & 6.08 & 7.79 & 6.3 & 6.47\\
#
# & 0.398 & 0.398 & 0.11 & 0.11 & 0.938 & 0.938\\
#
# DiffMAGCumPapersAtRetraction
# & 18.57 & 37.57 & 21.28 & 23.67 & 19.98 & 23.29\\
#
# & 5.29 & 13.99 & 10.76 & 13.08 & 11.36 & 11.89\\
#
# & 81.92 & 136.1 & 53.05 & 57.89 & 60.35 & 49.72\\
#
# & 0.349 & 0.349 & 0.744 & 0.744 & 0.656 & 0.656\\
#
# DiffMAGCumCitationsAtRetraction
# & 267.93 & 481.13 & 264.13 & 217.33 & 81.25 & 344.66\\
#
# & 3.82 & 94.67 & -0.1 & 24.0 & 59.01 & 111.3\\
#
# & 1695.69 & 1794.34 & 1459.28 & 1175.92 & 1554.05 & 1603.38\\
#
# & 0.498 & 0.498 & 0.789 & 0.789 & 0.215 & 0.215\\
#
# DiffMAGCumCollaboratorsAtRetraction
# & 4.48 & 73.67 & 21.29 & 34.67 & 32.73 & 31.86\\
#
# & 1.88 & 31.94 & 8.2 & 19.14 & 12.5 & 15.8\\
#
# & 329.31 & 460.63 & 142.85 & 136.04 & 120.91 & 125.69\\
#
# & 0.338 & 0.338 & 0.468 & 0.468 & 0.958 & 0.958\\

# %% [markdown]
# # Processing dictionaries for plots

# %%
expfield_categories = ['Academic Age','Number of Papers',
                       'Number of Citations', 'Number of Collaborators']

master_dict = {}

master_dict['Retention'] = {}

for i in range(len(expfield_categories)):
    master_dict['Retention'][expfield_categories[i]] = lst_dicts_retention[i]

master_dict['Gain'] = {}

for i in range(len(expfield_categories)):
    master_dict['Gain'][expfield_categories[i]] = lst_dicts_gain[i]
    
master_dict['DiD'] = {}

for i in range(len(expfield_categories)):
    master_dict['DiD'][expfield_categories[i]] = lst_dicts_a3[i]

# %%
master_dict.keys()
# Out:
# dict_keys(['Retention', 'Gain', 'DiD'])

# %%
master_dict
# Out:
# {'Retention': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.92,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 13.86,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.12,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 14.68,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 13.36,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 6.8,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.77,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.154,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.97,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.44},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.61,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 12.5,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.97,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.41,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 13.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.87,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -2.8,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.003,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -4.53,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -1.07},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 15.11,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 15.46,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.75,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.88,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.64,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.14,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.77,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.401,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.29,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.74}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 69.8,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 46.51,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 96.54,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 93.75,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 63.28,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 176.22,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -23.94,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.343,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -75.21,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 27.32},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 63.89,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 44.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 68.83,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 66.41,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 57.0,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 59.84,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -2.52,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.759,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -18.7,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 13.66},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 69.93,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 53.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 72.68,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 74.76,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 61.67,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 55.39,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -4.82,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.572,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -21.62,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 11.98}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1498.48,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 532.42,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2443.6,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1683.14,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 1037.17,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2759.87,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -184.67,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.689,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -1116.73,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 747.4},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1158.96,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 410.5,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2846.24,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1009.08,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 497.78,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1440.51,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 149.88,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.603,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -390.57,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 690.33},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1487.99,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 862.22,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1947.44,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1568.09,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 924.0,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2243.95,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -80.11,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.773,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -609.85,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 449.64}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 194.34,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 102.0,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 326.47,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 272.99,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 142.93,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 712.28,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -78.65,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.424,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -281.12,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 123.82},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 140.04,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 70.86,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 175.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 140.57,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 95.25,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 170.37,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -0.53,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.981,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -43.02,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 41.95},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 175.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 101.0,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 203.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 162.51,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 120.29,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 149.9,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 13.05,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.58,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -31.83,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 57.92}}},
#  'Gain': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 7.22,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 6.5,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.34,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.54,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.4,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 3.97,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.32,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.722,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.81,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.17},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 6.49,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 6.1,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.83,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.33,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 5.21,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.24,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.052,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.41,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.07},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.89,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 8.67,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.97,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.95,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.82,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 3.95,
#     'CollabAcademicAgeAtCollaboration_delta_mean': 0.94,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.107,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -0.11,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.98}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 40.07,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 28.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 42.09,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 35.18,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 32.47,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 21.42,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 4.88,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.392,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -5.8,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 15.56},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 29.84,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 20.92,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 32.65,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 31.83,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 27.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 24.46,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -1.99,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.587,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -8.83,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 4.85},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 43.2,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 35.89,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 35.95,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 37.48,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 29.13,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 32.2,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 5.72,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.195,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -2.42,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 13.87}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1076.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 377.0,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2407.45,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 701.72,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 455.6,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 775.03,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 374.32,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.222,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -219.0,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 967.65},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 493.04,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 208.3,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 807.3,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 569.0,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 299.03,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 740.29,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -75.96,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.439,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -249.69,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 97.77},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1044.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 626.4,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1289.48,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 918.02,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 398.87,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1590.28,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 126.04,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.501,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -239.47,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 491.54}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 121.88,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.43,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 157.37,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 115.58,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 75.52,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 155.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 6.31,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.813,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -48.73,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 61.34},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 98.82,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 39.76,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 179.72,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 85.22,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 55.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 89.08,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 13.6,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.449,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -18.11,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 45.31},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 181.71,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.44,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 317.59,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 108.25,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 71.71,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 117.65,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 73.46,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.019,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': 14.62,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 132.3}}},
#  'DiD': {'Academic Age': {'Misconduct': {'DiffAcademicAgeAtRetraction_retracted_mean': 0.85,
#     'DiffAcademicAgeAtRetraction_retracted_median': 0.15,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.64,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 1.89,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.01,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.9,
#     'DiffAcademicAgeAtRetraction_delta_mean': -1.03,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.398,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -3.18,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 1.12},
#    'Plagiarism': {'DiffAcademicAgeAtRetraction_retracted_mean': 1.59,
#     'DiffAcademicAgeAtRetraction_retracted_median': 1.0,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.08,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 3.07,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.62,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 7.79,
#     'DiffAcademicAgeAtRetraction_delta_mean': -1.48,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.11,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -3.09,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.13},
#    'Mistake': {'DiffAcademicAgeAtRetraction_retracted_mean': 2.59,
#     'DiffAcademicAgeAtRetraction_retracted_median': 2.26,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.3,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.52,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.74,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.47,
#     'DiffAcademicAgeAtRetraction_delta_mean': 0.07,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.938,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -1.46,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 1.59}},
#   'Number of Papers': {'Misconduct': {'DiffMAGCumPapersAtRetraction_retracted_mean': 18.57,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 5.29,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 81.92,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 37.57,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 13.99,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 136.1,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -19.0,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.349,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -59.84,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 21.84},
#    'Plagiarism': {'DiffMAGCumPapersAtRetraction_retracted_mean': 21.28,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 10.76,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 53.05,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 23.67,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 13.08,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 57.89,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -2.4,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.744,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -17.22,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.43},
#    'Mistake': {'DiffMAGCumPapersAtRetraction_retracted_mean': 19.98,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 11.36,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 60.35,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 23.29,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 11.89,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 49.72,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -3.31,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.656,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -18.7,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.09}},
#   'Number of Citations': {'Misconduct': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 267.93,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 3.82,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1695.69,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 481.13,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 94.67,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1794.34,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -213.2,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.498,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -854.34,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 427.95},
#    'Plagiarism': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 264.13,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': -0.1,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1459.28,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 217.33,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 24.0,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1175.92,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': 46.8,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.789,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -296.92,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 390.52},
#    'Mistake': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 81.25,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 59.01,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1554.05,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 344.66,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 111.3,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1603.38,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -263.41,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.215,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -711.18,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 184.36}},
#   'Number of Collaborators': {'Misconduct': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 4.48,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 1.88,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 329.31,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 73.67,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 31.94,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 460.63,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -69.2,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.338,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -218.61,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 80.21},
#    'Plagiarism': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 21.29,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 8.2,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 142.85,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 34.67,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 19.14,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 136.04,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -13.38,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.468,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -50.95,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 24.19},
#    'Mistake': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 32.73,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 12.5,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 120.91,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 31.86,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 15.8,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 125.69,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': 0.87,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.958,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -32.49,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 34.22}}}}

# %%
def save_dict(dicto, fname):
    import pickle 

    with open(fname, 'wb') as f:
        pickle.dump(dicto, f)
        
def read_dict(fname):
    import pickle
    
    with open(fname, 'rb') as f:
        loaded_dict = pickle.load(f)
        return loaded_dict

# %%
OUTDIR = "/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/plot_data/"

save_dict(master_dict, OUTDIR+"/collaborator_chars_byReason_firstlastauthors.pkl")

# %%
master_dict
# Out:
# {'Retention': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.92,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 13.86,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.12,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 14.68,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 13.36,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 6.8,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.77,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.154,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.97,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.44},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.61,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 12.5,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.97,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.41,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 13.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.87,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -2.8,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.003,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -4.53,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -1.07},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 15.11,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 15.46,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.75,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.88,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.64,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.14,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.77,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.401,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.29,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.74}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 69.8,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 46.51,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 96.54,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 93.75,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 63.28,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 176.22,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -23.94,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.343,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -75.21,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 27.32},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 63.89,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 44.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 68.83,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 66.41,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 57.0,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 59.84,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -2.52,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.759,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -18.7,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 13.66},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 69.93,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 53.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 72.68,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 74.76,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 61.67,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 55.39,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -4.82,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.572,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -21.62,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 11.98}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1498.48,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 532.42,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2443.6,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1683.14,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 1037.17,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2759.87,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -184.67,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.689,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -1116.73,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 747.4},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1158.96,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 410.5,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2846.24,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1009.08,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 497.78,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1440.51,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 149.88,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.603,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -390.57,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 690.33},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1487.99,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 862.22,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1947.44,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1568.09,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 924.0,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2243.95,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -80.11,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.773,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -609.85,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 449.64}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 194.34,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 102.0,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 326.47,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 272.99,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 142.93,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 712.28,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -78.65,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.424,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -281.12,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 123.82},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 140.04,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 70.86,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 175.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 140.57,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 95.25,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 170.37,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -0.53,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.981,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -43.02,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 41.95},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 175.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 101.0,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 203.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 162.51,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 120.29,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 149.9,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 13.05,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.58,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -31.83,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 57.92}}},
#  'Gain': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 7.22,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 6.5,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.34,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.54,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.4,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 3.97,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.32,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.722,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.81,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.17},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 6.49,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 6.1,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.83,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.73,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.33,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 5.21,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.24,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.052,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.41,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.07},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.89,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 8.67,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.97,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.95,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.82,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 3.95,
#     'CollabAcademicAgeAtCollaboration_delta_mean': 0.94,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.107,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -0.11,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.98}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 40.07,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 28.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 42.09,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 35.18,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 32.47,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 21.42,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 4.88,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.392,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -5.8,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 15.56},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 29.84,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 20.92,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 32.65,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 31.83,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 27.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 24.46,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -1.99,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.587,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -8.83,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 4.85},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 43.2,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 35.89,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 35.95,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 37.48,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 29.13,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 32.2,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 5.72,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.195,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -2.42,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 13.87}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1076.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 377.0,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2407.45,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 701.72,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 455.6,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 775.03,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 374.32,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.222,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -219.0,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 967.65},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 493.04,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 208.3,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 807.3,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 569.0,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 299.03,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 740.29,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -75.96,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.439,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -249.69,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 97.77},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1044.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 626.4,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1289.48,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 918.02,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 398.87,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1590.28,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 126.04,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.501,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -239.47,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 491.54}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 121.88,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.43,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 157.37,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 115.58,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 75.52,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 155.2,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 6.31,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.813,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -48.73,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 61.34},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 98.82,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 39.76,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 179.72,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 85.22,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 55.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 89.08,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 13.6,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.449,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -18.11,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 45.31},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 181.71,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 74.44,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 317.59,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 108.25,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 71.71,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 117.65,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 73.46,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.019,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': 14.62,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 132.3}}},
#  'DiD': {'Academic Age': {'Misconduct': {'DiffAcademicAgeAtRetraction_retracted_mean': 0.85,
#     'DiffAcademicAgeAtRetraction_retracted_median': 0.15,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.64,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 1.89,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.01,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.9,
#     'DiffAcademicAgeAtRetraction_delta_mean': -1.03,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.398,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -3.18,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 1.12},
#    'Plagiarism': {'DiffAcademicAgeAtRetraction_retracted_mean': 1.59,
#     'DiffAcademicAgeAtRetraction_retracted_median': 1.0,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.08,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 3.07,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.62,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 7.79,
#     'DiffAcademicAgeAtRetraction_delta_mean': -1.48,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.11,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -3.09,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.13},
#    'Mistake': {'DiffAcademicAgeAtRetraction_retracted_mean': 2.59,
#     'DiffAcademicAgeAtRetraction_retracted_median': 2.26,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.3,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.52,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.74,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.47,
#     'DiffAcademicAgeAtRetraction_delta_mean': 0.07,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.938,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -1.46,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 1.59}},
#   'Number of Papers': {'Misconduct': {'DiffMAGCumPapersAtRetraction_retracted_mean': 18.57,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 5.29,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 81.92,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 37.57,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 13.99,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 136.1,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -19.0,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.349,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -59.84,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 21.84},
#    'Plagiarism': {'DiffMAGCumPapersAtRetraction_retracted_mean': 21.28,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 10.76,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 53.05,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 23.67,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 13.08,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 57.89,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -2.4,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.744,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -17.22,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.43},
#    'Mistake': {'DiffMAGCumPapersAtRetraction_retracted_mean': 19.98,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 11.36,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 60.35,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 23.29,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 11.89,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 49.72,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -3.31,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.656,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -18.7,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.09}},
#   'Number of Citations': {'Misconduct': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 267.93,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 3.82,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1695.69,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 481.13,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 94.67,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1794.34,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -213.2,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.498,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -854.34,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 427.95},
#    'Plagiarism': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 264.13,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': -0.1,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1459.28,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 217.33,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 24.0,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1175.92,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': 46.8,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.789,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -296.92,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 390.52},
#    'Mistake': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 81.25,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 59.01,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1554.05,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 344.66,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 111.3,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1603.38,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -263.41,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.215,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -711.18,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 184.36}},
#   'Number of Collaborators': {'Misconduct': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 4.48,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 1.88,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 329.31,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 73.67,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 31.94,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 460.63,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -69.2,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.338,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -218.61,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 80.21},
#    'Plagiarism': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 21.29,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 8.2,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 142.85,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 34.67,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 19.14,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 136.04,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -13.38,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.468,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -50.95,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 24.19},
#    'Mistake': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 32.73,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 12.5,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 120.91,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 31.86,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 15.8,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 125.69,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': 0.87,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.958,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -32.49,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 34.22}}}}
