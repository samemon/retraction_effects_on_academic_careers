# %% [markdown]
# # Characterizing Collaborators
#
# In this notebook, we shall characterize collaborators. We shall do that in the following way:
#
# There are three reasons: misconduct, plagiarism, and mistake.
#
# For each academic age group within retracted and matched scientists **at the time of retraction**, we shall conduct three analysis and create three tables:
#
# #### Retained for retracted vs. matched
# 1. Table 1 comparing the **retained** collaborators of retracted and matched scientists in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of collaboration**. The table will also contain median, standard deviation, and p-value for t-test.
#
# #### Gained for retracted vs. matched
# 2. Table 2 comparing the **gained/new** collaborators of retracted and matched scientists in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of collaboration**. The table will also contain median, standard deviation, and p-value for t-test.
#
# #### Retained vs. lost for retracted vs. matched
# 3. Table 3 comparing the **retained** collaborators of retracted and matched scientists to those **lost** in terms of their (a) mean academic age, (b) average number of papers, (c) average number of citations, (d) average number of collaborators, all **at the time of retraction**. The table will be produced by difference in differences approach where we shall first compute the averages for each field (papers, citations, etc.) for retained and lost for retracted and matched. Then we shall compute the difference between retained for retracted and matched, and between lost for retracted and matched. Finally we shall take the difference in difference (DiD) i.e. **RETAINED-LOST**. The table will also contain median, standard deviation, and p-value for t-test.

# %%
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
INDIR = "/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/"
INDIR_MATCHING = INDIR+"/author_matching/"
INDIR_COLLAB = INDIR+"/collaborator_quality_analysis/"

df = pd.read_csv(INDIR_COLLAB+"/1Dcollaborators_for_matched_sample_30.csv")

print(df.shape)

df.head()
# Out:
# (773033, 20)
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2004120834          1994.0                1983.0
# 1  2.105038e+09    2124401064          1994.0                1983.0
# 2  2.105038e+09    2486043001          1994.0                1983.0
# 3  2.105038e+09    2124401064          1994.0                1992.0
# 4  2.105038e+09    2276877851          1994.0                1992.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.74
# 2     retracted                  male                       0.60
# 3     retracted                  male                       0.74
# 4     retracted                female                       0.98
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1967.0                              1994.0
# 1                 1964.0                              1994.0
# 2                 1971.0                              1983.0
# 3                 1964.0                              1994.0
# 4                 1984.0                              1993.0
#
#    CollabMAGCumPapersAtRetraction  CollabMAGCumCitationsYearAtRetraction  \
# 0                           104.0                                 1994.0
# 1                            78.0                                 1994.0
# 2                            10.0                                 1994.0
# 3                            78.0                                 1994.0
# 4                            16.0                                 1994.0
#
#    CollabMAGCumCitationsAtRetraction  \
# 0                             3683.0
# 1                             2668.0
# 2                              532.0
# 3                             2668.0
# 4                              136.0
#
#    CollabMAGCumCollaboratorsYearAtRetraction  \
# 0                                     1994.0
# 1                                     1994.0
# 2                                     1983.0
# 3                                     1994.0
# 4                                     1993.0
#
#    CollabMAGCumCollaboratorsAtRetraction  \
# 0                                   83.0
# 1                                   81.0
# 2                                   18.0
# 3                                   81.0
# 4                                   31.0
#
#    CollabMAGCumPapersYearAtCollaboration  CollabMAGCumPapersAtCollaboration  \
# 0                                 1983.0                               47.0
# 1                                 1983.0                               47.0
# 2                                 1983.0                               10.0
# 3                                 1992.0                               74.0
# 4                                 1992.0                               14.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1983.0
# 1                                    1983.0
# 2                                    1983.0
# 3                                    1992.0
# 4                                    1992.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                1076.0
# 1                                1305.0
# 2                                 199.0
# 3                                2449.0
# 4                                  90.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1983.0
# 1                                        1983.0
# 2                                        1983.0
# 3                                        1992.0
# 4                                        1992.0
#
#    CollabMAGCumCollaboratorsAtCollaboration
# 0                                        46
# 1                                        37
# 2                                        18
# 3                                        71
# 4                                        27

# %%
print(df.shape)
# Out:
# (773033, 20)

# %%
df.MAGCollabAID.nunique()
# Out:
# 411911

# %% [markdown]
# ### Preprocessing

# %%
# Let us first augment the academic age of MAGAIDs. We will also add other columns to be used later

# Reading files used for matching

df_treatment = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_treatment_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5','ReasonPropagatedMajorityOfMajority'])\
                    .drop_duplicates()\
                    .rename(columns={
                                    'AcademicAgeBeforeRetraction': 'AcademicAgeAtRetraction'})

df_control = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MatchMAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5','ReasonPropagatedMajorityOfMajority'])\
                    .drop_duplicates()\
                    .rename(columns={'MatchMAGAID':'MAGAID'})

df_treatment_control = pd.concat([df_treatment,df_control])

# Removing reasons that are not misconduct, plagiarism, mistake

df_treatment_control = df_treatment_control[df_treatment_control.\
                                        ReasonPropagatedMajorityOfMajority.isin(['misconduct',
                                                                                'plagiarism',
                                                                                'mistake'])]

df_treatment_control
# Out:
#             MAGAID  RetractionYear ReasonPropagatedMajorityOfMajority  \
# 1     8.197726e+06          2012.0                            mistake
# 3     9.474215e+06          2015.0                            mistake
# 4     1.373700e+07          2014.0                            mistake
# 5     1.551904e+07          2013.0                         plagiarism
# 6     4.757012e+07          2015.0                         misconduct
# ...            ...             ...                                ...
# 5411  2.127710e+09          2015.0                         plagiarism
# 5412  1.974243e+09          2013.0                            mistake
# 5414  1.933448e+09          2014.0                         misconduct
# 5416  2.077873e+09          2008.0                         misconduct
# 5417  3.019838e+08          2014.0                         misconduct
#
#       NumRetentionW5  NumNewCollaboratorsW5
# 1                  4                     10
# 3                 55                    481
# 4                  8                      8
# 5                  0                      4
# 6                  5                     19
# ...              ...                    ...
# 5411               3                     25
# 5412               3                      2
# 5414              10                     36
# 5416               2                      3
# 5417              41                    141
#
# [5014 rows x 5 columns]

# %%
# Merging that with df

df2 = df.merge(df_treatment_control.drop(columns=['NumRetentionW5','NumNewCollaboratorsW5']), 
                                         on=['MAGAID','RetractionYear'])
df2
# Out:
#               MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0       2.105038e+09    2004120834          1994.0                1983.0
# 1       2.105038e+09    2124401064          1994.0                1983.0
# 2       2.105038e+09    2486043001          1994.0                1983.0
# 3       2.105038e+09    2124401064          1994.0                1992.0
# 4       2.105038e+09    2276877851          1994.0                1992.0
# ...              ...           ...             ...                   ...
# 626059  2.294600e+09    2972696792          2012.0                2020.0
# 626060  2.294600e+09    3111842016          2012.0                2020.0
# 626061  2.294600e+09    3112134165          2012.0                2020.0
# 626062  2.294600e+09    3112412017          2012.0                2020.0
# 626063  2.294600e+09    3171408538          2012.0                2020.0
#
#        ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0          retracted                  male                       0.99
# 1          retracted                  male                       0.74
# 2          retracted                  male                       0.60
# 3          retracted                  male                       0.74
# 4          retracted                female                       0.98
# ...              ...                   ...                        ...
# 626059       matched                  male                       0.99
# 626060       matched                female                       0.98
# 626061       matched                female                       0.99
# 626062       matched                female                       0.97
# 626063       matched                female                       0.96
#
#         CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                      1967.0                              1994.0
# 1                      1964.0                              1994.0
# 2                      1971.0                              1983.0
# 3                      1964.0                              1994.0
# 4                      1984.0                              1993.0
# ...                       ...                                 ...
# 626059                 2019.0                                 NaN
# 626060                 2020.0                                 NaN
# 626061                 2020.0                                 NaN
# 626062                 2020.0                                 NaN
# 626063                 2020.0                                 NaN
#
#         CollabMAGCumPapersAtRetraction  ...  \
# 0                                104.0  ...
# 1                                 78.0  ...
# 2                                 10.0  ...
# 3                                 78.0  ...
# 4                                 16.0  ...
# ...                                ...  ...
# 626059                             0.0  ...
# 626060                             0.0  ...
# 626061                             0.0  ...
# 626062                             0.0  ...
# 626063                             0.0  ...
#
#         CollabMAGCumCitationsAtRetraction  \
# 0                                  3683.0
# 1                                  2668.0
# 2                                   532.0
# 3                                  2668.0
# 4                                   136.0
# ...                                   ...
# 626059                                0.0
# 626060                                0.0
# 626061                                0.0
# 626062                                0.0
# 626063                                0.0
#
#         CollabMAGCumCollaboratorsYearAtRetraction  \
# 0                                          1994.0
# 1                                          1994.0
# 2                                          1983.0
# 3                                          1994.0
# 4                                          1993.0
# ...                                           ...
# 626059                                        NaN
# 626060                                        NaN
# 626061                                        NaN
# 626062                                        NaN
# 626063                                        NaN
#
#         CollabMAGCumCollaboratorsAtRetraction  \
# 0                                        83.0
# 1                                        81.0
# 2                                        18.0
# 3                                        81.0
# 4                                        31.0
# ...                                       ...
# 626059                                    0.0
# 626060                                    0.0
# 626061                                    0.0
# 626062                                    0.0
# 626063                                    0.0
#
#         CollabMAGCumPapersYearAtCollaboration  \
# 0                                      1983.0
# 1                                      1983.0
# 2                                      1983.0
# 3                                      1992.0
# 4                                      1992.0
# ...                                       ...
# 626059                                 2020.0
# 626060                                 2020.0
# 626061                                 2020.0
# 626062                                 2020.0
# 626063                                 2020.0
#
#         CollabMAGCumPapersAtCollaboration  \
# 0                                    47.0
# 1                                    47.0
# 2                                    10.0
# 3                                    74.0
# 4                                    14.0
# ...                                   ...
# 626059                                3.0
# 626060                                1.0
# 626061                                1.0
# 626062                                1.0
# 626063                                1.0
#
#         CollabMAGCumCitationsYearAtCollaboration  \
# 0                                         1983.0
# 1                                         1983.0
# 2                                         1983.0
# 3                                         1992.0
# 4                                         1992.0
# ...                                          ...
# 626059                                    2020.0
# 626060                                       NaN
# 626061                                       NaN
# 626062                                       NaN
# 626063                                       NaN
#
#         CollabMAGCumCitationsAtCollaboration  \
# 0                                     1076.0
# 1                                     1305.0
# 2                                      199.0
# 3                                     2449.0
# 4                                       90.0
# ...                                      ...
# 626059                                   1.0
# 626060                                   0.0
# 626061                                   0.0
# 626062                                   0.0
# 626063                                   0.0
#
#         CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                             1983.0
# 1                                             1983.0
# 2                                             1983.0
# 3                                             1992.0
# 4                                             1992.0
# ...                                              ...
# 626059                                        2020.0
# 626060                                        2020.0
# 626061                                        2020.0
# 626062                                        2020.0
# 626063                                        2020.0
#
#         CollabMAGCumCollaboratorsAtCollaboration  \
# 0                                             46
# 1                                             37
# 2                                             18
# 3                                             71
# 4                                             27
# ...                                          ...
# 626059                                        17
# 626060                                         7
# 626061                                         7
# 626062                                         7
# 626063                                         7
#
#         ReasonPropagatedMajorityOfMajority
# 0                                  mistake
# 1                                  mistake
# 2                                  mistake
# 3                                  mistake
# 4                                  mistake
# ...                                    ...
# 626059                          plagiarism
# 626060                          plagiarism
# 626061                          plagiarism
# 626062                          plagiarism
# 626063                          plagiarism
#
# [626064 rows x 21 columns]

# %%
# Let us first compute academic age at retraction and at collaboration for collaborators
df2['CollabAcademicAgeAtRetraction'] = df2['RetractionYear']-df2['CollabMAGFirstPubYear']

df2['CollabAcademicAgeAtCollaboration'] = df2['MAGCollaborationYear']-df2['CollabMAGFirstPubYear']

# So negatives are possible in academic age at retraction but not collaboration
df2.CollabAcademicAgeAtRetraction.describe()
# Out:
# count    626064.000000
# mean          9.744611
# std          13.963814
# min         -30.000000
# 25%           0.000000
# 50%           7.000000
# 75%          17.000000
# max         215.000000
# Name: CollabAcademicAgeAtRetraction, dtype: float64

# %%
# Let us first identify if the collaboration was pre- or post-retraction

def get_prepost_flag(row):
    if(row['MAGCollaborationYear'] <= row['RetractionYear']):
        return 'pre'
    else:
        if((row['MAGCollaborationYear']-row['RetractionYear'])<=5):
            return 'post5'
        else:
            return 'post'

df2['PrePostFlag5'] = df2.apply(lambda row: get_prepost_flag(row), axis=1)

# %%
# Let us remove the collaborators that are "post"

df3 = df2[~df2.PrePostFlag5.eq('post')]

# %%
df3.head()
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2004120834          1994.0                1983.0
# 1  2.105038e+09    2124401064          1994.0                1983.0
# 2  2.105038e+09    2486043001          1994.0                1983.0
# 3  2.105038e+09    2124401064          1994.0                1992.0
# 4  2.105038e+09    2276877851          1994.0                1992.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.74
# 2     retracted                  male                       0.60
# 3     retracted                  male                       0.74
# 4     retracted                female                       0.98
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1967.0                              1994.0
# 1                 1964.0                              1994.0
# 2                 1971.0                              1983.0
# 3                 1964.0                              1994.0
# 4                 1984.0                              1993.0
#
#    CollabMAGCumPapersAtRetraction  ...  CollabMAGCumPapersYearAtCollaboration  \
# 0                           104.0  ...                                 1983.0
# 1                            78.0  ...                                 1983.0
# 2                            10.0  ...                                 1983.0
# 3                            78.0  ...                                 1992.0
# 4                            16.0  ...                                 1992.0
#
#    CollabMAGCumPapersAtCollaboration  \
# 0                               47.0
# 1                               47.0
# 2                               10.0
# 3                               74.0
# 4                               14.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1983.0
# 1                                    1983.0
# 2                                    1983.0
# 3                                    1992.0
# 4                                    1992.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                1076.0
# 1                                1305.0
# 2                                 199.0
# 3                                2449.0
# 4                                  90.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1983.0
# 1                                        1983.0
# 2                                        1983.0
# 3                                        1992.0
# 4                                        1992.0
#
#    CollabMAGCumCollaboratorsAtCollaboration  \
# 0                                        46
# 1                                        37
# 2                                        18
# 3                                        71
# 4                                        27
#
#    ReasonPropagatedMajorityOfMajority  CollabAcademicAgeAtRetraction  \
# 0                             mistake                           27.0
# 1                             mistake                           30.0
# 2                             mistake                           23.0
# 3                             mistake                           30.0
# 4                             mistake                           10.0
#
#    CollabAcademicAgeAtCollaboration  PrePostFlag5
# 0                              16.0           pre
# 1                              19.0           pre
# 2                              12.0           pre
# 3                              28.0           pre
# 4                               8.0           pre
#
# [5 rows x 24 columns]

# %%
df3.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5'],
#       dtype='object')

# %%
# For each MAGAID, let us create a set of collaborators pre- and post- retraction

df4 = df3.groupby(['MAGAID','RetractionYear','PrePostFlag5'])\
                        ['MAGCollabAID'].apply(set).unstack().reset_index()


# Converting pre- and post5 columns to set so we can do set operations
df4['pre'] = df4['pre'].apply(lambda d: d if isinstance(d, set) else set())
df4['post5'] = df4['post5'].apply(lambda d: d if isinstance(d, set) else set())


# COLLABORATOR RETENTION

# Computing number of collaborators retained
df4['NumRetentionW5'] = df4.apply(lambda row: len(row.post5.intersection(row.pre)), 
                            axis=1)

# Creating the list of collaborators retained
df4['CollabAIDRetainedW5'] = df4.apply(lambda row: row.post5.intersection(row.pre), 
                                                    axis=1)


# Creating list of collaborators lost
df4['CollabAIDLostW5'] = df4.apply(lambda row: row['pre'] - row['CollabAIDRetainedW5'], 
                                                    axis=1)


# COLLABORATOR GAIN

# Computing number of collabortors gained
df4['NumNewCollaboratorsW5'] = df4.apply(lambda row: len(row['post5']-row['pre']), 
                                                    axis=1)

# Creating set of collaborators gained
df4['CollabAIDGainedW5'] = df4.apply(lambda row: row['post5']-row['pre'], 
                                                    axis=1)


df4.head()
# Out:
# PrePostFlag5      MAGAID  RetractionYear  \
# 0              5440459.0          2010.0
# 1              8197726.0          2012.0
# 2              8227037.0          2003.0
# 3              9474215.0          2015.0
# 4             13737004.0          2014.0
#
# PrePostFlag5                                              post5  \
# 0             {2084557827, 2402421397, 2235672854, 213407784...
# 1             {1969204096, 2226225926, 2024673639, 199363863...
# 2             {2438245003, 2566236814, 2099366676, 186420623...
# 3             {2741493764, 1134876678, 2589376522, 288503604...
# 4             {2144558976, 2068504066, 1986642243, 146813190...
#
# PrePostFlag5                                                pre  \
# 0             {2132186624, 2084557827, 3130870283, 222369435...
# 1             {2024673639, 279977545, 1970425162, 1689175372...
# 2             {2119475842, 2103663625, 3037713418, 276189799...
# 3             {2102010368, 2147699201, 2402001923, 277873818...
# 4             {2144558976, 1456934145, 2050002051, 146813190...
#
# PrePostFlag5  NumRetentionW5  \
# 0                         13
# 1                          4
# 2                          6
# 3                         55
# 4                          8
#
# PrePostFlag5                                CollabAIDRetainedW5  \
# 0             {2680186915, 2084557827, 2144828135, 97975655,...
# 1              {1970425162, 1689175372, 2122225613, 2024673639}
# 2             {2698681252, 2464725413, 2135649512, 251608811...
# 3             {2102010368, 2147699201, 2402001923, 211700557...
# 4             {2144558976, 1986642243, 146813190, 2304798023...
#
# PrePostFlag5                                    CollabAIDLostW5  \
# 0             {2132186624, 3130870283, 2223694350, 215816449...
# 1             {279977545, 1778388943, 2506500849, 343947537,...
# 2             {2119475842, 2103663625, 3037713418, 276189799...
# 3             {2613431302, 1578585096, 2047308816, 216607540...
# 4             {1456934145, 2050002051, 2672525068, 279086184...
#
# PrePostFlag5  NumNewCollaboratorsW5  \
# 0                                35
# 1                                10
# 2                                20
# 3                               481
# 4                                 8
#
# PrePostFlag5                                  CollabAIDGainedW5
# 0             {2134077845, 2402421397, 2235672854, 217199132...
# 1             {1969204096, 2226225926, 1993638631, 256742932...
# 2             {2438245003, 1513362301, 2566236814, 209936667...
# 3             {2741493764, 2589376522, 2885036046, 297136949...
# 4             {2068504066, 1526526887, 1529129866, 207583934...

# %% [markdown]
# ### Validation of the number of collaborators retained and gained
#
# We shall validate if the numbers we calculated now match the ones on which matching was done.

# %%
# Merging
dfvalidation = df4[['MAGAID','RetractionYear','NumRetentionW5','NumNewCollaboratorsW5']].drop_duplicates().\
                    merge(df_treatment_control, on=['MAGAID','RetractionYear'])

dfvalidation
# Out:
#             MAGAID  RetractionYear  NumRetentionW5_x  NumNewCollaboratorsW5_x  \
# 0     5.440459e+06          2010.0                13                       35
# 1     8.197726e+06          2012.0                 4                       10
# 2     8.227037e+06          2003.0                 6                       20
# 3     9.474215e+06          2015.0                55                      481
# 4     1.373700e+07          2014.0                 8                        8
# ...            ...             ...               ...                      ...
# 3838  3.174124e+09          2004.0                 1                        6
# 3839  3.174844e+09          2014.0                 3                        3
# 3840  3.175436e+09          2015.0                 1                       14
# 3841  3.176126e+09          2004.0                 4                        1
# 3842  3.176346e+09          2011.0                 1                        8
#
#      ReasonPropagatedMajorityOfMajority  NumRetentionW5_y  \
# 0                            plagiarism                13
# 1                               mistake                 4
# 2                               mistake                 6
# 3                               mistake                55
# 4                               mistake                 8
# ...                                 ...               ...
# 3838                            mistake                 1
# 3839                         misconduct                 3
# 3840                         plagiarism                 1
# 3841                            mistake                 4
# 3842                         misconduct                 1
#
#       NumNewCollaboratorsW5_y
# 0                          35
# 1                          10
# 2                          20
# 3                         481
# 4                           8
# ...                       ...
# 3838                        6
# 3839                        3
# 3840                       14
# 3841                        1
# 3842                        8
#
# [3843 rows x 7 columns]

# %%
# Finally validating

dfvalidation[(dfvalidation.NumRetentionW5_x == dfvalidation.NumRetentionW5_y) & 
            (dfvalidation.NumNewCollaboratorsW5_x == dfvalidation.NumNewCollaboratorsW5_y)]
# Out:
#             MAGAID  RetractionYear  NumRetentionW5_x  NumNewCollaboratorsW5_x  \
# 0     5.440459e+06          2010.0                13                       35
# 1     8.197726e+06          2012.0                 4                       10
# 2     8.227037e+06          2003.0                 6                       20
# 3     9.474215e+06          2015.0                55                      481
# 4     1.373700e+07          2014.0                 8                        8
# ...            ...             ...               ...                      ...
# 3838  3.174124e+09          2004.0                 1                        6
# 3839  3.174844e+09          2014.0                 3                        3
# 3840  3.175436e+09          2015.0                 1                       14
# 3841  3.176126e+09          2004.0                 4                        1
# 3842  3.176346e+09          2011.0                 1                        8
#
#      ReasonPropagatedMajorityOfMajority  NumRetentionW5_y  \
# 0                            plagiarism                13
# 1                               mistake                 4
# 2                               mistake                 6
# 3                               mistake                55
# 4                               mistake                 8
# ...                                 ...               ...
# 3838                            mistake                 1
# 3839                         misconduct                 3
# 3840                         plagiarism                 1
# 3841                            mistake                 4
# 3842                         misconduct                 1
#
#       NumNewCollaboratorsW5_y
# 0                          35
# 1                          10
# 2                          20
# 3                         481
# 4                           8
# ...                       ...
# 3838                        6
# 3839                        3
# 3840                       14
# 3841                        1
# 3842                        8
#
# [3843 rows x 7 columns]

# %% [markdown]
# **Hence all of them are validated.**

# %% [markdown]
# ## Analysis

# %%
# Our main dataframes are df3 and df4
# Let us look at them first
print(df3.shape)
df3.head()
# Out:
# (464191, 24)
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2004120834          1994.0                1983.0
# 1  2.105038e+09    2124401064          1994.0                1983.0
# 2  2.105038e+09    2486043001          1994.0                1983.0
# 3  2.105038e+09    2124401064          1994.0                1992.0
# 4  2.105038e+09    2276877851          1994.0                1992.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.74
# 2     retracted                  male                       0.60
# 3     retracted                  male                       0.74
# 4     retracted                female                       0.98
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1967.0                              1994.0
# 1                 1964.0                              1994.0
# 2                 1971.0                              1983.0
# 3                 1964.0                              1994.0
# 4                 1984.0                              1993.0
#
#    CollabMAGCumPapersAtRetraction  ...  CollabMAGCumPapersYearAtCollaboration  \
# 0                           104.0  ...                                 1983.0
# 1                            78.0  ...                                 1983.0
# 2                            10.0  ...                                 1983.0
# 3                            78.0  ...                                 1992.0
# 4                            16.0  ...                                 1992.0
#
#    CollabMAGCumPapersAtCollaboration  \
# 0                               47.0
# 1                               47.0
# 2                               10.0
# 3                               74.0
# 4                               14.0
#
#    CollabMAGCumCitationsYearAtCollaboration  \
# 0                                    1983.0
# 1                                    1983.0
# 2                                    1983.0
# 3                                    1992.0
# 4                                    1992.0
#
#    CollabMAGCumCitationsAtCollaboration  \
# 0                                1076.0
# 1                                1305.0
# 2                                 199.0
# 3                                2449.0
# 4                                  90.0
#
#    CollabMAGCumCollaboratorsYearAtCollaboration  \
# 0                                        1983.0
# 1                                        1983.0
# 2                                        1983.0
# 3                                        1992.0
# 4                                        1992.0
#
#    CollabMAGCumCollaboratorsAtCollaboration  \
# 0                                        46
# 1                                        37
# 2                                        18
# 3                                        71
# 4                                        27
#
#    ReasonPropagatedMajorityOfMajority  CollabAcademicAgeAtRetraction  \
# 0                             mistake                           27.0
# 1                             mistake                           30.0
# 2                             mistake                           23.0
# 3                             mistake                           30.0
# 4                             mistake                           10.0
#
#    CollabAcademicAgeAtCollaboration  PrePostFlag5
# 0                              16.0           pre
# 1                              19.0           pre
# 2                              12.0           pre
# 3                              28.0           pre
# 4                               8.0           pre
#
# [5 rows x 24 columns]

# %%
df4
# Out:
# PrePostFlag5        MAGAID  RetractionYear  \
# 0             5.440459e+06          2010.0
# 1             8.197726e+06          2012.0
# 2             8.227037e+06          2003.0
# 3             9.474215e+06          2015.0
# 4             1.373700e+07          2014.0
# ...                    ...             ...
# 3838          3.174124e+09          2004.0
# 3839          3.174844e+09          2014.0
# 3840          3.175436e+09          2015.0
# 3841          3.176126e+09          2004.0
# 3842          3.176346e+09          2011.0
#
# PrePostFlag5                                              post5  \
# 0             {2084557827, 2402421397, 2235672854, 213407784...
# 1             {1969204096, 2226225926, 2024673639, 199363863...
# 2             {2438245003, 2566236814, 2099366676, 186420623...
# 3             {2741493764, 1134876678, 2589376522, 288503604...
# 4             {2144558976, 2068504066, 1986642243, 146813190...
# ...                                                         ...
# 3838          {2706053123, 2250669861, 2568589385, 222924385...
# 3839          {2636262617, 550125002, 2295148299, 2265510894...
# 3840          {1805786912, 2999619457, 2658197410, 257933920...
# 3841          {1986848736, 2166182598, 2098417261, 264898482...
# 3842          {2078002947, 2029403719, 2137379546, 199009346...
#
# PrePostFlag5                                                pre  \
# 0             {2132186624, 2084557827, 3130870283, 222369435...
# 1             {2024673639, 279977545, 1970425162, 1689175372...
# 2             {2119475842, 2103663625, 3037713418, 276189799...
# 3             {2102010368, 2147699201, 2402001923, 277873818...
# 4             {2144558976, 1456934145, 2050002051, 146813190...
# ...                                                         ...
# 3838           {2939265617, 2687883010, 2424699715, 2100866894}
# 3839          {2954067065, 2311908582, 2005715177, 550125002...
# 3840          {2130470407, 2395301650, 1455333013, 231293572...
# 3841          {2509432581, 2132746631, 2105761291, 204507009...
# 3842          {677348324, 2657776906, 3170697964, 1758167412...
#
# PrePostFlag5  NumRetentionW5  \
# 0                         13
# 1                          4
# 2                          6
# 3                         55
# 4                          8
# ...                      ...
# 3838                       1
# 3839                       3
# 3840                       1
# 3841                       4
# 3842                       1
#
# PrePostFlag5                                CollabAIDRetainedW5  \
# 0             {2680186915, 2084557827, 2144828135, 97975655,...
# 1              {1970425162, 1689175372, 2122225613, 2024673639}
# 2             {2698681252, 2464725413, 2135649512, 251608811...
# 3             {2102010368, 2147699201, 2402001923, 211700557...
# 4             {2144558976, 1986642243, 146813190, 2304798023...
# ...                                                         ...
# 3838                                               {2100866894}
# 3839                        {2174600848, 2636262617, 550125002}
# 3840                                               {2121913688}
# 3841           {1986848736, 2477984924, 2648984820, 2166182598}
# 3842                                               {1990093460}
#
# PrePostFlag5                                    CollabAIDLostW5  \
# 0             {2132186624, 3130870283, 2223694350, 215816449...
# 1             {279977545, 1778388943, 2506500849, 343947537,...
# 2             {2119475842, 2103663625, 3037713418, 276189799...
# 3             {2613431302, 1578585096, 2047308816, 216607540...
# 4             {1456934145, 2050002051, 2672525068, 279086184...
# ...                                                         ...
# 3838                       {2939265617, 2687883010, 2424699715}
# 3839          {2311908582, 2005715177, 2124843274, 250398225...
# 3840          {2240552385, 2130470407, 2333910471, 252033530...
# 3841          {2780665794, 2117749316, 2509432581, 213274663...
# 3842          {677348324, 2657776906, 3170697964, 1758167412...
#
# PrePostFlag5  NumNewCollaboratorsW5  \
# 0                                35
# 1                                10
# 2                                20
# 3                               481
# 4                                 8
# ...                             ...
# 3838                              6
# 3839                              3
# 3840                             14
# 3841                              1
# 3842                              8
#
# PrePostFlag5                                  CollabAIDGainedW5
# 0             {2134077845, 2402421397, 2235672854, 217199132...
# 1             {1969204096, 2226225926, 1993638631, 256742932...
# 2             {2438245003, 1513362301, 2566236814, 209936667...
# 3             {2741493764, 2589376522, 2885036046, 297136949...
# 4             {2068504066, 1526526887, 1529129866, 207583934...
# ...                                                         ...
# 3838          {2706053123, 2250669861, 2568589385, 222924385...
# 3839                       {1494968409, 2295148299, 2265510894}
# 3840          {1805786912, 2999619457, 2658197410, 196858720...
# 3841                                               {2098417261}
# 3842          {2078002947, 2029403719, 2051974682, 188354341...
#
# [3843 rows x 9 columns]

# %%
# Let us first merge df3 and df4

df_A = df3.merge(df4, on=['MAGAID','RetractionYear'])

# Let us also create three flags checking whether current collaborator is retained, gained, or lost

df_A['CollabAIDinRetained'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDRetainedW5'], 
                                          axis=1)

df_A['CollabAIDinGained'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDGainedW5'], 
                                          axis=1)

df_A['CollabAIDinLost'] = df_A.apply(lambda row: row['MAGCollabAID'] in row['CollabAIDLostW5'], 
                                          axis=1)

df_A.head(3)
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2004120834          1994.0                1983.0
# 1  2.105038e+09    2124401064          1994.0                1983.0
# 2  2.105038e+09    2486043001          1994.0                1983.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.74
# 2     retracted                  male                       0.60
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1967.0                              1994.0
# 1                 1964.0                              1994.0
# 2                 1971.0                              1983.0
#
#    CollabMAGCumPapersAtRetraction  ...  \
# 0                           104.0  ...
# 1                            78.0  ...
# 2                            10.0  ...
#
#                                                post5  \
# 0  {2024377920, 2111173543, 2124401064, 213957751...
# 1  {2024377920, 2111173543, 2124401064, 213957751...
# 2  {2024377920, 2111173543, 2124401064, 213957751...
#
#                                                  pre  NumRetentionW5  \
# 0  {2935888513, 2004120834, 3069320578, 231952499...               4
# 1  {2935888513, 2004120834, 3069320578, 231952499...               4
# 2  {2935888513, 2004120834, 3069320578, 231952499...               4
#
#                                 CollabAIDRetainedW5  \
# 0  {2124401064, 2139577513, 2308282282, 2276877851}
# 1  {2124401064, 2139577513, 2308282282, 2276877851}
# 2  {2124401064, 2139577513, 2308282282, 2276877851}
#
#                                      CollabAIDLostW5  NumNewCollaboratorsW5  \
# 0  {2004120834, 2787959316, 2464403478, 263399605...                      4
# 1  {2004120834, 2787959316, 2464403478, 263399605...                      4
# 2  {2004120834, 2787959316, 2464403478, 263399605...                      4
#
#                                   CollabAIDGainedW5  CollabAIDinRetained  \
# 0  {2024377920, 2432858298, 2317413108, 2111173543}                False
# 1  {2024377920, 2432858298, 2317413108, 2111173543}                 True
# 2  {2024377920, 2432858298, 2317413108, 2111173543}                False
#
#    CollabAIDinGained  CollabAIDinLost
# 0              False             True
# 1              False            False
# 2              False             True
#
# [3 rows x 34 columns]

# %%
# Sensibility checks

df_A[['CollabAIDinRetained','CollabAIDinGained','CollabAIDinLost']].value_counts()
# Out:
# CollabAIDinRetained  CollabAIDinGained  CollabAIDinLost
# False                False              True               191468
#                      True               False              154178
# True                 False              False              118545
# Name: count, dtype: int64

# %%
df_A.columns, df_A.shape
# Out:
# (Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#         'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#         'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#         'CollabMAGCumPapersAtRetraction',
#         'CollabMAGCumCitationsYearAtRetraction',
#         'CollabMAGCumCitationsAtRetraction',
#         'CollabMAGCumCollaboratorsYearAtRetraction',
#         'CollabMAGCumCollaboratorsAtRetraction',
#         'CollabMAGCumPapersYearAtCollaboration',
#         'CollabMAGCumPapersAtCollaboration',
#         'CollabMAGCumCitationsYearAtCollaboration',
#         'CollabMAGCumCitationsAtCollaboration',
#         'CollabMAGCumCollaboratorsYearAtCollaboration',
#         'CollabMAGCumCollaboratorsAtCollaboration',
#         'ReasonPropagatedMajorityOfMajority', 'CollabAcademicAgeAtRetraction',
#         'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#         'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#         'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#         'CollabAIDinGained', 'CollabAIDinLost'],
#        dtype='object'),
#  (464191, 34))

# %% [markdown]
# ## DANGER ZONE!
#
# This code removes collaborators that have academic age > 70 at the time of collaboration.

# %%
df_A[df_A.CollabAcademicAgeAtCollaboration.gt(70) & df_A.ScientistType.eq('retracted')].MAGAID.nunique()
# Out:
# 312

# %%
df_A = df_A[df_A.CollabAcademicAgeAtCollaboration.le(70)]

# %% [markdown]
# ### A1: Collaborators retained: retracted vs. matched

# %%
#Let us now modify df_A1 such that we remove all rows with collaborations pre-retraction

df_A1_post = df_A[df_A['PrePostFlag5']=='post5']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A1_firstcollabs = df_A1_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A1_w_firstcollabs = df_A1_post.merge(df_A1_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A1_w_firstcollabs.shape
# Out:
# (206342, 35)

# %%
# Sensibility checks

df_A1_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#            MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 154838  5440459.0      97975655                2011.0
# 154858  5440459.0     165967445                2012.0
# 154800  5440459.0     238488652                2014.0
# 154832  5440459.0     293709409                2012.0
# 154833  5440459.0     298713076                2012.0
# 154835  5440459.0     324850990                2011.0
# 154802  5440459.0     698114488                2011.0
# 154803  5440459.0     698114488                2012.0
# 154804  5440459.0     698114488                2013.0
# 154801  5440459.0     698114488                2014.0
# 154819  5440459.0    1155384243                2012.0
# 154820  5440459.0    1155384243                2013.0
# 154847  5440459.0    1898953080                2013.0
# 154848  5440459.0    1898953080                2015.0
# 154851  5440459.0    1964584928                2012.0
# 154852  5440459.0    1964584928                2013.0
# 154808  5440459.0    1969819737                2012.0
# 154821  5440459.0    1970538733                2012.0
# 154822  5440459.0    1970538733                2013.0
# 154836  5440459.0    1982136528                2011.0
# 154853  5440459.0    2007304365                2012.0
# 154810  5440459.0    2029802714                2011.0
# 154809  5440459.0    2029802714                2012.0
# 154861  5440459.0    2045966497                2013.0
# 154860  5440459.0    2045966497                2015.0
# 154857  5440459.0    2067154876                2012.0
# 154859  5440459.0    2073043934                2011.0
# 154834  5440459.0    2076641102                2012.0
# 154855  5440459.0    2084557827                2012.0
# 154856  5440459.0    2095089605                2012.0
#
#         FirstPostRetractionMAGCollaborationYear
# 154838                                   2011.0
# 154858                                   2012.0
# 154800                                   2014.0
# 154832                                   2012.0
# 154833                                   2012.0
# 154835                                   2011.0
# 154802                                   2011.0
# 154803                                   2011.0
# 154804                                   2011.0
# 154801                                   2011.0
# 154819                                   2012.0
# 154820                                   2012.0
# 154847                                   2013.0
# 154848                                   2013.0
# 154851                                   2012.0
# 154852                                   2012.0
# 154808                                   2012.0
# 154821                                   2012.0
# 154822                                   2012.0
# 154836                                   2011.0
# 154853                                   2012.0
# 154810                                   2011.0
# 154809                                   2011.0
# 154861                                   2013.0
# 154860                                   2013.0
# 154857                                   2012.0
# 154859                                   2011.0
# 154834                                   2012.0
# 154855                                   2012.0
# 154856                                   2012.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A1_w_firstcollabs_only = df_A1_w_firstcollabs[df_A1_w_firstcollabs.MAGCollaborationYear == \
                                                df_A1_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A1_w_firstcollabs_only.shape
# Out:
# (155136, 35)

# %%
df_A1_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#        'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#        'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#        'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
def create_stratified_dfs_retention(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
               'CollabMAGCumPapersAtCollaboration', 'CollabMAGCumCitationsAtCollaboration',
               'CollabMAGCumCollaboratorsAtCollaboration', 'ReasonPropagatedMajorityOfMajority',
               'CollabAcademicAgeAtCollaboration', 'CollabAIDinRetained', 'NumRetentionW5']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi = dfi[dfi['CollabAIDinRetained']]
    
    # Dividing into retracted and matched
    df_retracted = dfi[dfi.ScientistType == 'retracted']
    df_nonretracted = dfi[dfi.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the retracted scientists have matches with non zero collaborators
    df_retracted = df_retracted[df_retracted.MAGAID.isin(df_nonretracted.MAGAID.unique())]
    
    # We need to make sure that the matches of those who retained 0 collaborators are removed
    df_nonretracted = df_nonretracted[df_nonretracted.MAGAID.isin(df_retracted.MAGAID.unique())]
    
    # Dividing into seniority for retracted
    df_retracted_junior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_retracted_midcareer = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_retracted_senior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='mistake']
    # and matched
    df_nonretracted_junior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_nonretracted_midcareer = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_nonretracted_senior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='mistake']
    
    return df_retracted_junior, df_retracted_midcareer, df_retracted_senior,df_nonretracted_junior, df_nonretracted_midcareer, df_nonretracted_senior

# %%
df_rj, df_rm, df_rs, df_nrj, df_nrm, df_nrs = create_stratified_dfs_retention(df_A1_w_firstcollabs_only)

# %%
df_rj.MAGAID.nunique(), df_rm.MAGAID.nunique(), df_rs.MAGAID.nunique(), df_nrj.MAGAID.nunique(), df_nrm.MAGAID.nunique(), df_nrs.MAGAID.nunique()
# Out:
# (256, 286, 341, 256, 286, 341)

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_retention(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtCollaboration':'MatchCollabMAGCumPapersAtCollaboration',
                                    'CollabAcademicAgeAtCollaboration':'MatchCollabAcademicAgeAtCollaboration',
                                    'CollabMAGCumCitationsAtCollaboration': 'MatchCollabMAGCumCitationsAtCollaboration',
                                    'CollabMAGCumCollaboratorsAtCollaboration': 'MatchCollabMAGCumCollaboratorsAtCollaboration'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj, mean_dfnrj = get_mean_df_retention(df_rj, df_nrj)
mean_dfrm, mean_dfnrm = get_mean_df_retention(df_rm, df_nrm)
mean_dfrs, mean_dfnrs = get_mean_df_retention(df_rs, df_nrs)

mean_dfnrj
# Out:
#             MatchCollabAcademicAgeAtCollaboration  \
# MAGAID
# 40749300                                12.642857
# 48740240                                11.142857
# 59171237                                10.428571
# 115663519                                7.904762
# 207280435                               13.857143
# ...                                           ...
# 3023902287                              12.654762
# 3024473098                               9.625000
# 3052744139                               8.812500
# 3095995937                              14.882353
# 3174844467                              12.833333
#
#             MatchCollabMAGCumPapersAtCollaboration  \
# MAGAID
# 40749300                                 37.857143
# 48740240                                 40.142857
# 59171237                                 85.000000
# 115663519                                18.238095
# 207280435                                28.500000
# ...                                            ...
# 3023902287                               43.226190
# 3024473098                               22.500000
# 3052744139                              110.187500
# 3095995937                               63.882353
# 3174844467                               57.500000
#
#             MatchCollabMAGCumCitationsAtCollaboration  \
# MAGAID
# 40749300                                   359.000000
# 48740240                                   443.714286
# 59171237                                   235.142857
# 115663519                                  268.428571
# 207280435                                  439.642857
# ...                                               ...
# 3023902287                                 855.238095
# 3024473098                                  23.000000
# 3052744139                                 898.125000
# 3095995937                                 395.117647
# 3174844467                                  39.333333
#
#             MatchCollabMAGCumCollaboratorsAtCollaboration
# MAGAID
# 40749300                                        88.928571
# 48740240                                       126.000000
# 59171237                                       154.428571
# 115663519                                       56.428571
# 207280435                                       61.642857
# ...                                                   ...
# 3023902287                                     197.619048
# 3024473098                                      76.750000
# 3052744139                                     123.250000
# 3095995937                                      91.294118
# 3174844467                                      31.833333
#
# [256 rows x 4 columns]

# %%
exp_fields = ['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_retention = []

for exp_field in exp_fields:
    dicts_retention = {}
    
    dict_stats_j = get_stats(mean_dfrj, mean_dfnrj, exp_field)
    dict_stats_m = get_stats(mean_dfrm, mean_dfnrm, exp_field)
    dict_stats_s = get_stats(mean_dfrs, mean_dfnrs, exp_field)
    
    dicts_retention['Misconduct'] = dict_stats_j
    dicts_retention['Plagiarism'] = dict_stats_m
    dicts_retention['Mistake'] = dict_stats_s
    
    lst_dicts_retention.append(dicts_retention)

# %%
pd.DataFrame(lst_dicts_retention[0])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabAcademicAgeAtCollaboration_retracted_mean         13.560       12.71
# CollabAcademicAgeAtCollaboration_retracted_median       13.650       12.14
# CollabAcademicAgeAtCollaboration_retracted_std           7.430        7.03
# CollabAcademicAgeAtCollaboration_nonretracted_mean      14.780       15.24
# CollabAcademicAgeAtCollaboration_nonretracted_m...      14.420       14.10
# CollabAcademicAgeAtCollaboration_nonretracted_std        6.410        7.11
# CollabAcademicAgeAtCollaboration_delta_mean             -1.230       -2.54
# CollabAcademicAgeAtCollaboration_pval_welch              0.046        0.00
# CollabAcademicAgeAtCollaboration_CI_95lower             -2.310       -3.62
# CollabAcademicAgeAtCollaboration_CI_95upper             -0.150       -1.45
#
#                                                     Mistake
# CollabAcademicAgeAtCollaboration_retracted_mean      15.070
# CollabAcademicAgeAtCollaboration_retracted_median    15.290
# CollabAcademicAgeAtCollaboration_retracted_std        6.550
# CollabAcademicAgeAtCollaboration_nonretracted_mean   15.710
# CollabAcademicAgeAtCollaboration_nonretracted_m...   15.000
# CollabAcademicAgeAtCollaboration_nonretracted_std     6.690
# CollabAcademicAgeAtCollaboration_delta_mean          -0.640
# CollabAcademicAgeAtCollaboration_pval_welch           0.207
# CollabAcademicAgeAtCollaboration_CI_95lower          -1.490
# CollabAcademicAgeAtCollaboration_CI_95upper           0.210

# %%
pd.DataFrame(lst_dicts_retention[1])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumPapersAtCollaboration_retracted_mean        73.600      61.950
# CollabMAGCumPapersAtCollaboration_retracted_median      56.590      44.250
# CollabMAGCumPapersAtCollaboration_retracted_std        100.320      64.510
# CollabMAGCumPapersAtCollaboration_nonretracted_...      81.770      69.020
# CollabMAGCumPapersAtCollaboration_nonretracted_...      60.940      57.840
# CollabMAGCumPapersAtCollaboration_nonretracted_std     104.120      53.990
# CollabMAGCumPapersAtCollaboration_delta_mean            -8.160      -7.070
# CollabMAGCumPapersAtCollaboration_pval_welch             0.367       0.156
# CollabMAGCumPapersAtCollaboration_CI_95lower           -25.700     -16.500
# CollabMAGCumPapersAtCollaboration_CI_95upper             9.370       2.350
#
#                                                     Mistake
# CollabMAGCumPapersAtCollaboration_retracted_mean     75.330
# CollabMAGCumPapersAtCollaboration_retracted_median   61.000
# CollabMAGCumPapersAtCollaboration_retracted_std      64.380
# CollabMAGCumPapersAtCollaboration_nonretracted_...   80.690
# CollabMAGCumPapersAtCollaboration_nonretracted_...   61.890
# CollabMAGCumPapersAtCollaboration_nonretracted_std   71.000
# CollabMAGCumPapersAtCollaboration_delta_mean         -5.360
# CollabMAGCumPapersAtCollaboration_pval_welch          0.302
# CollabMAGCumPapersAtCollaboration_CI_95lower        -14.740
# CollabMAGCumPapersAtCollaboration_CI_95upper          4.030

# %%
pd.DataFrame(lst_dicts_retention[2])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCitationsAtCollaboration_retracted_...    1480.050     981.900
# CollabMAGCumCitationsAtCollaboration_retracted_...     818.350     409.830
# CollabMAGCumCitationsAtCollaboration_retracted_std    1962.390    2121.710
# CollabMAGCumCitationsAtCollaboration_nonretract...    1790.190    1045.830
# CollabMAGCumCitationsAtCollaboration_nonretract...     902.490     577.980
# CollabMAGCumCitationsAtCollaboration_nonretract...    2870.800    1318.450
# CollabMAGCumCitationsAtCollaboration_delta_mean       -310.140     -63.930
# CollabMAGCumCitationsAtCollaboration_pval_welch          0.154       0.665
# CollabMAGCumCitationsAtCollaboration_CI_95lower       -701.970    -337.870
# CollabMAGCumCitationsAtCollaboration_CI_95upper         81.680     210.010
#
#                                                     Mistake
# CollabMAGCumCitationsAtCollaboration_retracted_...  1778.22
# CollabMAGCumCitationsAtCollaboration_retracted_...  1087.60
# CollabMAGCumCitationsAtCollaboration_retracted_std  2193.66
# CollabMAGCumCitationsAtCollaboration_nonretract...  1824.58
# CollabMAGCumCitationsAtCollaboration_nonretract...   977.36
# CollabMAGCumCitationsAtCollaboration_nonretract...  2794.45
# CollabMAGCumCitationsAtCollaboration_delta_mean      -46.35
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.81
# CollabMAGCumCitationsAtCollaboration_CI_95lower     -394.47
# CollabMAGCumCitationsAtCollaboration_CI_95upper      301.76

# %%
pd.DataFrame(lst_dicts_retention[3])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     181.990      153.51
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     131.150       84.01
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     219.750      186.01
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     218.300      161.11
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     147.750      109.83
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     393.010      179.80
# CollabMAGCumCollaboratorsAtCollaboration_delta_...     -36.310       -7.60
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...       0.198        0.62
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...     -92.330      -33.90
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...      19.710       18.71
#
#                                                     Mistake
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  207.920
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  133.060
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  279.890
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  197.270
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  125.790
# CollabMAGCumCollaboratorsAtCollaboration_nonret...  221.370
# CollabMAGCumCollaboratorsAtCollaboration_delta_...   10.660
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...    0.581
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...  -24.960
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...   46.280

# %% [markdown]
# ### A2: Collaborators gained: retracted vs. matched

# %%
#Let us now modify df_A1 such that we remove all rows with collaborations pre-retraction

df_A2_post = df_A[df_A['PrePostFlag5']=='post5']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A2_firstcollabs = df_A2_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A2_w_firstcollabs = df_A2_post.merge(df_A2_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A2_w_firstcollabs.shape
# Out:
# (206342, 35)

# %%
# Sensibility checks

df_A2_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#            MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 154838  5440459.0      97975655                2011.0
# 154858  5440459.0     165967445                2012.0
# 154800  5440459.0     238488652                2014.0
# 154832  5440459.0     293709409                2012.0
# 154833  5440459.0     298713076                2012.0
# 154835  5440459.0     324850990                2011.0
# 154802  5440459.0     698114488                2011.0
# 154803  5440459.0     698114488                2012.0
# 154804  5440459.0     698114488                2013.0
# 154801  5440459.0     698114488                2014.0
# 154819  5440459.0    1155384243                2012.0
# 154820  5440459.0    1155384243                2013.0
# 154847  5440459.0    1898953080                2013.0
# 154848  5440459.0    1898953080                2015.0
# 154851  5440459.0    1964584928                2012.0
# 154852  5440459.0    1964584928                2013.0
# 154808  5440459.0    1969819737                2012.0
# 154821  5440459.0    1970538733                2012.0
# 154822  5440459.0    1970538733                2013.0
# 154836  5440459.0    1982136528                2011.0
# 154853  5440459.0    2007304365                2012.0
# 154810  5440459.0    2029802714                2011.0
# 154809  5440459.0    2029802714                2012.0
# 154861  5440459.0    2045966497                2013.0
# 154860  5440459.0    2045966497                2015.0
# 154857  5440459.0    2067154876                2012.0
# 154859  5440459.0    2073043934                2011.0
# 154834  5440459.0    2076641102                2012.0
# 154855  5440459.0    2084557827                2012.0
# 154856  5440459.0    2095089605                2012.0
#
#         FirstPostRetractionMAGCollaborationYear
# 154838                                   2011.0
# 154858                                   2012.0
# 154800                                   2014.0
# 154832                                   2012.0
# 154833                                   2012.0
# 154835                                   2011.0
# 154802                                   2011.0
# 154803                                   2011.0
# 154804                                   2011.0
# 154801                                   2011.0
# 154819                                   2012.0
# 154820                                   2012.0
# 154847                                   2013.0
# 154848                                   2013.0
# 154851                                   2012.0
# 154852                                   2012.0
# 154808                                   2012.0
# 154821                                   2012.0
# 154822                                   2012.0
# 154836                                   2011.0
# 154853                                   2012.0
# 154810                                   2011.0
# 154809                                   2011.0
# 154861                                   2013.0
# 154860                                   2013.0
# 154857                                   2012.0
# 154859                                   2011.0
# 154834                                   2012.0
# 154855                                   2012.0
# 154856                                   2012.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A2_w_firstcollabs_only = df_A2_w_firstcollabs[df_A2_w_firstcollabs.MAGCollaborationYear == \
                                                df_A2_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A2_w_firstcollabs_only.shape
# Out:
# (155136, 35)

# %%
df_A2_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#        'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#        'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#        'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
def create_stratified_dfs_gain(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
               'CollabMAGCumPapersAtCollaboration', 'CollabMAGCumCitationsAtCollaboration',
               'CollabMAGCumCollaboratorsAtCollaboration', 'ReasonPropagatedMajorityOfMajority',
               'CollabAcademicAgeAtCollaboration', 'CollabAIDinGained', 'NumNewCollaboratorsW5']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi = dfi[dfi['CollabAIDinGained']]
    
    # Dividing into retracted and matched
    df_retracted = dfi[dfi.ScientistType == 'retracted']
    df_nonretracted = dfi[dfi.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the retracted scientists have matches with non zero collaborators
    df_retracted = df_retracted[df_retracted.MAGAID.isin(df_nonretracted.MAGAID.unique())]
    
    # We need to make sure that the matches of those who retained 0 collaborators are removed
    df_nonretracted = df_nonretracted[df_nonretracted.MAGAID.isin(df_retracted.MAGAID.unique())]
    
    # Dividing into seniority for retracted
    df_retracted_junior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_retracted_midcareer = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_retracted_senior = df_retracted[df_retracted.ReasonPropagatedMajorityOfMajority=='mistake']
    # and matched
    df_nonretracted_junior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='misconduct']
    df_nonretracted_midcareer = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='plagiarism']
    df_nonretracted_senior = df_nonretracted[df_nonretracted.ReasonPropagatedMajorityOfMajority=='mistake']
    
    return df_retracted_junior, df_retracted_midcareer, df_retracted_senior,df_nonretracted_junior, df_nonretracted_midcareer, df_nonretracted_senior

# %%
df_rj, df_rm, df_rs, df_nrj, df_nrm, df_nrs = create_stratified_dfs_gain(df_A2_w_firstcollabs_only)

# %%
df_rj.MAGAID.nunique(), df_rm.MAGAID.nunique(), df_rs.MAGAID.nunique(), df_nrj.MAGAID.nunique(), df_nrm.MAGAID.nunique(), df_nrs.MAGAID.nunique()
# Out:
# (260, 292, 368, 260, 292, 368)

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_gain(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtCollaboration':'MatchCollabMAGCumPapersAtCollaboration',
                                    'CollabAcademicAgeAtCollaboration':'MatchCollabAcademicAgeAtCollaboration',
                                    'CollabMAGCumCitationsAtCollaboration': 'MatchCollabMAGCumCitationsAtCollaboration',
                                    'CollabMAGCumCollaboratorsAtCollaboration': 'MatchCollabMAGCumCollaboratorsAtCollaboration'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj, mean_dfnrj = get_mean_df_gain(df_rj, df_nrj)
mean_dfrm, mean_dfnrm = get_mean_df_gain(df_rm, df_nrm)
mean_dfrs, mean_dfnrs = get_mean_df_gain(df_rs, df_nrs)

mean_dfnrj
# Out:
#             MatchCollabAcademicAgeAtCollaboration  \
# MAGAID
# 40749300                                 8.565217
# 48740240                                 9.166667
# 59171237                                 5.952381
# 62104001                                 9.000000
# 115663519                                3.840000
# ...                                           ...
# 3024473098                               2.764706
# 3052744139                               6.987405
# 3095995937                               9.129032
# 3166925194                              13.375000
# 3174844467                               3.529412
#
#             MatchCollabMAGCumPapersAtCollaboration  \
# MAGAID
# 40749300                                 39.456522
# 48740240                                 34.000000
# 59171237                                  9.333333
# 62104001                                  4.000000
# 115663519                                13.906667
# ...                                            ...
# 3024473098                                5.117647
# 3052744139                               53.289624
# 3095995937                               51.193548
# 3166925194                               29.375000
# 3174844467                               23.647059
#
#             MatchCollabMAGCumCitationsAtCollaboration  \
# MAGAID
# 40749300                                   601.043478
# 48740240                                   624.500000
# 59171237                                    55.571429
# 62104001                                    22.000000
# 115663519                                  183.520000
# ...                                               ...
# 3024473098                                   1.823529
# 3052744139                                1168.337350
# 3095995937                                 492.774194
# 3166925194                                 375.750000
# 3174844467                                 138.156863
#
#             MatchCollabMAGCumCollaboratorsAtCollaboration
# MAGAID
# 40749300                                        87.195652
# 48740240                                        71.333333
# 59171237                                        27.190476
# 62104001                                        10.000000
# 115663519                                       52.933333
# ...                                                   ...
# 3024473098                                      19.588235
# 3052744139                                     245.023625
# 3095995937                                     109.580645
# 3166925194                                      90.500000
# 3174844467                                      30.058824
#
# [260 rows x 4 columns]

# %%
exp_fields = ['CollabAcademicAgeAtCollaboration',
                      'CollabMAGCumPapersAtCollaboration',
                      'CollabMAGCumCitationsAtCollaboration',
                      'CollabMAGCumCollaboratorsAtCollaboration']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_gain = []

for exp_field in exp_fields:
    dicts_gain = {}
    
    dict_stats_j = get_stats(mean_dfrj, mean_dfnrj, exp_field)
    dict_stats_m = get_stats(mean_dfrm, mean_dfnrm, exp_field)
    dict_stats_s = get_stats(mean_dfrs, mean_dfnrs, exp_field)
    
    dicts_gain['Misconduct'] = dict_stats_j
    dicts_gain['Plagiarism'] = dict_stats_m
    dicts_gain['Mistake'] = dict_stats_s
    
    lst_dicts_gain.append(dicts_gain)

# %%
pd.DataFrame(lst_dicts_gain[0])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabAcademicAgeAtCollaboration_retracted_mean          7.980       6.680
# CollabAcademicAgeAtCollaboration_retracted_median        7.550       6.330
# CollabAcademicAgeAtCollaboration_retracted_std           6.070       4.830
# CollabAcademicAgeAtCollaboration_nonretracted_mean       8.100       7.740
# CollabAcademicAgeAtCollaboration_nonretracted_m...       7.920       7.560
# CollabAcademicAgeAtCollaboration_nonretracted_std        4.480       4.750
# CollabAcademicAgeAtCollaboration_delta_mean             -0.120      -1.060
# CollabAcademicAgeAtCollaboration_pval_welch              0.792       0.008
# CollabAcademicAgeAtCollaboration_CI_95lower             -1.000      -1.780
# CollabAcademicAgeAtCollaboration_CI_95upper              0.760      -0.340
#
#                                                     Mistake
# CollabAcademicAgeAtCollaboration_retracted_mean       8.610
# CollabAcademicAgeAtCollaboration_retracted_median     8.610
# CollabAcademicAgeAtCollaboration_retracted_std        4.830
# CollabAcademicAgeAtCollaboration_nonretracted_mean    8.140
# CollabAcademicAgeAtCollaboration_nonretracted_m...    7.840
# CollabAcademicAgeAtCollaboration_nonretracted_std     4.530
# CollabAcademicAgeAtCollaboration_delta_mean           0.470
# CollabAcademicAgeAtCollaboration_pval_welch           0.172
# CollabAcademicAgeAtCollaboration_CI_95lower          -0.140
# CollabAcademicAgeAtCollaboration_CI_95upper           1.090

# %%
pd.DataFrame(lst_dicts_gain[1])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumPapersAtCollaboration_retracted_mean        45.010      32.430
# CollabMAGCumPapersAtCollaboration_retracted_median      28.360      22.320
# CollabMAGCumPapersAtCollaboration_retracted_std         62.330      34.170
# CollabMAGCumPapersAtCollaboration_nonretracted_...      34.420      33.890
# CollabMAGCumPapersAtCollaboration_nonretracted_...      31.270      28.240
# CollabMAGCumPapersAtCollaboration_nonretracted_std      25.450      30.070
# CollabMAGCumPapersAtCollaboration_delta_mean            10.590      -1.460
# CollabMAGCumPapersAtCollaboration_pval_welch             0.012       0.584
# CollabMAGCumPapersAtCollaboration_CI_95lower             2.330      -6.310
# CollabMAGCumPapersAtCollaboration_CI_95upper            18.850       3.390
#
#                                                     Mistake
# CollabMAGCumPapersAtCollaboration_retracted_mean     41.390
# CollabMAGCumPapersAtCollaboration_retracted_median   34.300
# CollabMAGCumPapersAtCollaboration_retracted_std      42.970
# CollabMAGCumPapersAtCollaboration_nonretracted_...   37.490
# CollabMAGCumPapersAtCollaboration_nonretracted_...   26.770
# CollabMAGCumPapersAtCollaboration_nonretracted_std   39.040
# CollabMAGCumPapersAtCollaboration_delta_mean          3.900
# CollabMAGCumPapersAtCollaboration_pval_welch          0.198
# CollabMAGCumPapersAtCollaboration_CI_95lower         -1.860
# CollabMAGCumPapersAtCollaboration_CI_95upper          9.650

# %%
pd.DataFrame(lst_dicts_gain[2])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCitationsAtCollaboration_retracted_...    1105.930     603.460
# CollabMAGCumCitationsAtCollaboration_retracted_...     501.370     271.050
# CollabMAGCumCitationsAtCollaboration_retracted_std    1928.010    1149.470
# CollabMAGCumCitationsAtCollaboration_nonretract...     702.350     625.350
# CollabMAGCumCitationsAtCollaboration_nonretract...     473.390     299.330
# CollabMAGCumCitationsAtCollaboration_nonretract...     856.960     937.570
# CollabMAGCumCitationsAtCollaboration_delta_mean        403.580     -21.900
# CollabMAGCumCitationsAtCollaboration_pval_welch          0.002       0.801
# CollabMAGCumCitationsAtCollaboration_CI_95lower        160.250    -182.450
# CollabMAGCumCitationsAtCollaboration_CI_95upper        646.900     138.660
#
#                                                      Mistake
# CollabMAGCumCitationsAtCollaboration_retracted_...  1075.940
# CollabMAGCumCitationsAtCollaboration_retracted_...   624.410
# CollabMAGCumCitationsAtCollaboration_retracted_std  1575.770
# CollabMAGCumCitationsAtCollaboration_nonretract...   946.340
# CollabMAGCumCitationsAtCollaboration_nonretract...   429.640
# CollabMAGCumCitationsAtCollaboration_nonretract...  1554.610
# CollabMAGCumCitationsAtCollaboration_delta_mean      129.600
# CollabMAGCumCitationsAtCollaboration_pval_welch        0.262
# CollabMAGCumCitationsAtCollaboration_CI_95lower      -94.110
# CollabMAGCumCitationsAtCollaboration_CI_95upper      353.310

# %%
pd.DataFrame(lst_dicts_gain[3])
# Out:
#                                                     Misconduct  Plagiarism  \
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     156.420     103.740
# CollabMAGCumCollaboratorsAtCollaboration_retrac...      79.560      50.840
# CollabMAGCumCollaboratorsAtCollaboration_retrac...     319.800     149.550
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     110.780     102.410
# CollabMAGCumCollaboratorsAtCollaboration_nonret...      73.730      58.680
# CollabMAGCumCollaboratorsAtCollaboration_nonret...     132.790     147.470
# CollabMAGCumCollaboratorsAtCollaboration_delta_...      45.630       1.330
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...       0.034       0.914
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...       3.210     -20.020
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...      88.060      22.670
#
#                                                      Mistake
# CollabMAGCumCollaboratorsAtCollaboration_retrac...   206.150
# CollabMAGCumCollaboratorsAtCollaboration_retrac...    88.210
# CollabMAGCumCollaboratorsAtCollaboration_retrac...  1031.160
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   123.360
# CollabMAGCumCollaboratorsAtCollaboration_nonret...    70.960
# CollabMAGCumCollaboratorsAtCollaboration_nonret...   169.270
# CollabMAGCumCollaboratorsAtCollaboration_delta_...    82.790
# CollabMAGCumCollaboratorsAtCollaboration_pval_w...     0.129
# CollabMAGCumCollaboratorsAtCollaboration_CI_95l...   -24.660
# CollabMAGCumCollaboratorsAtCollaboration_CI_95u...   190.240

# %%
def create_latex_for_filling(dicto, col):
    
    def create_string(metric):
        string = ""
        if metric == 'pval_welch':
            string = "& " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                "\\\ \n"
        else:
            string = "& " + \
                    str(dicto.get('Misconduct').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Misconduct').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_nonretracted_"+metric)) + \
                    "\\\ \n"
        
        
        
        return string
    
    print(create_string("mean"))
    print(create_string("median"))
    print(create_string("std"))
    print(create_string("pval_welch"))
    

for i in range(len(lst_dicts_retention)):
    dicto = lst_dicts_retention[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto, col)
    
    
# pd.DataFrame(lst_dicts_retention[0])
# Out:
# CollabAcademicAgeAtCollaboration
# & 13.56 & 14.78 & 12.71 & 15.24 & 15.07 & 15.71\\
#
# & 13.65 & 14.42 & 12.14 & 14.1 & 15.29 & 15.0\\
#
# & 7.43 & 6.41 & 7.03 & 7.11 & 6.55 & 6.69\\
#
# & 0.046 & 0.046 & 0.0 & 0.0 & 0.207 & 0.207\\
#
# CollabMAGCumPapersAtCollaboration
# & 73.6 & 81.77 & 61.95 & 69.02 & 75.33 & 80.69\\
#
# & 56.59 & 60.94 & 44.25 & 57.84 & 61.0 & 61.89\\
#
# & 100.32 & 104.12 & 64.51 & 53.99 & 64.38 & 71.0\\
#
# & 0.367 & 0.367 & 0.156 & 0.156 & 0.302 & 0.302\\
#
# CollabMAGCumCitationsAtCollaboration
# & 1480.05 & 1790.19 & 981.9 & 1045.83 & 1778.22 & 1824.58\\
#
# & 818.35 & 902.49 & 409.83 & 577.98 & 1087.6 & 977.36\\
#
# & 1962.39 & 2870.8 & 2121.71 & 1318.45 & 2193.66 & 2794.45\\
#
# & 0.154 & 0.154 & 0.665 & 0.665 & 0.81 & 0.81\\
#
# CollabMAGCumCollaboratorsAtCollaboration
# & 181.99 & 218.3 & 153.51 & 161.11 & 207.92 & 197.27\\
#
# & 131.15 & 147.75 & 84.01 & 109.83 & 133.06 & 125.79\\
#
# & 219.75 & 393.01 & 186.01 & 179.8 & 279.89 & 221.37\\
#
# & 0.198 & 0.198 & 0.62 & 0.62 & 0.581 & 0.581\\

# %%
for i in range(len(lst_dicts_gain)):
    dicto = lst_dicts_gain[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto, col)
# Out:
# CollabAcademicAgeAtCollaboration
# & 7.98 & 8.1 & 6.68 & 7.74 & 8.61 & 8.14\\
#
# & 7.55 & 7.92 & 6.33 & 7.56 & 8.61 & 7.84\\
#
# & 6.07 & 4.48 & 4.83 & 4.75 & 4.83 & 4.53\\
#
# & 0.792 & 0.792 & 0.008 & 0.008 & 0.172 & 0.172\\
#
# CollabMAGCumPapersAtCollaboration
# & 45.01 & 34.42 & 32.43 & 33.89 & 41.39 & 37.49\\
#
# & 28.36 & 31.27 & 22.32 & 28.24 & 34.3 & 26.77\\
#
# & 62.33 & 25.45 & 34.17 & 30.07 & 42.97 & 39.04\\
#
# & 0.012 & 0.012 & 0.584 & 0.584 & 0.198 & 0.198\\
#
# CollabMAGCumCitationsAtCollaboration
# & 1105.93 & 702.35 & 603.46 & 625.35 & 1075.94 & 946.34\\
#
# & 501.37 & 473.39 & 271.05 & 299.33 & 624.41 & 429.64\\
#
# & 1928.01 & 856.96 & 1149.47 & 937.57 & 1575.77 & 1554.61\\
#
# & 0.002 & 0.002 & 0.801 & 0.801 & 0.262 & 0.262\\
#
# CollabMAGCumCollaboratorsAtCollaboration
# & 156.42 & 110.78 & 103.74 & 102.41 & 206.15 & 123.36\\
#
# & 79.56 & 73.73 & 50.84 & 58.68 & 88.21 & 70.96\\
#
# & 319.8 & 132.79 & 149.55 & 147.47 & 1031.16 & 169.27\\
#
# & 0.034 & 0.034 & 0.914 & 0.914 & 0.129 & 0.129\\

# %% [markdown]
# ### A3: Collaborators retained vs lost: retracted vs. matched

# %%
#Let us now modify df_A3 such that we remove all rows with collaborations pre-retraction

df_A3_post = df_A[df_A['PrePostFlag5']=='post5']
df_A3_pre = df_A[df_A['PrePostFlag5']=='pre']

# %%
# Now we shall groupby MAGAID, MAGCollabAID, RetractionYear, and sort by MAGCollaborationYear
# Then I shall extract the earliest collaboration year post retraction

df_A3_firstcollabs = df_A3_post.groupby(['MAGAID','MAGCollabAID','RetractionYear'])['MAGCollaborationYear']\
                        .min().reset_index()\
                        .rename(columns={'MAGCollaborationYear':'FirstPostRetractionMAGCollaborationYear'})


# Now we shall merge the new column with A1

df_A3_w_firstcollabs = df_A3_post.merge(df_A1_firstcollabs,
                                   on=['MAGAID','MAGCollabAID','RetractionYear'])

df_A3_w_firstcollabs.shape
# Out:
# (206342, 35)

# %%
# Sensibility checks

df_A3_w_firstcollabs.sort_values(by=['MAGAID','MAGCollabAID','MAGCollaborationYear'])\
            [['MAGAID','MAGCollabAID','MAGCollaborationYear','FirstPostRetractionMAGCollaborationYear']].head(30)
# Out:
#            MAGAID  MAGCollabAID  MAGCollaborationYear  \
# 154838  5440459.0      97975655                2011.0
# 154858  5440459.0     165967445                2012.0
# 154800  5440459.0     238488652                2014.0
# 154832  5440459.0     293709409                2012.0
# 154833  5440459.0     298713076                2012.0
# 154835  5440459.0     324850990                2011.0
# 154802  5440459.0     698114488                2011.0
# 154803  5440459.0     698114488                2012.0
# 154804  5440459.0     698114488                2013.0
# 154801  5440459.0     698114488                2014.0
# 154819  5440459.0    1155384243                2012.0
# 154820  5440459.0    1155384243                2013.0
# 154847  5440459.0    1898953080                2013.0
# 154848  5440459.0    1898953080                2015.0
# 154851  5440459.0    1964584928                2012.0
# 154852  5440459.0    1964584928                2013.0
# 154808  5440459.0    1969819737                2012.0
# 154821  5440459.0    1970538733                2012.0
# 154822  5440459.0    1970538733                2013.0
# 154836  5440459.0    1982136528                2011.0
# 154853  5440459.0    2007304365                2012.0
# 154810  5440459.0    2029802714                2011.0
# 154809  5440459.0    2029802714                2012.0
# 154861  5440459.0    2045966497                2013.0
# 154860  5440459.0    2045966497                2015.0
# 154857  5440459.0    2067154876                2012.0
# 154859  5440459.0    2073043934                2011.0
# 154834  5440459.0    2076641102                2012.0
# 154855  5440459.0    2084557827                2012.0
# 154856  5440459.0    2095089605                2012.0
#
#         FirstPostRetractionMAGCollaborationYear
# 154838                                   2011.0
# 154858                                   2012.0
# 154800                                   2014.0
# 154832                                   2012.0
# 154833                                   2012.0
# 154835                                   2011.0
# 154802                                   2011.0
# 154803                                   2011.0
# 154804                                   2011.0
# 154801                                   2011.0
# 154819                                   2012.0
# 154820                                   2012.0
# 154847                                   2013.0
# 154848                                   2013.0
# 154851                                   2012.0
# 154852                                   2012.0
# 154808                                   2012.0
# 154821                                   2012.0
# 154822                                   2012.0
# 154836                                   2011.0
# 154853                                   2012.0
# 154810                                   2011.0
# 154809                                   2011.0
# 154861                                   2013.0
# 154860                                   2013.0
# 154857                                   2012.0
# 154859                                   2011.0
# 154834                                   2012.0
# 154855                                   2012.0
# 154856                                   2012.0

# %%
# Now let us only extract rows where collaboration year is the first collaboration year

df_A3_w_firstcollabs_only = df_A3_w_firstcollabs[df_A3_w_firstcollabs.MAGCollaborationYear == \
                                                df_A3_w_firstcollabs.FirstPostRetractionMAGCollaborationYear]

df_A3_w_firstcollabs_only.shape
# Out:
# (155136, 35)

# %%
df_A3_w_firstcollabs_only.columns
# Out:
# Index(['MAGAID', 'MAGCollabAID', 'RetractionYear', 'MAGCollaborationYear',
#        'ScientistType', 'CollabGenderizeGender', 'CollabGenderizeConfidence',
#        'CollabMAGFirstPubYear', 'CollabMAGCumPapersYearAtRetraction',
#        'CollabMAGCumPapersAtRetraction',
#        'CollabMAGCumCitationsYearAtRetraction',
#        'CollabMAGCumCitationsAtRetraction',
#        'CollabMAGCumCollaboratorsYearAtRetraction',
#        'CollabMAGCumCollaboratorsAtRetraction',
#        'CollabMAGCumPapersYearAtCollaboration',
#        'CollabMAGCumPapersAtCollaboration',
#        'CollabMAGCumCitationsYearAtCollaboration',
#        'CollabMAGCumCitationsAtCollaboration',
#        'CollabMAGCumCollaboratorsYearAtCollaboration',
#        'CollabMAGCumCollaboratorsAtCollaboration',
#        'ReasonPropagatedMajorityOfMajority', 'CollabAcademicAgeAtRetraction',
#        'CollabAcademicAgeAtCollaboration', 'PrePostFlag5', 'post5', 'pre',
#        'NumRetentionW5', 'CollabAIDRetainedW5', 'CollabAIDLostW5',
#        'NumNewCollaboratorsW5', 'CollabAIDGainedW5', 'CollabAIDinRetained',
#        'CollabAIDinGained', 'CollabAIDinLost',
#        'FirstPostRetractionMAGCollaborationYear'],
#       dtype='object')

# %%
# Finally let us merge post and pre

df_A3_post_pre = pd.concat([df_A3_w_firstcollabs_only,df_A3_pre])

df_A3_post_pre.head()
# Out:
#          MAGAID  MAGCollabAID  RetractionYear  MAGCollaborationYear  \
# 0  2.105038e+09    2024377920          1994.0                1999.0
# 1  2.105038e+09    2111173543          1994.0                1999.0
# 2  2.105038e+09    2317413108          1994.0                1999.0
# 3  2.105038e+09    2432858298          1994.0                1999.0
# 4  2.105038e+09    2124401064          1994.0                1996.0
#
#   ScientistType CollabGenderizeGender  CollabGenderizeConfidence  \
# 0     retracted                  male                       0.99
# 1     retracted                  male                       0.99
# 2     retracted                  male                       0.99
# 3     retracted                  male                       0.86
# 4     retracted                  male                       0.74
#
#    CollabMAGFirstPubYear  CollabMAGCumPapersYearAtRetraction  \
# 0                 1992.0                              1994.0
# 1                 1979.0                              1994.0
# 2                 1998.0                                 NaN
# 3                 1962.0                              1994.0
# 4                 1964.0                              1994.0
#
#    CollabMAGCumPapersAtRetraction  ...  \
# 0                             3.0  ...
# 1                            41.0  ...
# 2                             0.0  ...
# 3                            67.0  ...
# 4                            78.0  ...
#
#                                                  pre  NumRetentionW5  \
# 0  {2935888513, 2004120834, 3069320578, 231952499...               4
# 1  {2935888513, 2004120834, 3069320578, 231952499...               4
# 2  {2935888513, 2004120834, 3069320578, 231952499...               4
# 3  {2935888513, 2004120834, 3069320578, 231952499...               4
# 4  {2935888513, 2004120834, 3069320578, 231952499...               4
#
#                                 CollabAIDRetainedW5  \
# 0  {2124401064, 2139577513, 2308282282, 2276877851}
# 1  {2124401064, 2139577513, 2308282282, 2276877851}
# 2  {2124401064, 2139577513, 2308282282, 2276877851}
# 3  {2124401064, 2139577513, 2308282282, 2276877851}
# 4  {2124401064, 2139577513, 2308282282, 2276877851}
#
#                                      CollabAIDLostW5  NumNewCollaboratorsW5  \
# 0  {2004120834, 2787959316, 2464403478, 263399605...                      4
# 1  {2004120834, 2787959316, 2464403478, 263399605...                      4
# 2  {2004120834, 2787959316, 2464403478, 263399605...                      4
# 3  {2004120834, 2787959316, 2464403478, 263399605...                      4
# 4  {2004120834, 2787959316, 2464403478, 263399605...                      4
#
#                                   CollabAIDGainedW5  CollabAIDinRetained  \
# 0  {2024377920, 2432858298, 2317413108, 2111173543}                False
# 1  {2024377920, 2432858298, 2317413108, 2111173543}                False
# 2  {2024377920, 2432858298, 2317413108, 2111173543}                False
# 3  {2024377920, 2432858298, 2317413108, 2111173543}                False
# 4  {2024377920, 2432858298, 2317413108, 2111173543}                 True
#
#    CollabAIDinGained  CollabAIDinLost  FirstPostRetractionMAGCollaborationYear
# 0               True            False                                   1999.0
# 1               True            False                                   1999.0
# 2               True            False                                   1999.0
# 3               True            False                                   1999.0
# 4              False            False                                   1996.0
#
# [5 rows x 35 columns]

# %%
def create_stratified_dfs_a3(dfi):
    
    # This function will create 6 dataframes relevant for conducting our analysis
    # 3 of those dataframes will be for relevant columns for treatment
    # rest 3 will be average control. 
    # These will be stratified by treatment and control, and further stratified by seniority
    df_ids = pd.read_csv(INDIR_MATCHING+"/RWMAG_rematched_control_augmented_rematching_30perc.csv",
                    usecols=['MAGAID','MatchMAGAID', 'RetractionYear']).drop_duplicates()
    
    rel_cols = ['MAGAID', 'ScientistType','MAGCollabAID', 'RetractionYear',
               'CollabMAGCumPapersAtRetraction', 'CollabMAGCumCitationsAtRetraction',
               'CollabMAGCumCollaboratorsAtRetraction', 'ReasonPropagatedMajorityOfMajority',
               'CollabAcademicAgeAtRetraction', 'CollabAIDinRetained', 'CollabAIDinLost']
    
    # Only extracting relevant cols
    dfi = dfi[rel_cols].drop_duplicates()
    
    # Only extract those collaborators that were retained
    dfi_retained = dfi[dfi['CollabAIDinRetained']]
    dfi_lost = dfi[dfi['CollabAIDinLost']]
    
    # Dividing into retracted and matched
    df_retracted_retained = dfi_retained[dfi_retained.ScientistType == 'retracted']
    df_retracted_lost = dfi_lost[dfi_lost.ScientistType == 'retracted']
    
    df_nonretracted_retained = dfi_retained[dfi_retained.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    df_nonretracted_lost = dfi_lost[dfi_lost.ScientistType == 'matched']\
                        .rename(columns={'MAGAID':'MatchMAGAID'})\
                        .merge(df_ids, on=['MatchMAGAID','RetractionYear'])
    
    # We also need to makre sure that the four groups retracted,non-retracted,retained,lost have same ids
    
    set1 = set(df_retracted_retained['MAGAID'].unique())
    set2 = set(df_retracted_lost['MAGAID'].unique())
    set3 = set(df_nonretracted_retained['MAGAID'].unique())
    set4 = set(df_nonretracted_lost['MAGAID'].unique())
    
    magaids_intersection = set1.intersection(set2, set3, set4)
    
    df_retracted_retained = df_retracted_retained[df_retracted_retained.MAGAID.isin(magaids_intersection)]
    df_retracted_lost = df_retracted_lost[df_retracted_lost.MAGAID.isin(magaids_intersection)]
    df_nonretracted_retained = df_nonretracted_retained[df_nonretracted_retained.MAGAID.isin(magaids_intersection)]
    df_nonretracted_lost = df_nonretracted_lost[df_nonretracted_lost.MAGAID.isin(magaids_intersection)]

    
    # Dividing into seniority for retracted retained
    
    dfrj_r = df_retracted_retained[df_retracted_retained.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfrm_r = df_retracted_retained[df_retracted_retained.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfrs_r = df_retracted_retained[df_retracted_retained.ReasonPropagatedMajorityOfMajority=='mistake']
    
    dfrj_l = df_retracted_lost[df_retracted_lost.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfrm_l = df_retracted_lost[df_retracted_lost.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfrs_l = df_retracted_lost[df_retracted_lost.ReasonPropagatedMajorityOfMajority=='mistake']
    
    # and matched
    dfnrj_r = df_nonretracted_retained[df_nonretracted_retained.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfnrm_r = df_nonretracted_retained[df_nonretracted_retained.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfnrs_r = df_nonretracted_retained[df_nonretracted_retained.ReasonPropagatedMajorityOfMajority=='mistake']
    
    dfnrj_l = df_nonretracted_lost[df_nonretracted_lost.ReasonPropagatedMajorityOfMajority=='misconduct']
    dfnrm_l = df_nonretracted_lost[df_nonretracted_lost.ReasonPropagatedMajorityOfMajority=='plagiarism']
    dfnrs_l = df_nonretracted_lost[df_nonretracted_lost.ReasonPropagatedMajorityOfMajority=='mistake']
    
    return [dfrj_r,dfrm_r,dfrs_r,dfrj_l,dfrm_l,dfrs_l,dfnrj_r,dfnrm_r,dfnrs_r,dfnrj_l,dfnrm_l,dfnrs_l]

# %%
lst_stratified_dfs = create_stratified_dfs_a3(df_A3_post_pre)

for dfj in lst_stratified_dfs:
    print(dfj.MAGAID.nunique())
    
dfrj_r,dfrm_r,dfrs_r,dfrj_l,dfrm_l,dfrs_l,dfnrj_r,dfnrm_r,dfnrs_r,dfnrj_l,dfnrm_l,dfnrs_l = lst_stratified_dfs
# Out:
# 251
# 275
# 332
# 251
# 275
# 332
# 251
# 275
# 332
# 251
# 275
# 332

# %%
# Let us extract the mean dataframes and merge them for different age categories

def get_mean_df_a3(dfr, dfnr):
    mean_dfr = dfr.groupby('MAGAID')[['CollabAcademicAgeAtRetraction',
                      'CollabMAGCumPapersAtRetraction',
                      'CollabMAGCumCitationsAtRetraction',
                      'CollabMAGCumCollaboratorsAtRetraction']].mean()
    
    mean_dfnr = dfnr.groupby(['MAGAID','MatchMAGAID'])[['CollabAcademicAgeAtRetraction',
                      'CollabMAGCumPapersAtRetraction',
                      'CollabMAGCumCitationsAtRetraction',
                      'CollabMAGCumCollaboratorsAtRetraction']].mean()\
                    .groupby('MAGAID').mean()\
                    .rename(columns={'CollabMAGCumPapersAtRetraction':'MatchCollabMAGCumPapersAtRetraction',
                                    'CollabAcademicAgeAtRetraction':'MatchCollabAcademicAgeAtRetraction',
                                    'CollabMAGCumCitationsAtRetraction': 'MatchCollabMAGCumCitationsAtRetraction',
                                    'CollabMAGCumCollaboratorsAtRetraction': 'MatchCollabMAGCumCollaboratorsAtRetraction'})
    
    return mean_dfr, mean_dfnr

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

def get_stats(dfr, dfnr, column):
    """
    This code will compute the mean, median, std dev. and p-value (as per welch test), and CIs for
    the given column
    """
    
    mean_r = dfr[column].mean()
    median_r = dfr[column].median()
    std_r = dfr[column].std()
    
    mean_nr = dfnr['Match'+column].mean()
    median_nr = dfnr['Match'+column].median()
    std_nr = dfnr['Match'+column].std()
    
    _, pval = stats.ttest_ind(dfr[column],dfnr['Match'+column], equal_var=False)
    
    lst_delta = (dfr[column]- dfnr['Match'+column]).tolist()
    delta_mean, conf_lower, conf_upper = mean_confidence_interval(lst_delta, confidence=0.95)
    
    return {column+'_retracted_mean':round(mean_r,2), 
            column+'_retracted_median':round(median_r,2), 
            column+'_retracted_std':round(std_r,2), 
            column+'_nonretracted_mean':round(mean_nr,2), 
            column+'_nonretracted_median':round(median_nr,2), 
            column+'_nonretracted_std':round(std_nr,2), 
            column+'_delta_mean':round(delta_mean,2), 
            column+'_pval_welch':round(pval,3), 
            column+'_CI_95lower':round(conf_lower,2), 
            column+'_CI_95upper':round(conf_upper,2)}

# %%
# Now let us do the comparison

# Let us first get the mean dataframes

mean_dfrj_r, mean_dfnrj_r = get_mean_df_a3(dfrj_r, dfnrj_r)
mean_dfrj_l, mean_dfnrj_l = get_mean_df_a3(dfrj_l, dfnrj_l)

mean_dfrm_r, mean_dfnrm_r = get_mean_df_a3(dfrm_r, dfnrm_r)
mean_dfrm_l, mean_dfnrm_l = get_mean_df_a3(dfrm_l, dfnrm_l)

mean_dfrs_r, mean_dfnrs_r = get_mean_df_a3(dfrs_r, dfnrs_r)
mean_dfrs_l, mean_dfnrs_l = get_mean_df_a3(dfrs_l, dfnrs_l)


# Now let us compute differences

def compute_diff_df(df_ri, df_li, scientistType='retracted'):
    
    dfrli = df_ri.merge(df_li, right_index=True, left_index=True)
    
    if scientistType == 'matched':
        
        dfrli['MatchDiffAcademicAgeAtRetraction'] = dfrli['MatchCollabAcademicAgeAtRetraction_x'] - \
                                                dfrli['MatchCollabAcademicAgeAtRetraction_y']
        
        dfrli['MatchDiffMAGCumPapersAtRetraction'] = dfrli['MatchCollabMAGCumPapersAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumPapersAtRetraction_y']
        
        dfrli['MatchDiffMAGCumCitationsAtRetraction'] = dfrli['MatchCollabMAGCumCitationsAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumCitationsAtRetraction_y']
        
        dfrli['MatchDiffMAGCumCollaboratorsAtRetraction'] = dfrli['MatchCollabMAGCumCollaboratorsAtRetraction_x'] - \
                                                dfrli['MatchCollabMAGCumCollaboratorsAtRetraction_y']
        
        return dfrli
    
        
    dfrli['DiffAcademicAgeAtRetraction'] = dfrli['CollabAcademicAgeAtRetraction_x'] - \
                                            dfrli['CollabAcademicAgeAtRetraction_y']

    dfrli['DiffMAGCumPapersAtRetraction'] = dfrli['CollabMAGCumPapersAtRetraction_x'] - \
                                            dfrli['CollabMAGCumPapersAtRetraction_y']

    dfrli['DiffMAGCumCitationsAtRetraction'] = dfrli['CollabMAGCumCitationsAtRetraction_x'] - \
                                            dfrli['CollabMAGCumCitationsAtRetraction_y']

    dfrli['DiffMAGCumCollaboratorsAtRetraction'] = dfrli['CollabMAGCumCollaboratorsAtRetraction_x'] - \
                                            dfrli['CollabMAGCumCollaboratorsAtRetraction_y']

    return dfrli

# %%
dfrj_rMinusl = compute_diff_df(mean_dfrj_r, mean_dfrj_l)
dfnrj_rMinusl = compute_diff_df(mean_dfnrj_r, mean_dfnrj_l, scientistType='matched')


dfrm_rMinusl = compute_diff_df(mean_dfrm_r, mean_dfrm_l)
dfnrm_rMinusl = compute_diff_df(mean_dfnrm_r, mean_dfnrm_l, scientistType='matched')

dfrs_rMinusl = compute_diff_df(mean_dfrs_r, mean_dfrs_l)
dfnrs_rMinusl = compute_diff_df(mean_dfnrs_r, mean_dfnrs_l, scientistType='matched')

# %%
exp_fields = ['DiffAcademicAgeAtRetraction',
              'DiffMAGCumPapersAtRetraction',
              'DiffMAGCumCitationsAtRetraction',
              'DiffMAGCumCollaboratorsAtRetraction']

# Now we should compute outcome variabels for each of the four experience variables.

lst_dicts_a3 = []

for exp_field in exp_fields:
    dicts_a3 = {}
    
    dict_stats_j = get_stats(dfrj_rMinusl, dfnrj_rMinusl, exp_field)
    dict_stats_m = get_stats(dfrm_rMinusl, dfnrm_rMinusl, exp_field)
    dict_stats_s = get_stats(dfrs_rMinusl, dfnrs_rMinusl, exp_field)
    
    dicts_a3['Misconduct'] = dict_stats_j
    dicts_a3['Plagiarism'] = dict_stats_m
    dicts_a3['Mistake'] = dict_stats_s
    
    lst_dicts_a3.append(dicts_a3)

# %%
pd.DataFrame(lst_dicts_a3[0])
# Out:
#                                                  Misconduct  Plagiarism  \
# DiffAcademicAgeAtRetraction_retracted_mean            1.710        1.90
# DiffAcademicAgeAtRetraction_retracted_median          0.920        1.00
# DiffAcademicAgeAtRetraction_retracted_std             6.520        5.67
# DiffAcademicAgeAtRetraction_nonretracted_mean         2.050        2.86
# DiffAcademicAgeAtRetraction_nonretracted_median       1.510        1.88
# DiffAcademicAgeAtRetraction_nonretracted_std          6.240        6.99
# DiffAcademicAgeAtRetraction_delta_mean               -0.340       -0.95
# DiffAcademicAgeAtRetraction_pval_welch                0.553        0.08
# DiffAcademicAgeAtRetraction_CI_95lower               -1.360       -1.98
# DiffAcademicAgeAtRetraction_CI_95upper                0.680        0.07
#
#                                                  Mistake
# DiffAcademicAgeAtRetraction_retracted_mean         2.270
# DiffAcademicAgeAtRetraction_retracted_median       1.710
# DiffAcademicAgeAtRetraction_retracted_std          6.730
# DiffAcademicAgeAtRetraction_nonretracted_mean      2.350
# DiffAcademicAgeAtRetraction_nonretracted_median    2.240
# DiffAcademicAgeAtRetraction_nonretracted_std       6.400
# DiffAcademicAgeAtRetraction_delta_mean            -0.080
# DiffAcademicAgeAtRetraction_pval_welch             0.883
# DiffAcademicAgeAtRetraction_CI_95lower            -0.980
# DiffAcademicAgeAtRetraction_CI_95upper             0.830

# %%
pd.DataFrame(lst_dicts_a3[1])
# Out:
#                                                   Misconduct  Plagiarism  \
# DiffMAGCumPapersAtRetraction_retracted_mean           25.670       19.56
# DiffMAGCumPapersAtRetraction_retracted_median          9.710        9.50
# DiffMAGCumPapersAtRetraction_retracted_std            88.150       51.93
# DiffMAGCumPapersAtRetraction_nonretracted_mean        28.540       23.22
# DiffMAGCumPapersAtRetraction_nonretracted_median      16.620       14.28
# DiffMAGCumPapersAtRetraction_nonretracted_std         85.200       49.82
# DiffMAGCumPapersAtRetraction_delta_mean               -2.870       -3.65
# DiffMAGCumPapersAtRetraction_pval_welch                0.711        0.40
# DiffMAGCumPapersAtRetraction_CI_95lower              -17.830      -12.45
# DiffMAGCumPapersAtRetraction_CI_95upper               12.090        5.14
#
#                                                   Mistake
# DiffMAGCumPapersAtRetraction_retracted_mean        19.390
# DiffMAGCumPapersAtRetraction_retracted_median      13.970
# DiffMAGCumPapersAtRetraction_retracted_std         57.560
# DiffMAGCumPapersAtRetraction_nonretracted_mean     27.510
# DiffMAGCumPapersAtRetraction_nonretracted_median   15.310
# DiffMAGCumPapersAtRetraction_nonretracted_std      63.780
# DiffMAGCumPapersAtRetraction_delta_mean            -8.120
# DiffMAGCumPapersAtRetraction_pval_welch             0.085
# DiffMAGCumPapersAtRetraction_CI_95lower           -16.830
# DiffMAGCumPapersAtRetraction_CI_95upper             0.580

# %%
pd.DataFrame(lst_dicts_a3[2])
# Out:
#                                                     Misconduct  Plagiarism  \
# DiffMAGCumCitationsAtRetraction_retracted_mean         251.030     158.230
# DiffMAGCumCitationsAtRetraction_retracted_median        32.500       3.000
# DiffMAGCumCitationsAtRetraction_retracted_std         1552.030    1283.600
# DiffMAGCumCitationsAtRetraction_nonretracted_mean      549.730     168.860
# DiffMAGCumCitationsAtRetraction_nonretracted_me...     117.370      27.700
# DiffMAGCumCitationsAtRetraction_nonretracted_std      1992.590    1039.260
# DiffMAGCumCitationsAtRetraction_delta_mean            -298.700     -10.630
# DiffMAGCumCitationsAtRetraction_pval_welch               0.062       0.915
# DiffMAGCumCitationsAtRetraction_CI_95lower            -609.160    -212.130
# DiffMAGCumCitationsAtRetraction_CI_95upper              11.760     190.870
#
#                                                      Mistake
# DiffMAGCumCitationsAtRetraction_retracted_mean       184.520
# DiffMAGCumCitationsAtRetraction_retracted_median      56.130
# DiffMAGCumCitationsAtRetraction_retracted_std       1796.200
# DiffMAGCumCitationsAtRetraction_nonretracted_mean    481.550
# DiffMAGCumCitationsAtRetraction_nonretracted_me...   117.890
# DiffMAGCumCitationsAtRetraction_nonretracted_std    2164.780
# DiffMAGCumCitationsAtRetraction_delta_mean          -297.030
# DiffMAGCumCitationsAtRetraction_pval_welch             0.055
# DiffMAGCumCitationsAtRetraction_CI_95lower          -609.020
# DiffMAGCumCitationsAtRetraction_CI_95upper            14.960

# %%
pd.DataFrame(lst_dicts_a3[3])
# Out:
#                                                     Misconduct  Plagiarism  \
# DiffMAGCumCollaboratorsAtRetraction_retracted_mean       30.72       29.74
# DiffMAGCumCollaboratorsAtRetraction_retracted_m...       14.72        8.94
# DiffMAGCumCollaboratorsAtRetraction_retracted_std       195.62      139.08
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...       38.10       40.96
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...       35.29       27.00
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...      416.61      118.81
# DiffMAGCumCollaboratorsAtRetraction_delta_mean           -7.38      -11.22
# DiffMAGCumCollaboratorsAtRetraction_pval_welch            0.80        0.31
# DiffMAGCumCollaboratorsAtRetraction_CI_95lower          -65.53      -33.62
# DiffMAGCumCollaboratorsAtRetraction_CI_95upper           50.77       11.19
#
#                                                     Mistake
# DiffMAGCumCollaboratorsAtRetraction_retracted_mean   41.910
# DiffMAGCumCollaboratorsAtRetraction_retracted_m...   16.800
# DiffMAGCumCollaboratorsAtRetraction_retracted_std   217.600
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...   44.750
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...   23.530
# DiffMAGCumCollaboratorsAtRetraction_nonretracte...  155.450
# DiffMAGCumCollaboratorsAtRetraction_delta_mean       -2.830
# DiffMAGCumCollaboratorsAtRetraction_pval_welch        0.847
# DiffMAGCumCollaboratorsAtRetraction_CI_95lower      -30.900
# DiffMAGCumCollaboratorsAtRetraction_CI_95upper       25.230

# %%
def create_latex_for_filling(dicto, col):
    
    def create_string(metric):
        string = ""
        if metric == 'pval_welch':
            string = "& " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Misconduct').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Plagiarism').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                " & " + \
                str(dicto.get('Mistake').get(col+"_"+metric)) + \
                "\\\ \n"
        else:
            string = "& " + \
                    str(dicto.get('Misconduct').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Misconduct').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Plagiarism').get(col+"_nonretracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_retracted_"+metric)) + \
                    " & " + \
                    str(dicto.get('Mistake').get(col+"_nonretracted_"+metric)) + \
                    "\\\ \n"
        
        
        
        return string
    
    print(create_string("mean"))
    print(create_string("median"))
    print(create_string("std"))
    print(create_string("pval_welch"))
    

for i in range(len(lst_dicts_a3)):
    dicto = lst_dicts_a3[i]
    col = exp_fields[i]
    print(col)
    create_latex_for_filling(dicto, col)
# Out:
# DiffAcademicAgeAtRetraction
# & 1.71 & 2.05 & 1.9 & 2.86 & 2.27 & 2.35\\
#
# & 0.92 & 1.51 & 1.0 & 1.88 & 1.71 & 2.24\\
#
# & 6.52 & 6.24 & 5.67 & 6.99 & 6.73 & 6.4\\
#
# & 0.553 & 0.553 & 0.08 & 0.08 & 0.883 & 0.883\\
#
# DiffMAGCumPapersAtRetraction
# & 25.67 & 28.54 & 19.56 & 23.22 & 19.39 & 27.51\\
#
# & 9.71 & 16.62 & 9.5 & 14.28 & 13.97 & 15.31\\
#
# & 88.15 & 85.2 & 51.93 & 49.82 & 57.56 & 63.78\\
#
# & 0.711 & 0.711 & 0.4 & 0.4 & 0.085 & 0.085\\
#
# DiffMAGCumCitationsAtRetraction
# & 251.03 & 549.73 & 158.23 & 168.86 & 184.52 & 481.55\\
#
# & 32.5 & 117.37 & 3.0 & 27.7 & 56.13 & 117.89\\
#
# & 1552.03 & 1992.59 & 1283.6 & 1039.26 & 1796.2 & 2164.78\\
#
# & 0.062 & 0.062 & 0.915 & 0.915 & 0.055 & 0.055\\
#
# DiffMAGCumCollaboratorsAtRetraction
# & 30.72 & 38.1 & 29.74 & 40.96 & 41.91 & 44.75\\
#
# & 14.72 & 35.29 & 8.94 & 27.0 & 16.8 & 23.53\\
#
# & 195.62 & 416.61 & 139.08 & 118.81 & 217.6 & 155.45\\
#
# & 0.8 & 0.8 & 0.31 & 0.31 & 0.847 & 0.847\\

# %% [markdown]
# # Processing dictionaries for plots

# %%
expfield_categories = ['Academic Age','Number of Papers',
                       'Number of Citations', 'Number of Collaborators']

master_dict = {}

master_dict['Retention'] = {}

for i in range(len(expfield_categories)):
    master_dict['Retention'][expfield_categories[i]] = lst_dicts_retention[i]

master_dict['Gain'] = {}

for i in range(len(expfield_categories)):
    master_dict['Gain'][expfield_categories[i]] = lst_dicts_gain[i]
    
master_dict['DiD'] = {}

for i in range(len(expfield_categories)):
    master_dict['DiD'][expfield_categories[i]] = lst_dicts_a3[i]

# %%
master_dict.keys()
# Out:
# dict_keys(['Retention', 'Gain', 'DiD'])

# %%
master_dict
# Out:
# {'Retention': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 13.56,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 13.65,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.43,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 14.78,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.42,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 6.41,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.23,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.046,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.31,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.15},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.71,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 12.14,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.03,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.24,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.1,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.11,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -2.54,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.0,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.62,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -1.45},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 15.07,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 15.29,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.55,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.71,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 15.0,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 6.69,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.64,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.207,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.49,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.21}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 73.6,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 56.59,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 100.32,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 81.77,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 60.94,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 104.12,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -8.16,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.367,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -25.7,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 9.37},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 61.95,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 44.25,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 64.51,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 69.02,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 57.84,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 53.99,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -7.07,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.156,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -16.5,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 2.35},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 75.33,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 61.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 64.38,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 80.69,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 61.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 71.0,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -5.36,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.302,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -14.74,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 4.03}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1480.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 818.35,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1962.39,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1790.19,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 902.49,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2870.8,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -310.14,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.154,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -701.97,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 81.68},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 981.9,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 409.83,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2121.71,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1045.83,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 577.98,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1318.45,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -63.93,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.665,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -337.87,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 210.01},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1778.22,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 1087.6,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2193.66,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1824.58,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 977.36,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2794.45,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -46.35,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.81,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -394.47,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 301.76}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 181.99,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 131.15,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 219.75,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 218.3,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 147.75,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 393.01,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -36.31,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.198,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -92.33,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 19.71},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 153.51,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 84.01,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 186.01,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 161.11,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 109.83,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 179.8,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -7.6,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.62,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -33.9,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 18.71},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 207.92,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 133.06,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 279.89,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 197.27,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 125.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 221.37,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 10.66,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.581,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -24.96,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 46.28}}},
#  'Gain': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 7.98,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 7.55,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.07,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 8.1,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.92,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.48,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.12,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.792,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.0,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.76},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 6.68,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 6.33,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.83,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.74,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.56,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.75,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.06,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.008,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.78,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.34},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.61,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 8.61,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.83,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 8.14,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.84,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.53,
#     'CollabAcademicAgeAtCollaboration_delta_mean': 0.47,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.172,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -0.14,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.09}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 45.01,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 28.36,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 62.33,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 34.42,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 31.27,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 25.45,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 10.59,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.012,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': 2.33,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 18.85},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 32.43,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 22.32,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 34.17,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 33.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 28.24,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 30.07,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -1.46,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.584,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -6.31,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 3.39},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 41.39,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 34.3,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 42.97,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 37.49,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 26.77,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 39.04,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 3.9,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.198,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -1.86,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 9.65}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1105.93,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 501.37,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1928.01,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 702.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 473.39,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 856.96,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 403.58,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.002,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': 160.25,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 646.9},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 603.46,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 271.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1149.47,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 625.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 299.33,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 937.57,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -21.9,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.801,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -182.45,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 138.66},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1075.94,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 624.41,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1575.77,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 946.34,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 429.64,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1554.61,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 129.6,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.262,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -94.11,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 353.31}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 156.42,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 79.56,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 319.8,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 110.78,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 73.73,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 132.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 45.63,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.034,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': 3.21,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 88.06},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 103.74,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 50.84,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 149.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 102.41,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 58.68,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 147.47,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 1.33,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.914,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -20.02,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 22.67},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 206.15,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 88.21,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 1031.16,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 123.36,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 70.96,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 169.27,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 82.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.129,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -24.66,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 190.24}}},
#  'DiD': {'Academic Age': {'Misconduct': {'DiffAcademicAgeAtRetraction_retracted_mean': 1.71,
#     'DiffAcademicAgeAtRetraction_retracted_median': 0.92,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.52,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.05,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.51,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.24,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.34,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.553,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -1.36,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.68},
#    'Plagiarism': {'DiffAcademicAgeAtRetraction_retracted_mean': 1.9,
#     'DiffAcademicAgeAtRetraction_retracted_median': 1.0,
#     'DiffAcademicAgeAtRetraction_retracted_std': 5.67,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.86,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.88,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.99,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.95,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.08,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -1.98,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.07},
#    'Mistake': {'DiffAcademicAgeAtRetraction_retracted_mean': 2.27,
#     'DiffAcademicAgeAtRetraction_retracted_median': 1.71,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.73,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.35,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 2.24,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.4,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.08,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.883,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -0.98,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.83}},
#   'Number of Papers': {'Misconduct': {'DiffMAGCumPapersAtRetraction_retracted_mean': 25.67,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.71,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 88.15,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 28.54,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 16.62,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 85.2,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -2.87,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.711,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -17.83,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.09},
#    'Plagiarism': {'DiffMAGCumPapersAtRetraction_retracted_mean': 19.56,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.5,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 51.93,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 23.22,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 14.28,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 49.82,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -3.65,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.4,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -12.45,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 5.14},
#    'Mistake': {'DiffMAGCumPapersAtRetraction_retracted_mean': 19.39,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 13.97,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 57.56,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 27.51,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 15.31,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 63.78,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -8.12,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.085,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -16.83,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 0.58}},
#   'Number of Citations': {'Misconduct': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 251.03,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 32.5,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1552.03,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 549.73,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 117.37,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1992.59,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -298.7,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.062,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -609.16,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 11.76},
#    'Plagiarism': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 158.23,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 3.0,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1283.6,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 168.86,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 27.7,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1039.26,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -10.63,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.915,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -212.13,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 190.87},
#    'Mistake': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 184.52,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 56.13,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1796.2,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 481.55,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 117.89,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 2164.78,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -297.03,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.055,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -609.02,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 14.96}},
#   'Number of Collaborators': {'Misconduct': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 30.72,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 14.72,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 195.62,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 38.1,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 35.29,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 416.61,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -7.38,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.8,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -65.53,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 50.77},
#    'Plagiarism': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 29.74,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 8.94,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 139.08,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 40.96,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 27.0,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 118.81,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -11.22,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.31,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -33.62,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 11.19},
#    'Mistake': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 41.91,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 16.8,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 217.6,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 44.75,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 23.53,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 155.45,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -2.83,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.847,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -30.9,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 25.23}}}}

# %%
def save_dict(dicto, fname):
    import pickle 

    with open(fname, 'wb') as f:
        pickle.dump(dicto, f)
        
def read_dict(fname):
    import pickle
    
    with open(fname, 'rb') as f:
        loaded_dict = pickle.load(f)
        return loaded_dict

# %%
save_dict(master_dict, "collaborator_chars_byReason.pkl")

# %%
master_dict
# Out:
# {'Retention': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 13.56,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 13.65,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.43,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 14.78,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.42,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 6.41,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.23,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.046,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -2.31,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.15},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 12.71,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 12.14,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 7.03,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.24,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 14.1,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 7.11,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -2.54,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.0,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -3.62,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -1.45},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 15.07,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 15.29,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.55,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 15.71,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 15.0,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 6.69,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.64,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.207,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.49,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.21}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 73.6,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 56.59,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 100.32,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 81.77,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 60.94,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 104.12,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -8.16,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.367,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -25.7,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 9.37},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 61.95,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 44.25,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 64.51,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 69.02,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 57.84,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 53.99,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -7.07,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.156,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -16.5,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 2.35},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 75.33,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 61.0,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 64.38,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 80.69,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 61.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 71.0,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -5.36,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.302,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -14.74,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 4.03}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1480.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 818.35,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1962.39,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1790.19,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 902.49,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2870.8,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -310.14,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.154,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -701.97,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 81.68},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 981.9,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 409.83,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2121.71,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1045.83,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 577.98,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1318.45,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -63.93,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.665,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -337.87,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 210.01},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1778.22,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 1087.6,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 2193.66,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 1824.58,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 977.36,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 2794.45,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -46.35,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.81,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -394.47,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 301.76}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 181.99,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 131.15,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 219.75,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 218.3,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 147.75,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 393.01,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -36.31,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.198,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -92.33,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 19.71},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 153.51,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 84.01,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 186.01,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 161.11,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 109.83,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 179.8,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': -7.6,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.62,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -33.9,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 18.71},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 207.92,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 133.06,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 279.89,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 197.27,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 125.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 221.37,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 10.66,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.581,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -24.96,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 46.28}}},
#  'Gain': {'Academic Age': {'Misconduct': {'CollabAcademicAgeAtCollaboration_retracted_mean': 7.98,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 7.55,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 6.07,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 8.1,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.92,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.48,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -0.12,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.792,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.0,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 0.76},
#    'Plagiarism': {'CollabAcademicAgeAtCollaboration_retracted_mean': 6.68,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 6.33,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.83,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 7.74,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.56,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.75,
#     'CollabAcademicAgeAtCollaboration_delta_mean': -1.06,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.008,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -1.78,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': -0.34},
#    'Mistake': {'CollabAcademicAgeAtCollaboration_retracted_mean': 8.61,
#     'CollabAcademicAgeAtCollaboration_retracted_median': 8.61,
#     'CollabAcademicAgeAtCollaboration_retracted_std': 4.83,
#     'CollabAcademicAgeAtCollaboration_nonretracted_mean': 8.14,
#     'CollabAcademicAgeAtCollaboration_nonretracted_median': 7.84,
#     'CollabAcademicAgeAtCollaboration_nonretracted_std': 4.53,
#     'CollabAcademicAgeAtCollaboration_delta_mean': 0.47,
#     'CollabAcademicAgeAtCollaboration_pval_welch': 0.172,
#     'CollabAcademicAgeAtCollaboration_CI_95lower': -0.14,
#     'CollabAcademicAgeAtCollaboration_CI_95upper': 1.09}},
#   'Number of Papers': {'Misconduct': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 45.01,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 28.36,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 62.33,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 34.42,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 31.27,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 25.45,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 10.59,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.012,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': 2.33,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 18.85},
#    'Plagiarism': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 32.43,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 22.32,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 34.17,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 33.89,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 28.24,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 30.07,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': -1.46,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.584,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -6.31,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 3.39},
#    'Mistake': {'CollabMAGCumPapersAtCollaboration_retracted_mean': 41.39,
#     'CollabMAGCumPapersAtCollaboration_retracted_median': 34.3,
#     'CollabMAGCumPapersAtCollaboration_retracted_std': 42.97,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_mean': 37.49,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_median': 26.77,
#     'CollabMAGCumPapersAtCollaboration_nonretracted_std': 39.04,
#     'CollabMAGCumPapersAtCollaboration_delta_mean': 3.9,
#     'CollabMAGCumPapersAtCollaboration_pval_welch': 0.198,
#     'CollabMAGCumPapersAtCollaboration_CI_95lower': -1.86,
#     'CollabMAGCumPapersAtCollaboration_CI_95upper': 9.65}},
#   'Number of Citations': {'Misconduct': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1105.93,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 501.37,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1928.01,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 702.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 473.39,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 856.96,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 403.58,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.002,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': 160.25,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 646.9},
#    'Plagiarism': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 603.46,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 271.05,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1149.47,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 625.35,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 299.33,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 937.57,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': -21.9,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.801,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -182.45,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 138.66},
#    'Mistake': {'CollabMAGCumCitationsAtCollaboration_retracted_mean': 1075.94,
#     'CollabMAGCumCitationsAtCollaboration_retracted_median': 624.41,
#     'CollabMAGCumCitationsAtCollaboration_retracted_std': 1575.77,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_mean': 946.34,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_median': 429.64,
#     'CollabMAGCumCitationsAtCollaboration_nonretracted_std': 1554.61,
#     'CollabMAGCumCitationsAtCollaboration_delta_mean': 129.6,
#     'CollabMAGCumCitationsAtCollaboration_pval_welch': 0.262,
#     'CollabMAGCumCitationsAtCollaboration_CI_95lower': -94.11,
#     'CollabMAGCumCitationsAtCollaboration_CI_95upper': 353.31}},
#   'Number of Collaborators': {'Misconduct': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 156.42,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 79.56,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 319.8,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 110.78,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 73.73,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 132.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 45.63,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.034,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': 3.21,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 88.06},
#    'Plagiarism': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 103.74,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 50.84,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 149.55,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 102.41,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 58.68,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 147.47,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 1.33,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.914,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -20.02,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 22.67},
#    'Mistake': {'CollabMAGCumCollaboratorsAtCollaboration_retracted_mean': 206.15,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_median': 88.21,
#     'CollabMAGCumCollaboratorsAtCollaboration_retracted_std': 1031.16,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_mean': 123.36,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_median': 70.96,
#     'CollabMAGCumCollaboratorsAtCollaboration_nonretracted_std': 169.27,
#     'CollabMAGCumCollaboratorsAtCollaboration_delta_mean': 82.79,
#     'CollabMAGCumCollaboratorsAtCollaboration_pval_welch': 0.129,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95lower': -24.66,
#     'CollabMAGCumCollaboratorsAtCollaboration_CI_95upper': 190.24}}},
#  'DiD': {'Academic Age': {'Misconduct': {'DiffAcademicAgeAtRetraction_retracted_mean': 1.71,
#     'DiffAcademicAgeAtRetraction_retracted_median': 0.92,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.52,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.05,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.51,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.24,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.34,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.553,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -1.36,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.68},
#    'Plagiarism': {'DiffAcademicAgeAtRetraction_retracted_mean': 1.9,
#     'DiffAcademicAgeAtRetraction_retracted_median': 1.0,
#     'DiffAcademicAgeAtRetraction_retracted_std': 5.67,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.86,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 1.88,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.99,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.95,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.08,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -1.98,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.07},
#    'Mistake': {'DiffAcademicAgeAtRetraction_retracted_mean': 2.27,
#     'DiffAcademicAgeAtRetraction_retracted_median': 1.71,
#     'DiffAcademicAgeAtRetraction_retracted_std': 6.73,
#     'DiffAcademicAgeAtRetraction_nonretracted_mean': 2.35,
#     'DiffAcademicAgeAtRetraction_nonretracted_median': 2.24,
#     'DiffAcademicAgeAtRetraction_nonretracted_std': 6.4,
#     'DiffAcademicAgeAtRetraction_delta_mean': -0.08,
#     'DiffAcademicAgeAtRetraction_pval_welch': 0.883,
#     'DiffAcademicAgeAtRetraction_CI_95lower': -0.98,
#     'DiffAcademicAgeAtRetraction_CI_95upper': 0.83}},
#   'Number of Papers': {'Misconduct': {'DiffMAGCumPapersAtRetraction_retracted_mean': 25.67,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.71,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 88.15,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 28.54,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 16.62,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 85.2,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -2.87,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.711,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -17.83,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 12.09},
#    'Plagiarism': {'DiffMAGCumPapersAtRetraction_retracted_mean': 19.56,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 9.5,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 51.93,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 23.22,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 14.28,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 49.82,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -3.65,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.4,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -12.45,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 5.14},
#    'Mistake': {'DiffMAGCumPapersAtRetraction_retracted_mean': 19.39,
#     'DiffMAGCumPapersAtRetraction_retracted_median': 13.97,
#     'DiffMAGCumPapersAtRetraction_retracted_std': 57.56,
#     'DiffMAGCumPapersAtRetraction_nonretracted_mean': 27.51,
#     'DiffMAGCumPapersAtRetraction_nonretracted_median': 15.31,
#     'DiffMAGCumPapersAtRetraction_nonretracted_std': 63.78,
#     'DiffMAGCumPapersAtRetraction_delta_mean': -8.12,
#     'DiffMAGCumPapersAtRetraction_pval_welch': 0.085,
#     'DiffMAGCumPapersAtRetraction_CI_95lower': -16.83,
#     'DiffMAGCumPapersAtRetraction_CI_95upper': 0.58}},
#   'Number of Citations': {'Misconduct': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 251.03,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 32.5,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1552.03,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 549.73,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 117.37,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1992.59,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -298.7,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.062,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -609.16,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 11.76},
#    'Plagiarism': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 158.23,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 3.0,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1283.6,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 168.86,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 27.7,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 1039.26,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -10.63,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.915,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -212.13,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 190.87},
#    'Mistake': {'DiffMAGCumCitationsAtRetraction_retracted_mean': 184.52,
#     'DiffMAGCumCitationsAtRetraction_retracted_median': 56.13,
#     'DiffMAGCumCitationsAtRetraction_retracted_std': 1796.2,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_mean': 481.55,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_median': 117.89,
#     'DiffMAGCumCitationsAtRetraction_nonretracted_std': 2164.78,
#     'DiffMAGCumCitationsAtRetraction_delta_mean': -297.03,
#     'DiffMAGCumCitationsAtRetraction_pval_welch': 0.055,
#     'DiffMAGCumCitationsAtRetraction_CI_95lower': -609.02,
#     'DiffMAGCumCitationsAtRetraction_CI_95upper': 14.96}},
#   'Number of Collaborators': {'Misconduct': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 30.72,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 14.72,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 195.62,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 38.1,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 35.29,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 416.61,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -7.38,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.8,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -65.53,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 50.77},
#    'Plagiarism': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 29.74,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 8.94,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 139.08,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 40.96,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 27.0,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 118.81,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -11.22,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.31,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -33.62,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 11.19},
#    'Mistake': {'DiffMAGCumCollaboratorsAtRetraction_retracted_mean': 41.91,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_median': 16.8,
#     'DiffMAGCumCollaboratorsAtRetraction_retracted_std': 217.6,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_mean': 44.75,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_median': 23.53,
#     'DiffMAGCumCollaboratorsAtRetraction_nonretracted_std': 155.45,
#     'DiffMAGCumCollaboratorsAtRetraction_delta_mean': -2.83,
#     'DiffMAGCumCollaboratorsAtRetraction_pval_welch': 0.847,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95lower': -30.9,
#     'DiffMAGCumCollaboratorsAtRetraction_CI_95upper': 25.23}}}}
