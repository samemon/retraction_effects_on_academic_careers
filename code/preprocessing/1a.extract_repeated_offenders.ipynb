# %% [markdown]
# # Extracting repeated offenders
#
# In this notebook, we shall flag authors that have been retracted multiple times. More concretely,
#
# 1) We will first identify all bulk retractions in RW, and flag them.
#
# 2) We will then extract all the author names from RW along with Record ID, RetractionDate, RetractionYear
#
# 3) We will then split the author names such that we have Author first name, last name, Record ID as separate columns
#
# 4) We will then identify authors that were
#
#     a) Retracted just once
#
#     b) Retracted multiple times if bulk retractions not included
#
#     c) Retracted mmultiple times if bulk retractions included
#
# 5) For each author retracted multiple times, we will identify the difference in years between their first and second retraction. We will identify difference in years by (i) exact date, and (ii) by year, to allow for different levels of precision.

# %%
# Importing relevant packages

import pandas as pd
import os
from config_reader import read_config
from rapidfuzz import process, fuzz

# %%
# Reading paths
paths = read_config()
RW_ORIGINAL_W_YEAR_LOCAL_PATH = paths['RW_ORIGINAL_W_YEAR_LOCAL_PATH']
OUTDIR = paths['PROCESSED_FOLDER_LOCAL']

# %%
# Reading retraction watch
df_rw = pd.read_csv(RW_ORIGINAL_W_YEAR_LOCAL_PATH,
                   usecols=['Record ID', 'Author', 'RetractionDate', 'RetractionYear', 'Title',
                           'Journal'])
df_rw.head(1)
# Out:
#    Record ID                                              Title  \
# 0      28599  TWEAK-Fn14 Influences Neurogenesis Status via ...
#
#                   Journal                                        Author  \
# 0  Molecular Neurobiology  Jing Xu;Jian He;Huang He;Renjun Peng;Jian Xi
#
#   RetractionDate  RetractionYear
# 0     2021-05-15          2021.0

# %% [markdown]
# ## 1. Identifying bulk retractions

# %%
# Identify bulk retreactions
df_rw_bulkCounts = df_rw.groupby(['Journal','RetractionDate'])['Record ID'].nunique().reset_index()\
                            .rename(columns={'Record ID':'bulkCounts'})

# merging with actual RW 
df_rw2 = df_rw.merge(df_rw_bulkCounts, on=['Journal','RetractionDate'], how='left')

# Flagging Records to be removed due to bulk retractions
df_rw2['RetractedInBulk'] = df_rw2['bulkCounts'].apply(lambda c: c >= 5)

# Removing records from 2021
df_rw2 = df_rw2[df_rw2['RetractionYear'].le(2020)]

# Removing bulk retractions
df_rw2 = df_rw2[~df_rw2['RetractedInBulk']]

df_rw2.head(1)
# Out:
#     Record ID                                              Title  \
# 63      27832  Enantioselective Organocatalytic Hantzsch Synt...
#
#             Journal                                 Author RetractionDate  \
# 63  Organic Letters  Christopher G Evans;Jason E Gestwicki     2014-10-02
#
#     RetractionYear  bulkCounts  RetractedInBulk
# 63          2014.0         1.0            False

# %%
df_rw2['Record ID'].nunique()
# Out:
# 14480

# %% [markdown]
# ## 2. Extracting author names

# %%
pd.set_option('display.max_colwidth', None)

# Split the "Author" column by ";" and then explode it to separate rows
df_rw2['AuthorName'] = df_rw2['Author'].str.split(';')
df_exploded = df_rw2.explode('AuthorName')

# Removing empty authors
df_exploded['AuthorName'] = df_exploded['AuthorName'].str.strip().str.lower()
df_exploded = df_exploded[df_exploded['AuthorName'].ne('') & 
                         ~df_exploded['AuthorName'].isna()]

# sorting
df_exploded.sort_values(by='AuthorName').reset_index().head(1)
# Out:
#    index  Record ID  \
# 0   3091      22375
#
#                                                                                        Title  \
# 0  Targeted Protein Internalization and Degradation by ENDosome TArgeting Chimeras (ENDTACs)
#
#                Journal  \
# 0  ACS Central Science
#
#                                                                                                   Author  \
# 0  Dhanusha A Nalawansha;Stacey-Lynn Paiva;/duane N Rafizadeh;Mariell Pettersson;Liena Qin;Craig M Crews
#
#   RetractionDate  RetractionYear  bulkCounts  RetractedInBulk  \
# 0     2020-01-23          2020.0         1.0            False
#
#            AuthorName
# 0  /duane n rafizadeh

# %%
# Before we move, we will change some names 
# These names were matched in MAG, but there is a weird problem
"""
The problem is when identifying repeated offenders, 
we are doing author disambiguation in RW, and we put the 
fuzzy matching score to be 96 or above as criteria, 
but there are names that do not fit this criteria but are still the same authors. 
So these authors remain disambiguated in RW. 
What happens then is that when I do fuzzy matching of names in MAG to match RW authors to MAG authors, 
two authors who have not been disambiguated get matched to the same 
MAG author. In other words, both names in RW are in close match with 
the MAG author name, but not with each other. 
So we will just change these names here for simplicity
"""


rw_to_mag_authorname = {"angela d'angelo": 'angela dangelo',
 'angela dâ€™angelo': 'angela dangelo',
 'li bin': 'bin li',
 'bin li': 'bin li',
 'chenhui qiao': 'chenhui qiao',
 'qiao chenhui': 'chenhui qiao',
 'clement asiedu': 'clement asiedu',
 'clement k asiedu': 'clement asiedu',
 'dong hee shin': 'donghee shin',
 'dong-hee shin': 'donghee shin',
 'eric poehlman': 'eric t poehlman',
 'eric t poehlman': 'eric t poehlman',
 'hyung in moon': 'hyungin moon',
 'hyung-in moon': 'hyungin moon',
 'jiahong xia': 'jiahong xia',
 'xia jiahong': 'jiahong xia',
 'jing chen': 'jing chen',
 'chen jing': 'jing chen',
 'jose a martinez': 'jose a martinez',
 'jose martinez': 'jose a martinez',
 'zhang kailun': 'kailun zhang',
 'kailun zhang': 'kailun zhang',
 'kyung-hee paek': 'kyung hee paek',
 'kyung hee paek': 'kyung hee paek',
 'lian-da li': 'lianda li',
 'lianda li': 'lianda li',
 'limao wu': 'limao wu',
 'li-mao wu': 'limao wu',
 'lu zhang': 'lu zhang',
 'l zhang': 'lu zhang',
 'mi sun kim': 'misun kim',
 'mi-sun kim': 'misun kim',
 'ning li': 'ning li',
 'li ning': 'ning li',
 'roland h mertelsmann': 'roland mertelsmann',
 'roland mertelsmann': 'roland mertelsmann',
 'yu liu': 'yu liu',
 'y liu': 'yu liu'}


df_exploded['AuthorName']=df_exploded['AuthorName'].replace(rw_to_mag_authorname)
df_exploded.head()
# Out:
#      Record ID  \
# 63       27832
# 63       27832
# 581      25550
# 581      25550
# 581      25550
#
#                                                                                                                                                Title  \
# 63                                                                        Enantioselective Organocatalytic Hantzsch Synthesis of Polyhydroquinolines
# 63                                                                        Enantioselective Organocatalytic Hantzsch Synthesis of Polyhydroquinolines
# 581  Mechanistic attributes of S100A7 (psoriasin) in resistance of anoikis resulting tumor progression in squamous cell carcinoma of the oral cavity
# 581  Mechanistic attributes of S100A7 (psoriasin) in resistance of anoikis resulting tumor progression in squamous cell carcinoma of the oral cavity
# 581  Mechanistic attributes of S100A7 (psoriasin) in resistance of anoikis resulting tumor progression in squamous cell carcinoma of the oral cavity
#
#                        Journal  \
# 63             Organic Letters
# 63             Organic Letters
# 581  Cancer Cell International
# 581  Cancer Cell International
# 581  Cancer Cell International
#
#                                                                                                                                                        Author  \
# 63                                                                                                                      Christopher G Evans;Jason E Gestwicki
# 63                                                                                                                      Christopher G Evans;Jason E Gestwicki
# 581  Kaushik Kumar Dey;Siddik Sarkar;Ipsita Pal;Subhasis Das;Goutam Dey;Rashmi Bharti;Payel Banik;Jay Gopal Roy;Sukumar Maity;Indranil Kulavi;Mahitosh Mandal
# 581  Kaushik Kumar Dey;Siddik Sarkar;Ipsita Pal;Subhasis Das;Goutam Dey;Rashmi Bharti;Payel Banik;Jay Gopal Roy;Sukumar Maity;Indranil Kulavi;Mahitosh Mandal
# 581  Kaushik Kumar Dey;Siddik Sarkar;Ipsita Pal;Subhasis Das;Goutam Dey;Rashmi Bharti;Payel Banik;Jay Gopal Roy;Sukumar Maity;Indranil Kulavi;Mahitosh Mandal
#
#     RetractionDate  RetractionYear  bulkCounts  RetractedInBulk  \
# 63      2014-10-02          2014.0         1.0            False
# 63      2014-10-02          2014.0         1.0            False
# 581     2015-10-08          2015.0         1.0            False
# 581     2015-10-08          2015.0         1.0            False
# 581     2015-10-08          2015.0         1.0            False
#
#               AuthorName
# 63   christopher g evans
# 63     jason e gestwicki
# 581    kaushik kumar dey
# 581        siddik sarkar
# 581           ipsita pal

# %%
# Identifying authors that were retracted multiple times

df_numRetracted = df_exploded.groupby('AuthorName')['Record ID'].nunique().reset_index()\
                            .rename(columns={'Record ID':'nRetracted'})


df_numRetracted.head(1)
# Out:
#            AuthorName  nRetracted
# 0  /duane n rafizadeh           1

# %%
# Printing authors will multiple retractions
df_numRetracted[df_numRetracted['nRetracted'].gt(1)]
# Out:
#                    AuthorName  nRetracted
# 29             a a nesterenko           3
# 37                  a a zafar           2
# 38            a abdel motelib           2
# 39              a abdul ajees           2
# 42               a abou-elela           2
# ...                       ...         ...
# 51247              zongxi han           2
# 51275              zu-hua gao           2
# 51288  zulkanain abdul rahman           2
# 51303             zuoren wang           2
# 51317        zuzana kubinkova           2
#
# [6425 rows x 2 columns]

# %% [markdown]
# # Cleaning author names

# %%
# The problem now is that there are some authors that may have same name but not exactly same. 
# For example the author angela d'angelo and angela dangelo are both same except they occur 
# with different spellings in RW. So we need to merge these entries.
# We will do so by using fuzzy matching within RW author names
# Then we will normalize the name to a single entry, and then redo the above code 
# Think of this like normalizing the name (except also disambiguating)
# The example below shows that fuzzy matching could work well.

fuzz.ratio("angela d'angelo", "angela dâ€™angelo")
# Out:
# 87.5

# %%
authornames = list(df_exploded['AuthorName'].unique())

#authornames.remove('Christopher G Evans')

len(authornames)
# Out:
# 51329

# %%
# What we will do is create a dictionary i.e. for each author, we will run fuzzy match and extract top 3 variations
# We will limit the score to > 90 or > 95 -- after testing. 
# After testing -- it seems 96 works best as the threshold

authornames = list(df_exploded['AuthorName'].unique())

# For each authorname, we will identify their top matches with score > 96
name_to_correctName = {}

# We will do so until authornames are all gone through fuzzy matching
print(len(authornames))
while(len(authornames) > 0):
    
    current_author = authornames[0] # We fix 0 as we are removing authornames
    # Let us remove current author from authornames
    authornames.remove(current_author)
    # Let us find all the similar authornames
    choices = process.extract(current_author, authornames, score_cutoff=96)
    # Let us iterate through all the choices to get only names
    choices = [name for (name, score, freq) in choices]
    # Add to dictionary
    if len(choices) != 0:
        for choice in choices:
            name_to_correctName[choice] = current_author
        # Update authorname list
        authornames = [name for name in authornames if name not in choices]
        print(current_author, choices)
        print(f"Number of authors left: {len(authornames)}")
# Out:
# 51329
# yandong zhang ['yadong zhang']
# Number of authors left: 51263
# zhi ping zhang ['zhiping zhang']
# Number of authors left: 51216
# catriona mclean ['caitriona mclean']
# Number of authors left: 51168
# rafael arcesio delgado-ruiz ['rafael arcesio delgado ruiz']
# Number of authors left: 51048
# manuel fernandez dominguez ['manuel fernandez-dominguez']
# Number of authors left: 51046
# guanghui wei ['guang hui wei']
# Number of authors left: 50935
# g krishnamurthy naidu ['g krishna murthy naidu']
# Number of authors left: 50692
# andreas hinz ['andreas heinz']
# Number of authors left: 50570
# zhenlin zhang ['zhenling zhang']
# Number of authors left: 50530
# chaojun duan ['chao-jun duan']
# Number of authors left: 50528
# jianhua zang ['jianhua zhang']
# Number of authors left: 50490
# guoping jiang ['guoping jian']
# Number of authors left: 50481
# xiaoping zhu ['xiaoping zhou']
# Number of authors left: 50330
# chengyong qin ['cheng-yong qin']
# Number of authors left: 50201
# sagartirtha sarkar ['sagatirtha sarkar']
# Number of authors left: 50184
# xiuying chen ['xiuying cheng']
# Number of authors left: 49989
# xiaodong zhang ['xiao-dong zhang']
# Number of authors left: 49976
# xiufeng zhang ['xufeng zhang']
# Number of authors left: 49969
# dong hyun kim ['dong hun kim']
# Number of authors left: 49935
# jin ming zhang ['jinming zhang']
# Number of authors left: 49915
# chengyong wang ['cheng-yong wang']
# Number of authors left: 49879
# shinichi harad ['shinichi harada']
# Number of authors left: 49818
# zhigang yang ['zhi gang yang']
# Number of authors left: 49695
# jingzhe zhang ['jingze zhang']
# Number of authors left: 49668
# yanfeng wang ['yan feng wang']
# Number of authors left: 49605
# tingting zhao ['ting ting zhao']
# Number of authors left: 49583
# weidong zhang ['weidong zang']
# Number of authors left: 49580
# dong lin zhang ['dong li zhang']
# Number of authors left: 49527
# pablo velasquez ['pablo velaquez']
# Number of authors left: 49487
# jing lin wang ['jinglin wang', 'jin lin wang']
# Number of authors left: 49456
# shoichi ichimura ['shouichi ichimura']
# Number of authors left: 49420
# sung won kim ['sung woon kim']
# Number of authors left: 49288
# jianwei wang ['jian-wei wang']
# Number of authors left: 49072
# hongjian zheng ['hongjin zheng']
# Number of authors left: 49000
# yanling zhang ['anling zhang']
# Number of authors left: 48980
# chenliang hu ['chenliang huo']
# Number of authors left: 48959
# haruhiko sugimura ['haruhiko sugiura']
# Number of authors left: 48922
# xiaoqing zheng ['xiaoqing zeng']
# Number of authors left: 48843
# junling wang ['junliang wang']
# Number of authors left: 48592
# wenhao zhang ['wenchao zhang']
# Number of authors left: 48501
# jianmei wang ['jian-mei wang']
# Number of authors left: 48494
# chaowei lian ['chaowei liang']
# Number of authors left: 48347
# bing rong zhou ['bingrong zhou']
# Number of authors left: 48341
# mingquan gao ['ming quan gao']
# Number of authors left: 48077
# wenyuan ding ['wen-yuan ding']
# Number of authors left: 48039
# chunxiao liu ['chun-xiao liu']
# Number of authors left: 48016
# christian perrone ['christian perronne']
# Number of authors left: 47980
# paul lalukala ['paula lalukala']
# Number of authors left: 47975
# sai murali krishna pulukur ['sai murali krishna pulukuri', 'sai muralikrishna pulukuri']
# Number of authors left: 47868
# zhenling liu ['zhengling liu']
# Number of authors left: 47676
# xiaohong wang ['xiao-hong wang']
# Number of authors left: 47603
# anna kosieradzka ['anna kosieradzaka']
# Number of authors left: 47590
# yuanyuan zheng ['yuanyuan zeng']
# Number of authors left: 47506
# xiaoyi zhang ['xiaoyin zhang']
# Number of authors left: 47184
# jianjun peng ['jian jun peng']
# Number of authors left: 47132
# xiaomei wang ['xiao-mei wang']
# Number of authors left: 47090
# jae yong kim ['jae ryong kim']
# Number of authors left: 46996
# luis meseguer-olmo ['luis meseguer-olmos']
# Number of authors left: 46838
# xiujuan zhuang ['xiujuan zhang']
# Number of authors left: 46813
# jianing zhang ['jianming zhang']
# Number of authors left: 46658
# chengfeng wan ['chengfeng wang']
# Number of authors left: 46253
# zhi qiang liu ['zhi qiang li']
# Number of authors left: 46221
# xinxing wang ['xingxing wang']
# Number of authors left: 46213
# zhaoyao zhang ['zhaoyao zhan']
# Number of authors left: 46173
# zhenghua fei ['zheng-hua fei']
# Number of authors left: 45871
# chunyang wang ['chunyan wang']
# Number of authors left: 45533
# guo qing feng ['guoqing feng']
# Number of authors left: 45476
# jinxiong wang ['jinxing wang']
# Number of authors left: 45413
# yunfeng zhang ['yufeng zhang']
# Number of authors left: 45221
# zhiqiang chen ['zhiqiang cheng', 'zhi-qiang chen']
# Number of authors left: 45174
# zhiqiang wang ['zhi qiang wang']
# Number of authors left: 45051
# xiaoyan zhang ['xiao yan zhang']
# Number of authors left: 44954
# chandrabhushan roy ['chandrbhushan roy']
# Number of authors left: 44926
# kingsley c amadi ['kingley c amadi']
# Number of authors left: 44701
# hongxia zhang ['hong xia zhang']
# Number of authors left: 44640
# jian hua chen ['jianhua chen']
# Number of authors left: 44585
# xiao qiong liu ['xiao qiong li']
# Number of authors left: 44561
# xiaoai zhang ['xiao-ai zhang']
# Number of authors left: 44505
# kohei kamiya ['kouhei kamiya']
# Number of authors left: 44421
# brandon c jeffus ['brandonc jeffus']
# Number of authors left: 44405
# yuanyuan wang ['yuan-yuan wang']
# Number of authors left: 44387
# wenqiao zang ['wen qiao zang', 'wen-qiao zang']
# Number of authors left: 44384
# guoqiang zhao ['guo qiang zhao', 'guo-qiang zhao']
# Number of authors left: 44376
# dongshuo wang ['dongshu wang']
# Number of authors left: 43686
# jianping zhou ['jian ping zhou', 'jian-ping zhou']
# Number of authors left: 43563
# yueqing wang ['yueqiang wang']
# Number of authors left: 43439
# concetta scimone ['concetta simone']
# Number of authors left: 43168
# yingchun wang ['ying-chun wang']
# Number of authors left: 43133
# xiaodong guo ['xiao-dong guo']
# Number of authors left: 43038
# chengjing li ['chengjiang li']
# Number of authors left: 42868
# xiaoping hong ['xiao ping hong']
# Number of authors left: 42764
# jinghua chen ['jianghua chen']
# Number of authors left: 42624
# yongsheng xu ['yong sheng xu']
# Number of authors left: 42516
# peng fei zhang ['pengfei zhang']
# Number of authors left: 42351
# yu ling zheng ['yuling zheng']
# Number of authors left: 42288
# xiaolong yan ['xiaolong yang']
# Number of authors left: 42268
# zhigang zang ['zhigang zhang']
# Number of authors left: 42083
# xiao juan liu ['xiaojuan liu']
# Number of authors left: 42067
# jianfeng zhang ['jian-feng zhang']
# Number of authors left: 42047
# svyatoslav valerievich (ð¡ð²ññ‚ð¾ñð»ð°ð² ð’ð°ð»ðµñ€ñœðµð²ð¸) dudarev (ð”ñƒð´ð°ñ€ðµð²) ['svyatoslav valerievich (ð¡ð²ñ\x8fñ‚ð¾ñ\x81ð»ð°ð² ð’ð°ð»ðµñ€ñœðµð²ð¸ñ‡) dudarev (ð”ñƒð´ð°ñ€ðµð²)']
# Number of authors left: 41992
# zhong yang shen ['zhongyang shen']
# Number of authors left: 41621
# xiao hua wang ['xiaohua wang']
# Number of authors left: 41457
# shusen zheng ['shu sen zheng']
# Number of authors left: 41285
# davide serrano ['david serrano']
# Number of authors left: 41257
# xiao wen feng ['xiaowen feng']
# Number of authors left: 40793
# guangzhong xiong ['guangzhong xing']
# Number of authors left: 40772
# oleksandr oleksandrovich (ðžð»ðµðºñð°ð½ð´ñ€ ðžð»ðµðºñð°ð½ð´ñ€ð¾ð²ð¸ñ‡) garbar (ð“ð°ñ€ð±ð°ñ€) ['olexander olexandrovich (ðžð»ðµðºñ\x81ð°ð½ð´ñ€ ðžð»ðµðºñ\x81ð°ð½ð´ñ€ð¾ð²ð¸ñ‡) garbar (ð“ð°ñ€ð±ð°ñ€)']
# Number of authors left: 40706
# chongjun wang ['hongjun wang']
# Number of authors left: 40697
# chang qing zheng ['changqing zheng']
# Number of authors left: 40623
# chunying wang ['chuanying wang']
# Number of authors left: 40257
# jian dong zhang ['jiandong zhang']
# Number of authors left: 40246
# rosit accardi ['rosita accardi']
# Number of authors left: 39985
# richard i fischer ['richard i fisher']
# Number of authors left: 39893
# johnathan friedberg ['jonathan friedberg']
# Number of authors left: 39888
# anoshirvan kazemnejad ['anoushirvan kazemnejad', 'anoshiravan kazemnejad']
# Number of authors left: 39828
# shahrzad nemtollahi ['shahrzad nematollahi']
# Number of authors left: 39636
# xiaoling liu ['xiao ling liu']
# Number of authors left: 39612
# yu jing zhang ['yujing zhang']
# Number of authors left: 39589
# etienne mainsonneuve ['etienne maisonneuve']
# Number of authors left: 39515
# jianguang wang ['jiangang wang']
# Number of authors left: 39398
# da sheng wang ['dasheng wang']
# Number of authors left: 39283
# xiao hui deng ['xiaohui deng']
# Number of authors left: 39114
# fernando aros ['fernandos aros']
# Number of authors left: 39064
# giovanni tallini, ['giovanni tallini']
# Number of authors left: 38955
# munir pirmohamaed ['munir pirmohamed']
# Number of authors left: 38809
# yong ming wang ['yongming wang']
# Number of authors left: 38797
# sun kyoung han ['sun young han']
# Number of authors left: 38506
# ali reza yaghoubi ['alireza yaghoubi']
# Number of authors left: 38467
# al refaey kandeel ['alrefaey kandeel']
# Number of authors left: 38454
# polina goihberg ['polina goichberg']
# Number of authors left: 38326
# d g (ð” ð“) volkova (ð’ð¾ð»ðºð¾ð²ð°) ['d g (ð” ð“) volkov (ð’ð¾ð»ðºð¾ð²ð°)']
# Number of authors left: 38246
# constantino del gaudio ['costantino del gaudio']
# Number of authors left: 37838
# yun feng zhao ['yu feng zhao']
# Number of authors left: 37764
# konstantinos francis ['kostantinos francis']
# Number of authors left: 37657
# xiaojuan huang ['xiaojun huang']
# Number of authors left: 37606
# michael olausson ['michael lausson']
# Number of authors left: 37577
# mitsuhiro osame ['mituhiro osame']
# Number of authors left: 37318
# xiangyang liu ['xiang-yang liu']
# Number of authors left: 37305
# hong liang zheng ['hongliang zheng']
# Number of authors left: 37093
# xiao ping chen ['xiaoping chen']
# Number of authors left: 37090
# sung june kim ['sung jun kim']
# Number of authors left: 37059
# hanchun chen ['huanchun chen']
# Number of authors left: 36954
# madihah helmii ['madihah helmi']
# Number of authors left: 36616
# yong gang zhao ['yonggang zhao']
# Number of authors left: 36492
# phillip j barter ['philip j barter']
# Number of authors left: 36361
# muhmmad kamran ['muhammad kamran']
# Number of authors left: 36338
# wenjuan wang ['wen juan wang']
# Number of authors left: 36265
# roberto j barrios ['robert j barrios']
# Number of authors left: 36224
# sung soo kim ['sung soon kim']
# Number of authors left: 36106
# adriano piatelli ['adriano piattelli']
# Number of authors left: 36026
# jose barreto campello carvalheira ['jose barreto campelo carvalheira']
# Number of authors left: 35993
# zhiren zhang ['zhi ren zhang']
# Number of authors left: 35872
# nidhi aggarwal ['nidhi agarwal']
# Number of authors left: 35354
# yongsheng hang ['yongsheng zhang']
# Number of authors left: 35318
# xiangwu yang ['xiang-wu yang']
# Number of authors left: 35297
# shaihong zhu ['shai-hong zhu']
# Number of authors left: 35292
# josep basora ['joseph basora']
# Number of authors left: 35055
# xiao ting wang ['xiaoting wang']
# Number of authors left: 34849
# xiaocheng dong ['xiaochen dong']
# Number of authors left: 34782
# jose eduardo mate-sanchez de val ['jose eduardo mate-sanchez del val']
# Number of authors left: 34752
# gongyou chen ['gong-you chen']
# Number of authors left: 34728
# mohamed hammadi ['mohamed hamadi']
# Number of authors left: 34465
# xiaowei zhang ['xiao-wei zhang', 'xiawei zhang']
# Number of authors left: 34450
# chunxiao wang ['chunxia wang']
# Number of authors left: 34389
# wei min zhang ['wei ming zhang']
# Number of authors left: 34330
# s sharif malvajerdi ['s sharifi malvajerdi']
# Number of authors left: 34328
# zhenguang li ['zhengguang li']
# Number of authors left: 33937
# xiaodan zhang ['xiao-dan zhang']
# Number of authors left: 33841
# shuhong zhang ['shuhong+ zhang']
# Number of authors left: 33198
# zhongwei tian ['zhongwei tan']
# Number of authors left: 33135
# chuangping hu ['chuanping hu']
# Number of authors left: 32567
# natarajan meghanathan ['natarajan meghanatha']
# Number of authors left: 32403
# xiaojing zhang ['xiaojiang zhang']
# Number of authors left: 32390
# mohammed ben husein ['mohamed ben husein']
# Number of authors left: 32294
# yong-feng chen ['yongfeng chen']
# Number of authors left: 32200
# jingdong zhang ['jindong zhang']
# Number of authors left: 32016
# wengdong huang ['wendong huang']
# Number of authors left: 31899
# sudharkar thakur ['sudhakar thakur']
# Number of authors left: 31618
# xiaoming zhang ['xiaoming zhan']
# Number of authors left: 31493
# yonghui wang ['yong-hui wang']
# Number of authors left: 31489
# jian-tong jiao ['jiantong jiao']
# Number of authors left: 30835
# yuichiro tanaka ['ryuichiro tanaka']
# Number of authors left: 30787
# s ashokkumar ['s ashok kumar']
# Number of authors left: 30355
# anna piotrowska ['hanna piotrowska']
# Number of authors left: 29906
# zhengjun wang ['zhenjun wang']
# Number of authors left: 29814
# hongyuan zhao ['hongyan zhao']
# Number of authors left: 29722
# arrigo f g cicero ['arrigo fg cicero']
# Number of authors left: 29421
# xiang-sheng zhang ['xiangsheng zhang']
# Number of authors left: 28987
# shi-qing feng ['shiqing feng']
# Number of authors left: 28598
# liping huang ['li-ping huang']
# Number of authors left: 28039
# jianming zhou ['jinming zhou']
# Number of authors left: 27886
# caiyun zhang ['cai yun zhang']
# Number of authors left: 27176
# satoshi konno ['satoshi kono']
# Number of authors left: 27149
# shu-bin wang ['shou-bin wang']
# Number of authors left: 26862
# quan-hong han ['quanhong han']
# Number of authors left: 26841
# yu-chuan wang ['yuchuan wang']
# Number of authors left: 26838
# guo-qing chen ['guo-qiang chen']
# Number of authors left: 26701
# mickey m martin ['mickey m. martin']
# Number of authors left: 26547
# jiyoung park ['ji-young park']
# Number of authors left: 26466
# youhoon chong ['youhoon cheong']
# Number of authors left: 26460
# tae young kim ['tae yong kim']
# Number of authors left: 26456
# noman khandoker ['norman khandoker']
# Number of authors left: 26433
# steven c huber ['steven c. huber']
# Number of authors left: 25761
# zhenhua feng ['zhen-hua feng']
# Number of authors left: 24321
# zhi-dong wang ['zhidong wang']
# Number of authors left: 23462
# stefani fischer ['stefan fischer']
# Number of authors left: 23261
# jun-jie zhang ['junjie zhang']
# Number of authors left: 23090
# xiao-wei zheng ['xiao-wei zeng']
# Number of authors left: 22682
# yanbin zhang ['yanbing zhang']
# Number of authors left: 22329
# young hwan kim ['yong hwan kim']
# Number of authors left: 22317
# hamid javaherian naghash ['hamid javaheriannaghash']
# Number of authors left: 22268
# krutisundar mandal ['kruti sundar mandal']
# Number of authors left: 22043
# masano makino ['masanao makino']
# Number of authors left: 22007
# guillermo blanco ['guillermo blaco']
# Number of authors left: 21810
# mohammed fadl tazi ['mohamed fadl tazi']
# Number of authors left: 21531
# xueliang yang ['xueling yang']
# Number of authors left: 21502
# li-hui zhang ['lie-hui zhang']
# Number of authors left: 21454
# xue-jun zhang ['xuejun zhang']
# Number of authors left: 21074
# jian-hua huang ['jianhua huang']
# Number of authors left: 20953
# james p. warne ['james p warne']
# Number of authors left: 20244
# jillian m. varonin ['jillian m varonin']
# Number of authors left: 20240
# allison w. xu ['allison w xu']
# Number of authors left: 20233
# jinbao zhang ['jin-bao zhang']
# Number of authors left: 19983
# wei-fang zhang ['weifang zhang']
# Number of authors left: 19754
# congxin huang ['cong-xin huang']
# Number of authors left: 19746
# rajinder singh ['rajwinder singh']
# Number of authors left: 19612
# p reddyprasad ['p reddy prasad']
# Number of authors left: 19434
# sudhish kumar ['sudish kumar']
# Number of authors left: 19372
# shinichiro takezawa ['shin-ichiro takezawa']
# Number of authors left: 18910
# miloslav pospisil ['miloslav posisil']
# Number of authors left: 18524
# michael a hansson ['michael a hanson']
# Number of authors left: 18336
# bikash manda ['bikash mandal']
# Number of authors left: 18287
# xiaodong chen ['xiao-dong chen', 'xiaodong cheng']
# Number of authors left: 18037
# hiromich nagasawa ['hiromichi nagasawa']
# Number of authors left: 17146
# xianfeng wang ['xiangfeng wang']
# Number of authors left: 17133
# ling ling rong ['lingling rong']
# Number of authors left: 17078
# guo-dong wang ['guodong wang']
# Number of authors left: 16941
# frances m a shcroft ['frances m ashcroft']
# Number of authors left: 16376
# gunther haisch ['gunter haisch']
# Number of authors left: 15983
# brajesh kumar ['rajesh kumar']
# Number of authors left: 15667
# thomas d schmittgen ['thomas d shmittgen']
# Number of authors left: 14623
# alvin v terry ['alivin v terry']
# Number of authors left: 14621
# jia-hong dong ['jiahong dong']
# Number of authors left: 14428
# rao muralikrishna adibhatla ['rao muralikrishna-adibhatla']
# Number of authors left: 13945
# jong soo kim ['joong soo kim']
# Number of authors left: 13866
# chang-quan ling ['changquan ling']
# Number of authors left: 13551
# anabel heniger ['anabel heiniger']
# Number of authors left: 13506
# anne e willis ['anne e wills']
# Number of authors left: 12392
# spiros parmithiotis ['spiros paramithiotis']
# Number of authors left: 12096
# xiaoning wang ['xiao-ning wang']
# Number of authors left: 11946
# hong wei chen ['hongwei chen']
# Number of authors left: 11748
# bjorn wachsmann ['bjoern wachsmann']
# Number of authors left: 11593
# kalanithi nesaretam ['kalanithi nesaretnam']
# Number of authors left: 11386
# yutaka atomi ['yutaka yatomi']
# Number of authors left: 11202
# haribalaganesh ravinarayanan ['haribalaganesh ravinarayannan']
# Number of authors left: 10006
# jian-jun zhao ['jianjun zhao']
# Number of authors left: 9268
# helen neighbour ['helen neighbor']
# Number of authors left: 8486
# nikolaos papadopoulos ['nikolas papadopoulos']
# Number of authors left: 8107
# r padmanabhan ['r. padmanabhan']
# Number of authors left: 7123
# cristina panuzzo ['christina panuzzo']
# Number of authors left: 7099
# xinsheng yao ['xin-sheng yao']
# Number of authors left: 6063
# mengqiong shi ['meng-qiong shi']
# Number of authors left: 5397
# xianzhe yang ['xian-zhe yang']
# Number of authors left: 5395
# kenji takabayashi ['kenji takabayshi']
# Number of authors left: 5156
# jennnifer s lerner ['jennifer s lerner']
# Number of authors left: 5037
# masaki watanabe ['masaki watanbe']
# Number of authors left: 4886
# masayuki yoshioka ['masayuki yoshiokac']
# Number of authors left: 4837
# kenji onouchi ['kenji onouchia']
# Number of authors left: 4835
# masayo morita ['masayo moritaa']
# Number of authors left: 4833
# soichiro mochio ['soichiro mochiob']
# Number of authors left: 4831
# kiyoharu inoue ['kiyoharu inouec']
# Number of authors left: 4826
# philippe yaba ['phillippe yaba']
# Number of authors left: 4541
# p subrahmanyam ['p subramanyam']
# Number of authors left: 4439
# b krishnapriya ['b krishna priya']
# Number of authors left: 4437
# sung jong kim ['sun jong kim']
# Number of authors left: 2598
# robert cattaneo ['roberto cattaneo']
# Number of authors left: 336
# philip e crye ['philip e cryer']
# Number of authors left: 179
# gideon stritch ['gideon strich']
# Number of authors left: 140
# g b john mancini ['g. b john mancini']
# Number of authors left: 137

# %%
# Disambiguating names

# Function to map names
def map_names(name):
    if name in name_to_correctName:
        return name_to_correctName[name]
    else:
        return name

# Apply mapping to create new column
df_exploded["AuthorNameDisambiguated"] = df_exploded["AuthorName"].map(lambda x: map_names(x))
df_exploded.head(1)
# Out:
#     Record ID  \
# 63      27832
#
#                                                                          Title  \
# 63  Enantioselective Organocatalytic Hantzsch Synthesis of Polyhydroquinolines
#
#             Journal                                 Author RetractionDate  \
# 63  Organic Letters  Christopher G Evans;Jason E Gestwicki     2014-10-02
#
#     RetractionYear  bulkCounts  RetractedInBulk           AuthorName  \
# 63          2014.0         1.0            False  christopher g evans
#
#    AuthorNameDisambiguated
# 63     christopher g evans

# %%
# Now we will run the code to identify multiple authors again
# Note the column change: AuthorNameDisambiguated

# Identifying authors that were retracted multiple times

df_numRetracted = df_exploded.groupby('AuthorNameDisambiguated')['Record ID'].nunique().reset_index()\
                            .rename(columns={'Record ID':'nRetracted'})


df_numRetracted.head(1)
# Out:
#   AuthorNameDisambiguated  nRetracted
# 0      /duane n rafizadeh           1

# %%
# Printing authors will multiple retractions
df_numRetracted[df_numRetracted['nRetracted'].gt(1)]
# We see that there are more authors now
# Out:
#       AuthorNameDisambiguated  nRetracted
# 29             a a nesterenko           3
# 37                  a a zafar           2
# 38            a abdel motelib           2
# 39              a abdul ajees           2
# 42               a abou-elela           2
# ...                       ...         ...
# 50959              zongxi han           2
# 50987              zu-hua gao           2
# 51000  zulkanain abdul rahman           2
# 51015             zuoren wang           2
# 51029        zuzana kubinkova           2
#
# [6591 rows x 2 columns]

# %%
from dateutil.relativedelta import relativedelta

# merging with rw

df_rw3 = df_exploded.merge(df_numRetracted, on='AuthorNameDisambiguated')

# Convert 'RetractionDate' to datetime
df_rw3['RetractionDate'] = pd.to_datetime(df_rw3['RetractionDate'])

# Sort the DataFrame by 'AuthorNameDisambiguated' and 'RetractionDate'
df_rw3 = df_rw3.sort_values(by=['AuthorNameDisambiguated', 'RetractionDate'])

# Group by 'AuthorNameDisambiguated' and get the first RetractionDate
df_rw3_firstRetraction = df_rw3.groupby('AuthorNameDisambiguated')['RetractionDate'].min().reset_index()\
                                .rename(columns={'RetractionDate':'FirstRetractionDate'})

df_rw3 = df_rw3.merge(df_rw3_firstRetraction, on='AuthorNameDisambiguated', how='left')

# Computing difference from first retraction
# Calculate the difference in months
df_rw3['MonthsDiff'] = df_rw3.apply(lambda row: relativedelta(row['RetractionDate'], 
                            row['FirstRetractionDate']).years * 12 + relativedelta(row['RetractionDate'], 
                            row['FirstRetractionDate']).months, axis=1)

df_rw3.head(2)
# Out:
#    Record ID  \
# 0      22375
# 1      25367
#
#                                                                                        Title  \
# 0  Targeted Protein Internalization and Degradation by ENDosome TArgeting Chimeras (ENDTACs)
# 1                       Factors Influencing the Success of Small and Medium-Sized Businesses
#
#                                                                                        Journal  \
# 0                                                                          ACS Central Science
# 1  Economy and Entrepreneurship (Ð­ÐšÐžÐÐžÐœÐ˜ÐšÐ Ð˜ ÐŸÐ Ð•Ð”ÐŸÐ Ð˜ÐÐ˜ÐœÐÐ¢Ð•Ð›Ð¬Ð¡Ð¢Ð’Ðž)
#
#                                                                                                                                                                     Author  \
# 0                                                                    Dhanusha A Nalawansha;Stacey-Lynn Paiva;/duane N Rafizadeh;Mariell Pettersson;Liena Qin;Craig M Crews
# 1  V (B) Egorichev (Ð•Ð³Ð¾Ñ€Ð¸Ñ‡ÐµÐ²);A (A) Zorina (Ð—Ð¾Ñ€Ð¸Ð½Ð°);P (ÐŸ) Malyarchuk (ÐœÐ°Ð»ÑÑ€Ñ‡ÑƒÐº);A (A) Bochtovaya (Ð‘Ð¾Ñ‡Ñ‚Ð¾Ð²Ð°Ñ);D (Ð”) Teremov (Ð¢ÐµÑ€ÐµÐ¼Ð¾Ð²)
#
#   RetractionDate  RetractionYear  bulkCounts  RetractedInBulk  \
# 0     2020-01-23          2020.0         1.0            False
# 1     2020-07-07          2020.0         1.0            False
#
#                             AuthorName              AuthorNameDisambiguated  \
# 0                   /duane n rafizadeh                   /duane n rafizadeh
# 1  a (a) bochtovaya (ð‘ð¾ñ‡ñ‚ð¾ð²ð°ñ)  a (a) bochtovaya (ð‘ð¾ñ‡ñ‚ð¾ð²ð°ñ)
#
#    nRetracted FirstRetractionDate  MonthsDiff
# 0           1          2020-01-23           0
# 1           1          2020-07-07           0

# %%
# Now we need to first only extract authors retracted multiple times

df_repeated_offenders = df_rw3[df_rw3['nRetracted'].gt(1)]
df_repeated_offenders['Record ID'].nunique(), df_repeated_offenders['AuthorNameDisambiguated'].nunique()
# Out:
# (7512, 6591)

# %%
# Now we need to mark those that have months difference greater than or equal to 12
# We will mark others as same year retraction

# Extractong authors that were retracted beyond 12 months
authors_ge12months = df_repeated_offenders[df_repeated_offenders['MonthsDiff'].ge(12)]['AuthorNameDisambiguated'].unique()


# Extracting only authors that were repeated offenders in the same year
df_authors_lt12months = df_repeated_offenders[~df_repeated_offenders['AuthorNameDisambiguated'].\
                                            isin(authors_ge12months)].copy()
# Flagging them
df_authors_lt12months['OffenseSameYear'] = True

# Extracting authors that were repeated offenders beyond 12 months
df_authors_ge12months = df_repeated_offenders[df_repeated_offenders['AuthorNameDisambiguated'].\
                                            isin(authors_ge12months)].copy()
# Flagging them
df_authors_ge12months['OffenseSameYear'] = False


# Merging the two

df_repeated_offenders2 = pd.concat([df_authors_lt12months,df_authors_ge12months])

# Extracting first retraction year
df_repeated_offenders2['FirstRetractionYear'] = df_repeated_offenders2['FirstRetractionDate'].dt.year

# At this point we will just remove AuthorName and call AuthorNameDisambiguated as AuthorName
df_repeated_offenders2 = df_repeated_offenders2.drop(columns=['AuthorName'])\
                                    .rename(columns={'AuthorNameDisambiguated':'AuthorName'})

df_repeated_offenders2.head(2)
# Out:
#     Record ID  \
# 29      25214
# 30      25101
#
#                                                                                                                              Title  \
# 29                       Properties and Compatibility of Microflora for Creating Starter Cultures in Sausage Production Technology
# 30  Development of Technology for Producing Organic Pork with the Introduce of Probiotics, Prebiotics and Synbiotics into the Diet
#
#                                                                      Journal  \
# 29                International Journal of Recent Technology and Engineering
# 30  International Journal of Innovative Technology and Exploring Engineering
#
#                                                               Author  \
# 29    A A Nesterenko;A G Koshchaev;N V Keniiz;R S Omarov;S N Shlykov
# 30  N N Zabashta;A A Nesterenko;A Zabashta;V I Guzenko;E N Chernobai
#
#    RetractionDate  RetractionYear  bulkCounts  RetractedInBulk  \
# 29     2020-09-25          2020.0         1.0            False
# 30     2020-12-07          2020.0         1.0            False
#
#         AuthorName  nRetracted FirstRetractionDate  MonthsDiff  \
# 29  a a nesterenko           3          2020-09-25           0
# 30  a a nesterenko           3          2020-09-25           2
#
#     OffenseSameYear  FirstRetractionYear
# 29             True                 2020
# 30             True                 2020

# %%
df_repeated_offenders2['AuthorName'].nunique()
# Out:
# 6591

# %% [markdown]
# # Saving

# %%
# Finally saving with relevant columns

relevant_cols = ['Record ID', 'AuthorName', 'nRetracted', 'FirstRetractionYear', 'OffenseSameYear']

# Constants
OUTPUT_DIRECTORY = OUTDIR
FILENAME = "RW_repeated_offenders"

file_path = os.path.join(OUTPUT_DIRECTORY, f"{FILENAME}.csv")

# Writing DataFrame to CSV with error handling
try:
    df_repeated_offenders2[relevant_cols].drop_duplicates().to_csv(file_path, index=False)
    print(f"File saved successfully")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# File saved successfully
