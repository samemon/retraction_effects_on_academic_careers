# %% [markdown]
# ## Processing Paper Matches
#
# In this notebook, we shall process the RW-MAG paper matches, and consolidate the matches based on different criteria into a single csv file. We shall also remove the retraction notices from the MAG matches.

# %% [markdown]
# ## The process of filtering records, and matches
#
#
# 0. **Remove retraction notices in RW**
# 1. **Remove all the bulk retractions**
# 2. **Remove all records with duplicate titles in RW**
# 3. **Remove all records beyond 1990-2015**
# 4. **Paper Matching**
#        a. Exact DOI
#        b. Exact Title
#        c. Exact year fuzzy title
#            c1. Keep all papers with the same DOI
#            c2. Matches to hard code: MAGPID: 2418262483 for 4465 and 3011105395 for 24881
#            c3. Remove all the matches that have "Retraction Note" or "Retraction Notice"
#            c4. We will keep all the records with the same retraction year as publication year.
#        d. Fuzzy year fuzzy matching
#            d1. Keep all papers with the same DOI
#            d3. Remove all the matches that have "Retraction Note" or "Retraction Notice"
#            d4. We will keep all the records with the same retraction year as publication year.
# 5. Compile all the matches into a single dataframe and save it

# %%
# Importing relevant packages

import pandas as pd
import os
from config_reader import read_config

# %%
# Reading paths
paths = read_config()
FUZZYMATCH_LOCAL_PATH = paths['FUZZYMATCH_LOCAL_PATH']
RW_ORIGINAL_W_YEAR_LOCAL_PATH = paths['RW_ORIGINAL_W_YEAR_LOCAL_PATH']
PROCESSED_EXACT_PAPER_MATCH_LOCAL_PATH = paths['PROCESSED_EXACT_PAPER_MATCH_LOCAL_PATH']
RETRACTION_NOTICES_LOCAL_PATH = paths['RETRACTION_NOTICES_LOCAL_PATH']
OUTDIR = paths['PROCESSED_FOLDER_LOCAL']

# %%
# Reading list of all files in fuzzy match directory
flist = os.listdir(FUZZYMATCH_LOCAL_PATH)

# %%
# Reading retraction watch dataset
df_rw = pd.read_csv(RW_ORIGINAL_W_YEAR_LOCAL_PATH, usecols=['Record ID', 'Title', 'RetractionDate' , 
                                                            'RetractionYear', 'OriginalPaperYear',
                                                           'RetractionDOI','OriginalPaperDOI',
                                                            'RetractionPubMedID', 'OriginalPaperPubMedID',
                                                           'Journal', 'ArticleType', 'Reason'])
df_rw.head(1)
# Out:
#    Record ID                                              Title  \
# 0      28599  TWEAK-Fn14 Influences Neurogenesis Status via ...
#
#                   Journal        ArticleType RetractionDate  \
# 0  Molecular Neurobiology  Research Article;     2021-05-15
#
#                 RetractionDOI RetractionPubMedID           OriginalPaperDOI  \
# 0  10.1007/s12035-021-02424-8           33991321  10.1007/s12035-016-0248-x
#
#   OriginalPaperPubMedID                                   Reason  \
# 0              27822714  +Duplication of Image;+Unreliable Data;
#
#    OriginalPaperYear  RetractionYear
# 0             2016.0          2021.0

# %% [markdown]
# # 0. Identifying Retraction Notices RW

# %%
# We are extracting all articletypes that contain "Retraction notice" as a keyword (very few records)
records_removed_notices_from_RW = df_rw[~df_rw['ArticleType'].isna() & df_rw['ArticleType']\
                                        .str.contains('Retraction Notice')]['Record ID'].unique()

print(f"Number of records identified as retraction notices in RW: {len(records_removed_notices_from_RW)}")
# Out:
# Number of records identified as retraction notices in RW: 6

# %% [markdown]
# # 1. Identifying bulk retractions

# %%
# Identify bulk retreactions
df_rw_bulkCounts = df_rw.groupby(['Journal','RetractionDate'])['Record ID'].nunique().reset_index()\
                            .rename(columns={'Record ID':'bulkCounts'})

# merging with actual RW 
df_rw_temp = df_rw.merge(df_rw_bulkCounts, on=['Journal','RetractionDate'], how='left')

# Records to be removed due to bulk retractions
records_removed_bulk_retractions = df_rw_temp[df_rw_temp['bulkCounts'].ge(5)]['Record ID'].unique()

print(f"Number of records identified in bulk retractions: {len(records_removed_bulk_retractions)}")
# Out:
# Number of records identified in bulk retractions: 11357

# %%
# printing the difference

len(set(records_removed_bulk_retractions)-set(records_removed_notices_from_RW))
# Out:
# 11356

# %% [markdown]
# # 2. Identifying duplicate title records

# %%
# Extracting records with duplicate titles in RW
records_removed_duplicate_titles = df_rw[df_rw['Title'].duplicated(keep=False)]\
                                        .sort_values(by=['Title'])['Record ID'].unique()

print(f"Number of records identified in duplicate titles: {len(records_removed_duplicate_titles)}")
# Out:
# Number of records identified in duplicate titles: 123

# %%
# printing the difference

len(set(records_removed_duplicate_titles)-set(records_removed_bulk_retractions)-set(records_removed_notices_from_RW))
# Out:
# 108

# %% [markdown]
# # 3. Identifying records beyond 1990-2015

# %%
# extracting records that are not in our window
records_removed_1990_2015 = df_rw[df_rw['RetractionYear'].lt(1990) | 
                                 df_rw['RetractionYear'].gt(2015)]\
                                        ['Record ID'].unique()

print(f"Number of records identified beyond 1990-2015: {len(records_removed_1990_2015)}")
# Out:
# Number of records identified beyond 1990-2015: 10321

# %%
# looking at the difference in the number of records due to this specific filter
len(set(records_removed_1990_2015)-set(records_removed_duplicate_titles)\
        -set(records_removed_bulk_retractions)-set(records_removed_notices_from_RW))
# Out:
# 8330

# %% [markdown]
# # * Creating big list of records removed so far

# %%
# Finally creating a big list of records that we just have to remove due to filtering process
records_filtered = set(list(records_removed_1990_2015)+list(records_removed_duplicate_titles)\
        +list(records_removed_bulk_retractions)+list(records_removed_notices_from_RW))

print(f"Number of records removed due to the above filters {len(records_filtered)}")
# Out:
# Number of records removed due to the above filters 19800

# %% [markdown]
# # 4. Paper Matching

# %%
def extract_record_summary(dfi):
    """
    This function shall be used to 
    give a summary in terms of the 
    (a) total records in the dataframe (dfi)
    as well as the 
    (b) total records between 1990-2015, as well as 
    (c) the average number of matches per record for 
    both (a) and (b) and also the 
    (d) the max number of matches for (a) and (b), and also
    (e) the number of records with more than 1 fuzzy match
    """
    
    print("Number of unique records:", dfi['Record ID'].nunique())
    print("Average number of matches per record", 
          dfi.groupby(['Record ID'])['MAGPID'].nunique().mean())
    print("Max number of matches per record", 
          dfi.groupby(['Record ID'])['MAGPID'].nunique().max())
    dfj = dfi.groupby(['Record ID'])['MAGPID'].nunique().reset_index()\
                .rename(columns={'MAGPID':'NumMatches'})
    print("Records with exactly 1 match", 
          dfj[dfj['NumMatches'].eq(1)]['Record ID'].nunique())
    print("Records with more than 1 match",
         dfj[dfj['NumMatches'].gt(1)]['Record ID'].nunique())
    
    
    print("###########")
    records_1990_2015 = dfi[dfi['RetractionYear'].ge(1990) & dfi['RetractionYear'].le(2015)]
    print("Number of unique records retracted between 1990-2015:", 
          records_1990_2015['Record ID'].nunique())
    print("Average number of matches per record for 1990-2015", 
          records_1990_2015.groupby(['Record ID'])['MAGPID'].nunique().mean())
    print("Max number of matches per record for 1990-2015", 
          records_1990_2015.groupby(['Record ID'])['MAGPID'].nunique().max())
    dfk = records_1990_2015.groupby(['Record ID'])['MAGPID'].nunique().reset_index()\
                .rename(columns={'MAGPID':'NumMatches'})
    print("Records with exactly 1 match for 1990-2015", 
          dfk[dfk['NumMatches'].eq(1)]['Record ID'].nunique())
    print("Records with more than 1 match for 1990-2015",
         dfk[dfk['NumMatches'].gt(1)]['Record ID'].nunique())

# %% [markdown]
# ## a. and b. Processing Exact Matching (based on DOI or Title)

# %%
# Let us explore exact matching first

# Reading papers that were matched by exact matching
df = pd.read_csv(PROCESSED_EXACT_PAPER_MATCH_LOCAL_PATH)
df = df.merge(df_rw.drop(columns=['OriginalPaperDOI']), on='Record ID')
df.head(1)
# Out:
#    Record ID                                        RWTitleNorm  \
# 0      28505  tet1 exerts its tumor suppressor function by r...
#
#       OriginalPaperDOI      MAGPID  \
# 0  10.1042/BSR20160523  2597493214
#
#                                             MAGTitle  MAGPubYear  \
# 0  tet1 exerts its tumour suppressor function by ...      2017.0
#
#                                                Title             Journal  \
# 0  TET1 exerts its tumor suppressor function by r...  Bioscience Reports
#
#          ArticleType RetractionDate             RetractionDOI  \
# 0  Research Article;     2021-05-14  10.1042/BSR-20160523_RET
#
#   RetractionPubMedID OriginalPaperPubMedID  \
# 0           33988682              28341638
#
#                                               Reason  OriginalPaperYear  \
# 0  +Concerns/Issues About Data;+Duplication of Im...             2017.0
#
#    RetractionYear
# 0          2021.0

# %%
# Extracting those that were matched only on DOI i.e. their DOI != NaN
matched_doi = df[~df['OriginalPaperDOI'].isna()]

# Let us remove all the records that were filtered
matched_doi = matched_doi[~matched_doi['Record ID'].isin(records_filtered)]

extract_record_summary(matched_doi)
# Out:
# Number of unique records: 1625
# Average number of matches per record 1.0104615384615385
# Max number of matches per record 4
# Records with exactly 1 match 1613
# Records with more than 1 match 12
# ###########
# Number of unique records retracted between 1990-2015: 1625
# Average number of matches per record for 1990-2015 1.0104615384615385
# Max number of matches per record for 1990-2015 4
# Records with exactly 1 match for 1990-2015 1613
# Records with more than 1 match for 1990-2015 12

# %%
# Extracting records that were matched on title (coz no DOI)
matched_title = df[df.OriginalPaperDOI.isna()]

# Let us remove all the records that were filtered
matched_title = matched_title[~matched_title['Record ID'].isin(records_filtered)]

#matched_title = matched_title[matched_title['Record ID'].isin(matched_doi['Record ID'].unique())]

extract_record_summary(matched_title)
# Out:
# Number of unique records: 1021
# Average number of matches per record 1.1547502448579823
# Max number of matches per record 20
# Records with exactly 1 match 926
# Records with more than 1 match 95
# ###########
# Number of unique records retracted between 1990-2015: 1021
# Average number of matches per record for 1990-2015 1.1547502448579823
# Max number of matches per record for 1990-2015 20
# Records with exactly 1 match for 1990-2015 926
# Records with more than 1 match for 1990-2015 95

# %% [markdown]
# # c. and d. Processing Fuzzy Matching

# %%
PROCESSED_EXACT_PAPER_MATCH_LOCAL_PATH
# Out:
# '/Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/fuzzymatch/RW_MAG_exact_paper_matched.csv'

# %%
# Initializing the two lists for two ways we did fuzzy matching
dfs_exactyear = []
dfs_fuzzyyear = []

exact_match_fname = PROCESSED_EXACT_PAPER_MATCH_LOCAL_PATH.split("/")[-1]

# going through the file list
for fname in flist:
    # Only reading if it is not exact match
    if fname != exact_match_fname:
        df = pd.read_csv(FUZZYMATCH_LOCAL_PATH+fname)
        # If it is exact year fuzzy matching
        if "exact_year" in fname:
            dfs_exactyear.append(df)
        # If it is fuzzy year fuzzy matching
        else:
            dfs_fuzzyyear.append(df)

# %% [markdown]
# ## c. Processing exact year fuzzy matching

# %%
# Processing exact year fuzzy matching
df_exactyear = pd.concat(dfs_exactyear)
df_exactyear = df_exactyear.merge(df_rw, on='Record ID')

# Removing records that were filtered
df_exactyear = df_exactyear[~df_exactyear['Record ID'].isin(records_filtered)]

df_exactyear.head(2)
# Out:
#                                               MAGTitle  score    index  \
# 76   retracted use of upper triangular matrix track...   95.0  7148009
# 198  retracted gamma glutamyl transferase activity ...   95.0  7380434
#
#          MAGPID                                         MAGTitle.1  \
# 76   2028375193  retracted use of upper triangular matrix track...
# 198  2003800286  retracted gamma glutamyl transferase activity ...
#
#      MAGPubYear Record ID                                        RWTitleNorm  \
# 76       2013.0     18798  use of upper triangular matrix tracking for co...
# 198      2013.0      9165  gamma-glutamyl transferase activity in kids bo...
#
#                                                  Title  \
# 76   Use of upper triangular matrix tracking for co...
# 198  Gamma-Glutamyl Transferase Activity in Kids Bo...
#
#                          Journal        ArticleType RetractionDate  \
# 76             Signal Processing  Research Article;     2013-09-01
# 198  Food and Nutrition Sciences  Research Article;     2015-12-15
#
#                     RetractionDOI RetractionPubMedID  \
# 76   10.1016/j.sigpro.2013.01.002                  0
# 198       10.4236/fns.2013.46A006                  0
#
#                  OriginalPaperDOI OriginalPaperPubMedID  \
# 76   10.1016/j.sigpro.2013.01.002                     0
# 198       10.4236/fns.2013.46A006                     0
#
#                                                 Reason  OriginalPaperYear  \
# 76   +Date of Retraction/Other Unknown;+Plagiarism ...             2013.0
# 198  +Falsification/Fabrication of Data;+Falsificat...             2013.0
#
#      RetractionYear
# 76           2013.0
# 198          2015.0

# %%
# summarizing exact year fuzzy matching
extract_record_summary(df_exactyear)
# Out:
# Number of unique records: 3137
# Average number of matches per record 1.1976410583359898
# Max number of matches per record 3
# Records with exactly 1 match 2596
# Records with more than 1 match 541
# ###########
# Number of unique records retracted between 1990-2015: 3137
# Average number of matches per record for 1990-2015 1.1976410583359898
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 2596
# Records with more than 1 match for 1990-2015 541

# %%
# Let us now define a list of papers to keep
# These will be those that are 
# a) in df_exactyear and have retraction doi same as original paper doi
# b) in df_exactyear and do not have "Retraction Note" or "Retraction Notice" in their title
# c) in df_exactyear and have publication year same as retraction year

# extracting records that have same paper doi as retraction doi
records_same_doi = df_rw[df_rw['OriginalPaperDOI'].eq(df_rw['RetractionDOI']) & 
                         ~df_rw['RetractionDOI'].isin(['unavailable','Unavailable'])]['Record ID'].unique()

# extracting the dataframe/matches for those
df_exactyear2 = df_exactyear[df_exactyear['Record ID'].isin(records_same_doi)]

extract_record_summary(df_exactyear2)
# Out:
# Number of unique records: 472
# Average number of matches per record 1.1398305084745763
# Max number of matches per record 3
# Records with exactly 1 match 412
# Records with more than 1 match 60
# ###########
# Number of unique records retracted between 1990-2015: 472
# Average number of matches per record for 1990-2015 1.1398305084745763
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 412
# Records with more than 1 match for 1990-2015 60

# %%
# Adding records that were not in retraction notices


# Now let us read retraction notices and remove them from matches
df_retraction_notices = pd.read_csv(RETRACTION_NOTICES_LOCAL_PATH)

# extracting records that were fuzyy matched but were not in retraction notices
records_not_in_notices = df_exactyear[~df_exactyear['MAGPID'].\
                                        isin(df_retraction_notices['PID'])]['Record ID'].unique()

# extracting records that either have same doi or are in retraction notice
df_exactyear22 = df_exactyear[df_exactyear['Record ID'].isin(records_same_doi) | 
                             df_exactyear['Record ID'].isin(records_not_in_notices)]

extract_record_summary(df_exactyear22)
# Out:
# Number of unique records: 3029
# Average number of matches per record 1.2040277319247277
# Max number of matches per record 3
# Records with exactly 1 match 2490
# Records with more than 1 match 539
# ###########
# Number of unique records retracted between 1990-2015: 3029
# Average number of matches per record for 1990-2015 1.2040277319247277
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 2490
# Records with more than 1 match for 1990-2015 539

# %%
# Adding records with same pubyear as retraction year
records_same_pubyear_ryear = df_exactyear[df_exactyear['MAGPubYear'].eq(df_exactyear['RetractionYear'])]\
                                ['Record ID'].unique()

# Extracting all records matched fuzzily, but have same doi OR same year OR not in retraction notice
# All these records are valid
df_exactyear3 = df_exactyear[df_exactyear['Record ID'].isin(records_same_doi) | 
                            df_exactyear['Record ID'].isin(records_same_pubyear_ryear) | 
                            df_exactyear['Record ID'].isin(records_not_in_notices)]

extract_record_summary(df_exactyear3)
# Out:
# Number of unique records: 3097
# Average number of matches per record 1.2001937358734258
# Max number of matches per record 3
# Records with exactly 1 match 2556
# Records with more than 1 match 541
# ###########
# Number of unique records retracted between 1990-2015: 3097
# Average number of matches per record for 1990-2015 1.2001937358734258
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 2556
# Records with more than 1 match for 1990-2015 541

# %%
# removing those with retraction notice keywords

df_exactyear4 = df_exactyear3[~df_exactyear3['MAGTitle'].str.contains('Retraction Notice') & 
                             ~df_exactyear3['MAGTitle'].str.contains('Retraction Note')]

extract_record_summary(df_exactyear4)
# Out:
# Number of unique records: 3097
# Average number of matches per record 1.2001937358734258
# Max number of matches per record 3
# Records with exactly 1 match 2556
# Records with more than 1 match 541
# ###########
# Number of unique records retracted between 1990-2015: 3097
# Average number of matches per record for 1990-2015 1.2001937358734258
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 2556
# Records with more than 1 match for 1990-2015 541

# %%
# Checking those that were removed

df_exactyear_remaining = df_exactyear[~df_exactyear['Record ID'].isin(df_exactyear4['Record ID'])]

print(f"# Records for which we are not sure {df_exactyear_remaining['Record ID'].nunique()}")
# Out:
# # Records for which we are not sure 40

# %% [markdown]
# ## d. Processing fuzzy year fuzzy matching

# %%
# processing fuzzy year fuzzy matching
df_fuzzyyear = pd.concat(dfs_fuzzyyear)
df_fuzzyyear = df_fuzzyyear.merge(df_rw, on='Record ID')

# removing those records that were in exact match
df_fuzzyyear = df_fuzzyyear[~df_fuzzyyear['Record ID'].isin(df_exactyear['Record ID'])]

# removing those records that were filtered
df_fuzzyyear = df_fuzzyyear[~df_fuzzyyear['Record ID'].isin(records_filtered)]

df_fuzzyyear.head(2)
# Out:
#                                            RWTitleNorm  \
# 198  protective effects of bazedoxifene paired with...
# 208  overexpression of thaumatin gene confers enhan...
#
#                                               MAGTitle      score    index  \
# 198  retraction protective effects of bazedoxifene ...  92.636816  7060760
# 208  retracted article overexpression of thaumatin ...  93.215339  4739624
#
#          MAGPID                                         MAGTitle.1  \
# 198  2179077735  retraction protective effects of bazedoxifene ...
# 208  1925258414  retracted article overexpression of thaumatin ...
#
#      MAGPubYear Record ID                                              Title  \
# 198      2016.0     17304  Protective effects of bazedoxifene paired with...
# 208      2016.0      8766  Overexpression of thaumatin gene confers enhan...
#
#                                           Journal        ArticleType  \
# 198          Biological & Pharmaceutical Bulletin  Research Article;
# 208  Plant Cell, Tissue and Organ Culture (PCTOC)  Research Article;
#
#     RetractionDate              RetractionDOI RetractionPubMedID  \
# 198     2015-11-06      10.1248/bpb.b15-00585           26548420
# 208     2015-08-20  10.1007/s11240-015-0846-8                  0
#
#               OriginalPaperDOI OriginalPaperPubMedID  \
# 198      10.1248/bpb.b15-00585              26548420
# 208  10.1007/s11240-015-0846-8                     0
#
#                                                 Reason  OriginalPaperYear  \
# 198  +Concerns/Issues About Authorship;+Conflict of...             2015.0
# 208                     +Lack of Approval from Author;             2015.0
#
#      RetractionYear
# 198          2015.0
# 208          2015.0

# %%
# summarizing fuzzy year fuzzy matching
extract_record_summary(df_fuzzyyear)
# Out:
# Number of unique records: 542
# Average number of matches per record 1.2250922509225093
# Max number of matches per record 3
# Records with exactly 1 match 433
# Records with more than 1 match 109
# ###########
# Number of unique records retracted between 1990-2015: 542
# Average number of matches per record for 1990-2015 1.2250922509225093
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 433
# Records with more than 1 match for 1990-2015 109

# %%
# Let us first keep those that have the same doi
# We already have a variable called 'records_same_doi'

# extracting the dataframe/matches for those
df_fuzzyyear2 = df_fuzzyyear[df_fuzzyyear['Record ID'].isin(records_same_doi)]

extract_record_summary(df_fuzzyyear2)
# Out:
# Number of unique records: 149
# Average number of matches per record 1.1208053691275168
# Max number of matches per record 3
# Records with exactly 1 match 132
# Records with more than 1 match 17
# ###########
# Number of unique records retracted between 1990-2015: 149
# Average number of matches per record for 1990-2015 1.1208053691275168
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 132
# Records with more than 1 match for 1990-2015 17

# %%
#Extracting records not in retraction notices

# extracting records that were fuzyy matched but were not in retraction notices
records_not_in_notices = df_fuzzyyear[~df_fuzzyyear['MAGPID'].\
                                        isin(df_retraction_notices['PID'])]['Record ID'].unique()

# extracting records that either have same doi or are in retraction notice
df_fuzzyyear22 = df_fuzzyyear[df_fuzzyyear['Record ID'].isin(records_same_doi) | 
                             df_fuzzyyear['Record ID'].isin(records_not_in_notices)]

extract_record_summary(df_fuzzyyear22)
# Out:
# Number of unique records: 522
# Average number of matches per record 1.2318007662835249
# Max number of matches per record 3
# Records with exactly 1 match 414
# Records with more than 1 match 108
# ###########
# Number of unique records retracted between 1990-2015: 522
# Average number of matches per record for 1990-2015 1.2318007662835249
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 414
# Records with more than 1 match for 1990-2015 108

# %%
# removing those with retraction notice keywords

df_fuzzyyear3 = df_fuzzyyear22[~df_fuzzyyear22['MAGTitle'].str.contains('Retraction Notice') & 
                             ~df_fuzzyyear22['MAGTitle'].str.contains('Retraction Note')]

extract_record_summary(df_fuzzyyear3)
# Out:
# Number of unique records: 522
# Average number of matches per record 1.2318007662835249
# Max number of matches per record 3
# Records with exactly 1 match 414
# Records with more than 1 match 108
# ###########
# Number of unique records retracted between 1990-2015: 522
# Average number of matches per record for 1990-2015 1.2318007662835249
# Max number of matches per record for 1990-2015 3
# Records with exactly 1 match for 1990-2015 414
# Records with more than 1 match for 1990-2015 108

# %% [markdown]
# # Compilation
#
# Let us now compile a dataframe of all the possible matches b/w RW and MAG.
#
# We shall also remove all the matches that were identified as retraction notices or contained the
# words 'Retraction Notice' or 'Retraction Note'.
#
# The columns we are interested in are:
#
# 1) Record ID
#
# 2) MAGPID
#
# 3) RW Title
#
# 4) MAG Title
#
# 5) Retraction Year
#
# 6) Fuzzy match score if applicable
#
# 7) Method of matching (doi, title, exactYearFuzzyTitle, fuzzyYearfuzzyTitle)
#
# 8) MAGPubYear
#
# 9) RWOriginalPubYear

# %%
# processing doi matched dataframe
imp_cols = ['Record ID', 'RWTitleNorm', 'MAGPID', 'MAGTitle', 'RetractionYear','MAGPubYear']
df_matched_doi = matched_doi[imp_cols].drop_duplicates()\
                                    .reset_index(drop=True)
df_matched_doi['RecordMatchingMethod'] = 'doi'

# processing title matched dataframe
df_matched_title = matched_title[imp_cols].drop_duplicates()\
                                    .reset_index(drop=True)
df_matched_title['RecordMatchingMethod'] = 'title'


######## Start of block ########

# processing exact year fuzzy title matched dataframe
df_matched_exactyear_fuzzytitle = df_exactyear4[imp_cols+['score']].drop_duplicates()\
                                    .rename(columns={'score':'FuzzyScore'})

df_matched_exactyear_fuzzytitle['RecordMatchingMethod'] = 'exactYearfuzzyTitle'

"""
Let us spell out what is happening in this block.

While we have identified records that we will keep based on 
if they have same retraction and paper doi OR
if they have same retraction year as original paper year OR
if they are not part of retraction notices.

What is missing is that in the matches, we haven't removed matches 
that were retraction notices. So we should remove the matches if 
they are for sure retraction notices and don't fall in either of the above 
criteria. This is only for records where there are more than 1 match. 

So we are removing them below.

"""

# Let me separate this dataframe into 2, those that have same original paper doi as retraction doi, and others
df_matched_exactyear_fuzzytitle_samedoiOryear = df_matched_exactyear_fuzzytitle[df_matched_exactyear_fuzzytitle['Record ID'].\
                                                                            isin(records_same_doi) | 
                                                                               df_matched_exactyear_fuzzytitle['Record ID'].\
                                                                            isin(records_same_pubyear_ryear)]

df_matched_exactyear_fuzzytitle_diffdoiAndYear = df_matched_exactyear_fuzzytitle[~df_matched_exactyear_fuzzytitle['Record ID'].\
                                                                            isin(df_matched_exactyear_fuzzytitle_samedoiOryear['Record ID'])]

# Those that have same doi will not be filtered except manually, those that have different, we will remove retraction notices.
# Let us remove matches that were identified as retraction notices 3717
df_matched_exactyear_fuzzytitle_diffdoiAndYear = df_matched_exactyear_fuzzytitle_diffdoiAndYear[~df_matched_exactyear_fuzzytitle_diffdoiAndYear['MAGPID'].isin(df_retraction_notices['PID']) & 
                                               ~df_matched_exactyear_fuzzytitle_diffdoiAndYear['MAGTitle'].str.contains('Retraction Notice') & 
                                               ~df_matched_exactyear_fuzzytitle_diffdoiAndYear['MAGTitle'].str.contains('Retraction Note')]


# Now let us merge the two dataframes back
df_matched_exactyear_fuzzytitle = pd.concat([df_matched_exactyear_fuzzytitle_samedoiOryear,
                                            df_matched_exactyear_fuzzytitle_diffdoiAndYear])\
                                    .reset_index(drop=True)

######## End of Block ########


# Finally processing the fuzzy year fuzzy match
df_matched_fuzzyyear_fuzzytitle_samedoi = df_fuzzyyear2.copy()

df_matched_fuzzyyear_fuzzytitle_diffdoi = df_fuzzyyear3[~df_fuzzyyear3['Record ID'].isin(df_matched_fuzzyyear_fuzzytitle_samedoi['Record ID'])]


df_matched_fuzzyyear_fuzzytitle_diffdoi = df_matched_fuzzyyear_fuzzytitle_diffdoi[~df_matched_fuzzyyear_fuzzytitle_diffdoi['MAGPID'].isin(df_retraction_notices['PID']) &
                                                                                 ~df_matched_fuzzyyear_fuzzytitle_diffdoi['MAGTitle'].str.contains('Retraction Notice') & 
                                                                                 ~df_matched_fuzzyyear_fuzzytitle_diffdoi['MAGTitle'].str.contains('Retraction Note')]

df_matched_fuzzyyear_fuzzytitle = pd.concat([df_matched_fuzzyyear_fuzzytitle_samedoi,
                                            df_matched_fuzzyyear_fuzzytitle_diffdoi])\
                                    .reset_index(drop=True)

df_matched_fuzzyyear_fuzzytitle = df_matched_fuzzyyear_fuzzytitle[imp_cols+['score']].drop_duplicates()\
                                    .rename(columns={'score':'FuzzyScore'})

df_matched_fuzzyyear_fuzzytitle['RecordMatchingMethod'] = 'fuzzyYearfuzzyTitle'


df_matched_fuzzyyear_fuzzytitle
# Now we merge the four dataframes

df_paper_matching = pd.concat([df_matched_doi,
                              df_matched_title,
                              df_matched_exactyear_fuzzytitle,
                              df_matched_fuzzyyear_fuzzytitle])

extract_record_summary(df_paper_matching)
# Out:
# Number of unique records: 6265
# Average number of matches per record 1.1297685554668795
# Max number of matches per record 20
# Records with exactly 1 match 5595
# Records with more than 1 match 670
# ###########
# Number of unique records retracted between 1990-2015: 6265
# Average number of matches per record for 1990-2015 1.1297685554668795
# Max number of matches per record for 1990-2015 20
# Records with exactly 1 match for 1990-2015 5595
# Records with more than 1 match for 1990-2015 670

# %% [markdown]
# # Removing anomalies: If Retraction year is less than MAG publication year

# %%
df_paper_matching_filtered = df_paper_matching[~df_paper_matching['RetractionYear']\
                                                   .lt(df_paper_matching['MAGPubYear'])]

extract_record_summary(df_paper_matching_filtered)
# Out:
# Number of unique records: 6199
# Average number of matches per record 1.1269559606388126
# Max number of matches per record 18
# Records with exactly 1 match 5541
# Records with more than 1 match 658
# ###########
# Number of unique records retracted between 1990-2015: 6199
# Average number of matches per record for 1990-2015 1.1269559606388126
# Max number of matches per record for 1990-2015 18
# Records with exactly 1 match for 1990-2015 5541
# Records with more than 1 match for 1990-2015 658

# %%
df_paper_matching_filtered.head(2)
# Out:
#   Record ID                                        RWTitleNorm      MAGPID  \
# 0      6582  a study on chinaâ€™s petroleum enterprise soci...  2025784643
# 1      6579  behavior analysis on the security object of th...  2219765734
#
#                                             MAGTitle  RetractionYear  \
# 0  retraction note a study on china s petroleum e...          2015.0
# 1  behavior analysis on the security object of th...          2015.0
#
#    MAGPubYear RecordMatchingMethod  FuzzyScore
# 0      2015.0                  doi         NaN
# 1      2015.0                  doi         NaN

# %% [markdown]
# # Adding an extra column on original paper year from RW

# %%
df_paper_matching_extended = df_paper_matching_filtered.merge(df_rw[['Record ID', 'OriginalPaperYear']], 
                                                              on='Record ID')\
                                                        .rename(columns={'OriginalPaperYear': 'RWPubYear'})
df_paper_matching_extended.head()
# Out:
#   Record ID                                        RWTitleNorm      MAGPID  \
# 0      6582  a study on chinaâ€™s petroleum enterprise soci...  2025784643
# 1      6579  behavior analysis on the security object of th...  2219765734
# 2      6580  communication arising from relationship orient...  2290303548
# 3      6581  prediction model of karstic large spring water...  2230565940
# 4      8450  unilaterally blocking the muscarinic receptors...  1913783002
#
#                                             MAGTitle  RetractionYear  \
# 0  retraction note a study on china s petroleum e...          2015.0
# 1  behavior analysis on the security object of th...          2015.0
# 2  communication arising from relationship orient...          2015.0
# 3  study on prediction model of karstic large spr...          2015.0
# 4  unilaterally blocking the muscarinic receptors...          2015.0
#
#    MAGPubYear RecordMatchingMethod  FuzzyScore  RWPubYear
# 0      2015.0                  doi         NaN     2015.0
# 1      2015.0                  doi         NaN     2015.0
# 2      2015.0                  doi         NaN     2015.0
# 3      2015.0                  doi         NaN     2015.0
# 4      2015.0                  doi         NaN     2015.0

# %% [markdown]
# # Saving

# %%
# Let us first organize columns

col_order = ['Record ID', 'MAGPID', 'RWTitleNorm', 'MAGTitle', 'RecordMatchingMethod',
            'FuzzyScore', 'RWPubYear', 'MAGPubYear' , 'RetractionYear']

import os
from datetime import datetime

# Constants
OUTPUT_DIRECTORY = OUTDIR
FILENAME = "paper_matching"

# Create a full file path with timestamp
timestamp = datetime.now().strftime("%Y%m%d")
file_path = os.path.join(OUTPUT_DIRECTORY, f"{FILENAME}_{timestamp}.csv")

# Writing DataFrame to CSV with error handling
try:
    df_paper_matching_extended[col_order].to_csv(file_path, index=False)
    print(f"File saved successfully at {file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# File saved successfully at /Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/paper_matching_20240219.csv

# %%
# Let us also save the dataframe with duplicates i.e. more than 1 match (to be decided manually)

df_duplicates = df_paper_matching_extended[df_paper_matching_extended['Record ID'].duplicated(keep=False)]\
                .sort_values(by=['Record ID','FuzzyScore'])

FILENAME = "paper_matching_multipleMatches"

# Create a full file path with timestamp
timestamp = datetime.now().strftime("%Y%m%d")
file_path = os.path.join(OUTPUT_DIRECTORY, f"{FILENAME}_{timestamp}.csv")

# Writing DataFrame to CSV with error handling
try:
    df_duplicates[col_order].to_csv(file_path, index=False)
    print(f"File saved successfully at {file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# File saved successfully at /Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/paper_matching_multipleMatches_20240219.csv

# %%
df_duplicates['Record ID'].nunique()
# Out:
# 658

# %% [markdown]
# ## Dealing with multiple matches
#
# Our criteria for multiple matches is as follows:
#
# For fuzzy matched:
#
# 1. we will choose those that have highest score
# 2. If all the options have same score, then we will choose, the one that matches pub years
# 3. If the pub years also match, then we will just choose one match at random
#
#
# For exact matched:
#
# 4. We will choose the exact year match for publication b/w mag and rw and also those that have > 90 fuzzy score on title
# 5. If the fuzzy match score is the same, and year is the same, we will just choose one at random
#
# In all the conditions, we shall flag which condition let to the choice of the final match.

# %%
# This dictionary will contain Record ID --> [MAGPID, Method]
duplicate_match_dict = {}

def select_match(group):
    
    # Get the max fuzzy score
    max_score = group['FuzzyScoreTemp'].max()
    group['maxFuzzyScore'] = max_score
    group1 = group[group['FuzzyScoreTemp']==group['maxFuzzyScore']]
    
    # If there is only 1 max, then choose that as a match
    if(group1.shape[0] == 1):
        duplicate_match_dict[group1['Record ID'].values[0]] = [group1['MAGPID'].values[0],'MaxFuzzy']
    
    # Otherwise
    else:
        # Filter rows where 'MAGPubYear' is closest to 'RWPubYear'
        group1['MAGPubYear-RWPubYear'] = abs(group1['MAGPubYear'] - group1['RWPubYear'])
        group1['LeastPubYearDiff'] = group1['MAGPubYear-RWPubYear'].min()
        group2 = group1[group1['LeastPubYearDiff'] == group1['MAGPubYear-RWPubYear']]
        
        # If there is only 1 match, then choose that
        if(group2.shape[0] == 1):
            duplicate_match_dict[group2['Record ID'].values[0]] = [group2['MAGPID'].values[0],'MaxFuzzy_SamePubYear']
        
        # If there are more, choose a random match
        else:
            group3 = group2.sample(1)
            duplicate_match_dict[group3['Record ID'].values[0]] = [group3['MAGPID'].values[0],'MaxFuzzy_SamePubYear_RandomSample']

            
from rapidfuzz import process, fuzz
import numpy as np

def extract_fuzzy_score(row):
    if pd.isna(row['FuzzyScore']):
        return fuzz.WRatio(row['MAGTitle'],row['RWTitleNorm'])
    else:
        return row['FuzzyScore']

df_duplicates['FuzzyScoreTemp'] = df_duplicates.apply(extract_fuzzy_score, axis=1)

df_duplicates.groupby('Record ID').apply(select_match)

duplicate_match_dict
# Out:
# {5: [1983805905, 'MaxFuzzy'],
#  20: [2394789333, 'MaxFuzzy'],
#  21: [1498045234, 'MaxFuzzy_SamePubYear_RandomSample'],
#  28: [1522658068, 'MaxFuzzy'],
#  31: [3148721216, 'MaxFuzzy_SamePubYear'],
#  41: [2340849561, 'MaxFuzzy_SamePubYear_RandomSample'],
#  44: [1996618667, 'MaxFuzzy'],
#  83: [2046503222, 'MaxFuzzy'],
#  98: [2141052107, 'MaxFuzzy_SamePubYear_RandomSample'],
#  135: [2321347871, 'MaxFuzzy'],
#  147: [2040121344, 'MaxFuzzy_SamePubYear_RandomSample'],
#  180: [1889698115, 'MaxFuzzy_SamePubYear_RandomSample'],
#  209: [2046891546, 'MaxFuzzy'],
#  214: [2026398863, 'MaxFuzzy'],
#  223: [1978944350, 'MaxFuzzy_SamePubYear_RandomSample'],
#  224: [2167258145, 'MaxFuzzy'],
#  240: [2061707676, 'MaxFuzzy_SamePubYear_RandomSample'],
#  242: [3143317349, 'MaxFuzzy_SamePubYear'],
#  243: [2951127773, 'MaxFuzzy'],
#  304: [2044308920, 'MaxFuzzy_SamePubYear_RandomSample'],
#  312: [296088407, 'MaxFuzzy'],
#  323: [2008637244, 'MaxFuzzy'],
#  391: [2062614449, 'MaxFuzzy'],
#  426: [2028272993, 'MaxFuzzy'],
#  428: [2064574709, 'MaxFuzzy'],
#  433: [2040389318, 'MaxFuzzy'],
#  439: [1978705754, 'MaxFuzzy'],
#  440: [1506421429, 'MaxFuzzy_SamePubYear_RandomSample'],
#  451: [2549035450, 'MaxFuzzy_SamePubYear_RandomSample'],
#  462: [3128879627, 'MaxFuzzy'],
#  473: [2060391326, 'MaxFuzzy'],
#  477: [1980807975, 'MaxFuzzy'],
#  487: [2026255795, 'MaxFuzzy'],
#  491: [2154358259, 'MaxFuzzy'],
#  492: [2160675481, 'MaxFuzzy'],
#  495: [1605213202, 'MaxFuzzy'],
#  497: [2182557341, 'MaxFuzzy_SamePubYear_RandomSample'],
#  503: [2106013255, 'MaxFuzzy_SamePubYear_RandomSample'],
#  510: [1517092168, 'MaxFuzzy_SamePubYear'],
#  527: [1994009775, 'MaxFuzzy'],
#  534: [2038132243, 'MaxFuzzy'],
#  535: [2141544538, 'MaxFuzzy'],
#  546: [2010421163, 'MaxFuzzy'],
#  548: [2143384769, 'MaxFuzzy'],
#  588: [2137017272, 'MaxFuzzy'],
#  590: [2416931972, 'MaxFuzzy_SamePubYear_RandomSample'],
#  629: [1935112242, 'MaxFuzzy'],
#  641: [1993503670, 'MaxFuzzy'],
#  647: [1968959914, 'MaxFuzzy'],
#  675: [2094113433, 'MaxFuzzy'],
#  681: [2020831765, 'MaxFuzzy'],
#  687: [2084865513, 'MaxFuzzy'],
#  716: [2133295759, 'MaxFuzzy'],
#  723: [2077569526, 'MaxFuzzy'],
#  777: [2527069805, 'MaxFuzzy'],
#  806: [2320486687, 'MaxFuzzy_SamePubYear'],
#  807: [1977294018, 'MaxFuzzy'],
#  861: [2044613360, 'MaxFuzzy'],
#  876: [2324540270, 'MaxFuzzy'],
#  889: [2000131570, 'MaxFuzzy'],
#  890: [2064766904, 'MaxFuzzy'],
#  894: [2593358005, 'MaxFuzzy'],
#  905: [2187322563, 'MaxFuzzy'],
#  906: [1948940236, 'MaxFuzzy'],
#  909: [1990931110, 'MaxFuzzy'],
#  912: [2414907493, 'MaxFuzzy'],
#  915: [2244084832, 'MaxFuzzy_SamePubYear'],
#  917: [2950109406, 'MaxFuzzy_SamePubYear'],
#  923: [1522205175, 'MaxFuzzy_SamePubYear_RandomSample'],
#  927: [1979448210, 'MaxFuzzy'],
#  931: [3028205309, 'MaxFuzzy_SamePubYear_RandomSample'],
#  939: [2038626831, 'MaxFuzzy_SamePubYear_RandomSample'],
#  959: [2058831540, 'MaxFuzzy_SamePubYear_RandomSample'],
#  963: [1975026723, 'MaxFuzzy_SamePubYear_RandomSample'],
#  980: [1999183541, 'MaxFuzzy'],
#  990: [142918283, 'MaxFuzzy'],
#  1007: [2097679827, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1011: [1989275572, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1021: [2416195475, 'MaxFuzzy_SamePubYear'],
#  1040: [2304650384, 'MaxFuzzy_SamePubYear'],
#  1041: [3138655903, 'MaxFuzzy_SamePubYear'],
#  1154: [2146613593, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1169: [1995198840, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1212: [2079135255, 'MaxFuzzy'],
#  1231: [2014978805, 'MaxFuzzy'],
#  1232: [2045435823, 'MaxFuzzy'],
#  1245: [2186255531, 'MaxFuzzy'],
#  1246: [1977224950, 'MaxFuzzy'],
#  1249: [1999399729, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1252: [2171673289, 'MaxFuzzy_SamePubYear'],
#  1282: [2063993053, 'MaxFuzzy'],
#  1283: [2026364577, 'MaxFuzzy'],
#  1286: [3151599155, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1322: [2962943371, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1332: [3147900542, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1352: [2954317913, 'MaxFuzzy'],
#  1372: [2065241853, 'MaxFuzzy'],
#  1403: [2095293611, 'MaxFuzzy'],
#  1410: [1995213909, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1412: [2121607722, 'MaxFuzzy'],
#  1424: [1535469484, 'MaxFuzzy'],
#  1428: [2154332214, 'MaxFuzzy'],
#  1475: [2150185326, 'MaxFuzzy'],
#  1505: [2020755710, 'MaxFuzzy'],
#  1511: [2566949031, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1517: [2612581618, 'MaxFuzzy'],
#  1543: [1583899813, 'MaxFuzzy'],
#  1608: [2622214288, 'MaxFuzzy'],
#  1705: [2950374338, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1712: [2156989245, 'MaxFuzzy'],
#  1722: [3145678181, 'MaxFuzzy'],
#  1739: [2170988604, 'MaxFuzzy'],
#  1740: [2097245721, 'MaxFuzzy'],
#  1777: [3150595163, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1802: [2067381127, 'MaxFuzzy'],
#  1806: [3160015215, 'MaxFuzzy'],
#  1815: [2052448943, 'MaxFuzzy'],
#  1816: [3144588093, 'MaxFuzzy'],
#  1825: [2597144343, 'MaxFuzzy'],
#  1835: [1994304522, 'MaxFuzzy'],
#  1842: [2183178777, 'MaxFuzzy'],
#  1851: [2026201856, 'MaxFuzzy'],
#  1879: [2017594289, 'MaxFuzzy'],
#  1889: [1974922292, 'MaxFuzzy_SamePubYear_RandomSample'],
#  1912: [2101418562, 'MaxFuzzy'],
#  1916: [2010814844, 'MaxFuzzy'],
#  1938: [2137258798, 'MaxFuzzy'],
#  1942: [2089016318, 'MaxFuzzy'],
#  1945: [2051883446, 'MaxFuzzy'],
#  1958: [2059704432, 'MaxFuzzy'],
#  1960: [2026581238, 'MaxFuzzy'],
#  1979: [2026785658, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2006: [3149488843, 'MaxFuzzy'],
#  2053: [2739310406, 'MaxFuzzy'],
#  2058: [2064344544, 'MaxFuzzy'],
#  2062: [2113574943, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2128: [2027794695, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2132: [2137369867, 'MaxFuzzy'],
#  2140: [3146177204, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2150: [2074986663, 'MaxFuzzy_SamePubYear'],
#  2151: [2616706594, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2169: [2218033849, 'MaxFuzzy'],
#  2188: [2614957253, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2204: [2025581974, 'MaxFuzzy'],
#  2211: [2013024769, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2222: [2031586574, 'MaxFuzzy'],
#  2236: [2049352189, 'MaxFuzzy'],
#  2247: [2963911691, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2248: [1982754959, 'MaxFuzzy'],
#  2283: [2308210524, 'MaxFuzzy'],
#  2323: [2615836323, 'MaxFuzzy'],
#  2338: [1766591620, 'MaxFuzzy'],
#  2343: [1790891469, 'MaxFuzzy'],
#  2379: [2168943199, 'MaxFuzzy'],
#  2383: [1977861022, 'MaxFuzzy'],
#  2385: [2953150318, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2401: [1997963010, 'MaxFuzzy'],
#  2402: [2472594475, 'MaxFuzzy'],
#  2410: [2028380082, 'MaxFuzzy'],
#  2411: [2093288290, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2412: [1593158148, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2413: [27789869, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2415: [2000894445, 'MaxFuzzy'],
#  2474: [2760912950, 'MaxFuzzy'],
#  2484: [1538961437, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2486: [2118466490, 'MaxFuzzy'],
#  2495: [2079379725, 'MaxFuzzy'],
#  2500: [3241265, 'MaxFuzzy'],
#  2502: [2094838560, 'MaxFuzzy'],
#  2506: [2044134799, 'MaxFuzzy'],
#  2512: [2192878045, 'MaxFuzzy_SamePubYear'],
#  2513: [2233077171, 'MaxFuzzy'],
#  2519: [2125165423, 'MaxFuzzy'],
#  2520: [2323665976, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2532: [2059517571, 'MaxFuzzy'],
#  2568: [2126317091, 'MaxFuzzy'],
#  2605: [2045245296, 'MaxFuzzy'],
#  2630: [2311410841, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2650: [2410634280, 'MaxFuzzy'],
#  2651: [2035940427, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2667: [3142993408, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2686: [2147510223, 'MaxFuzzy'],
#  2699: [2059942741, 'MaxFuzzy'],
#  2716: [1972262510, 'MaxFuzzy'],
#  2739: [2118134202, 'MaxFuzzy'],
#  2748: [2046564760, 'MaxFuzzy'],
#  2761: [1966859474, 'MaxFuzzy'],
#  2765: [2005429524, 'MaxFuzzy'],
#  2779: [147626409, 'MaxFuzzy'],
#  2800: [2054980805, 'MaxFuzzy'],
#  2836: [2138456509, 'MaxFuzzy_SamePubYear'],
#  2842: [2334233527, 'MaxFuzzy'],
#  2846: [2088801655, 'MaxFuzzy_SamePubYear'],
#  2865: [2416916392, 'MaxFuzzy'],
#  2872: [1991606072, 'MaxFuzzy'],
#  2876: [2084061842, 'MaxFuzzy'],
#  2878: [2015510611, 'MaxFuzzy'],
#  2879: [1992303766, 'MaxFuzzy'],
#  2880: [2508982812, 'MaxFuzzy'],
#  2901: [2115049351, 'MaxFuzzy'],
#  2909: [2076276077, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2911: [2064389765, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2937: [2426049836, 'MaxFuzzy_SamePubYear_RandomSample'],
#  2952: [1577672319, 'MaxFuzzy'],
#  2955: [2442731896, 'MaxFuzzy'],
#  2980: [2077426157, 'MaxFuzzy'],
#  2986: [4120187, 'MaxFuzzy'],
#  2989: [2040224956, 'MaxFuzzy'],
#  2998: [2000396955, 'MaxFuzzy'],
#  3001: [2011038139, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3014: [2323636552, 'MaxFuzzy'],
#  3016: [2047923769, 'MaxFuzzy'],
#  3024: [2914589974, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3028: [3125132151, 'MaxFuzzy'],
#  3033: [1993659641, 'MaxFuzzy'],
#  3059: [2007084464, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3086: [2054031365, 'MaxFuzzy'],
#  3097: [1940938568, 'MaxFuzzy'],
#  3107: [2145308640, 'MaxFuzzy'],
#  3112: [1896647631, 'MaxFuzzy'],
#  3124: [2405154158, 'MaxFuzzy'],
#  3143: [2618437667, 'MaxFuzzy'],
#  3145: [1967123000, 'MaxFuzzy'],
#  3155: [2003696679, 'MaxFuzzy'],
#  3198: [2065065616, 'MaxFuzzy_SamePubYear'],
#  3216: [2398062486, 'MaxFuzzy'],
#  3217: [2024266835, 'MaxFuzzy'],
#  3242: [2410431271, 'MaxFuzzy_SamePubYear'],
#  3264: [3024467981, 'MaxFuzzy'],
#  3270: [2053319913, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3314: [2061015034, 'MaxFuzzy'],
#  3317: [2032188814, 'MaxFuzzy_SamePubYear'],
#  3320: [2121277505, 'MaxFuzzy'],
#  3322: [2099380716, 'MaxFuzzy_SamePubYear'],
#  3325: [2395197220, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3326: [2073396290, 'MaxFuzzy'],
#  3333: [1804425585, 'MaxFuzzy'],
#  3337: [1981576637, 'MaxFuzzy'],
#  3338: [2104204979, 'MaxFuzzy'],
#  3343: [2145005022, 'MaxFuzzy'],
#  3357: [2080724847, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3359: [2065469502, 'MaxFuzzy'],
#  3382: [51762177, 'MaxFuzzy'],
#  3383: [51762177, 'MaxFuzzy'],
#  3384: [2162350607, 'MaxFuzzy'],
#  3407: [1978626818, 'MaxFuzzy'],
#  3420: [2121618285, 'MaxFuzzy'],
#  3445: [2115811412, 'MaxFuzzy'],
#  3452: [2616844975, 'MaxFuzzy'],
#  3458: [2140397628, 'MaxFuzzy'],
#  3465: [2006513882, 'MaxFuzzy'],
#  3475: [2162934857, 'MaxFuzzy'],
#  3478: [2087382704, 'MaxFuzzy'],
#  3481: [1996149590, 'MaxFuzzy'],
#  3485: [2077167412, 'MaxFuzzy'],
#  3487: [2022556419, 'MaxFuzzy'],
#  3500: [2008666091, 'MaxFuzzy'],
#  3509: [2025378051, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3513: [2183260407, 'MaxFuzzy'],
#  3518: [2107515803, 'MaxFuzzy_SamePubYear'],
#  3551: [2111670885, 'MaxFuzzy'],
#  3564: [2410099107, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3612: [2463513667, 'MaxFuzzy'],
#  3621: [1916086334, 'MaxFuzzy'],
#  3623: [1970384246, 'MaxFuzzy'],
#  3629: [2168308204, 'MaxFuzzy'],
#  3635: [2032160308, 'MaxFuzzy'],
#  3642: [3148980342, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3652: [2367251995, 'MaxFuzzy'],
#  3670: [188900355, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3681: [1533376794, 'MaxFuzzy'],
#  3712: [2057800258, 'MaxFuzzy'],
#  3713: [2607187007, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3722: [2103370207, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3724: [2002573183, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3725: [2151638388, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3754: [42998949, 'MaxFuzzy_SamePubYear'],
#  3778: [2616663063, 'MaxFuzzy'],
#  3783: [2610931064, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3785: [36376306, 'MaxFuzzy'],
#  3786: [2411356663, 'MaxFuzzy'],
#  3788: [1945375234, 'MaxFuzzy'],
#  3790: [2118009935, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3793: [2022329518, 'MaxFuzzy_SamePubYear'],
#  3823: [2998595837, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3844: [2406027787, 'MaxFuzzy'],
#  3853: [2083380864, 'MaxFuzzy'],
#  3855: [2125605081, 'MaxFuzzy'],
#  3856: [2156115769, 'MaxFuzzy'],
#  3883: [1998130318, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3904: [2133982863, 'MaxFuzzy_SamePubYear'],
#  3918: [1983787794, 'MaxFuzzy'],
#  3961: [2027891192, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3969: [2123265566, 'MaxFuzzy_SamePubYear_RandomSample'],
#  3973: [2748384113, 'MaxFuzzy'],
#  4007: [42676777, 'MaxFuzzy'],
#  4025: [1966393037, 'MaxFuzzy'],
#  4028: [2106542076, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4042: [240742869, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4043: [3146171442, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4045: [3144338437, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4048: [3150298077, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4058: [3141632327, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4111: [1885525395, 'MaxFuzzy'],
#  4120: [1970415794, 'MaxFuzzy'],
#  4163: [2106116149, 'MaxFuzzy'],
#  4169: [2066579710, 'MaxFuzzy'],
#  4174: [2949760324, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4180: [1971347001, 'MaxFuzzy'],
#  4181: [1985482574, 'MaxFuzzy'],
#  4191: [2019083402, 'MaxFuzzy'],
#  4195: [2001987482, 'MaxFuzzy'],
#  4230: [1968424852, 'MaxFuzzy_SamePubYear'],
#  4235: [2031889815, 'MaxFuzzy'],
#  4238: [2060958066, 'MaxFuzzy'],
#  4242: [1990470067, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4260: [2031171946, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4265: [1997851506, 'MaxFuzzy'],
#  4271: [1983118941, 'MaxFuzzy'],
#  4289: [2057473262, 'MaxFuzzy'],
#  4291: [2161403450, 'MaxFuzzy'],
#  4292: [2011528716, 'MaxFuzzy'],
#  4295: [1980248747, 'MaxFuzzy'],
#  4335: [1534017421, 'MaxFuzzy'],
#  4341: [2080216136, 'MaxFuzzy_SamePubYear'],
#  4372: [2406816531, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4375: [2326382061, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4386: [2078536260, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4390: [2605659762, 'MaxFuzzy'],
#  4397: [2316238658, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4408: [1992201186, 'MaxFuzzy'],
#  4409: [2104623627, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4410: [1574875065, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4433: [96443260, 'MaxFuzzy_SamePubYear'],
#  4451: [2044718899, 'MaxFuzzy'],
#  4453: [2044084797, 'MaxFuzzy'],
#  4455: [2354229457, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4460: [1908281935, 'MaxFuzzy'],
#  4466: [2132697604, 'MaxFuzzy'],
#  4469: [2062497504, 'MaxFuzzy'],
#  4471: [1965898024, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4477: [3006364933, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4484: [2599033197, 'MaxFuzzy'],
#  4487: [2009372522, 'MaxFuzzy'],
#  4532: [1831524103, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4562: [1523287377, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4564: [56867395, 'MaxFuzzy'],
#  4568: [2106530720, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4577: [1968685261, 'MaxFuzzy'],
#  4625: [2145937040, 'MaxFuzzy'],
#  4626: [2334519771, 'MaxFuzzy_SamePubYear'],
#  4632: [2091837378, 'MaxFuzzy'],
#  4641: [1976391244, 'MaxFuzzy'],
#  4657: [2035096976, 'MaxFuzzy'],
#  4709: [2543509233, 'MaxFuzzy'],
#  4720: [1972304827, 'MaxFuzzy'],
#  4746: [2950427588, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4748: [2912194016, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4749: [2952381956, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4763: [2064030855, 'MaxFuzzy'],
#  4764: [2068043487, 'MaxFuzzy'],
#  4771: [2008490374, 'MaxFuzzy'],
#  4849: [2127845314, 'MaxFuzzy'],
#  4870: [1753685005, 'MaxFuzzy'],
#  4873: [2006078445, 'MaxFuzzy'],
#  4883: [2066530348, 'MaxFuzzy_SamePubYear_RandomSample'],
#  4892: [2032691494, 'MaxFuzzy'],
#  4920: [1975129737, 'MaxFuzzy'],
#  4929: [2619746926, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5008: [3023846484, 'MaxFuzzy_SamePubYear'],
#  5012: [2203230159, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5089: [2949700125, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5105: [2333854011, 'MaxFuzzy'],
#  5117: [3141673207, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5174: [2436624724, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5175: [2015486913, 'MaxFuzzy'],
#  5183: [1523061757, 'MaxFuzzy'],
#  5213: [2951629855, 'MaxFuzzy'],
#  5214: [2047788515, 'MaxFuzzy'],
#  5228: [2162231717, 'MaxFuzzy'],
#  5237: [2163676172, 'MaxFuzzy'],
#  5267: [2897063397, 'MaxFuzzy'],
#  5287: [1634551193, 'MaxFuzzy'],
#  5291: [3123707030, 'MaxFuzzy'],
#  5307: [2013135965, 'MaxFuzzy'],
#  5322: [3103724959, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5324: [1966959703, 'MaxFuzzy'],
#  5352: [2027631244, 'MaxFuzzy'],
#  5360: [2043246102, 'MaxFuzzy'],
#  5380: [2182697478, 'MaxFuzzy'],
#  5414: [2072683842, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5433: [3140270767, 'MaxFuzzy'],
#  5436: [1981855241, 'MaxFuzzy'],
#  5461: [1995284036, 'MaxFuzzy'],
#  5513: [2021220372, 'MaxFuzzy_SamePubYear'],
#  5532: [2145223699, 'MaxFuzzy_SamePubYear'],
#  5567: [3147027482, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5604: [2001558034, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5606: [2065729975, 'MaxFuzzy'],
#  5656: [2012027559, 'MaxFuzzy'],
#  5657: [2026087575, 'MaxFuzzy'],
#  5687: [2053074195, 'MaxFuzzy'],
#  5716: [2172068359, 'MaxFuzzy_SamePubYear'],
#  5733: [1855292621, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5735: [2947069952, 'MaxFuzzy'],
#  5740: [1194614238, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5744: [2145940202, 'MaxFuzzy'],
#  5758: [2565906684, 'MaxFuzzy_SamePubYear_RandomSample'],
#  5768: [2950549212, 'MaxFuzzy'],
#  5840: [2095348223, 'MaxFuzzy'],
#  5845: [3148253948, 'MaxFuzzy'],
#  5881: [1901685860, 'MaxFuzzy'],
#  5954: [2007615003, 'MaxFuzzy'],
#  5986: [3148123890, 'MaxFuzzy'],
#  6002: [3100834088, 'MaxFuzzy'],
#  6007: [2540419480, 'MaxFuzzy'],
#  6038: [2078268859, 'MaxFuzzy'],
#  6049: [2073641425, 'MaxFuzzy'],
#  6072: [2059581598, 'MaxFuzzy'],
#  6077: [2035871610, 'MaxFuzzy_SamePubYear_RandomSample'],
#  6109: [93291833, 'MaxFuzzy_SamePubYear_RandomSample'],
#  6114: [2143909355, 'MaxFuzzy'],
#  6122: [2095265731, 'MaxFuzzy'],
#  6204: [1564445181, 'MaxFuzzy'],
#  6212: [2648971105, 'MaxFuzzy'],
#  6239: [2038398487, 'MaxFuzzy'],
#  6249: [3126094087, 'MaxFuzzy'],
#  6272: [2139588191, 'MaxFuzzy'],
#  6296: [2163091610, 'MaxFuzzy'],
#  6305: [2148212436, 'MaxFuzzy'],
#  6308: [3023386268, 'MaxFuzzy'],
#  6318: [1647210188, 'MaxFuzzy'],
#  6319: [2219366295, 'MaxFuzzy_SamePubYear'],
#  6345: [2029245566, 'MaxFuzzy'],
#  6350: [1710514309, 'MaxFuzzy'],
#  6356: [2058752154, 'MaxFuzzy_SamePubYear'],
#  6367: [1976231374, 'MaxFuzzy'],
#  6369: [2035310593, 'MaxFuzzy'],
#  6378: [2035310593, 'MaxFuzzy'],
#  6381: [2006539283, 'MaxFuzzy'],
#  6385: [1425829177, 'MaxFuzzy'],
#  6389: [1259163167, 'MaxFuzzy'],
#  6412: [2785626859, 'MaxFuzzy'],
#  6438: [2399151583, 'MaxFuzzy_SamePubYear_RandomSample'],
#  6439: [2197646340, 'MaxFuzzy'],
#  6440: [2481846099, 'MaxFuzzy_SamePubYear_RandomSample'],
#  6507: [2345149783, 'MaxFuzzy'],
#  6548: [3140852055, 'MaxFuzzy_SamePubYear_RandomSample'],
#  6553: [3022842670, 'MaxFuzzy'],
#  6742: [2002494244, 'MaxFuzzy'],
#  6807: [2021137614, 'MaxFuzzy'],
#  6895: [1976313240, 'MaxFuzzy'],
#  6898: [2023226107, 'MaxFuzzy'],
#  6925: [2558287256, 'MaxFuzzy'],
#  7068: [1535654876, 'MaxFuzzy_SamePubYear_RandomSample'],
#  7071: [2371481669, 'MaxFuzzy_SamePubYear_RandomSample'],
#  7077: [117976492, 'MaxFuzzy'],
#  7094: [3036326486, 'MaxFuzzy_SamePubYear_RandomSample'],
#  7098: [2598427489, 'MaxFuzzy'],
#  7198: [1252527267, 'MaxFuzzy'],
#  7245: [2116717140, 'MaxFuzzy_SamePubYear_RandomSample'],
#  7247: [1981941015, 'MaxFuzzy'],
#  7354: [2325447901, 'MaxFuzzy'],
#  7822: [1531284349, 'MaxFuzzy_SamePubYear_RandomSample'],
#  7884: [2063475028, 'MaxFuzzy_SamePubYear_RandomSample'],
#  8004: [2088427665, 'MaxFuzzy'],
#  8076: [2951407073, 'MaxFuzzy'],
#  8084: [2168094452, 'MaxFuzzy_SamePubYear_RandomSample'],
#  8102: [2156017633, 'MaxFuzzy_SamePubYear'],
#  8410: [1506240752, 'MaxFuzzy'],
#  8417: [2473704573, 'MaxFuzzy'],
#  8463: [1968159628, 'MaxFuzzy_SamePubYear_RandomSample'],
#  8519: [1964467065, 'MaxFuzzy_SamePubYear_RandomSample'],
#  8552: [1981001019, 'MaxFuzzy_SamePubYear_RandomSample'],
#  8667: [2096378302, 'MaxFuzzy'],
#  8845: [2102703210, 'MaxFuzzy'],
#  8957: [2072154172, 'MaxFuzzy_SamePubYear_RandomSample'],
#  9202: [2007331783, 'MaxFuzzy'],
#  9459: [2102516773, 'MaxFuzzy'],
#  9506: [2326362989, 'MaxFuzzy_SamePubYear_RandomSample'],
#  9564: [2060664701, 'MaxFuzzy_SamePubYear_RandomSample'],
#  9620: [2941342877, 'MaxFuzzy_SamePubYear'],
#  9789: [2396634959, 'MaxFuzzy_SamePubYear_RandomSample'],
#  9793: [2002365361, 'MaxFuzzy'],
#  10968: [2032595354, 'MaxFuzzy'],
#  10985: [189719170, 'MaxFuzzy'],
#  10987: [112265570, 'MaxFuzzy'],
#  11991: [2670207287, 'MaxFuzzy'],
#  12092: [2061057155, 'MaxFuzzy_SamePubYear_RandomSample'],
#  12093: [2053209977, 'MaxFuzzy'],
#  12311: [2054641633, 'MaxFuzzy'],
#  12485: [2070911371, 'MaxFuzzy'],
#  12497: [2323596667, 'MaxFuzzy'],
#  12992: [1824301527, 'MaxFuzzy_SamePubYear_RandomSample'],
#  13040: [2407773585, 'MaxFuzzy_SamePubYear_RandomSample'],
#  13407: [1995551754, 'MaxFuzzy'],
#  14754: [3140217331, 'MaxFuzzy'],
#  15835: [2609888259, 'MaxFuzzy'],
#  16006: [3148521644, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16014: [1973625508, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16016: [2460443296, 'MaxFuzzy'],
#  16310: [1799688488, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16345: [3142728181, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16485: [2028159472, 'MaxFuzzy'],
#  16487: [2088076734, 'MaxFuzzy'],
#  16491: [1926297758, 'MaxFuzzy'],
#  16501: [1986440906, 'MaxFuzzy'],
#  16502: [2405069742, 'MaxFuzzy'],
#  16504: [1974899218, 'MaxFuzzy'],
#  16505: [2075156646, 'MaxFuzzy'],
#  16508: [2053566062, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16543: [2278548439, 'MaxFuzzy'],
#  16617: [2079932159, 'MaxFuzzy'],
#  16698: [1060527488, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16736: [2465171863, 'MaxFuzzy'],
#  16737: [2036807118, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16738: [1970767446, 'MaxFuzzy_SamePubYear'],
#  16753: [1967016293, 'MaxFuzzy'],
#  16822: [2950533825, 'MaxFuzzy_SamePubYear'],
#  16828: [2056520407, 'MaxFuzzy'],
#  16829: [1964017817, 'MaxFuzzy'],
#  16858: [311035448, 'MaxFuzzy'],
#  16864: [2547848933, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16872: [1877395113, 'MaxFuzzy'],
#  16883: [171853957, 'MaxFuzzy'],
#  16902: [2951803692, 'MaxFuzzy'],
#  16908: [2338226595, 'MaxFuzzy'],
#  16928: [2021486877, 'MaxFuzzy'],
#  16930: [2094847710, 'MaxFuzzy'],
#  16934: [2070469856, 'MaxFuzzy_SamePubYear_RandomSample'],
#  16982: [2567435933, 'MaxFuzzy'],
#  17003: [1970809442, 'MaxFuzzy'],
#  17046: [1590077934, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17048: [2120195465, 'MaxFuzzy'],
#  17070: [2030999762, 'MaxFuzzy'],
#  17079: [1978794102, 'MaxFuzzy'],
#  17085: [3150394472, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17101: [2122984359, 'MaxFuzzy'],
#  17110: [2082146540, 'MaxFuzzy'],
#  17117: [2033633901, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17164: [2189326977, 'MaxFuzzy_SamePubYear'],
#  17213: [3083617487, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17220: [2234010788, 'MaxFuzzy'],
#  17221: [2034306562, 'MaxFuzzy_SamePubYear'],
#  17224: [2065840031, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17233: [1975005506, 'MaxFuzzy'],
#  17248: [2129328734, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17254: [2337680023, 'MaxFuzzy'],
#  17290: [2059485519, 'MaxFuzzy'],
#  17337: [2034577743, 'MaxFuzzy'],
#  17344: [2080637758, 'MaxFuzzy'],
#  17345: [2035658701, 'MaxFuzzy'],
#  17359: [1972856474, 'MaxFuzzy'],
#  17360: [2052252946, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17386: [1579600192, 'MaxFuzzy'],
#  17388: [1985396825, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17390: [2011560998, 'MaxFuzzy'],
#  17391: [1987449207, 'MaxFuzzy'],
#  17395: [1979378158, 'MaxFuzzy'],
#  17399: [2012562688, 'MaxFuzzy'],
#  17401: [2154822217, 'MaxFuzzy'],
#  17415: [2054817401, 'MaxFuzzy_SamePubYear'],
#  17418: [2109351083, 'MaxFuzzy'],
#  17525: [2014610570, 'MaxFuzzy'],
#  17632: [2170357136, 'MaxFuzzy'],
#  17653: [2031728786, 'MaxFuzzy'],
#  17696: [3123355616, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17708: [2320476366, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17718: [2081285931, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17722: [2160972592, 'MaxFuzzy'],
#  17724: [1966991447, 'MaxFuzzy'],
#  17727: [277645687, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17774: [2206226139, 'MaxFuzzy'],
#  17873: [2092765150, 'MaxFuzzy'],
#  17887: [2010270378, 'MaxFuzzy'],
#  17888: [2276100403, 'MaxFuzzy'],
#  17889: [2055480427, 'MaxFuzzy'],
#  17906: [2086052181, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17908: [2012232052, 'MaxFuzzy'],
#  17914: [2656938, 'MaxFuzzy'],
#  17918: [2561676788, 'MaxFuzzy_SamePubYear_RandomSample'],
#  17922: [1844732447, 'MaxFuzzy'],
#  17928: [2040006237, 'MaxFuzzy'],
#  18170: [2094599515, 'MaxFuzzy'],
#  18171: [2172295115, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18188: [2186753220, 'MaxFuzzy'],
#  18189: [2002175591, 'MaxFuzzy'],
#  18194: [2000684465, 'MaxFuzzy'],
#  18203: [2519517043, 'MaxFuzzy'],
#  18217: [2897015269, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18226: [1825883274, 'MaxFuzzy'],
#  18417: [3148271847, 'MaxFuzzy'],
#  18427: [2586078630, 'MaxFuzzy'],
#  18511: [1992858489, 'MaxFuzzy'],
#  18518: [2037428094, 'MaxFuzzy'],
#  18537: [2185547785, 'MaxFuzzy'],
#  18540: [2921461050, 'MaxFuzzy'],
#  18544: [3148772148, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18552: [2066523492, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18555: [2601918393, 'MaxFuzzy'],
#  18559: [3151691071, 'MaxFuzzy'],
#  18563: [2154579728, 'MaxFuzzy'],
#  18567: [1495392295, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18645: [3121840039, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18648: [3140432033, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18650: [1966281823, 'MaxFuzzy'],
#  18655: [3125937040, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18657: [2373677605, 'MaxFuzzy'],
#  18673: [3142786378, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18680: [1022365530, 'MaxFuzzy'],
#  18697: [2057675409, 'MaxFuzzy'],
#  18702: [2059028859, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18704: [1991225034, 'MaxFuzzy'],
#  18709: [2076618163, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18739: [2398741098, 'MaxFuzzy'],
#  18742: [1503964063, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18761: [98638232, 'MaxFuzzy'],
#  18766: [3140392793, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18788: [2057016496, 'MaxFuzzy'],
#  18796: [1993213538, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18797: [2150722967, 'MaxFuzzy'],
#  18807: [1990101849, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18810: [2325161071, 'MaxFuzzy'],
#  18826: [2008680148, 'MaxFuzzy_SamePubYear_RandomSample'],
#  18827: [2963976281, 'MaxFuzzy'],
#  19389: [2209846837, 'MaxFuzzy'],
#  19390: [2182498443, 'MaxFuzzy'],
#  19442: [2266929622, 'MaxFuzzy'],
#  19444: [2591185680, 'MaxFuzzy'],
#  19445: [2066284409, 'MaxFuzzy'],
#  19465: [2526793914, 'MaxFuzzy_SamePubYear_RandomSample'],
#  19784: [1674422799, 'MaxFuzzy'],
#  20842: [2318284405, 'MaxFuzzy'],
#  20887: [1983653404, 'MaxFuzzy_SamePubYear_RandomSample'],
#  21299: [1992603014, 'MaxFuzzy'],
#  21515: [2113271883, 'MaxFuzzy'],
#  21902: [2058678439, 'MaxFuzzy'],
#  21910: [2032247177, 'MaxFuzzy_SamePubYear_RandomSample'],
#  21911: [2949847484, 'MaxFuzzy'],
#  21912: [2090755804, 'MaxFuzzy_SamePubYear_RandomSample'],
#  21939: [3099153551, 'MaxFuzzy'],
#  22008: [2891811567, 'MaxFuzzy'],
#  22051: [2146676240, 'MaxFuzzy'],
#  22067: [1990079114, 'MaxFuzzy_SamePubYear_RandomSample'],
#  22182: [2156680094, 'MaxFuzzy'],
#  22185: [2949610092, 'MaxFuzzy'],
#  22186: [1976970829, 'MaxFuzzy_SamePubYear_RandomSample'],
#  22207: [1999626414, 'MaxFuzzy_SamePubYear_RandomSample'],
#  22359: [2049311906, 'MaxFuzzy'],
#  22615: [2043209556, 'MaxFuzzy'],
#  22673: [2274371157, 'MaxFuzzy'],
#  22741: [2000209650, 'MaxFuzzy'],
#  22997: [2035074991, 'MaxFuzzy_SamePubYear_RandomSample'],
#  23023: [2094791077, 'MaxFuzzy'],
#  23116: [3104996638, 'MaxFuzzy_SamePubYear_RandomSample'],
#  23421: [1992621302, 'MaxFuzzy'],
#  23429: [1965798768, 'MaxFuzzy'],
#  28021: [2189409154, 'MaxFuzzy']}

# %%
# Create DataFrame

# Convert dictionary to list of tuples
records_list = [(record_id, info[0], info[1]) for record_id, info in duplicate_match_dict.items()]


df_duplicate_matches = pd.DataFrame(records_list, 
                                    columns=['Record ID', 'MAGPID', 'RecordMatchingMethodStep2'])

df_duplicate_matches
# Out:
#      Record ID      MAGPID          RecordMatchingMethodStep2
# 0            5  1983805905                           MaxFuzzy
# 1           20  2394789333                           MaxFuzzy
# 2           21  1498045234  MaxFuzzy_SamePubYear_RandomSample
# 3           28  1522658068                           MaxFuzzy
# 4           31  3148721216               MaxFuzzy_SamePubYear
# ..         ...         ...                                ...
# 653      23023  2094791077                           MaxFuzzy
# 654      23116  3104996638  MaxFuzzy_SamePubYear_RandomSample
# 655      23421  1992621302                           MaxFuzzy
# 656      23429  1965798768                           MaxFuzzy
# 657      28021  2189409154                           MaxFuzzy
#
# [658 rows x 3 columns]

# %%
# merging with the original

df_duplicates_matched = df_duplicates.merge(df_duplicate_matches, on=['Record ID','MAGPID'])\
                                    .drop(columns=['FuzzyScoreTemp'])

df_duplicates_matched.head(1)
# Out:
#   Record ID                                        RWTitleNorm      MAGPID  \
# 0         5  effect of perindopril on large artery stiffnes...  1983805905
#
#                                             MAGTitle  RetractionYear  \
# 0  effect of perindopril on large artery stiffnes...          2015.0
#
#    MAGPubYear RecordMatchingMethod  FuzzyScore  RWPubYear  \
# 0      2007.0  exactYearfuzzyTitle   99.630996     2007.0
#
#   RecordMatchingMethodStep2
# 0                  MaxFuzzy

# %%
# Merging with the old

# First extracting those that have only 1 match
df_paper_matching_single = df_paper_matching_extended[~df_paper_matching_extended['Record ID']\
                                                          .isin(df_duplicates_matched['Record ID'])]

# Now extracting those that were matched but had more
df_paper_matching_duplicate = df_paper_matching_extended.merge(df_duplicates_matched[['Record ID', 'MAGPID',
                                                                                     'RecordMatchingMethodStep2']]\
                                                                .drop_duplicates(),
                                                              on=['Record ID','MAGPID'])

df_paper_matched_final = pd.concat([df_paper_matching_single,df_paper_matching_duplicate])

df_paper_matched_final['Record ID'].nunique()
# Out:
# 6199

# %%
df_paper_matching_duplicate['RecordMatchingMethodStep2'].value_counts()
# Out:
# RecordMatchingMethodStep2
# MaxFuzzy                             441
# MaxFuzzy_SamePubYear_RandomSample    178
# MaxFuzzy_SamePubYear                  39
# Name: count, dtype: int64

# %%
df_paper_matching_single['Record ID'].nunique()
# Out:
# 5541

# %%
df_paper_matched_final.head(2)
# Out:
#   Record ID                                        RWTitleNorm      MAGPID  \
# 0      6582  a study on chinaâ€™s petroleum enterprise soci...  2025784643
# 1      6579  behavior analysis on the security object of th...  2219765734
#
#                                             MAGTitle  RetractionYear  \
# 0  retraction note a study on china s petroleum e...          2015.0
# 1  behavior analysis on the security object of th...          2015.0
#
#    MAGPubYear RecordMatchingMethod  FuzzyScore  RWPubYear  \
# 0      2015.0                  doi         NaN     2015.0
# 1      2015.0                  doi         NaN     2015.0
#
#   RecordMatchingMethodStep2
# 0                       NaN
# 1                       NaN

# %% [markdown]
# ## Removing multiple matches on the MAG side i.e. 2 Record ID's matched to same MAGPID

# %%
# Checking if many-1 condition is true

df_paper_matched_final['MAGPID'].nunique() # This means there are 11 matches that are many to 1.
# Out:
# 6188

# %%
# Let us check those papers

df_paper_matched_final[df_paper_matched_final['MAGPID'].duplicated(keep=False)]\
                .sort_values(by='MAGPID')
# Out:
#      Record ID                                        RWTitleNorm      MAGPID  \
# 582       3383  interferon-gamma: biologic functions and hcv t...    51762177
# 583       3382  interferon-gamma: biologic functions and hcv t...    51762177
# 3299      2393  the effects of age and shiftwork on perceived ...  1967327460
# 3298      5182  the effects of age and shift work on perceived...  1967327460
# 966       1636  novel role of the cxc chemokine receptor 3 in ...  1978830702
# 965       1626  novel role of the cxc chemokine receptor 3 in ...  1978830702
# 286      17497  analysis of effective properties of three-phas...  1992608848
# 287      17498           fracture parameters for composite plates  1992608848
# 4914      2939  the effect of the mus309 mutation, defective i...  1999777473
# 4930      4903  the effect of the mus309 mutation, defective i...  1999777473
# 5055      3371  differential impact of diabetes and hypertensi...  2009829821
# 5531     16622  differential impact of diabetes and hypertensi...  2009829821
# 1265     16272  a single-chip digitally enhanced radio receive...  2026752566
# 1266     16271  spur and noise reduction techniques in ring os...  2026752566
# 541       6369  zno as a material mostly adapted for realisati...  2035310593
# 652       6378  zno as a material mostly adapted for realizati...  2035310593
# 873       1786  a novel bioartificial myocardial tissue and it...  2136521074
# 874       1787  bioartificial grafts for transmural myocardial...  2136521074
# 368      26446  numerical solution of nonlinear fredholm integ...  2138701682
# 4192      8576  solution of nonlinear fredholm integro-differe...  2138701682
# 4101      3021  ectopic bone formation by composite graft of c...  2411045189
# 4102      3020  ectopic bone formation by composite graft of c...  2411045189
#
#                                                MAGTitle  RetractionYear  \
# 582   interferon gamma biologic functions and hcv th...          2008.0
# 583   interferon gamma biologic functions and hcv th...          2008.0
# 3299  the effects of age and shiftwork on perceived ...          2010.0
# 3298  the effects of age and shiftwork on perceived ...          2010.0
# 966   novel role of the cxc chemokine receptor 3 in ...          2011.0
# 965   novel role of the cxc chemokine receptor 3 in ...          2011.0
# 286   analysis of effective properties of three phas...          2014.0
# 287   analysis of effective properties of three phas...          2014.0
# 4914  the effect of the mus309 mutation defective in...          2011.0
# 4930  the effect of the mus309 mutation defective in...          2010.0
# 5055  differential impact of diabetes and hypertensi...          2014.0
# 5531  differential impact of diabetes and hypertensi...          2014.0
# 1265  notice of violation of ieee publication princi...          2008.0
# 1266  notice of violation of ieee publication princi...          2008.0
# 541   zno as a material mostly adapted for realisati...          2004.0
# 652   zno as a material mostly adapted for realisati...          2004.0
# 873   a novel bioartificial myocardial tissue and it...          2011.0
# 874   a novel bioartificial myocardial tissue and it...          2011.0
# 368   numerical solution of nonlinear fredholm integ...          2014.0
# 4192  numerical solution of nonlinear fredholm integ...          2015.0
# 4101  ectopic bone formation by composite graft of c...          1991.0
# 4102  ectopic bone formation by composite graft of c...          1991.0
#
#       MAGPubYear RecordMatchingMethod  FuzzyScore  RWPubYear  \
# 582       2006.0  exactYearfuzzyTitle   95.364238     2006.0
# 583       2006.0  exactYearfuzzyTitle   97.368421     2006.0
# 3299      2010.0  exactYearfuzzyTitle   99.619772     2010.0
# 3298      2010.0  exactYearfuzzyTitle   99.242424     2010.0
# 966       2009.0                  doi         NaN     2009.0
# 965       2009.0                  doi         NaN     2009.0
# 286       2012.0                  doi         NaN     2012.0
# 287       2012.0                  doi         NaN     2012.0
# 4914      2009.0  exactYearfuzzyTitle   99.375000     2009.0
# 4930      2009.0  exactYearfuzzyTitle   91.854305     2009.0
# 5055      2011.0  exactYearfuzzyTitle   99.459459     2011.0
# 5531      2011.0  exactYearfuzzyTitle   95.698925     2011.0
# 1265      2008.0                  doi         NaN     2008.0
# 1266      2008.0                  doi         NaN     2008.0
# 541       2002.0  exactYearfuzzyTitle  100.000000     2002.0
# 652       2002.0  fuzzyYearfuzzyTitle   98.823529     2003.0
# 873       2002.0                  doi         NaN     2002.0
# 874       2002.0                  doi         NaN     2003.0
# 368       2013.0                  doi         NaN     2013.0
# 4192      2013.0  exactYearfuzzyTitle   92.857143     2013.0
# 4101      1991.0  exactYearfuzzyTitle   96.170213     1991.0
# 4102      1991.0  exactYearfuzzyTitle  100.000000     1991.0
#
#      RecordMatchingMethodStep2
# 582                   MaxFuzzy
# 583                   MaxFuzzy
# 3299                       NaN
# 3298                       NaN
# 966                        NaN
# 965                        NaN
# 286                        NaN
# 287                        NaN
# 4914                       NaN
# 4930                       NaN
# 5055                       NaN
# 5531                       NaN
# 1265                       NaN
# 1266                       NaN
# 541                   MaxFuzzy
# 652                   MaxFuzzy
# 873                        NaN
# 874                        NaN
# 368                        NaN
# 4192                       NaN
# 4101                       NaN
# 4102                       NaN

# %%
# Manually selecting Record ID's to remove -- i.e. choosing amongst those that were matched to same MAGPID
# Our strategy for choosing is as follows:
# Choose based on the highest fuzzy match score
# If not available, choose based on year match
# If still not decided, then choose randomly.

record_ids_to_remove = [3383, 5182, 1626, 17498, 4903, 16622, 16271,
                       6378, 1787, 8576, 3021]

# Hate to name it final_final.. but can't think of anything better

df_paper_matched_final_final = df_paper_matched_final[~df_paper_matched_final['Record ID']\
                                                        .isin(record_ids_to_remove)]

# If both of these values are same, then our work is done done done!
df_paper_matched_final_final['Record ID'].nunique(), df_paper_matched_final_final['MAGPID'].nunique()
# Out:
# (6188, 6188)

# %% [markdown]
# ## Final Saving
#
# Final saving the final dataframe file.

# %%
# Let us first organize columns

col_order = ['Record ID', 'MAGPID', 'RWTitleNorm', 'MAGTitle', 'RecordMatchingMethod',
            'FuzzyScore', 'RWPubYear', 'MAGPubYear' , 'RetractionYear',
            'RecordMatchingMethodStep2']

# Constants
OUTPUT_DIRECTORY = OUTDIR
FILENAME = "paper_matching_final"

# Create a full file path with timestamp
timestamp = datetime.now().strftime("%Y%m%d")
file_path = os.path.join(OUTPUT_DIRECTORY, f"{FILENAME}_{timestamp}.csv")

# Writing DataFrame to CSV with error handling
try:
    df_paper_matched_final_final[col_order].to_csv(file_path, index=False)
    print(f"File saved successfully at {file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# File saved successfully at /Users/sm9654/desktop/NYUAD/nyuad-research/retraction_openalex/retraction_effects_on_academic_careers/data/processed/paper_matching_final_20240219.csv
